# %% [markdown]
# # Read NSWFRD 2014
# Read the spreadsheet from NSW Flora Fire response database and extract hyperlinks that point to references.
# We will use the openpyxl library

# %%
import openpyxl
from pathlib import Path
import os

# %%
repodir = Path("../") 
inputdir = repodir / "data/"

# %% [markdown]
# ## Open the workbook and read main spreadsheet
# Here we will load the workbook:

# %%
wb = openpyxl.load_workbook(inputdir / "NSWFFRDv2.1.xlsx")

# %% [markdown]
# Use the sheet name to read data

# %%
ws = wb['SpeciesData']

# %% [markdown]
# Let's look at all the values in the second column (Species code)

# %%
ws['B2'].value
# Out:
# 'Species Code'

# %% [markdown]
# We want to count the number of unique values:

# %%
row_count = ws.max_row
column_count = ws.max_column
j=2
unique_list = list()
unique_items = 0
for i in range(1, row_count + 1):
    item = ws.cell(row=i, column=j).value
    if item not in unique_list and item is not None:
        unique_list.append(item)
        unique_items += 1
print(unique_items)
# Out:
# 3000

# %% [markdown]
# Which columns include information on traits? this will print out the names in the second row...:

# %%
for j in range(1, column_count + 1):
    print(ws.cell(row=2, column=j).value)
# Out:
# Current Scientific Name
# Species Code
# Legal Status
# Exotic
# 2010 Update
# Notes on Name / Synonym as used in source reference
# Family
# Group
# Life form
# Fireresponse
# Comments on regeneration
# Resprout location
# Seed storage
# Seed dispersal mechanism
# Seed dispersal distance
# Seed weight / size
# Seed viability
# Dormancy
# Germination cue
# Fecundity
# Seed predation
# Post-fire recruitment
# Establishment
# Post-fire flowering
# Flowering time
# Primary juvenile period
# Secondary juvenile period
# Seed set
# Seed-bank developed
# Fire tolerance
# Life span
# Seed-bank longevity
# "Maturity" (from source)
# "Extinction" (from source)
# "Rec. min fire interval" (from source)
# "Rec. max fire interval" (from source)
# NC
# CC
# SC
# NT
# CT
# ST
# NWS
# CWS
# SWS
# NWP
# SWP
# NFWP
# SFWP
# Distribution: extra NSW
# Vegetation
# Rainforest
# Wet Sclerophyll Forest (Shrubby)
# Wet Sclerophyll Forest (Grassy)
# Grassy Woodland
# Grassland
# Dry Sclerophyll Forest (Shrub/Grass)
# Dry Sclerophyll Forest (Shrubby)
# Heathland
# Alpine Complex
# Freshwater Wetland
# Forested Wetlands
# Saline Wetland
# Semi-arid Woodland
# Arid & Semi-arid Shrubland
# NFRR data
# Additional fire response data
# Other data
# VA group
# Sensitivity: frequent
# Sensitivity: infrequent
# Minimum maturity
# Maximum maturity
# Lifespan > than
# Lifespan < than
# Lifespan + seed-bank
# VA Data
# Establishment Data
# Maturity Data
# Lifespan Data
# Lifespan 2 Data
# Seedbank Data
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ## Dealing with hyperlinks
#
# The cell Q6 has a hyperlink. We can use cell rows and columns or cell name:

# %%
type(ws.cell(row=6, column=17).hyperlink)
# same as 
type(ws['Q6'].hyperlink)
# Out:
# openpyxl.worksheet.hyperlink.Hyperlink

# %% [markdown]
# If the cell is a hyperlink it will have a value to "display" and will point to a "location" within the workbook:

# %%
ws.cell(row=6, column=17).hyperlink.display
# Out:
# 'viability average-very good'

# %%
# This will fail if there is no hyperlink 
print(ws.cell(row=6, column=17).hyperlink.location)
# Out:
# References!C94

# %% [markdown]
# Let's see the value of this reference:

# %%
hlink = ws.cell(row=6, column=17).hyperlink.location
hlink = hlink.split("!")

# %% [markdown]
# This gives the name of the target sheet and the corresponding cell. We need to read the cell to its right side (add one to the column number) to get the information we need.

# %%
ref = wb[hlink[0]]
print("Cell value is :: " + str(ref[hlink[1]].value))
nlink = ref.cell(row=ref[hlink[1]].row,column=ref[hlink[1]].col_idx + 1)

print("Reference data is :: " + nlink.value)
# Out:
# Cell value is :: 93
# Reference data is :: Mortlock, W. & Lloyd, MV (Eds) (2001) Floradata - A guide to collection, storage and propogation of Australian native plant seed. AUsttralian Centre for Mining Environmental Research, Brisbane; Australian National Botanic Gardens, CSIRO Forestry and Forest Products and Greening Australia Limited, Canberra. Searchable Database February 2001. a=survey data, b=test data

# %% [markdown]
# If there is no hyperlink, it will result in NoneType

# %%
type(ws.cell(row=5, column=17).hyperlink)
# Out:
# NoneType

# %%
type(ws.cell(row=5, column=17))
# Out:
# openpyxl.cell.cell.Cell

# %%
ws.cell(row=5, column=17)
# Out:
# <Cell 'SpeciesData'.Q5>

# %% [markdown]
# ## Read data from a column
# For a selected variable (column), we can query data for the list of species.

# %%
ws['Q6']
# Out:
# <Cell 'SpeciesData'.Q6>

# %%
ws.cell(row=2, column=17).value
# Out:
# 'Seed viability'

# %%
ws.cell(row=6, column=17).value
# Out:
# 'average-very good'

# %% [markdown]
# Example loop for querying values from one variable for all species in a range of cells:

# %%
# for i in 3:3088
# for j in 17
i=3
j=17
varname=ws.cell(row=2, column=j).value
print(varname)
for i in range(13,40):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (spcode,spname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (spcode,spname,varvalue))
# Out:
# Seed viability
# 3710: Acacia baileyana / 0.96 / References!C94
# 3723: Acacia brownii / good / References!C94
# 3725: Acacia burbidgeae / 0.76 / References!C94
# 8242: Acacia burkittii / good
# 3727: Acacia buxifolia / good / References!C94
# 3743: Acacia colletioides / 0.837

# %% [markdown]
# ## Read data for a row
# We can now do the same for a single species (row) and query values of each variable in a range. For example:

# %%
# for j in 17
i=18
spname=ws.cell(row=i, column=1).value
spcode=ws.cell(row=i, column=2).value
print("%s: %s" %(spcode,spname))
    
for j in range(3,30):
    varname=ws.cell(row=2, column=j).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (j,varname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (j,varname,varvalue))
# Out:
# 3716: Acacia binervata
# 7: Family / Fabaceae: Mimosoideae
# 8: Group / D
# 9: Life form / T
# 10: Fireresponse / Sr
# 11: Comments on regeneration / Resprouting form in northern tablelands (134)
# 12: Resprout location / basal buds
# 13: Seed storage / persistent soil
# 14: Seed dispersal mechanism / a-ant / References!C56
# 18: Dormancy / hard seed coat
# 19: Germination cue / heat / References!C94
# 22: Post-fire recruitment / prolific / References!C106
# 23: Establishment / I / References!A94
# 25: Flowering time / Aug-Nov
# 26: Primary juvenile period / 5 / References!C36
# 27: Secondary juvenile period / References!C36 / References!C36
# 28: Seed set / 6 / References!C36
# 29: Seed-bank developed / 10 / References!C36

# %% [markdown]
# ## Search for a species code
# Here we try to locate the species code and then return the values for that row:

# %%
for cell in ws['A']:
    if(cell.value is not None): #We need to check that the cell is not empty.
        if 'Actinotus helianthi' in cell.value: #Check if the value of the cell contains the text 'Table'
            print('Found header with name: {} at row: {} and column: {}. In cell {}'.format(cell.value,cell.row,cell.column,cell))
# Out:
# Found header with name: Actinotus helianthi at row: 179 and column: 1. In cell <Cell 'SpeciesData'.A179>

# %%
# for j in 17
i=17
spname=ws.cell(row=i, column=1).value
spcode=ws.cell(row=i, column=2).value
print("%s: %s" %(spcode,spname))
    
for j in range(3,50):
    varname=ws.cell(row=2, column=j).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (j,varname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (j,varname,varvalue))
# Out:
# 3715: Acacia betchei
# 7: Family / Fabaceae: Mimosoideae
# 8: Group / D
# 9: Life form / S
# 10: Fireresponse / S
# 13: Seed storage / persistent soil
# 18: Dormancy / hard seed coat
# 19: Germination cue / scarification / References!C94
# 25: Flowering time / Nov-Feb
# 37: NC / -
# 38: CC / -
# 39: SC / -
# 40: NT / 1
# 41: CT / -
# 42: ST / -
# 43: NWS / 1
# 44: CWS / -
# 45: SWS / -
# 46: NWP / -
# 47: SWP / -
# 48: NFWP / -
# 49: SFWP / -

# %% [markdown]
# ## Populate the 'blue table'
# Select one column, translate the values to the accepted range and update entries into the table

# %%
from configparser import ConfigParser

filename = repodir / 'secrets' / 'database.ini'
section = 'aws-lght-sl'

# create a parser
parser = ConfigParser()
# read config file
parser.read(filename)

# get section, default to postgresql
db = {}
if parser.has_section(section):
    params = parser.items(section)
    for param in params:
        db[param[0]] = param[1]
else:
    raise Exception('Section {0} not found in the {1} file'.format(section, filename))

# %%
import psycopg2
params = db

# %%
# for i in 3:3088
# for j in 10
row_count = ws.max_row
i=3
j=10
varname=ws.cell(row=2, column=j).value
print(varname)

switcher={
    "S": "none",
    "Sr": "few",
    "S/R": "half",
    "Rs": "most",
    "R": "all"
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)


qrystr= "INSERT INTO litrev.traits(species,species_code,resprouting) values('%s',%s,'%s') ON CONFLICT (species,species_code) DO UPDATE SET resprouting=EXCLUDED.resprouting"
for i in range(3,row_count):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "unknown")
        if (isinstance(spcode, str) and spcode.isnumeric()) or isinstance(spcode,int):
            cur = conn.cursor()
            cur.execute(qrystr % (spname,spcode,transvalue))
            updated_rows = cur.rowcount
            if updated_rows > 0:
                if varref is not None:
                    print("%s: %s / %s / %s" % (spcode,spname,transvalue, varref.location))
                else:
                    print("%s: %s / %s " % (spcode,spname,transvalue))
                print("%s rows updated" % (updated_rows))
            conn.commit()
            cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Fireresponse
# Connecting to the PostgreSQL database...
# 7184: Abutilon otocarpum / none
# 1 rows updated
# 3632: Abutilon oxycarpum / none
# 1 rows updated
# 3698: Acacia acanthoclada / none
# 1 rows updated
# 3699: Acacia acinacea / none
# 1 rows updated
# 3700: Acacia aculeatissima / none
# 1 rows updated
# 3701: Acacia adunca / none
# 1 rows updated
# 3702: Acacia alpina / none
# 1 rows updated
# 3705: Acacia aneura / few
# 1 rows updated
# 7581: Acacia aulacocarpa / all
# 1 rows updated
# 3708: Acacia ausfeldii / none
# 1 rows updated
# 3710: Acacia baileyana / none
# 1 rows updated
# 3712: Acacia barringtonensis / all
# 1 rows updated
# 7060: Acacia baueri subsp. baueri / none
# 1 rows updated
# 11039: Acacia beadleana / all
# 1 rows updated
# 3715: Acacia betchei / none
# 1 rows updated
# 3716: Acacia binervata / few
# 1 rows updated
# 3717: Acacia binervia / none
# 1 rows updated
# 10788: Acacia blakei subsp. diphylla / none
# 1 rows updated
# 10788: Acacia blakei subsp. diphylla / none
# 1 rows updated
# 8381: Acacia blayana / none
# 1 rows updated
# 3723: Acacia brownii / most
# 1 rows updated
# 6498: Acacia brunioides subsp. brunioides / none
# 1 rows updated
# 8601: Acacia bulgaensis / none
# 1 rows updated
# 3725: Acacia burbidgeae / none
# 1 rows updated
# 8242: Acacia burkittii / all
# 1 rows updated
# 3727: Acacia buxifolia / most
# 1 rows updated
# 9282: Acacia buxifolia subsp. pubiflora / all
# 1 rows updated
# 3730: Acacia calamifolia / none
# 1 rows updated
# 7524: Acacia calcicola / none
# 1 rows updated
# 3738: Acacia cheelii / none
# 1 rows updated
# 3739: Acacia chrysotricha / none
# 1 rows updated
# 3742: Acacia cognata / all
# 1 rows updated
# 3743: Acacia colletioides / none
# 1 rows updated
# 3747: Acacia constablei / none
# 1 rows updated
# 3750: Acacia costiniana / none
# 1 rows updated
# 555: Acacia courtii / none
# 1 rows updated
# 3752: Acacia cowleana / none
# 1 rows updated
# 3755: Acacia curranii / all
# 1 rows updated
# 3756: Acacia dallachiana / none
# 1 rows updated
# 3757: Acacia dawsonii / none
# 1 rows updated
# 3758: Acacia dealbata / few
# 1 rows updated
# 8269: Acacia deanei subsp. deanei / none
# 1 rows updated
# 7482: Acacia deanei subsp. paucijuga / none
# 1 rows updated
# 3761: Acacia decora / none
# 1 rows updated
# 3762: Acacia decurrens / none
# 1 rows updated
# 3763: Acacia difformis / none
# 1 rows updated
# 3767: Acacia echinula / none
# 1 rows updated
# 3768: Acacia elata / none
# 1 rows updated
# 3769: Acacia elongata / few
# 1 rows updated
# 3771: Acacia falcata / none
# 1 rows updated
# 3772: Acacia falciformis / most
# 1 rows updated
# 3773: Acacia filicifolia / few
# 1 rows updated
# 3774: Acacia fimbriata / none
# 1 rows updated
# 3777: Acacia floribunda / half
# 1 rows updated
# 3780: Acacia fulva / none
# 1 rows updated
# 3781: Acacia genistifolia / none
# 1 rows updated
# 3782: Acacia georgensis / none
# 1 rows updated
# 7229: Acacia gordonii / all
# 1 rows updated
# 3784: Acacia granitica / none
# 1 rows updated
# 3785: Acacia gunnii / few
# 1 rows updated
# 3786: Acacia hakeoides / all
# 1 rows updated
# 3788: Acacia harpophylla / all
# 1 rows updated
# 8929: Acacia havilandiorum / none
# 1 rows updated
# 3790: Acacia hispidula / none
# 1 rows updated
# 3791: Acacia homalophylla / none
# 1 rows updated
# 3792: Acacia implexa / few
# 1 rows updated
# 3793: Acacia ingramii / none
# 1 rows updated
# 6472: Acacia irrorata subsp. irrorata / few
# 1 rows updated
# 7109: Acacia irrorata subsp. velutinella / all
# 1 rows updated
# 3797: Acacia jennerae / all
# 1 rows updated
# 3799: Acacia jonesii / none
# 1 rows updated
# 3802: Acacia juncifolia / all
# 1 rows updated
# 9983: Acacia kulnurensis / none
# 1 rows updated
# 3806: Acacia lanigera / none
# 1 rows updated
# 3807: Acacia latisepala / none
# 1 rows updated
# 6597: Acacia leiocalyx subsp. leiocalyx / all
# 1 rows updated
# 3810: Acacia leptoclada / all
# 1 rows updated
# 8603: Acacia ligulata / most
# 1 rows updated
# 3813: Acacia lineata / none
# 1 rows updated
# 3814: Acacia linifolia / none
# 1 rows updated
# 3815: Acacia loderi / all
# 1 rows updated
# 10790: Acacia longifolia subsp. longifolia / few
# 1 rows updated
# 10791: Acacia longifolia subsp. sophorae / few
# 1 rows updated
# 3817: Acacia longissima / none
# 1 rows updated
# 3818: Acacia lucasii / none
# 1 rows updated
# 6748: Acacia lunata / none
# 1 rows updated
# 3820: Acacia macnuttiana / none
# 1 rows updated
# 3821: Acacia maidenii / none
# 1 rows updated
# 3822: Acacia maitlandii / all
# 1 rows updated
# 8972: Acacia matthewii / all
# 1 rows updated
# 3823: Acacia mearnsii / few
# 1 rows updated
# 8973: Acacia meiantha / all
# 1 rows updated
# 3824: Acacia melanoxylon / most
# 1 rows updated
# 3825: Acacia melvillei / all
# 1 rows updated
# 3827: Acacia mitchellii / none
# 1 rows updated
# 10058: Acacia mucronata subsp. longifolia / most
# 1 rows updated
# 3832: Acacia murrayana / all
# 1 rows updated
# 3834: Acacia myrtifolia / few
# 1 rows updated
# 3835: Acacia neriifolia / all
# 1 rows updated
# 3836: Acacia notabilis / none
# 1 rows updated
# 11005: Acacia nova-anglica ms / all
# 1 rows updated
# 3837: Acacia obliquinervia / none
# 1 rows updated
# 3839: Acacia obtusifolia / few
# 1 rows updated
# 3843: Acacia oswaldii / all
# 1 rows updated
# 3844: Acacia oxycedrus / few
# 1 rows updated
# 3845: Acacia paradoxa / none
# 1 rows updated
# 3846: Acacia parramattensis / none
# 1 rows updated
# 3847: Acacia parvipinnula / none
# 1 rows updated
# 3848: Acacia pendula / all
# 1 rows updated
# 10922: Acacia penninervis var. penninervis / none
# 1 rows updated
# 3851: Acacia phasmoides / none
# 1 rows updated
# 3853: Acacia podalyriifolia / none
# 1 rows updated
# 3857: Acacia prominens / none
# 1 rows updated
# 3858: Acacia pruinosa / all
# 1 rows updated
# 3858: Acacia pruinosa / all
# 1 rows updated
# 3860: Acacia pubescens / most
# 1 rows updated
# 9405: Acacia pubifolia / none
# 1 rows updated
# 3861: Acacia pycnantha / none
# 1 rows updated
# 3862: Acacia pycnostachya / few
# 1 rows updated
# 3863: Acacia quadrilateralis / all
# 1 rows updated
# 12042: Acacia ramulosa var. ramulosa / most
# 1 rows updated
# 3869: Acacia rubida / few
# 1 rows updated
# 3871: Acacia saliciformis / none
# 1 rows updated
# 3872: Acacia salicina / none
# 1 rows updated
# 3873: Acacia saligna / half
# 1 rows updated
# 3874: Acacia schinoides / none
# 1 rows updated
# 12441: Acacia serpentinicola / all
# 1 rows updated
# 12072: Acacia sibirica / none
# 1 rows updated
# 3880: Acacia stricta / none
# 1 rows updated
# 3881: Acacia suaveolens / few
# 1 rows updated
# 3882: Acacia subporosa / none
# 1 rows updated
# 3883: Acacia subtilinervis / none
# 1 rows updated
# 3885: Acacia terminalis / few
# 1 rows updated
# 3886: Acacia tetragonophylla / half
# 1 rows updated
# 3888: Acacia torringtonensis / none
# 1 rows updated
# 3890: Acacia trinervata / none
# 1 rows updated
# 3892: Acacia triptera / none
# 1 rows updated
# 3893: Acacia ulicifolia / few
# 1 rows updated
# 3894: Acacia uncinata / none
# 1 rows updated
# 8865: Acacia venulosa / half
# 1 rows updated
# 3895: Acacia verniciflua / none
# 1 rows updated
# 11245: Acacia verticillata subsp. verticillata / all
# 1 rows updated
# 11245: Acacia verticillata subsp. verticillata / few
# 1 rows updated
# 3898: Acacia victoriae / most
# 1 rows updated
# 3899: Acacia viscidula / few
# 1 rows updated
# 3900: Acacia wilhelmiana / none
# 1 rows updated
# 10796: Acacia williamsiana / unknown
# 1 rows updated
# 5603: Acaena echinata / all
# 1 rows updated
# 5604: Acaena novae-zelandiae / half
# 1 rows updated
# 5605: Acaena ovina / all
# 1 rows updated
# 2674: Acalypha nemorum / none
# 1 rows updated
# 5263: Acetosa sagittata / all
# 1 rows updated
# 5265: Acetosella vulgaris / half
# 1 rows updated
# 4351: Acianthus caudatus / all
# 1 rows updated
# 4352: Acianthus exsertus / all
# 1 rows updated
# 4353: Acianthus fornicatus / all
# 1 rows updated
# 9088: Acianthus pusillus / all
# 1 rows updated
# 1090: Aciphylla glacialis / all
# 1 rows updated
# 1091: Aciphylla simplicifolia / all
# 1 rows updated
# 3968: Acmena smithii / all
# 1 rows updated
# 5719: Acradenia euodiiformis / all
# 1 rows updated
# 8418: Acronychia imperforata / all
# 1 rows updated
# 5722: Acronychia oblongifolia / few
# 1 rows updated
# 2265: Acrophyllum australe / all
# 1 rows updated
# 11966: Acrothamnus hookeri / few
# 1 rows updated
# 12059: Acrothamnus montanus / half
# 1 rows updated
# 2580: Acrotriche aggregata / all
# 1 rows updated
# 2581: Acrotriche divaricata / none
# 1 rows updated
# 8231: Acrotriche leucocarpa / none
# 1 rows updated
# 2583: Acrotriche serrulata / all
# 1 rows updated
# 2675: Actephila lindleyi / none
# 1 rows updated
# 1253: Actinobole uliginosum / none
# 1 rows updated
# 1092: Actinotus forsythii / none
# 1 rows updated
# 1093: Actinotus gibbonsii / none
# 1 rows updated
# 1094: Actinotus helianthi / none
# 1 rows updated
# 1095: Actinotus minor / few
# 1 rows updated
# 7997: Adiantum aethiopicum / all
# 1 rows updated
# 7998: Adiantum diaphanum / none
# 1 rows updated
# 8000: Adiantum hispidulum / all
# 1 rows updated
# 2525: Adrastaea salicifolia / all
# 1 rows updated
# 10564: Adriana tomentosa var. tomentosa / none
# 1 rows updated
# 7459: Aegiceras corniculatum / most
# 1 rows updated
# 1255: Ageratina adenophora / all
# 1 rows updated
# 1256: Ageratina riparia / all
# 1 rows updated
# 12005: Agiortia cicatricata / none
# 1 rows updated
# 12011: Agiortia pedicellata / all
# 1 rows updated
# 4726: Agrostis parviflora / none
# 1 rows updated
# 4729: Agrostis venusta / half
# 1 rows updated
# 4730: Aira caryophyllea / none
# 1 rows updated
# 4731: Aira cupaniana / none
# 1 rows updated
# 6547: Aira elegantissima / none
# 1 rows updated
# 3371: Ajuga australis / half
# 1 rows updated
# 8669: Alchornea ilicifolia / all
# 1 rows updated
# 5872: Alectryon coriaceus / all
# 1 rows updated
# 6639: Alectryon oleifolius subsp. canescens / all
# 1 rows updated
# 5875: Alectryon subcinereus / few
# 1 rows updated
# 8979: Alexfloydia repens / all
# 1 rows updated
# 13923: Allittia cardiocarpa / none
# 1 rows updated
# 9090: Allocasuarina brachystachya / few
# 1 rows updated
# 8980: Allocasuarina defungens / all
# 1 rows updated
# 9710: Allocasuarina diminuta subsp. annectens / all
# 1 rows updated
# 2010: Allocasuarina distyla / few
# 1 rows updated
# 8320: Allocasuarina glareicola / all
# 1 rows updated
# 2011: Allocasuarina inophloia / all
# 1 rows updated
# 2012: Allocasuarina littoralis / most
# 1 rows updated
# 2013: Allocasuarina luehmannii / none
# 1 rows updated
# 2014: Allocasuarina nana / all
# 1 rows updated
# 2015: Allocasuarina paludosa / all
# 1 rows updated
# 8791: Allocasuarina rigida subsp. rigida / none
# 1 rows updated
# 9011: Allocasuarina simulans / all
# 1 rows updated
# 2017: Allocasuarina torulosa / all
# 1 rows updated
# 2018: Allocasuarina verticillata / most
# 1 rows updated
# 7289: Alloteropsis semialata / all
# 1 rows updated
# 8368: Almaleea cambagei / all
# 1 rows updated
# 8367: Almaleea capitata / none
# 1 rows updated
# 8365: Almaleea incurvata / none
# 1 rows updated
# 8364: Almaleea paludosa / none
# 1 rows updated
# 8366: Almaleea subumbellata / none
# 1 rows updated
# 7686: Alphitonia excelsa / all
# 1 rows updated
# 5553: Alphitonia petriei / none
# 1 rows updated
# 6913: Alpinia arundelliana / all
# 1 rows updated
# 6340: Alpinia caerulea / all
# 1 rows updated
# 1775: Alyssum linifolium / none
# 1 rows updated
# 1165: Alyxia buxifolia / all
# 1 rows updated
# 1167: Alyxia ruscifolia / few
# 1 rows updated
# 1259: Ambrosia artemisiifolia / all
# 1 rows updated
# 1261: Ambrosia psilostachya / all
# 1 rows updated
# 1263: Ammobium alatum / none
# 1 rows updated
# 4738: Ammophila arenaria / all
# 1 rows updated
# 9713: Amperea xiphoclada var. xiphoclada / all
# 1 rows updated
# 6842: Amphibromus nervosus / all
# 1 rows updated
# 7539: Amphipogon caricinus var. caricinus / all
# 1 rows updated
# 7650: Amphipogon strictus var. strictus / all
# 1 rows updated
# 6856: Amyema congener subsp. congener / none
# 1 rows updated
# 7497: Amyema linophyllum subsp. orientale / none
# 1 rows updated
# 6394: Amyema miquelii / few
# 1 rows updated
# 7308: Amyema pendulum subsp. pendulum / none
# 1 rows updated
# 5334: Anagallis arvensis / none
# 1 rows updated
# 4748: Andropogon virginicus / all
# 1 rows updated
# 10999: Anetholea anisata / none
# 1 rows updated
# 1268: Angianthus tomentosus / none
# 1 rows updated
# 3969: Angophora bakeri / all
# 1 rows updated
# 3970: Angophora costata / all
# 1 rows updated
# 9012: Angophora crassifolia / all
# 1 rows updated
# 9717: Angophora euryphylla / all
# 1 rows updated
# 3971: Angophora floribunda / all
# 1 rows updated
# 3972: Angophora hispida / all
# 1 rows updated
# 9619: Angophora inopina / all
# 1 rows updated
# 3974: Angophora subvelutina / all
# 1 rows updated
# 4749: Anisopogon avenaceus / all
# 1 rows updated
# 3221: Anopterus macleayanus / few
# 1 rows updated
# 1733: Anredera cordifolia / all
# 1 rows updated
# 1269: Anthemis arvensis / none
# 1 rows updated
# 4750: Anthoxanthum odoratum / most
# 1 rows updated
# 2770: Aotus ericoides / most
# 1 rows updated
# 2771: Aotus lanigera / none
# 1 rows updated
# 11046: Aotus subglauca var. subglauca / all
# 1 rows updated
# 6955: Aotus subspinescens / all
# 1 rows updated
# 8221: Apalochlamys spectabilis / none
# 1 rows updated
# 2025: Apatophyllum constablei / none
# 1 rows updated
# 5609: Aphanes australiana / none
# 1 rows updated
# 2266: Aphanopetalum resinosum / none
# 1 rows updated
# 2037: Aphelia gracilis / none
# 1 rows updated
# 11824: Apium prostratum var. prostratum / none
# 1 rows updated
# 11047: Araujia sericifera / none
# 1 rows updated
# 3976: Archirhodomyrtus beckleri / all
# 1 rows updated
# 6458: Archontophoenix cunninghamiana / none
# 1 rows updated
# 1273: Arctotheca calendula / none
# 1 rows updated
# 9721: Argentipallium obtusifolium / none
# 1 rows updated
# 12689: Argyrotegium fordianum / all
# 1 rows updated
# 12690: Argyrotegium mackayi / none
# 1 rows updated
# 13926: Argyrotegium poliochlorum / none
# 1 rows updated
# 9722: Aristea ecklonii / all
# 1 rows updated
# 4755: Aristida benthamii / all
# 1 rows updated
# 9334: Aristida calycina var. calycina / all
# 1 rows updated
# 7537: Aristida holathera var. holathera / all
# 1 rows updated
# 6439: Aristida jerichoensis var. jerichoensis / all
# 1 rows updated
# 6933: Aristida jerichoensis var. subspinulifera / all
# 1 rows updated
# 4770: Aristida ramosa / all
# 1 rows updated
# 4773: Aristida vagans / all
# 1 rows updated
# 4774: Aristida warburgii / all
# 1 rows updated
# 2567: Aristotelia australasica / all
# 1 rows updated
# 1276: Arrhenechthites mixta / none
# 1 rows updated
# 5943: Artanema fimbriatum / none
# 1 rows updated
# 3517: Arthropodium milleflorum / all
# 1 rows updated
# 3518: Arthropodium minus / all
# 1 rows updated
# 9097: Arthropodium sp. B / all
# 1 rows updated
# 4777: Arundo donax / all
# 1 rows updated
# 11784: Asparagus aethiopicus / all
# 1 rows updated
# 3519: Asparagus asparagoides / all
# 1 rows updated
# 3522: Asparagus scandens / all
# 1 rows updated
# 5653: Asperula conferta / all
# 1 rows updated
# 5657: Asperula gunnii / half
# 1 rows updated
# 5658: Asperula pusilla / none
# 1 rows updated
# 5659: Asperula scoparia / most
# 1 rows updated
# 3524: Asphodelus fistulosus / all
# 1 rows updated
# 8031: Asplenium australasicum / none
# 1 rows updated
# 8866: Asplenium bulbiferum subsp. gracillimum / none
# 1 rows updated
# 8033: Asplenium flabellifolium / all
# 1 rows updated
# 8037: Asplenium polyodon / none
# 1 rows updated
# 9259: Asplenium trichomanes / none
# 1 rows updated
# 7534: Astelia alpina var. novae-hollandiae / all
# 1 rows updated
# 3526: Astelia psychrocharis / all
# 1 rows updated
# 1280: Aster subulatus / none
# 1 rows updated
# 12190: Asterolasia asteriscophora subsp. asteriscophora / none
# 1 rows updated
# 5728: Asterolasia correifolia / none
# 1 rows updated
# 8851: Asterolasia elegans / none
# 1 rows updated
# 5730: Asterolasia trymalioides / none
# 1 rows updated
# 2584: Astroloma humifusum / all
# 1 rows updated
# 2585: Astroloma pinifolium / none
# 1 rows updated
# 1200: Astrotricha crassifolia / all
# 1 rows updated
# 1202: Astrotricha latifolia / none
# 1 rows updated
# 1203: Astrotricha ledifolia / all
# 1 rows updated
# 1204: Astrotricha linearis / none
# 1 rows updated
# 1205: Astrotricha longifolia / all
# 1 rows updated
# 9015: Astrotricha roddii / all
# 1 rows updated
# 6365: Atalaya hemiglauca / all
# 1 rows updated
# 3910: Atherosperma moschatum / most
# 1 rows updated
# 3611: Atkinsonia ligustrina / all
# 1 rows updated
# 2050: Atriplex elachophylla / all
# 1 rows updated
# 2070: Atriplex semibaccata / none
# 1 rows updated
# 2073: Atriplex stipitata / none
# 1 rows updated
# 2078: Atriplex vesicaria / none
# 1 rows updated
# 7710: Australopyrum pectinatum / none
# 1 rows updated
# 7840: Australopyrum velutinum / all
# 1 rows updated
# 8667: Austrocynoglossum latifolium / none
# 1 rows updated
# 6594: Austrofestuca littoralis / all
# 1 rows updated
# 3979: Austromyrtus dulcis / none
# 1 rows updated
# 3982: Austromyrtus tenuifolia / all
# 1 rows updated
# 10386: Austrostipa bigeniculata / all
# 1 rows updated
# 10367: Austrostipa elegantissima / half
# 1 rows updated
# 10385: Austrostipa gibbosa / all
# 1 rows updated
# 10393: Austrostipa mollis / most
# 1 rows updated
# 10375: Austrostipa nitida / most
# 1 rows updated
# 9960: Austrostipa nivicola / half
# 1 rows updated
# 9603: Austrostipa pubescens / all
# 1 rows updated
# 10400: Austrostipa pubinodis / all
# 1 rows updated
# 10396: Austrostipa rudis / all
# 1 rows updated
# 10398: Austrostipa rudis subsp. nervosa / all
# 1 rows updated
# 10394: Austrostipa semibarbata / all
# 1 rows updated
# 10382: Austrostipa setacea / all
# 1 rows updated
# 10368: Austrostipa tuckeri / all
# 1 rows updated
# 4780: Avena fatua / none
# 1 rows updated
# 10427: Avicennia marina subsp. australasica / half
# 1 rows updated
# 9817: Babingtonia odontocalyx / none
# 1 rows updated
# 3984: Backhousia myrtifolia / all
# 1 rows updated
# 3986: Baeckea brevifolia / few
# 1 rows updated
# 3989: Baeckea crassifolia / none
# 1 rows updated
# 3993: Baeckea diosmifolia / all
# 1 rows updated
# 9835: Baeckea frutescens / all
# 1 rows updated
# 3994: Baeckea gunniana / all
# 1 rows updated
# 3995: Baeckea imbricata / all
# 1 rows updated
# 3995: Baeckea imbricata / none
# 1 rows updated
# 3997: Baeckea linifolia / all
# 1 rows updated
# 9836: Baeckea omissa / all
# 1 rows updated
# 4000: Baeckea utilis / all
# 1 rows updated
# 8400: Baloghia inophylla / all
# 1 rows updated
# 8325: Baloghia marmorata / none
# 1 rows updated
# 10605: Baloskion australe / all
# 1 rows updated
# 10606: Baloskion fimbriatum / all
# 1 rows updated
# 10607: Baloskion gracile / half
# 1 rows updated
# 10608: Baloskion longipes / all
# 1 rows updated
# 10609: Baloskion pallens / all
# 1 rows updated
# 10610: Baloskion stenocoleum / all
# 1 rows updated
# 10611: Baloskion tenuiculme / none
# 1 rows updated
# 10614: Baloskion tetraphyllum subsp. meiostachyum / all
# 1 rows updated
# 10614: Baloskion tetraphyllum subsp. meiostachyum / none
# 1 rows updated
# 10613: Baloskion tetraphyllum subsp. tetraphyllum / all
# 1 rows updated
# 10613: Baloskion tetraphyllum subsp. tetraphyllum / none
# 1 rows updated
# 5339: Banksia aemula / all
# 1 rows updated
# 5340: Banksia canei / none
# 1 rows updated
# 7509: Banksia collina / all
# 1 rows updated
# 8595: Banksia cunninghamii / none
# 1 rows updated
# 11049: Banksia ericifolia subsp. ericifolia / none
# 1 rows updated
# 11050: Banksia ericifolia subsp. macrantha / none
# 1 rows updated
# 5343: Banksia integrifolia / all
# 1 rows updated
# 6603: Banksia integrifolia subsp. integrifolia / few
# 1 rows updated
# 10817: Banksia integrifolia subsp. monticola / few
# 1 rows updated
# 5344: Banksia marginata / all
# 1 rows updated
# 5344: Banksia marginata / none
# 1 rows updated
# 14554: Banksia neoanglica / all
# 1 rows updated
# 14554: Banksia neoanglica / all
# 1 rows updated
# 5345: Banksia oblongifolia / all
# 1 rows updated
# 5346: Banksia paludosa / all
# 1 rows updated
# 10873: Banksia paludosa subsp. astrolux / none
# 1 rows updated
# 10874: Banksia paludosa subsp. paludosa / all
# 1 rows updated
# 10872: Banksia penicillata / none
# 1 rows updated
# 5347: Banksia robur / all
# 1 rows updated
# 5348: Banksia serrata / all
# 1 rows updated
# 5349: Banksia spinulosa / all
# 1 rows updated
# 7509: Banksia spinulosa var. collina / all
# 1 rows updated
# 7488: Banksia spinulosa var. spinulosa / all
# 1 rows updated
# 7495: Barbarea grayi / none
# 1 rows updated
# 9188: Bartsia trixago / none
# 1 rows updated
# 2267: Bauera capitata / all
# 1 rows updated
# 7219: Bauera microphylla / all
# 1 rows updated
# 2268: Bauera rubioides / most
# 1 rows updated
# 2268: Bauera rubioides / half
# 1 rows updated
# 2294: Baumea acuta / all
# 1 rows updated
# 2296: Baumea articulata / all
# 1 rows updated
# 2297: Baumea gunnii / all
# 1 rows updated
# 2299: Baumea juncea / all
# 1 rows updated
# 2300: Baumea muelleri / all
# 1 rows updated
# 2301: Baumea nuda / all
# 1 rows updated
# 2302: Baumea rubiginosa / all
# 1 rows updated
# 2303: Baumea teretifolia / all
# 1 rows updated
# 2304: Baumea tetragona / all
# 1 rows updated
# 1282: Bedfordia arborescens / all
# 1 rows updated
# 8440: Berberidopsis beckleri  / none
# 1 rows updated
# 7159: Bertya brownii / none
# 1 rows updated
# 2681: Bertya cunninghamii / none
# 1 rows updated
# 2682: Bertya findlayi / none
# 1 rows updated
# 2691: Beyeria lasiocarpa / none
# 1 rows updated
# 11051: Beyeria leschenaultii / none
# 1 rows updated
# 2693: Beyeria opaca / none
# 1 rows updated
# 2694: Beyeria viscosa / none
# 1 rows updated
# 1283: Bidens pilosa / none
# 1 rows updated
# 1284: Bidens subalternans / none
# 1 rows updated
# 1285: Bidens tripartita / none
# 1 rows updated
# 12236: Billardiera heterophylla / all
# 1 rows updated
# 12235: Billardiera macrantha / all
# 1 rows updated
# 4671: Billardiera scandens / all
# 1 rows updated
# 4671: Billardiera scandens / half
# 1 rows updated
# 3527: Blandfordia cunninghamii / all
# 1 rows updated
# 3528: Blandfordia grandiflora / all
# 1 rows updated
# 3529: Blandfordia nobilis / all
# 1 rows updated
# 8050: Blechnum ambiguum / all
# 1 rows updated
# 8051: Blechnum camfieldii / all
# 1 rows updated
# 8052: Blechnum cartilagineum / all
# 1 rows updated
# 8057: Blechnum indicum / all
# 1 rows updated
# 7760: Blechnum minus / all
# 1 rows updated
# 8058: Blechnum nudum / all
# 1 rows updated
# 8063: Blechnum wattsii / all
# 1 rows updated
# 5732: Boronia algida / few
# 1 rows updated
# 5733: Boronia anemonifolia / none
# 1 rows updated
# 12257: Boronia anemonifolia subsp. anemonifolia / all
# 1 rows updated
# 11607: Boronia anemonifolia subsp. variabilis / none
# 1 rows updated
# 5734: Boronia anethifolia / none
# 1 rows updated
# 10750: Boronia angustisepala / none
# 1 rows updated
# 5735: Boronia barkeriana / all
# 1 rows updated
# 5736: Boronia bipinnata / none
# 1 rows updated
# 10751: Boronia boliviensis / none
# 1 rows updated
# 9098: Boronia chartacea / none
# 1 rows updated
# 10752: Boronia coerulescens subsp. coerulescens / most
# 1 rows updated
# 5739: Boronia falcifolia / all
# 1 rows updated
# 5740: Boronia floribunda / all
# 1 rows updated
# 5741: Boronia fraseri / none
# 1 rows updated
# 5743: Boronia granitica / none
# 1 rows updated
# 5744: Boronia ledifolia / few
# 1 rows updated
# 5745: Boronia microphylla / all
# 1 rows updated
# 5746: Boronia mollis / none
# 1 rows updated
# 5747: Boronia muelleri / all
# 1 rows updated
# 7942: Boronia nana var. hyssopifolia / none
# 1 rows updated
# 5749: Boronia parviflora / most
# 1 rows updated
# 5750: Boronia pinnata / half
# 1 rows updated
# 5751: Boronia polygalifolia / most
# 1 rows updated
# 5755: Boronia rosmarinifolia / all
# 1 rows updated
# 5757: Boronia ruppii / none
# 1 rows updated
# 5758: Boronia safrolifera / all
# 1 rows updated
# 5759: Boronia serrulata / none
# 1 rows updated
# 7210: Boronia thujona / none
# 1 rows updated
# 9099: Boronia umbellata / none
# 1 rows updated
# 2777: Bossiaea cinerea / all
# 1 rows updated
# 2778: Bossiaea ensata / most
# 1 rows updated
# 2779: Bossiaea foliosa / half
# 1 rows updated
# 2780: Bossiaea heterophylla / most
# 1 rows updated
# 2780: Bossiaea heterophylla / none
# 1 rows updated
# 2781: Bossiaea kiamensis / all
# 1 rows updated
# 2783: Bossiaea neo-anglica / all
# 1 rows updated
# 2784: Bossiaea obcordata / most
# 1 rows updated
# 2786: Bossiaea prostrata / all
# 1 rows updated
# 2787: Bossiaea rhombifolia / half
# 1 rows updated
# 2788: Bossiaea riparia / half
# 1 rows updated
# 2789: Bossiaea scolopendria / most
# 1 rows updated
# 2790: Bossiaea scortechinii / all
# 1 rows updated
# 2791: Bossiaea stephensonii / half
# 1 rows updated
# 2792: Bossiaea walkeri / half
# 1 rows updated
# 4790: Bothriochloa macra / all
# 1 rows updated
# 8144: Botrychium australe / all
# 1 rows updated
# 8145: Botrychium lunaria / none
# 1 rows updated
# 8961: Brachychiton populneus subsp. populneus / all
# 1 rows updated
# 10689: Brachyloma daphnoides subsp. daphnoides / most
# 1 rows updated
# 10690: Brachyloma daphnoides subsp. glabrum / all
# 1 rows updated
# 9295: Brachyloma saxicola / few
# 1 rows updated
# 2587: Brachyloma scortechinii / none
# 1 rows updated
# 7218: Brachyscome aculeata / none
# 1 rows updated
# 7700: Brachyscome angustifolia var. heterophylla / none
# 1 rows updated
# 6914: Brachyscome debilis / none
# 1 rows updated
# 6485: Brachyscome decipiens / few
# 1 rows updated
# 11056: Brachyscome dentata / all
# 1 rows updated
# 11056: Brachyscome dentata / all
# 1 rows updated
# 7562: Brachyscome goniocarpa / none
# 1 rows updated
# 6542: Brachyscome gracilis / none
# 1 rows updated
# 13832: Brachyscome linearifolia / all
# 1 rows updated
# 6861: Brachyscome lineariloba / none
# 1 rows updated
# 7317: Brachyscome multifida / all
# 1 rows updated
# 7264: Brachyscome obovata / all
# 1 rows updated
# 10409: Brachyscome perpusilla var. tenella / none
# 1 rows updated
# 6567: Brachyscome ptychocarpa / none
# 1 rows updated
# 10411: Brachyscome radicans / all
# 1 rows updated
# 6559: Brachyscome rigidula / all
# 1 rows updated
# 7318: Brachyscome scapigera / all
# 1 rows updated
# 7357: Brachyscome spathulata / all
# 1 rows updated
# 7266: Brachyscome tenuiscapa / none
# 1 rows updated
# 7538: Brachyscome tenuiscapa var. pubescens / none
# 1 rows updated
# 1786: Brassica fruticulosa / none
# 1 rows updated
# 1790: Brassica tournefortii / none
# 1 rows updated
# 2695: Breynia oblongifolia / most
# 1 rows updated
# 4800: Briza maxima / none
# 1 rows updated
# 4801: Briza minor / none
# 1 rows updated
# 4804: Bromus arenarius / none
# 1 rows updated
# 4806: Bromus diandrus / none
# 1 rows updated
# 4807: Bromus hordeaceus / none
# 1 rows updated
# 4813: Bromus rubens / none
# 1 rows updated
# 4817: Bromus sterilis / none
# 1 rows updated
# 1863: Brunonia australis / all
# 1 rows updated
# 1003: Brunoniella australis / all
# 1 rows updated
# 1004: Brunoniella pumilio / all
# 1 rows updated
# 9191: Buddleja madagascariensis / all
# 1 rows updated
# 3531: Bulbine bulbosa / all
# 1 rows updated
# 6848: Bulbine glauca / all
# 1 rows updated
# 3532: Bulbine semibarbata / none
# 1 rows updated
# 4364: Bulbophyllum globuliforme / none
# 1 rows updated
# 7748: Bulbostylis barbata / none
# 1 rows updated
# 3533: Burchardia umbellata / all
# 1 rows updated
# 4368: Burnettia cuneata / all
# 1 rows updated
# 4674: Bursaria spinosa / all
# 1 rows updated
# 11018: Bursaria spinosa subsp. spinosa / all
# 1 rows updated
# 6161: Cadellia pentastylis / all
# 1 rows updated
# 3534: Caesia alpina / all
# 1 rows updated
# 6896: Caesia calliantha / most
# 1 rows updated
# 3535: Caesia parviflora / all
# 1 rows updated
# 7183: Caesia parviflora var. parviflora / all
# 1 rows updated
# 7333: Caesia parviflora var. vittata / all
# 1 rows updated
# 1791: Cakile edentula / none
# 1 rows updated
# 6838: Caladenia alata / all
# 1 rows updated
# 10712: Caladenia alpina / all
# 1 rows updated
# 11246: Caladenia capillata / all
# 1 rows updated
# 4373: Caladenia carnea / all
# 1 rows updated
# 6703: Caladenia catenata / all
# 1 rows updated
# 9548: Caladenia clarkiae / all
# 1 rows updated
# 9523: Caladenia concolor / all
# 1 rows updated
# 4376: Caladenia cucullata / all
# 1 rows updated
# 4379: Caladenia dimorpha / all
# 1 rows updated
# 4380: Caladenia filamentosa / none
# 1 rows updated
# 9123: Caladenia gracilis / all
# 1 rows updated
# 9477: Caladenia rosella / all
# 1 rows updated
# 9192: Caladenia sp. A / all
# 1 rows updated
# 4386: Caladenia tessellata / all
# 1 rows updated
# 13313: Caladenia transitoria / all
# 1 rows updated
# 5309: Calandrinia calyptrata / none
# 1 rows updated
# 5312: Calandrinia granulifera / none
# 1 rows updated
# 5314: Calandrinia pickeringii / all
# 1 rows updated
# 2269: Caldcluvia paniculosa / half
# 1 rows updated
# 4389: Caleana major / all
# 1 rows updated
# 10175: Calendula officinalis / none
# 1 rows updated
# 2270: Callicoma serratifolia / all
# 1 rows updated
# 4002: Callistemon acuminatus / all
# 1 rows updated
# 4004: Callistemon citrinus / all
# 1 rows updated
# 4005: Callistemon comboynensis / all
# 1 rows updated
# 4006: Callistemon flavovirens / all
# 1 rows updated
# 4008: Callistemon linearis / all
# 1 rows updated
# 4009: Callistemon montanus / all
# 1 rows updated
# 4010: Callistemon pachyphyllus / all
# 1 rows updated
# 4011: Callistemon pallidus / all
# 1 rows updated
# 4013: Callistemon pinifolius / all
# 1 rows updated
# 7943: Callistemon pityoides / all
# 1 rows updated
# 9126: Callistemon pungens / all
# 1 rows updated
# 9126: Callistemon pungens / all
# 1 rows updated
# 4014: Callistemon rigidus / all
# 1 rows updated
# 4015: Callistemon salignus / all
# 1 rows updated
# 4016: Callistemon shiressii / all
# 1 rows updated
# 4017: Callistemon sieberi / all
# 1 rows updated
# 14189: Callistemon sp. aff. flavovirens / all
# 1 rows updated
# 4018: Callistemon subulatus / all
# 1 rows updated
# 2279: Callitris endlicheri / none
# 1 rows updated
# 6379: Callitris glaucophylla / none
# 1 rows updated
# 2280: Callitris macleayana / none
# 1 rows updated
# 2281: Callitris monticola / none
# 1 rows updated
# 2282: Callitris muelleri / none
# 1 rows updated
# 2283: Callitris oblonga / none
# 1 rows updated
# 9986: Callitris oblonga subsp. parva / none
# 1 rows updated
# 2285: Callitris rhomboidea / none
# 1 rows updated
# 6805: Callitris verrucosa / none
# 1 rows updated
# 1330: Calocephalus citreus / all
# 1 rows updated
# 1331: Calocephalus platycephalus / all
# 1 rows updated
# 4390: Calochilus campestris / all
# 1 rows updated
# 4391: Calochilus gracillimus / none
# 1 rows updated
# 4394: Calochilus paludosus / all
# 1 rows updated
# 4395: Calochilus robertsonii / all
# 1 rows updated
# 8341: Calochlaena dubia / all
# 1 rows updated
# 1333: Calomeria amaranthoides / none
# 1 rows updated
# 3537: Calostemma purpureum / all
# 1 rows updated
# 1335: Calotis anthemoides / all
# 1 rows updated
# 1337: Calotis cuneifolia / none
# 1 rows updated
# 1339: Calotis dentex / none
# 1 rows updated
# 1341: Calotis glandulosa / few
# 1 rows updated
# 1342: Calotis hispidula / none
# 1 rows updated
# 1344: Calotis lappulacea / all
# 1 rows updated
# 2215: Calystegia marginata / none
# 1 rows updated
# 4021: Calytrix tetragona / half
# 1 rows updated
# 1865: Canarium australasicum / all
# 1 rows updated
# 1941: Canna indica / all
# 1 rows updated
# 6374: Capparis lasiantha / none
# 1 rows updated
# 7284: Capparis loranthifolia var. loranthifolia / none
# 1 rows updated
# 1794: Capsella bursa-pastoris / none
# 1 rows updated
# 10566: Cardamine astoniae / all
# 1 rows updated
# 7410: Cardamine flexuosa / none
# 1 rows updated
# 1795: Cardamine hirsuta / none
# 1 rows updated
# 1796: Cardamine lilacina / half
# 1 rows updated
# 10570: Cardamine papillata / none
# 1 rows updated
# 1355: Carduus tenuiflorus / half
# 1 rows updated
# 2310: Carex appressa / all
# 1 rows updated
# 2311: Carex bichenoviana / all
# 1 rows updated
# 2312: Carex blakei / all
# 1 rows updated
# 2313: Carex breviculmis / most
# 1 rows updated
# 2315: Carex canescens / all
# 1 rows updated
# 2316: Carex capillacea / all
# 1 rows updated
# 2317: Carex cephalotes / all
# 1 rows updated
# 2318: Carex chlorantha / all
# 1 rows updated
# 2322: Carex gaudichaudiana / all
# 1 rows updated
# 2324: Carex hebes / all
# 1 rows updated
# 7898: Carex incomitata / all
# 1 rows updated
# 2327: Carex inversa / all
# 1 rows updated
# 2329: Carex jackiana / all
# 1 rows updated
# 2331: Carex longebrachiata / all
# 1 rows updated
# 2336: Carex raleighii / all
# 1 rows updated
# 2338: Carpha alpina / none
# 1 rows updated
# 2339: Carpha nivicola / all
# 1 rows updated
# 1024: Carpobrotus edulis / none
# 1 rows updated
# 1798: Carrichtera annua / none
# 1 rows updated
# 1358: Carthamus lanatus / none
# 1 rows updated
# 9296: Cassia brewsteri var. marksiana / all
# 1 rows updated
# 1360: Cassinia aculeata / none
# 1 rows updated
# 1362: Cassinia arcuata / none
# 1 rows updated
# 1363: Cassinia aureonitens / none
# 1 rows updated
# 1364: Cassinia compacta / none
# 1 rows updated
# 1365: Cassinia cunninghamii / none
# 1 rows updated
# 1366: Cassinia denticulata / none
# 1 rows updated
# 1367: Cassinia laevis / none
# 1 rows updated
# 12706: Cassinia lepschii / all
# 1 rows updated
# 9246: Cassinia leptocephala subsp. leptocephala / none
# 1 rows updated
# 1369: Cassinia longifolia / few
# 1 rows updated
# 12709: Cassinia monticola / half
# 1 rows updated
# 1370: Cassinia quinquefaria / none
# 1 rows updated
# 12711: Cassinia straminea / none
# 1 rows updated
# 12425: Cassinia telfordii / none
# 1 rows updated
# 1374: Cassinia trinerva / half
# 1 rows updated
# 1375: Cassinia uncata / none
# 1 rows updated
# 7220: Cassytha filiformis / all
# 1 rows updated
# 3467: Cassytha glabella / none
# 1 rows updated
# 3468: Cassytha melantha / none
# 1 rows updated
# 3469: Cassytha pubescens / none
# 1 rows updated
# 2019: Casuarina cristata / none
# 1 rows updated
# 9006: Casuarina cunninghamiana subsp. cunninghamiana / none
# 1 rows updated
# 2022: Casuarina glauca / all
# 1 rows updated
# 11001: Caustis blakei subsp. blakei / all
# 1 rows updated
# 2341: Caustis flexuosa / most
# 1 rows updated
# 2342: Caustis pentandra / most
# 1 rows updated
# 2342: Caustis pentandra / none
# 1 rows updated
# 9315: Caustis recurvata var. recurvata / few
# 1 rows updated
# 6281: Cayratia clematidea / all
# 1 rows updated
# 6794: Celastrus subspicata / none
# 1 rows updated
# 1377: Celmisia longifolia / none
# 1 rows updated
# 10835: Celmisia pugioniformis / all
# 1 rows updated
# 10836: Celmisia tomentella / all
# 1 rows updated
# 1382: Centaurea melitensis / none
# 1 rows updated
# 3131: Centaurium erythraea / few
# 1 rows updated
# 3133: Centaurium tenuiflorum / none
# 1 rows updated
# 1106: Centella asiatica / none
# 1 rows updated
# 1386: Centipeda thespidioides / none
# 1 rows updated
# 10339: Centrolepis aristata / none
# 1 rows updated
# 2038: Centrolepis fascicularis / none
# 1 rows updated
# 2040: Centrolepis polygyna / none
# 1 rows updated
# 8807: Centrolepis strigosa subsp. strigosa / half
# 1 rows updated
# 1206: Cephalaralia cephalobotrys  / all
# 1 rows updated
# 9348: Cerastium balearicum / none
# 1 rows updated
# 1960: Cerastium glomeratum / none
# 1 rows updated
# 10550: Cerastium vulgare / none
# 1 rows updated
# 1388: Ceratogyne obionoides / none
# 1 rows updated
# 2271: Ceratopetalum apetalum / all
# 1 rows updated
# 2272: Ceratopetalum gummiferum / all
# 1 rows updated
# 14091: Cestichis reflexa / all
# 1 rows updated
# 6027: Cestrum parqui / all
# 1 rows updated
# 9737: Chamaecytisus palmensis / none
# 1 rows updated
# 9130: Chamaesyce hirta / none
# 1 rows updated
# 8005: Cheilanthes austrotenuifolia / half
# 1 rows updated
# 6382: Cheilanthes distans / all
# 1 rows updated
# 8007: Cheilanthes sieberi subsp. sieberi / all
# 1 rows updated
# 2084: Chenopodium album / none
# 1 rows updated
# 2089: Chenopodium cristatum / none
# 1 rows updated
# 2091: Chenopodium desertorum / none
# 1 rows updated
# 2093: Chenopodium erosum / none
# 1 rows updated
# 8868: Chiloglottis sphyrnoides / all
# 1 rows updated
# 6881: Chiloglottis sylvestris / all
# 1 rows updated
# 6525: Chiloglottis trilabra / all
# 1 rows updated
# 10289: Chiloglottis valida / all
# 1 rows updated
# 6242: Chloanthes parviflora / none
# 1 rows updated
# 6243: Chloanthes stoechadis / few
# 1 rows updated
# 4831: Chloris gayana / all
# 1 rows updated
# 4833: Chloris truncata / all
# 1 rows updated
# 4834: Chloris ventricosa / all
# 1 rows updated
# 3538: Chlorophytum comosum / all
# 1 rows updated
# 1391: Chondrilla juncea / half
# 1 rows updated
# 13527: Chordifex dimorphus / none
# 1 rows updated
# 13528: Chordifex fastigiatus / all
# 1 rows updated
# 5856: Choretrum candollei / all
# 1 rows updated
# 5857: Choretrum glomeratum / none
# 1 rows updated
# 5858: Choretrum pauciflorum / none
# 1 rows updated
# 4022: Choricarpia leptopetala / all
# 1 rows updated
# 2344: Chorizandra cymbaria / all
# 1 rows updated
# 2345: Chorizandra sphaerocephala / all
# 1 rows updated
# 2797: Chorizema parviflorum / most
# 1 rows updated
# 8188: Christella dentata / all
# 1 rows updated
# 1392: Chrysanthemoides monilifera / half
# 1 rows updated
# 9400: Chrysanthemoides monilifera subsp. monilifera / none
# 1 rows updated
# 8686: Chrysanthemoides monilifera subsp. rotundata / all
# 1 rows updated
# 8559: Chrysocephalum apiculatum / most
# 1 rows updated
# 9609: Chrysocephalum baxteri / few
# 1 rows updated
# 8562: Chrysocephalum semipapposum / most
# 1 rows updated
# 4835: Chrysopogon fallax / all
# 1 rows updated
# 1395: Chthonocephalus pseudevax / none
# 1 rows updated
# 3135: Cicendia quadrangularis / none
# 1 rows updated
# 3471: Cinnamomum camphora / all
# 1 rows updated
# 3472: Cinnamomum oliveri / few
# 1 rows updated
# 1400: Cirsium vulgare / none
# 1 rows updated
# 1400: Cirsium vulgare / few
# 1 rows updated
# 6283: Cissus hypoglauca / all
# 1 rows updated
# 3275: Citronella moorei / none
# 1 rows updated
# 2698: Claoxylon australe / all
# 1 rows updated
# 5493: Clematis aristata / most
# 1 rows updated
# 5494: Clematis fawcettii / none
# 1 rows updated
# 5495: Clematis glycinoides / none
# 1 rows updated
# 6903: Clematis glycinoides var. glycinoides / all
# 1 rows updated
# 13520: Clematis leptophylla / none
# 1 rows updated
# 5496: Clematis microphylla / all
# 1 rows updated
# 12201: Clerodendrum floribundum var. floribundum / all
# 1 rows updated
# 6484: Clerodendrum tomentosum / all
# 1 rows updated
# 3231: Codonocarpus attenuatus / none
# 1 rows updated
# 5531: Coleocarya gracilis / most
# 1 rows updated
# 5252: Comesperma defoliatum / all
# 1 rows updated
# 5253: Comesperma ericinum / few
# 1 rows updated
# 5255: Comesperma retusum / half
# 1 rows updated
# 5256: Comesperma sphaerocarpum / all
# 1 rows updated
# 5257: Comesperma volubile / half
# 1 rows updated
# 2209: Commelina cyanea / half
# 1 rows updated
# 6129: Commersonia bartramia / all
# 1 rows updated
# 13958: Commersonia breviseta / none
# 1 rows updated
# 5350: Conospermum burgessiorum / none
# 1 rows updated
# 9136: Conospermum ellipticum / all
# 1 rows updated
# 9976: Conospermum ericifolium / none
# 1 rows updated
# 5351: Conospermum longifolium / most
# 1 rows updated
# 5352: Conospermum taxifolium / half
# 1 rows updated
# 5353: Conospermum tenuifolium / all
# 1 rows updated
# 2219: Convolvulus arvensis / all
# 1 rows updated
# 2220: Convolvulus erubescens / most
# 1 rows updated
# 1403: Conyza bilbaoana / none
# 1 rows updated
# 1404: Conyza bonariensis / none
# 1 rows updated
# 10138: Conyza canadensis var. canadensis / all
# 1 rows updated
# 1408: Conyza parva / none
# 1 rows updated
# 10442: Conyza sumatrensis / none
# 1 rows updated
# 3166: Coopernookia barbata / all
# 1 rows updated
# 5670: Coprosma hirtella / all
# 1 rows updated
# 8677: Coprosma nitida / few
# 1 rows updated
# 6557: Coprosma nivalis / none
# 1 rows updated
# 6678: Coprosma perpusilla subsp. perpusilla / none
# 1 rows updated
# 5675: Coprosma quadrifida / half
# 1 rows updated
# 5676: Coprosma repens / all
# 1 rows updated
# 6198: Corchorus cunninghamii / none
# 1 rows updated
# 1409: Coreopsis lanceolata / half
# 1 rows updated
# 13745: Coronidium elatum / none
# 1 rows updated
# 13961: Coronidium oxylepis / few
# 1 rows updated
# 13836: Coronidium scorpioides / most
# 1 rows updated
# 13966: Coronidium waddelliae / none
# 1 rows updated
# 1800: Coronopus didymus / none
# 1 rows updated
# 5769: Correa baeuerlenii / none
# 1 rows updated
# 11022: Correa lawrenceana var. glandulifera / none
# 1 rows updated
# 5772: Correa reflexa / most
# 1 rows updated
# 5772: Correa reflexa (obligate seeder red flowered) / none
# 1 rows updated
# 5772: Correa reflexa (resprouter green flowered) / all
# 1 rows updated
# 8801: Correa reflexa var. reflexa / none
# 1 rows updated
# 4839: Cortaderia selloana / all
# 1 rows updated
# 4404: Corybas aconitiflorus / all
# 1 rows updated
# 4408: Corybas fordhamii / all
# 1 rows updated
# 4409: Corybas hispidus / all
# 1 rows updated
# 9743: Corymbia eximia / all
# 1 rows updated
# 9687: Corymbia gummifera / all
# 1 rows updated
# 9601: Corymbia intermedia / all
# 1 rows updated
# 9692: Corymbia maculata / all
# 1 rows updated
# 9744: Corymbia tessellaris / all
# 1 rows updated
# 6981: Corynocarpus rupestris / all
# 1 rows updated
# 6830: Corynotheca licrota / all
# 1 rows updated
# 1410: Cosmos bipinnatus / none
# 1 rows updated
# 8640: Cotoneaster franchetii / all
# 1 rows updated
# 5612: Cotoneaster glaucophyllus / all
# 1 rows updated
# 1411: Cotula alpina / all
# 1 rows updated
# 1412: Cotula australis / none
# 1 rows updated
# 9952: Craspedia aurantia / all
# 1 rows updated
# 9139: Craspedia canens / all
# 1 rows updated
# 8565: Craspedia coolaminica / all
# 1 rows updated
# 8566: Craspedia jamesii / all
# 1 rows updated
# 10153: Craspedia lamicola / all
# 1 rows updated
# 11656: Craspedia sp. aff. crocata (Bogong Swamp) / all
# 1 rows updated
# 1421: Crassocephalum crepidioides / none
# 1 rows updated
# 7745: Crassula decumbens var. decumbens / none
# 1 rows updated
# 2240: Crassula multicava / all
# 1 rows updated
# 6820: Crassula peduncularis / none
# 1 rows updated
# 2242: Crassula sieberiana / few
# 1 rows updated
# 1422: Cratystylis conocephala / none
# 1 rows updated
# 12520: Crepidomanes venosum / none
# 1 rows updated
# 1423: Crepis capillaris / half
# 1 rows updated
# 10271: Crocosmia X crocosmiiflora / all
# 1 rows updated
# 6901: Crotalaria cunninghamii / all
# 1 rows updated
# 12020: Crotalaria montana var. angustifolia / none
# 1 rows updated
# 2706: Croton verreauxii / none
# 1 rows updated
# 12205: Crowea exalata subsp. magnifolia / none
# 1 rows updated
# 5775: Crowea saligna / none
# 1 rows updated
# 5554: Cryptandra amara / half
# 1 rows updated
# 8611: Cryptandra amara var. amara / all
# 1 rows updated
# 8246: Cryptandra amara var. floribunda / none
# 1 rows updated
# 8784: Cryptandra amara var. longiflora / all
# 1 rows updated
# 5556: Cryptandra ericoides / none
# 1 rows updated
# 5557: Cryptandra lanosiflora / none
# 1 rows updated
# 3477: Cryptocarya foetida / all
# 1 rows updated
# 3478: Cryptocarya foveolata / all
# 1 rows updated
# 3479: Cryptocarya glaucescens / all
# 1 rows updated
# 8756: Cryptocarya meissneriana / all
# 1 rows updated
# 3483: Cryptocarya microneura / none
# 1 rows updated
# 3485: Cryptocarya rigida / all
# 1 rows updated
# 4414: Cryptostylis erecta / all
# 1 rows updated
# 4415: Cryptostylis hunteriana / all
# 1 rows updated
# 4416: Cryptostylis leptochila / all
# 1 rows updated
# 4417: Cryptostylis subulata / all
# 1 rows updated
# 2255: Cucurbita maxima / none
# 1 rows updated
# 10668: Cullen cinereum / none
# 1 rows updated
# 10671: Cullen microcephalum / none
# 1 rows updated
# 9987: Cullen parvum / all
# 1 rows updated
# 10673: Cullen patens / none
# 1 rows updated
# 10674: Cullen tenax / none
# 1 rows updated
# 5884: Cupaniopsis anacardioides / most
# 1 rows updated
# 7384: Cupaniopsis newmanii / all
# 1 rows updated
# 2286: Cuscuta australis / none
# 1 rows updated
# 2287: Cuscuta campestris / none
# 1 rows updated
# 10187: Cuscuta victoriana / none
# 1 rows updated
# 11228: Cyanicula caerulea / all
# 1 rows updated
# 8074: Cyathea australis / all
# 1 rows updated
# 8077: Cyathea cunninghamii / none
# 1 rows updated
# 8079: Cyathea leichhardtiana / few
# 1 rows updated
# 2347: Cyathochaeta diandra / all
# 1 rows updated
# 11599: Cyclophyllum longipetalum / all
# 1 rows updated
# 4419: Cymbidium suave / all
# 1 rows updated
# 1426: Cymbonotus lawsonianus / none
# 1 rows updated
# 1427: Cymbonotus preissianus / all
# 1 rows updated
# 7675: Cymbopogon ambiguus / all
# 1 rows updated
# 4841: Cymbopogon refractus / all
# 1 rows updated
# 14560: Cynanchum viminale subsp. australe / none
# 1 rows updated
# 6540: Cynodon dactylon / all
# 1 rows updated
# 1749: Cynoglossum suaveolens / half
# 1 rows updated
# 4845: Cynosurus echinatus / none
# 1 rows updated
# 2348: Cyperus albostriatus / all
# 1 rows updated
# 2353: Cyperus brevifolius / all
# 1 rows updated
# 2354: Cyperus bulbosus / all
# 1 rows updated
# 2364: Cyperus eragrostis / all
# 1 rows updated
# 2372: Cyperus fulvus / all
# 1 rows updated
# 2374: Cyperus gracilis / all
# 1 rows updated
# 2379: Cyperus laevigatus / all
# 1 rows updated
# 8483: Cyperus polystachyos / none
# 1 rows updated
# 2395: Cyperus sanguinolentus / none
# 1 rows updated
# 9677: Cyperus semifertilis / all
# 1 rows updated
# 7469: Cyperus tenellus / none
# 1 rows updated
# 7617: Cyperus vaginatus / all
# 1 rows updated
# 7342: Cyphanthera albicans subsp. albicans / none
# 1 rows updated
# 11075: Cytisus scoparius subsp. scoparius / none
# 1 rows updated
# 9338: Dactyloctenium aegyptium / none
# 1 rows updated
# 7440: Dampiera fusca / all
# 1 rows updated
# 9745: Dampiera lanceolata var. lanceolata / all
# 1 rows updated
# 3172: Dampiera purpurea / all
# 1 rows updated
# 3173: Dampiera scottiana / all
# 1 rows updated
# 3174: Dampiera stricta / all
# 1 rows updated
# 3911: Daphnandra micrantha / all
# 1 rows updated
# 4024: Darwinia biflora / none
# 1 rows updated
# 4025: Darwinia camptostylis / all
# 1 rows updated
# 4026: Darwinia diminuta / none
# 1 rows updated
# 6508: Darwinia fascicularis subsp. fascicularis / few
# 1 rows updated
# 7135: Darwinia fascicularis subsp. oligantha / half
# 1 rows updated
# 4028: Darwinia glaucophylla / none
# 1 rows updated
# 4029: Darwinia grandiflora / all
# 1 rows updated
# 4030: Darwinia leptantha / none
# 1 rows updated
# 4032: Darwinia procera / none
# 1 rows updated
# 10039: Darwinia taxifolia subsp. macrolaena / none
# 1 rows updated
# 10038: Darwinia taxifolia subsp. taxifolia / none
# 1 rows updated
# 1109: Daucus glochidiatus / none
# 1 rows updated
# 10647: Davallia solida var. pyxidata / none
# 1 rows updated
# 2816: Daviesia acicularis / none
# 1 rows updated
# 2831: Daviesia alata / none
# 1 rows updated
# 6874: Daviesia benthamii subsp. humilis / none
# 1 rows updated
# 2819: Daviesia brevifolia / all
# 1 rows updated
# 2821: Daviesia corymbosa / most
# 1 rows updated
# 8823: Daviesia elliptica / none
# 1 rows updated
# 2822: Daviesia genistifolia / few
# 1 rows updated
# 2823: Daviesia latifolia / most
# 1 rows updated
# 9597: Daviesia leptophylla / all
# 1 rows updated
# 2824: Daviesia mimosoides / all
# 1 rows updated
# 7211: Daviesia mimosoides subsp. mimosoides / all
# 1 rows updated
# 8774: Daviesia nova-anglica / none
# 1 rows updated
# 2826: Daviesia squarrosa / half
# 1 rows updated
# 2827: Daviesia ulicifolia / most
# 1 rows updated
# 10831: Daviesia ulicifolia subsp. ulicifolia / none
# 1 rows updated
# 2828: Daviesia umbellulata / few
# 1 rows updated
# 8592: Daviesia villifera / none
# 1 rows updated
# 2830: Daviesia wyattiana / none
# 1 rows updated
# 4420: Dendrobium aemulum / none
# 1 rows updated
# 4432: Dendrobium speciosum / all
# 1 rows updated
# 4433: Dendrobium striolatum / none
# 1 rows updated
# 6226: Dendrocnide excelsa / none
# 1 rows updated
# 8387: Denhamia celastroides / all
# 1 rows updated
# 8700: Derwentia arcuata / none
# 1 rows updated
# 9775: Derwentia perfoliata / half
# 1 rows updated
# 2834: Desmodium brachypodum / all
# 1 rows updated
# 6621: Desmodium gunnii / all
# 1 rows updated
# 2839: Desmodium rhytidophyllum / most
# 1 rows updated
# 2840: Desmodium varians / all
# 1 rows updated
# 4871: Deyeuxia accedens / none
# 1 rows updated
# 4880: Deyeuxia crassiuscula / all
# 1 rows updated
# 4881: Deyeuxia decipiens / few
# 1 rows updated
# 4884: Deyeuxia imbricata / none
# 1 rows updated
# 10361: Deyeuxia innominata / half
# 1 rows updated
# 6940: Deyeuxia monticola var. monticola / all
# 1 rows updated
# 4889: Deyeuxia nudiflora / none
# 1 rows updated
# 6964: Deyeuxia parviseta var. boormanii / half
# 1 rows updated
# 4891: Deyeuxia quadriseta / all
# 1 rows updated
# 11273: Deyeuxia talariata / none
# 1 rows updated
# 3540: Dianella caerulea / half
# 1 rows updated
# 6811: Dianella caerulea var. assera / all
# 1 rows updated
# 6700: Dianella caerulea var. caerulea / all
# 1 rows updated
# 6789: Dianella caerulea var. cinerascens / all
# 1 rows updated
# 7337: Dianella caerulea var. producta / all
# 1 rows updated
# 7344: Dianella caerulea var. vannata / all
# 1 rows updated
# 7783: Dianella longifolia / all
# 1 rows updated
# 8725: Dianella longifolia var. longifolia / all
# 1 rows updated
# 6912: Dianella prunina / all
# 1 rows updated
# 3542: Dianella revoluta / all
# 1 rows updated
# 7580: Dianella revoluta var. revoluta / all
# 1 rows updated
# 3543: Dianella tasmanica / all
# 1 rows updated
# 4897: Dichelachne crinita / half
# 1 rows updated
# 8748: Dichelachne inaequiglumis / all
# 1 rows updated
# 4898: Dichelachne micrantha / all
# 1 rows updated
# 4899: Dichelachne rara / all
# 1 rows updated
# 9151: Dichelachne sieberiana / all
# 1 rows updated
# 2222: Dichondra repens / few
# 1 rows updated
# 3545: Dichopogon strictus / half
# 1 rows updated
# 8082: Dicksonia antarctica / all
# 1 rows updated
# 8155: Dictymia brownii / none
# 1 rows updated
# 4903: Digitaria coenicola / all
# 1 rows updated
# 4905: Digitaria diffusa / none
# 1 rows updated
# 4907: Digitaria divaricatissima / few
# 1 rows updated
# 4913: Digitaria parviflora / all
# 1 rows updated
# ...
# 7336: Pomaderris virgata / none
# 1 rows updated
# 5703: Pomax umbellata / none
# 1 rows updated
# 2753: Poranthera corymbosa / none
# 1 rows updated
# 2754: Poranthera ericifolia / none
# 1 rows updated
# 7395: Poranthera microphylla / half
# 1 rows updated
# 5324: Portulaca oleracea / all
# 1 rows updated
# 5325: Portulaca pilosa / all
# 1 rows updated
# 11955: Potentilla indica / all
# 1 rows updated
# 5621: Potentilla recta / none
# 1 rows updated
# 7779: Prasophyllum affine / all
# 1 rows updated
# 4491: Prasophyllum australe / all
# 1 rows updated
# 4494: Prasophyllum brevilabre / all
# 1 rows updated
# 4497: Prasophyllum elatum / all
# 1 rows updated
# 4501: Prasophyllum fitzgeraldii / all
# 1 rows updated
# 4502: Prasophyllum flavum / all
# 1 rows updated
# 4503: Prasophyllum frenchii / all
# 1 rows updated
# 10279: Prasophyllum lindleyanum / all
# 1 rows updated
# 4516: Prasophyllum odoratum / all
# 1 rows updated
# 4517: Prasophyllum patens / all
# 1 rows updated
# 11301: Prasophyllum retroflexum / all
# 1 rows updated
# 4520: Prasophyllum rogersii / all
# 1 rows updated
# 10935: Prasophyllum sphacelatum / all
# 1 rows updated
# 4525: Prasophyllum suttonii / all
# 1 rows updated
# 7980: Pratia pedunculata / all
# 1 rows updated
# 1925: Pratia purpurascens / all
# 1 rows updated
# 1926: Pratia surrepens / all
# 1 rows updated
# 3401: Prostanthera cineolifera / none
# 1 rows updated
# 3403: Prostanthera cuneata / all
# 1 rows updated
# 8256: Prostanthera decussata / none
# 1 rows updated
# 3405: Prostanthera denticulata / none
# 1 rows updated
# 3412: Prostanthera incana / none
# 1 rows updated
# 3413: Prostanthera incisa / none
# 1 rows updated
# 9884: Prostanthera junonis / half
# 1 rows updated
# 3415: Prostanthera lasianthos / few
# 1 rows updated
# 3417: Prostanthera linearis / none
# 1 rows updated
# 6877: Prostanthera monticola / none
# 1 rows updated
# 3421: Prostanthera nivea / none
# 1 rows updated
# 9380: Prostanthera nivea var. nivea / none
# 1 rows updated
# 3423: Prostanthera ovalifolia / none
# 1 rows updated
# 3426: Prostanthera rhombea / none
# 1 rows updated
# 3429: Prostanthera saxicola / none
# 1 rows updated
# 3430: Prostanthera scutellarioides / none
# 1 rows updated
# 3432: Prostanthera spinosa / none
# 1 rows updated
# 3434: Prostanthera striatiflora / all
# 1 rows updated
# 3436: Prostanthera teretifolia / none
# 1 rows updated
# 3438: Prostanthera walteri / none
# 1 rows updated
# 3440: Prunella vulgaris / none
# 1 rows updated
# 2755: Pseudanthus divaricatissimus / most
# 1 rows updated
# 2756: Pseudanthus orientalis / few
# 1 rows updated
# 9467: Pseudanthus ovalifolius / all
# 1 rows updated
# 12971: Pseudanthus pauciflorus / none
# 1 rows updated
# 2757: Pseudanthus pimeleoides / all
# 1 rows updated
# 1010: Pseuderanthemum variabile / most
# 1 rows updated
# 7780: Pseudognaphalium luteoalbum / none
# 1 rows updated
# 8165: Psilotum nudum / none
# 1 rows updated
# 2969: Psoralea pinnata / none
# 1 rows updated
# 5705: Psychotria daphnoides / none
# 1 rows updated
# 5706: Psychotria loniceroides / half
# 1 rows updated
# 13524: Psychrophila introloba / all
# 1 rows updated
# 11944: Psydrax latifolia / none
# 1 rows updated
# 6403: Pteridium esculentum / all
# 1 rows updated
# 8457: Pteris comans / half
# 1 rows updated
# 8175: Pteris tremula / none
# 1 rows updated
# 8177: Pteris vittata / none
# 1 rows updated
# 7829: Pterocaulon sphacelatum / all
# 1 rows updated
# 4535: Pterostylis acuminata / all
# 1 rows updated
# 7854: Pterostylis aestiva / all
# 1 rows updated
# 4538: Pterostylis alveata / all
# 1 rows updated
# 4539: Pterostylis baptistii / all
# 1 rows updated
# 6712: Pterostylis bicolor / all
# 1 rows updated
# 6536: Pterostylis chaetophora / all
# 1 rows updated
# 7502: Pterostylis coccina / all
# 1 rows updated
# 4544: Pterostylis concinna / all
# 1 rows updated
# 4545: Pterostylis curta / all
# 1 rows updated
# 7895: Pterostylis cycnocephala / all
# 1 rows updated
# 4547: Pterostylis decurva / all
# 1 rows updated
# 4549: Pterostylis fischii / all
# 1 rows updated
# 4553: Pterostylis gibbosa / all
# 1 rows updated
# 4554: Pterostylis grandiflora / all
# 1 rows updated
# 4557: Pterostylis laxa / all
# 1 rows updated
# 4559: Pterostylis longifolia / all
# 1 rows updated
# 7004: Pterostylis longipetala / all
# 1 rows updated
# 6551: Pterostylis maxima / all
# 1 rows updated
# 4560: Pterostylis mutica / all
# 1 rows updated
# 4561: Pterostylis nana / all
# 1 rows updated
# 4562: Pterostylis nutans / all
# 1 rows updated
# 4566: Pterostylis parviflora / all
# 1 rows updated
# 4567: Pterostylis pedoglossa / all
# 1 rows updated
# 4568: Pterostylis pedunculata / all
# 1 rows updated
# 4569: Pterostylis plumosa / all
# 1 rows updated
# 4575: Pterostylis truncata / all
# 1 rows updated
# 8956: Ptilothrix deusta / all
# 1 rows updated
# 1070: Ptilotus erubescens / all
# 1 rows updated
# 1077: Ptilotus macrocephalus / all
# 1 rows updated
# 1078: Ptilotus nobilis / none
# 1 rows updated
# 1079: Ptilotus obovatus / most
# 1 rows updated
# 7822: Ptilotus spathulatus f. spathulatus / all
# 1 rows updated
# 2973: Pultenaea altissima / none
# 1 rows updated
# 2974: Pultenaea aristata / none
# 1 rows updated
# 2976: Pultenaea benthamii / none
# 1 rows updated
# 2977: Pultenaea blakelyi / none
# 1 rows updated
# 6600: Pultenaea campbellii / all
# 1 rows updated
# 2985: Pultenaea daphnoides / none
# 1 rows updated
# 2986: Pultenaea dentata / none
# 1 rows updated
# 2987: Pultenaea divaricata / all
# 1 rows updated
# 2991: Pultenaea fasciculata / all
# 1 rows updated
# 2992: Pultenaea ferruginea / none
# 1 rows updated
# 2993: Pultenaea flexilis / none
# 1 rows updated
# 2994: Pultenaea foliolosa / all
# 1 rows updated
# 2995: Pultenaea glabra / none
# 1 rows updated
# 2997: Pultenaea hispidula / none
# 1 rows updated
# 3000: Pultenaea largiflorens / none
# 1 rows updated
# 3002: Pultenaea linophylla / none
# 1 rows updated
# 3003: Pultenaea microphylla / few
# 1 rows updated
# 11407: Pultenaea mollis / none
# 1 rows updated
# 3004: Pultenaea myrtoides / all
# 1 rows updated
# 12224: Pultenaea parrisiae / none
# 1 rows updated
# 3007: Pultenaea parviflora / none
# 1 rows updated
# 3008: Pultenaea pedunculata / all
# 1 rows updated
# 3011: Pultenaea polifolia / none
# 1 rows updated
# 3012: Pultenaea procumbens / all
# 1 rows updated
# 3013: Pultenaea pycnocephala / none
# 1 rows updated
# 3014: Pultenaea retusa / none
# 1 rows updated
# 3015: Pultenaea rosmarinifolia / none
# 1 rows updated
# 3016: Pultenaea scabra / none
# 1 rows updated
# 11810: Pultenaea setulosa / all
# 1 rows updated
# 3017: Pultenaea spinosa / none
# 1 rows updated
# 3018: Pultenaea stipularis / none
# 1 rows updated
# 3020: Pultenaea subspicata / none
# 1 rows updated
# 12552: Pultenaea tarik / none
# 1 rows updated
# 11386: Pultenaea tuberculata / most
# 1 rows updated
# 3022: Pultenaea villifera / none
# 1 rows updated
# 3023: Pultenaea villosa / none
# 1 rows updated
# 3025: Pultenaea vrolandii / none
# 1 rows updated
# 10155: Pycnosorus chrysanthes / all
# 1 rows updated
# 8912: Pycnosorus pleiocephalus / none
# 1 rows updated
# 5627: Pyracantha angustifolia / all
# 1 rows updated
# 12465: Pyracantha crenatoserrata / all
# 1 rows updated
# 5628: Pyracantha crenulata / all
# 1 rows updated
# 10853: Pyrorchis nigricans / most
# 1 rows updated
# 8163: Pyrrosia rupestris / none
# 1 rows updated
# 3228: Quintinia sieberi / all
# 1 rows updated
# 3661: Radyera farragei / none
# 1 rows updated
# 5505: Ranunculus graniticola / half
# 1 rows updated
# 5506: Ranunculus gunnianus / all
# 1 rows updated
# 5508: Ranunculus lappaceus / none
# 1 rows updated
# 5509: Ranunculus millanii / all
# 1 rows updated
# 5517: Ranunculus pimpinellifolius / none
# 1 rows updated
# 5520: Ranunculus pumilio / none
# 1 rows updated
# 5521: Ranunculus repens / all
# 1 rows updated
# 5525: Ranunculus sessiliflorus / none
# 1 rows updated
# 1641: Reichardia tingitana / none
# 1 rows updated
# 7808: Rhagodia candolleana subsp. candolleana / none
# 1 rows updated
# 2160: Rhagodia parabolica / none
# 1 rows updated
# 2161: Rhagodia spinescens / none
# 1 rows updated
# 2162: Rhagodia ulicina / none
# 1 rows updated
# 4283: Rhodamnia rubescens / all
# 1 rows updated
# 8563: Rhodanthe anthemoides / all
# 1 rows updated
# 8919: Rhodanthe corymbiflora / none
# 1 rows updated
# 9383: Rhodanthe laevis / none
# 1 rows updated
# 8921: Rhodanthe moschata / none
# 1 rows updated
# 9384: Rhodanthe pygmaea / none
# 1 rows updated
# 8922: Rhodanthe stuartiana / none
# 1 rows updated
# 9421: Rhodanthe tietkensii / half
# 1 rows updated
# 1237: Rhyncharrhena linearis / all
# 1 rows updated
# 2482: Rhynchospora brownii / all
# 1 rows updated
# 2484: Rhynchospora rubra / none
# 1 rows updated
# 8809: Rhytidosporum alpinum / all
# 1 rows updated
# 10892: Rhytidosporum diosmoides / all
# 1 rows updated
# 8623: Rhytidosporum procumbens / few
# 1 rows updated
# 2651: Richea continentis / none
# 1 rows updated
# 2759: Ricinocarpos pinifolius / most
# 1 rows updated
# 2760: Ricinocarpos speciosus / all
# 1 rows updated
# 2761: Ricinus communis / all
# 1 rows updated
# 2761: Ricinus communis / none
# 1 rows updated
# 4578: Rimacola elliptica / all
# 1 rows updated
# 6019: Ripogonum discolor / all
# 1 rows updated
# 6614: Roldana petasitis / all
# 1 rows updated
# 1842: Rorippa dictyosperma / none
# 1 rows updated
# 7382: Rorippa palustris / none
# 1 rows updated
# 11587: Rubus moluccanus / all
# 1 rows updated
# 11236: Rubus moluccanus var. trilobus / all
# 1 rows updated
# 5641: Rubus moorei / all
# 1 rows updated
# 5642: Rubus parvifolius / all
# 1 rows updated
# 10813: Rubus rosifolius var. rosifolius / all
# 1 rows updated
# 6145: Rulingia dasyphylla / none
# 1 rows updated
# 6146: Rulingia hermanniifolia / none
# 1 rows updated
# 6148: Rulingia prostrata / none
# 1 rows updated
# 5296: Rumex brownii / all
# 1 rows updated
# 5297: Rumex conglomeratus / all
# 1 rows updated
# 5300: Rumex dumosus / all
# 1 rows updated
# 1642: Rutidosis helichrysoides / none
# 1 rows updated
# 1644: Rutidosis leiolepis / all
# 1 rows updated
# 1645: Rutidosis leptorrhynchoides / all
# 1 rows updated
# 14303: Rytidosperma auriculatum / all
# 1 rows updated
# 14305: Rytidosperma caespitosum / most
# 1 rows updated
# 14306: Rytidosperma carphoides / all
# 1 rows updated
# 14307: Rytidosperma duttonianum / all
# 1 rows updated
# 14308: Rytidosperma erianthum / all
# 1 rows updated
# 14310: Rytidosperma indutum / all
# 1 rows updated
# 14311: Rytidosperma laeve / all
# 1 rows updated
# 14312: Rytidosperma longifolium / all
# 1 rows updated
# 10638: Rytidosperma nudiflorum / all
# 1 rows updated
# 10947: Rytidosperma oreophilum / all
# 1 rows updated
# 14314: Rytidosperma pallidum / all
# 1 rows updated
# 14315: Rytidosperma penicillatum / all
# 1 rows updated
# 14316: Rytidosperma pilosum / all
# 1 rows updated
# 10639: Rytidosperma procerum / all
# 1 rows updated
# 14321: Rytidosperma semiannulare / all
# 1 rows updated
# 14322: Rytidosperma setaceum / all
# 1 rows updated
# 14323: Rytidosperma tenuius / all
# 1 rows updated
# 1980: Sagina apetala / none
# 1 rows updated
# 7510: Salix cinerea / none
# 1 rows updated
# 6061: Salpichroa origanifolia / all
# 1 rows updated
# 7923: Salsola kali var. kali / all
# 1 rows updated
# 3444: Salvia plebeia / none
# 1 rows updated
# 3444: Salvia plebeia / none
# 1 rows updated
# 1954: Sambucus gaudichaudiana / none
# 1 rows updated
# 13751: Sannantha pluriflora  / most
# 1 rows updated
# 5868: Santalum acuminatum / few
# 1 rows updated
# 6384: Santalum lanceolatum / all
# 1 rows updated
# 5869: Santalum murrayanum / all
# 1 rows updated
# 5870: Santalum obtusifolium / half
# 1 rows updated
# 4579: Sarcochilus australis / none
# 1 rows updated
# 4583: Sarcochilus fitzgeraldii / none
# 1 rows updated
# 4584: Sarcochilus hartmannii / none
# 1 rows updated
# 6489: Sarcochilus parviflorus / none
# 1 rows updated
# 7144: Sarcochilus spathulatus / none
# 1 rows updated
# 4587: Sarcochilus weinthalii / all
# 1 rows updated
# 8842: Sarcomelicope simplicifolia subsp. simplicifolia / none
# 1 rows updated
# 3688: Sarcopetalum harveyanum / all
# 1 rows updated
# 3201: Scaevola aemula / none
# 1 rows updated
# 3202: Scaevola albida / none
# 1 rows updated
# 9209: Scaevola albida var. albida / all
# 1 rows updated
# 3204: Scaevola depauperata / all
# 1 rows updated
# 3205: Scaevola hookeri / none
# 1 rows updated
# 3208: Scaevola ramosissima / all
# 1 rows updated
# 3209: Scaevola spinescens / all
# 1 rows updated
# 3566: Schelhammera undulata / all
# 1 rows updated
# 13834: Schenkia spicata / none
# 1 rows updated
# 5156: Schismus barbatus / none
# 1 rows updated
# 5157: Schizachyrium fragile / none
# 1 rows updated
# 8181: Schizaea bifida / all
# 1 rows updated
# 8182: Schizaea dichotoma / all
# 1 rows updated
# 2275: Schizomeria ovata / all
# 1 rows updated
# 2490: Schoenoplectus validus / all
# 1 rows updated
# 2491: Schoenus apogon / most
# 1 rows updated
# 2492: Schoenus brevifolius / all
# 1 rows updated
# 2494: Schoenus calyptratus / none
# 1 rows updated
# 2495: Schoenus ericetorum / all
# 1 rows updated
# 2496: Schoenus imberbis / all
# 1 rows updated
# 2498: Schoenus latelaminatus / half
# 1 rows updated
# 9057: Schoenus lepidosperma subsp. pachylepis / all
# 1 rows updated
# 2499: Schoenus maschalinus / all
# 1 rows updated
# 2500: Schoenus melanostachys / all
# 1 rows updated
# 2501: Schoenus moorei / all
# 1 rows updated
# 2502: Schoenus nitens / all
# 1 rows updated
# 2504: Schoenus paludosus / all
# 1 rows updated
# 2505: Schoenus scabripes / all
# 1 rows updated
# 2506: Schoenus subaphyllus / all
# 1 rows updated
# 2507: Schoenus turbinatus / half
# 1 rows updated
# 2508: Schoenus villosus / all
# 1 rows updated
# 1985: Scleranthus biflorus / most
# 1 rows updated
# 1987: Scleranthus minusculus / none
# 1 rows updated
# 1989: Scleranthus singuliflorus / all
# 1 rows updated
# 2165: Scleroblitum atriplicinum / none
# 1 rows updated
# 2174: Sclerolaena convexula / none
# 1 rows updated
# 2177: Sclerolaena diacantha / none
# 1 rows updated
# 2189: Sclerolaena parviflora / none
# 1 rows updated
# 3110: Scolopia braunii / all
# 1 rows updated
# 3448: Scutellaria mollis / none
# 1 rows updated
# 3137: Sebaea ovata / none
# 1 rows updated
# 5159: Secale cereale / none
# 1 rows updated
# 8185: Selaginella gracillima / all
# 1 rows updated
# 8187: Selaginella uliginosa / all
# 1 rows updated
# 1652: Senecio behrianus / none
# 1 rows updated
# 1654: Senecio biserratus / none
# 1 rows updated
# 7914: Senecio diaschides / none
# 1 rows updated
# 11635: Senecio extensus / all
# 1 rows updated
# 7097: Senecio garlandii / none
# 1 rows updated
# 1659: Senecio georgianus / none
# 1 rows updated
# 1660: Senecio glomeratus / none
# 1 rows updated
# 1661: Senecio glossanthus / none
# 1 rows updated
# 1663: Senecio gunnii / most
# 1 rows updated
# 1664: Senecio hispidulus / none
# 1 rows updated
# 1664: Senecio hispidulus / few
# 1 rows updated
# 11636: Senecio lageniformis / all
# 1 rows updated
# 1666: Senecio lautus / none
# 1 rows updated
# 10172: Senecio leptocarpus / none
# 1 rows updated
# 1667: Senecio linearifolius / none
# 1 rows updated
# 11632: Senecio longipilus / all
# 1 rows updated
# 6465: Senecio madagascariensis / none
# 1 rows updated
# 1669: Senecio magnificus / none
# 1 rows updated
# 1671: Senecio minimus / few
# 1 rows updated
# 11033: Senecio pectinatus var. major / all
# 1 rows updated
# 11164: Senecio picridioides / half
# 1 rows updated
# 14039: Senecio pinnatifolius var. alpinus / all
# 1 rows updated
# 1674: Senecio platylepis / none
# 1 rows updated
# 10115: Senecio pterophorus / none
# 1 rows updated
# 1675: Senecio quadridentatus / none
# 1 rows updated
# 8589: Senecio tenuiflorus / none
# 1 rows updated
# 11237: Senecio vagus subsp. eglandulosus / none
# 1 rows updated
# 1680: Senecio velleioides / none
# 1 rows updated
# 1681: Senecio vulgaris / none
# 1 rows updated
# 8772: Senna acclinis / none
# 1 rows updated
# 14539: Senna artemisioides subsp. X artemisioides / all
# 1 rows updated
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /var/folders/14/vyrp_30975d7y17lqxjblf2c0000gn/T/ipykernel_37471/3033073936.py in <module>
#      30         if (isinstance(spcode, str) and spcode.isnumeric()) or isinstance(spcode,int):
#      31             cur = conn.cursor()
# ---> 32             cur.execute(qrystr % (spname,spcode,transvalue))
#      33             updated_rows = cur.rowcount
#      34             if updated_rows >0:
#
# SyntaxError: syntax error at or near "helmsii"
# LINE 1: ...ecies_code,resprouting) values('Senna form taxon 'helmsii'',...
#                                                              ^

# %%
int(spcode)
# Out:
# 6354

# %%
j=12
varname=ws.cell(row=2, column=j).value
print(varname)


switcher={
    "epicormic": "epicormic",
    "stem buds": "epicormic",
    "apical": "apical",
    "lignotuber": "lignotuber", 
    "rootstock": "lignotuber", 
    "root stock": "lignotuber",
    "basal": "basal",
    "basal buds": "basal",
    "coppice": "basal",
    "tuber": "tuber",
    "taproot": "tuber",
    "tussock": "tussock",
    "rhizome": "short rhizome",
    "root sucker": "long rhizome or root sucker",
    "root suckers": "long rhizome or root sucker",
    "rootsucker": "long rhizome or root sucker",
    "root buds": "long rhizome or root sucker",
    "stolon": "stolon",
    "stolons": "stolon"
}
# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,regenerative_organ) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET regenerative_organ=EXCLUDED.regenerative_organ"
updated_rows=0
for i in range(3,row_count):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "other")
        #if varref is not None:
        #    print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        #else:
        #    print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur = conn.cursor()
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = updated_rows + cur.rowcount
        #    print("%s rows updated" % (updated_rows))
            conn.commit()
            cur.close()
print("Total of %s rows updated" % (updated_rows))
        
if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Resprout location
# Connecting to the PostgreSQL database...
# Total of 1242 rows updated
# Database connection closed.

# %%
j=13
varname=ws.cell(row=2, column=j).value
print(varname)


switcher={
    "canopy":"canopy",
    "canopy - transient":"canopy",
    "persistent":"soil-persistent",
    "peristent":"soil-persistent",
    "persistent soil":"soil-persistent", 
    "a-persistent soil":"soil-persistent", 
    "soil":"soil-persistent",
    "transient":"transient", 
    "none":"transient",
    "shed at maturity":"transient", 
    "viviparous":"transient",
    "canopy / released at maturity":"transient",
    "canopy / regularly without fire":"transient",
    "not canopy":"non-canopy",
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,seedbank_type) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET seedbank_type=EXCLUDED.seedbank_type"
updated_rows = 0

for i in range(1300,2800):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "other")
        #if varref is not None:
        #    print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        #else:
        #    print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur = conn.cursor()
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = updated_rows + cur.rowcount
            conn.commit()
            cur.close()
print("Total of %s rows updated" % (updated_rows))


if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Seed storage
# Connecting to the PostgreSQL database...
# Total of 2660 rows updated
# Database connection closed.

# %%
j=22
varname=ws.cell(row=2, column=j).value
print(varname)

switcher={
    "prolific":"abundant",
    "abundant":"abundant",
    "common":"abundant",
    "high":"abundant",
    "substantial":"abundant",
    "vigourous":"abundant",
    "1-4 seedlings/m2":"abundant",
    "no":"absent",
    "none observed":"absent"
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,postfire_seedling_recruitment) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET postfire_seedling_recruitment=EXCLUDED.postfire_seedling_recruitment"
cur = conn.cursor()
updated_rows = 0
for i in range(3,3000):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "present")
        #if varref is not None:
        #    print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        #else:
        #    print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = updated_rows + cur.rowcount
            
conn.commit()
cur.close()            
print("Total of %s rows updated" % (updated_rows))

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Post-fire recruitment
# Connecting to the PostgreSQL database...
# Total of 590 rows updated
# Database connection closed.
