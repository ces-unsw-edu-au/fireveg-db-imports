# %% [markdown]
# # Read NSWFRD 2014
# Read the spreadsheet from NSW Flora Fire response database and extract hyperlinks that point to references.
# We will use the openpyxl library

# %%
import openpyxl
from pathlib import Path
import os

# %%
repodir = Path("../") 
inputdir = repodir / "data/"

# %% [markdown]
# ## Open the workbook and read main spreadsheet
# Here we will load the workbook:

# %%
wb = openpyxl.load_workbook(inputdir / "NSWFFRDv2.1.xlsx")

# %% [markdown]
# Use the sheet name to read data

# %%
ws = wb['SpeciesData']

# %% [markdown]
# Let's look at all the values in the second column (Species code)

# %%
ws['B2'].value
# Out:
# 'Species Code'

# %% [markdown]
# We want to count the number of unique values:

# %%
row_count = ws.max_row
column_count = ws.max_column
j=2
unique_list = list()
unique_items = 0
for i in range(1, row_count + 1):
    item = ws.cell(row=i, column=j).value
    if item not in unique_list and item is not None:
        unique_list.append(item)
        unique_items += 1
print(unique_items)
# Out:
# 3000

# %% [markdown]
# Which columns include information on traits? this will print out the names in the second row...:

# %%
for j in range(1, column_count + 1):
    print(ws.cell(row=2, column=j).value)
# Out:
# Current Scientific Name
# Species Code
# Legal Status
# Exotic
# 2010 Update
# Notes on Name / Synonym as used in source reference
# Family
# Group
# Life form
# Fireresponse
# Comments on regeneration
# Resprout location
# Seed storage
# Seed dispersal mechanism
# Seed dispersal distance
# Seed weight / size
# Seed viability
# Dormancy
# Germination cue
# Fecundity
# Seed predation
# Post-fire recruitment
# Establishment
# Post-fire flowering
# Flowering time
# Primary juvenile period
# Secondary juvenile period
# Seed set
# Seed-bank developed
# Fire tolerance
# Life span
# Seed-bank longevity
# "Maturity" (from source)
# "Extinction" (from source)
# "Rec. min fire interval" (from source)
# "Rec. max fire interval" (from source)
# NC
# CC
# SC
# NT
# CT
# ST
# NWS
# CWS
# SWS
# NWP
# SWP
# NFWP
# SFWP
# Distribution: extra NSW
# Vegetation
# Rainforest
# Wet Sclerophyll Forest (Shrubby)
# Wet Sclerophyll Forest (Grassy)
# Grassy Woodland
# Grassland
# Dry Sclerophyll Forest (Shrub/Grass)
# Dry Sclerophyll Forest (Shrubby)
# Heathland
# Alpine Complex
# Freshwater Wetland
# Forested Wetlands
# Saline Wetland
# Semi-arid Woodland
# Arid & Semi-arid Shrubland
# NFRR data
# Additional fire response data
# Other data
# VA group
# Sensitivity: frequent
# Sensitivity: infrequent
# Minimum maturity
# Maximum maturity
# Lifespan > than
# Lifespan < than
# Lifespan + seed-bank
# VA Data
# Establishment Data
# Maturity Data
# Lifespan Data
# Lifespan 2 Data
# Seedbank Data
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ## Dealing with hyperlinks
#
# The cell Q6 has a hyperlink. We can use cell rows and columns or cell name:

# %%
type(ws.cell(row=6, column=17).hyperlink)
# same as 
type(ws['Q6'].hyperlink)
# Out:
# openpyxl.worksheet.hyperlink.Hyperlink

# %% [markdown]
# If the cell is a hyperlink it will have a value to "display" and will point to a "location" within the workbook:

# %%
ws.cell(row=6, column=17).hyperlink.display
# Out:
# 'viability average-very good'

# %%
# This will fail if there is no hyperlink 
print(ws.cell(row=6, column=17).hyperlink.location)
# Out:
# References!C94

# %% [markdown]
# Let's see the value of this reference:

# %%
hlink = ws.cell(row=6, column=17).hyperlink.location
hlink = hlink.split("!")

# %% [markdown]
# This gives the name of the target sheet and the corresponding cell. We need to read the cell to its right side (add one to the column number) to get the information we need.

# %%
ref = wb[hlink[0]]
print("Cell value is :: " + str(ref[hlink[1]].value))
nlink = ref.cell(row=ref[hlink[1]].row,column=ref[hlink[1]].col_idx + 1)

print("Reference data is :: " + nlink.value)
# Out:
# Cell value is :: 93
# Reference data is :: Mortlock, W. & Lloyd, MV (Eds) (2001) Floradata - A guide to collection, storage and propogation of Australian native plant seed. AUsttralian Centre for Mining Environmental Research, Brisbane; Australian National Botanic Gardens, CSIRO Forestry and Forest Products and Greening Australia Limited, Canberra. Searchable Database February 2001. a=survey data, b=test data

# %% [markdown]
# If there is no hyperlink, it will result in NoneType

# %%
type(ws.cell(row=5, column=17).hyperlink)
# Out:
# NoneType

# %%
type(ws.cell(row=5, column=17))
# Out:
# openpyxl.cell.cell.Cell

# %%
ws.cell(row=5, column=17)
# Out:
# <Cell 'SpeciesData'.Q5>

# %% [markdown]
# ## Read data from a column
# For a selected variable (column), we can query data for the list of species.

# %%
ws['Q6']
# Out:
# <Cell 'SpeciesData'.Q6>

# %%
ws.cell(row=2, column=17).value
# Out:
# 'Seed viability'

# %%
ws.cell(row=6, column=17).value
# Out:
# 'average-very good'

# %% [markdown]
# Example loop for querying values from one variable for all species in a range of cells:

# %%
# for i in 3:3088
# for j in 17
i=3
j=17
varname=ws.cell(row=2, column=j).value
print(varname)
for i in range(13,40):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (spcode,spname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (spcode,spname,varvalue))
# Out:
# Seed viability
# 3710: Acacia baileyana / 0.96 / References!C94
# 3723: Acacia brownii / good / References!C94
# 3725: Acacia burbidgeae / 0.76 / References!C94
# 8242: Acacia burkittii / good
# 3727: Acacia buxifolia / good / References!C94
# 3743: Acacia colletioides / 0.837

# %% [markdown]
# ## Read data for a row
# We can now do the same for a single species (row) and query values of each variable in a range. For example:

# %%
# for j in 17
i=18
spname=ws.cell(row=i, column=1).value
spcode=ws.cell(row=i, column=2).value
print("%s: %s" %(spcode,spname))
    
for j in range(3,30):
    varname=ws.cell(row=2, column=j).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (j,varname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (j,varname,varvalue))
# Out:
# 3716: Acacia binervata
# 7: Family / Fabaceae: Mimosoideae
# 8: Group / D
# 9: Life form / T
# 10: Fireresponse / Sr
# 11: Comments on regeneration / Resprouting form in northern tablelands (134)
# 12: Resprout location / basal buds
# 13: Seed storage / persistent soil
# 14: Seed dispersal mechanism / a-ant / References!C56
# 18: Dormancy / hard seed coat
# 19: Germination cue / heat / References!C94
# 22: Post-fire recruitment / prolific / References!C106
# 23: Establishment / I / References!A94
# 25: Flowering time / Aug-Nov
# 26: Primary juvenile period / 5 / References!C36
# 27: Secondary juvenile period / References!C36 / References!C36
# 28: Seed set / 6 / References!C36
# 29: Seed-bank developed / 10 / References!C36

# %% [markdown]
# ## Search for a species code
# Here we try to locate the species code and then return the values for that row:

# %%
for cell in ws['A']:
    if(cell.value is not None): #We need to check that the cell is not empty.
        if 'Actinotus helianthi' in cell.value: #Check if the value of the cell contains the text 'Table'
            print('Found header with name: {} at row: {} and column: {}. In cell {}'.format(cell.value,cell.row,cell.column,cell))
# Out:
# Found header with name: Actinotus helianthi at row: 179 and column: 1. In cell <Cell 'SpeciesData'.A179>

# %%
# for j in 17
i=17
spname=ws.cell(row=i, column=1).value
spcode=ws.cell(row=i, column=2).value
print("%s: %s" %(spcode,spname))
    
for j in range(3,50):
    varname=ws.cell(row=2, column=j).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (j,varname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (j,varname,varvalue))
# Out:
# 3715: Acacia betchei
# 7: Family / Fabaceae: Mimosoideae
# 8: Group / D
# 9: Life form / S
# 10: Fireresponse / S
# 13: Seed storage / persistent soil
# 18: Dormancy / hard seed coat
# 19: Germination cue / scarification / References!C94
# 25: Flowering time / Nov-Feb
# 37: NC / -
# 38: CC / -
# 39: SC / -
# 40: NT / 1
# 41: CT / -
# 42: ST / -
# 43: NWS / 1
# 44: CWS / -
# 45: SWS / -
# 46: NWP / -
# 47: SWP / -
# 48: NFWP / -
# 49: SFWP / -

# %% [markdown]
# ## Populate the 'blue table'
# Select one column, translate the values to the accepted range and update entries into the table

# %%
from configparser import ConfigParser

filename = repodir / 'secrets' / 'database.ini'
section = 'aws-lght-sl'

# create a parser
parser = ConfigParser()
# read config file
parser.read(filename)

# get section, default to postgresql
db = {}
if parser.has_section(section):
    params = parser.items(section)
    for param in params:
        db[param[0]] = param[1]
else:
    raise Exception('Section {0} not found in the {1} file'.format(section, filename))

# %%
import psycopg2
params = db

# %%
# for i in 3:3088
# for j in 10
i=3
j=10
varname=ws.cell(row=2, column=j).value
print(varname)

switcher={
    "S": "none",
    "Sr": "few",
    "S/R": "half",
    "Rs": "most",
    "R": "all"
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)


qrystr= "INSERT INTO litrev.traits(species,species_code,resprouting) values('%s',%s,'%s') ON CONFLICT (species,species_code) DO UPDATE SET resprouting=EXCLUDED.resprouting"
for i in range(15,2000):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "unknown")
        if varref is not None:
            print("%s: %s / %s / %s" % (spcode,spname,transvalue, varref.location))
        else:
            print("%s: %s / %s " % (spcode,spname,transvalue))
            if (isinstance(spcode, str) and spcode.isnumeric()) or isinstance(spcode,int):
                cur = conn.cursor()
                cur.execute(qrystr % (spname,spcode,transvalue))
                updated_rows = cur.rowcount
                print("%s rows updated" % (updated_rows))
                conn.commit()
                cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Fireresponse
# Connecting to the PostgreSQL database...
# 7060: Acacia baueri subsp. baueri / none
# 1 rows updated
# 11039: Acacia beadleana / all
# 1 rows updated
# 3715: Acacia betchei / none
# 1 rows updated
# 3716: Acacia binervata / few
# 1 rows updated
# 3717: Acacia binervia / none
# 1 rows updated
# 10788: Acacia blakei subsp. diphylla / none
# 1 rows updated
# 10788: Acacia blakei subsp. diphylla / none
# 1 rows updated
# 8381: Acacia blayana / none
# 1 rows updated
# 3723: Acacia brownii / most
# 1 rows updated
# 6498: Acacia brunioides subsp. brunioides / none
# 1 rows updated
# 8601: Acacia bulgaensis / none
# 1 rows updated
# 3725: Acacia burbidgeae / none
# 1 rows updated
# 8242: Acacia burkittii / all
# 1 rows updated
# 3727: Acacia buxifolia / most
# 1 rows updated
# 9282: Acacia buxifolia subsp. pubiflora / all
# 1 rows updated
# 3730: Acacia calamifolia / none
# 1 rows updated
# 7524: Acacia calcicola / none
# 1 rows updated
# n/a: Acacia capitata / none
# 3738: Acacia cheelii / none
# 1 rows updated
# 3739: Acacia chrysotricha / none
# 1 rows updated
# 3742: Acacia cognata / all
# 1 rows updated
# 3743: Acacia colletioides / none
# 1 rows updated
# 3747: Acacia constablei / none
# 1 rows updated
# 3750: Acacia costiniana / none
# 1 rows updated
# 555: Acacia courtii / none
# 1 rows updated
# 3752: Acacia cowleana / none
# 1 rows updated
# 3755: Acacia curranii / all
# 1 rows updated
# 3756: Acacia dallachiana / none
# 1 rows updated
# 3757: Acacia dawsonii / none
# 1 rows updated
# 3758: Acacia dealbata / few
# 1 rows updated
# 8269: Acacia deanei subsp. deanei / none
# 1 rows updated
# 7482: Acacia deanei subsp. paucijuga / none
# 1 rows updated
# 3761: Acacia decora / none
# 1 rows updated
# 3762: Acacia decurrens / none
# 1 rows updated
# 3763: Acacia difformis / none
# 1 rows updated
# 3767: Acacia echinula / none
# 1 rows updated
# 3768: Acacia elata / none
# 1 rows updated
# 3769: Acacia elongata / few
# 1 rows updated
# 3771: Acacia falcata / none
# 1 rows updated
# 3772: Acacia falciformis / most
# 1 rows updated
# 3773: Acacia filicifolia / few
# 1 rows updated
# 3774: Acacia fimbriata / none
# 1 rows updated
# 3777: Acacia floribunda / half
# 1 rows updated
# 3780: Acacia fulva / none
# 1 rows updated
# 3781: Acacia genistifolia / none
# 1 rows updated
# 3782: Acacia georgensis / none
# 1 rows updated
# 7229: Acacia gordonii / all
# 1 rows updated
# 3784: Acacia granitica / none
# 1 rows updated
# 3785: Acacia gunnii / few
# 1 rows updated
# 3786: Acacia hakeoides / all
# 1 rows updated
# 3788: Acacia harpophylla / all
# 1 rows updated
# 8929: Acacia havilandiorum / none
# 1 rows updated
# 3790: Acacia hispidula / none
# 1 rows updated
# 3791: Acacia homalophylla / none
# 1 rows updated
# 3792: Acacia implexa / few
# 1 rows updated
# 3793: Acacia ingramii / none
# 1 rows updated
# 6472: Acacia irrorata subsp. irrorata / few
# 1 rows updated
# 7109: Acacia irrorata subsp. velutinella / all
# 1 rows updated
# 3797: Acacia jennerae / all
# 1 rows updated
# 3799: Acacia jonesii / none
# 1 rows updated
# 3802: Acacia juncifolia / all
# 1 rows updated
# 9983: Acacia kulnurensis / none
# 1 rows updated
# 3806: Acacia lanigera / none
# 1 rows updated
# 3807: Acacia latisepala / none
# 1 rows updated
# 6597: Acacia leiocalyx subsp. leiocalyx / all
# 1 rows updated
# 3810: Acacia leptoclada / all
# 1 rows updated
# 8603: Acacia ligulata / most
# 1 rows updated
# 3813: Acacia lineata / none
# 1 rows updated
# 3814: Acacia linifolia / none
# 1 rows updated
# 3815: Acacia loderi / all
# 1 rows updated
# 10790: Acacia longifolia subsp. longifolia / few
# 1 rows updated
# 10791: Acacia longifolia subsp. sophorae / few
# 1 rows updated
# 3817: Acacia longissima / none
# 1 rows updated
# 3818: Acacia lucasii / none
# 1 rows updated
# 6748: Acacia lunata / none
# 1 rows updated
# 3820: Acacia macnuttiana / none
# 1 rows updated
# 3821: Acacia maidenii / none
# 1 rows updated
# 3822: Acacia maitlandii / all
# 1 rows updated
# 8972: Acacia matthewii / all
# 1 rows updated
# 3823: Acacia mearnsii / few
# 1 rows updated
# 8973: Acacia meiantha / all
# 1 rows updated
# 3824: Acacia melanoxylon / most
# 1 rows updated
# 3825: Acacia melvillei / all
# 1 rows updated
# 3827: Acacia mitchellii / none
# 1 rows updated
# 10058: Acacia mucronata subsp. longifolia / most
# 1 rows updated
# 3832: Acacia murrayana / all
# 1 rows updated
# 3834: Acacia myrtifolia / few
# 1 rows updated
# 3835: Acacia neriifolia / all
# 1 rows updated
# 3836: Acacia notabilis / none
# 1 rows updated
# 11005: Acacia nova-anglica ms / all
# 1 rows updated
# 3837: Acacia obliquinervia / none
# 1 rows updated
# 3839: Acacia obtusifolia / few
# 1 rows updated
# 3843: Acacia oswaldii / all
# 1 rows updated
# 3844: Acacia oxycedrus / few
# 1 rows updated
# 3845: Acacia paradoxa / none
# 1 rows updated
# 3846: Acacia parramattensis / none
# 1 rows updated
# 3847: Acacia parvipinnula / none
# 1 rows updated
# 3848: Acacia pendula / all
# 1 rows updated
# 10922: Acacia penninervis var. penninervis / none
# 1 rows updated
# 3851: Acacia phasmoides / none
# 1 rows updated
# 3853: Acacia podalyriifolia / none
# 1 rows updated
# 3857: Acacia prominens / none
# 1 rows updated
# 3858: Acacia pruinosa / all
# 1 rows updated
# 3858: Acacia pruinosa / all
# 1 rows updated
# 3860: Acacia pubescens / most
# 1 rows updated
# 9405: Acacia pubifolia / none
# 1 rows updated
# 3861: Acacia pycnantha / none
# 1 rows updated
# 3862: Acacia pycnostachya / few
# 1 rows updated
# 3863: Acacia quadrilateralis / all
# 1 rows updated
# 12042: Acacia ramulosa var. ramulosa / most
# 1 rows updated
# 3869: Acacia rubida / few
# 1 rows updated
# 3871: Acacia saliciformis / none
# 1 rows updated
# 3872: Acacia salicina / none
# 1 rows updated
# 3873: Acacia saligna / half
# 1 rows updated
# 3874: Acacia schinoides / none
# 1 rows updated
# 12441: Acacia serpentinicola / all
# 1 rows updated
# 12072: Acacia sibirica / none
# 1 rows updated
# 3880: Acacia stricta / none
# 1 rows updated
# 3881: Acacia suaveolens / few
# 1 rows updated
# 3882: Acacia subporosa / none
# 1 rows updated
# 3883: Acacia subtilinervis / none
# 1 rows updated
# 3885: Acacia terminalis / few
# 1 rows updated
# n/a: Acacia terminalis s. lat. (winged form) / none
# 3886: Acacia tetragonophylla / half
# 1 rows updated
# 3888: Acacia torringtonensis / none
# 1 rows updated
# 3890: Acacia trinervata / none
# 1 rows updated
# 3892: Acacia triptera / none
# 1 rows updated
# 3893: Acacia ulicifolia / few
# 1 rows updated
# 3894: Acacia uncinata / none
# 1 rows updated
# 8865: Acacia venulosa / half
# 1 rows updated
# 3895: Acacia verniciflua / none
# 1 rows updated
# 11245: Acacia verticillata subsp. verticillata / all
# 1 rows updated
# 11245: Acacia verticillata subsp. verticillata / few
# 1 rows updated
# 3898: Acacia victoriae / most
# 1 rows updated
# 3899: Acacia viscidula / few
# 1 rows updated
# 3900: Acacia wilhelmiana / none
# 1 rows updated
# 10796: Acacia williamsiana / unknown
# 1 rows updated
# 5603: Acaena echinata / all
# 1 rows updated
# 5604: Acaena novae-zelandiae / half
# 1 rows updated
# 5605: Acaena ovina / all
# 1 rows updated
# 2674: Acalypha nemorum / none
# 1 rows updated
# 5263: Acetosa sagittata / all
# 1 rows updated
# 5265: Acetosella vulgaris / half
# 1 rows updated
# 4351: Acianthus caudatus / all
# 1 rows updated
# 4352: Acianthus exsertus / all
# 1 rows updated
# 4353: Acianthus fornicatus / all
# 1 rows updated
# 9088: Acianthus pusillus / all
# 1 rows updated
# 1090: Aciphylla glacialis / all
# 1 rows updated
# 1091: Aciphylla simplicifolia / all
# 1 rows updated
# 3968: Acmena smithii / all
# 1 rows updated
# 5719: Acradenia euodiiformis / all
# 1 rows updated
# 8418: Acronychia imperforata / all
# 1 rows updated
# 5722: Acronychia oblongifolia / few
# 1 rows updated
# 2265: Acrophyllum australe / all
# 1 rows updated
# 11966: Acrothamnus hookeri / few
# 1 rows updated
# 12059: Acrothamnus montanus / half
# 1 rows updated
# 2580: Acrotriche aggregata / all
# 1 rows updated
# 2581: Acrotriche divaricata / none
# 1 rows updated
# 8231: Acrotriche leucocarpa / none
# 1 rows updated
# 2583: Acrotriche serrulata / all
# 1 rows updated
# 2675: Actephila lindleyi / none
# 1 rows updated
# 1253: Actinobole uliginosum / none
# 1 rows updated
# 1092: Actinotus forsythii / none
# 1 rows updated
# 1093: Actinotus gibbonsii / none
# 1 rows updated
# 1094: Actinotus helianthi / none
# 1 rows updated
# 1095: Actinotus minor / few
# 1 rows updated
# 7997: Adiantum aethiopicum / all
# 1 rows updated
# 7998: Adiantum diaphanum / none
# 1 rows updated
# 8000: Adiantum hispidulum / all
# 1 rows updated
# 2525: Adrastaea salicifolia / all
# 1 rows updated
# 10564: Adriana tomentosa var. tomentosa / none
# 1 rows updated
# 7459: Aegiceras corniculatum / most
# 1 rows updated
# 1255: Ageratina adenophora / all
# 1 rows updated
# 1256: Ageratina riparia / all
# 1 rows updated
# 12005: Agiortia cicatricata / none
# 1 rows updated
# 12011: Agiortia pedicellata / all
# 1 rows updated
# 4726: Agrostis parviflora / none
# 1 rows updated
# 4729: Agrostis venusta / half
# 1 rows updated
# 4730: Aira caryophyllea / none
# 1 rows updated
# 4731: Aira cupaniana / none
# 1 rows updated
# 6547: Aira elegantissima / none
# 1 rows updated
# 3371: Ajuga australis / half
# 1 rows updated
# 8669: Alchornea ilicifolia / all
# 1 rows updated
# 5872: Alectryon coriaceus / all
# 1 rows updated
# 6639: Alectryon oleifolius subsp. canescens / all
# 1 rows updated
# 5875: Alectryon subcinereus / few
# 1 rows updated
# 8979: Alexfloydia repens / all
# 1 rows updated
# 13923: Allittia cardiocarpa / none
# 1 rows updated
# 9090: Allocasuarina brachystachya / few
# 1 rows updated
# 8980: Allocasuarina defungens / all
# 1 rows updated
# 9710: Allocasuarina diminuta subsp. annectens / all
# 1 rows updated
# 2010: Allocasuarina distyla / few
# 1 rows updated
# 8320: Allocasuarina glareicola / all
# 1 rows updated
# 2011: Allocasuarina inophloia / all
# 1 rows updated
# 2012: Allocasuarina littoralis / most
# 1 rows updated
# 2013: Allocasuarina luehmannii / none
# 1 rows updated
# 2014: Allocasuarina nana / all
# 1 rows updated
# 2015: Allocasuarina paludosa / all
# 1 rows updated
# 8791: Allocasuarina rigida subsp. rigida / none
# 1 rows updated
# 9011: Allocasuarina simulans / all
# 1 rows updated
# 2017: Allocasuarina torulosa / all
# 1 rows updated
# 2018: Allocasuarina verticillata / most
# 1 rows updated
# 7289: Alloteropsis semialata / all
# 1 rows updated
# 8368: Almaleea cambagei / all
# 1 rows updated
# 8367: Almaleea capitata / none
# 1 rows updated
# 8365: Almaleea incurvata / none
# 1 rows updated
# 8364: Almaleea paludosa / none
# 1 rows updated
# 8366: Almaleea subumbellata / none
# 1 rows updated
# 7686: Alphitonia excelsa / all
# 1 rows updated
# 5553: Alphitonia petriei / none
# 1 rows updated
# 6913: Alpinia arundelliana / all
# 1 rows updated
# 6340: Alpinia caerulea / all
# 1 rows updated
# 1775: Alyssum linifolium / none
# 1 rows updated
# 1165: Alyxia buxifolia / all
# 1 rows updated
# 1167: Alyxia ruscifolia / few
# 1 rows updated
# 1259: Ambrosia artemisiifolia / all
# 1 rows updated
# 1261: Ambrosia psilostachya / all
# 1 rows updated
# 1263: Ammobium alatum / none
# 1 rows updated
# 4738: Ammophila arenaria / all
# 1 rows updated
# 9713: Amperea xiphoclada var. xiphoclada / all
# 1 rows updated
# 6842: Amphibromus nervosus / all
# 1 rows updated
# 7539: Amphipogon caricinus var. caricinus / all
# 1 rows updated
# 7650: Amphipogon strictus var. strictus / all
# 1 rows updated
# 6856: Amyema congener subsp. congener / none
# 1 rows updated
# 7497: Amyema linophyllum subsp. orientale / none
# 1 rows updated
# 6394: Amyema miquelii / few
# 1 rows updated
# 7308: Amyema pendulum subsp. pendulum / none
# 1 rows updated
# 5334: Anagallis arvensis / none
# 1 rows updated
# 4748: Andropogon virginicus / all
# 1 rows updated
# 10999: Anetholea anisata / none
# 1 rows updated
# 1268: Angianthus tomentosus / none
# 1 rows updated
# 3969: Angophora bakeri / all
# 1 rows updated
# 3970: Angophora costata / all
# 1 rows updated
# 9012: Angophora crassifolia / all
# 1 rows updated
# 9717: Angophora euryphylla / all
# 1 rows updated
# 3971: Angophora floribunda / all
# 1 rows updated
# 3972: Angophora hispida / all
# 1 rows updated
# 9619: Angophora inopina / all
# 1 rows updated
# 3974: Angophora subvelutina / all
# 1 rows updated
# 4749: Anisopogon avenaceus / all
# 1 rows updated
# 3221: Anopterus macleayanus / few
# 1 rows updated
# 1733: Anredera cordifolia / all
# 1 rows updated
# 1269: Anthemis arvensis / none
# 1 rows updated
# 4750: Anthoxanthum odoratum / most
# 1 rows updated
# 2770: Aotus ericoides / most
# 1 rows updated
# 2771: Aotus lanigera / none
# 1 rows updated
# 11046: Aotus subglauca var. subglauca / all
# 1 rows updated
# 6955: Aotus subspinescens / all
# 1 rows updated
# 8221: Apalochlamys spectabilis / none
# 1 rows updated
# 2025: Apatophyllum constablei / none
# 1 rows updated
# 5609: Aphanes australiana / none
# 1 rows updated
# 2266: Aphanopetalum resinosum / none
# 1 rows updated
# 2037: Aphelia gracilis / none
# 1 rows updated
# 11824: Apium prostratum var. prostratum / none
# 1 rows updated
# 11047: Araujia sericifera / none
# 1 rows updated
# 3976: Archirhodomyrtus beckleri / all
# 1 rows updated
# 6458: Archontophoenix cunninghamiana / none
# 1 rows updated
# 1273: Arctotheca calendula / none
# 1 rows updated
# 9721: Argentipallium obtusifolium / none
# 1 rows updated
# 12689: Argyrotegium fordianum / all
# 1 rows updated
# 12690: Argyrotegium mackayi / none
# 1 rows updated
# 13926: Argyrotegium poliochlorum / none
# 1 rows updated
# 9722: Aristea ecklonii / all
# 1 rows updated
# 4755: Aristida benthamii / all
# 1 rows updated
# 9334: Aristida calycina var. calycina / all
# 1 rows updated
# 7537: Aristida holathera var. holathera / all
# 1 rows updated
# 6439: Aristida jerichoensis var. jerichoensis / all
# 1 rows updated
# 6933: Aristida jerichoensis var. subspinulifera / all
# 1 rows updated
# 4770: Aristida ramosa / all
# 1 rows updated
# 4773: Aristida vagans / all
# 1 rows updated
# 4774: Aristida warburgii / all
# 1 rows updated
# 2567: Aristotelia australasica / all
# 1 rows updated
# 1276: Arrhenechthites mixta / none
# 1 rows updated
# 5943: Artanema fimbriatum / none
# 1 rows updated
# 3517: Arthropodium milleflorum / all
# 1 rows updated
# 3518: Arthropodium minus / all
# 1 rows updated
# 9097: Arthropodium sp. B / all
# 1 rows updated
# 4777: Arundo donax / all
# 1 rows updated
# 11784: Asparagus aethiopicus / all
# 1 rows updated
# 3519: Asparagus asparagoides / all
# 1 rows updated
# 3522: Asparagus scandens / all
# 1 rows updated
# 5653: Asperula conferta / all
# 1 rows updated
# 5657: Asperula gunnii / half
# 1 rows updated
# 5658: Asperula pusilla / none
# 1 rows updated
# 5659: Asperula scoparia / most
# 1 rows updated
# 3524: Asphodelus fistulosus / all
# 1 rows updated
# 8031: Asplenium australasicum / none
# 1 rows updated
# 8866: Asplenium bulbiferum subsp. gracillimum / none
# 1 rows updated
# 8033: Asplenium flabellifolium / all
# 1 rows updated
# 8037: Asplenium polyodon / none
# 1 rows updated
# 9259: Asplenium trichomanes / none
# 1 rows updated
# 7534: Astelia alpina var. novae-hollandiae / all
# 1 rows updated
# 3526: Astelia psychrocharis / all
# 1 rows updated
# 1280: Aster subulatus / none
# 1 rows updated
# 12190: Asterolasia asteriscophora subsp. asteriscophora / none
# 1 rows updated
# 5728: Asterolasia correifolia / none
# 1 rows updated
# 8851: Asterolasia elegans / none
# 1 rows updated
# 5730: Asterolasia trymalioides / none
# 1 rows updated
# 2584: Astroloma humifusum / all
# 1 rows updated
# 2585: Astroloma pinifolium / none
# 1 rows updated
# 1200: Astrotricha crassifolia / all
# 1 rows updated
# 1202: Astrotricha latifolia / none
# 1 rows updated
# 1203: Astrotricha ledifolia / all
# 1 rows updated
# 1204: Astrotricha linearis / none
# 1 rows updated
# 1205: Astrotricha longifolia / all
# 1 rows updated
# 9015: Astrotricha roddii / all
# 1 rows updated
# 6365: Atalaya hemiglauca / all
# 1 rows updated
# 3910: Atherosperma moschatum / most
# 1 rows updated
# 3611: Atkinsonia ligustrina / all
# 1 rows updated
# 2050: Atriplex elachophylla / all
# 1 rows updated
# 2070: Atriplex semibaccata / none
# 1 rows updated
# 2073: Atriplex stipitata / none
# 1 rows updated
# 2078: Atriplex vesicaria / none
# 1 rows updated
# 7710: Australopyrum pectinatum / none
# 1 rows updated
# 7840: Australopyrum velutinum / all
# 1 rows updated
# 8667: Austrocynoglossum latifolium / none
# 1 rows updated
# 6594: Austrofestuca littoralis / all
# 1 rows updated
# 3979: Austromyrtus dulcis / none
# 1 rows updated
# 3982: Austromyrtus tenuifolia / all
# 1 rows updated
# 10386: Austrostipa bigeniculata / all
# 1 rows updated
# 10367: Austrostipa elegantissima / half
# 1 rows updated
# 10385: Austrostipa gibbosa / all
# 1 rows updated
# 10393: Austrostipa mollis / most
# 1 rows updated
# 10375: Austrostipa nitida / most
# 1 rows updated
# 9960: Austrostipa nivicola / half
# 1 rows updated
# 9603: Austrostipa pubescens / all
# 1 rows updated
# 10400: Austrostipa pubinodis / all
# 1 rows updated
# 10396: Austrostipa rudis / all
# 1 rows updated
# 10398: Austrostipa rudis subsp. nervosa / all
# 1 rows updated
# 10394: Austrostipa semibarbata / all
# 1 rows updated
# 10382: Austrostipa setacea / all
# 1 rows updated
# 10368: Austrostipa tuckeri / all
# 1 rows updated
# 4780: Avena fatua / none
# 1 rows updated
# 10427: Avicennia marina subsp. australasica / half
# 1 rows updated
# 9817: Babingtonia odontocalyx / none
# 1 rows updated
# 3984: Backhousia myrtifolia / all
# 1 rows updated
# 3986: Baeckea brevifolia / few
# 1 rows updated
# 3989: Baeckea crassifolia / none
# 1 rows updated
# 3993: Baeckea diosmifolia / all
# 1 rows updated
# 9835: Baeckea frutescens / all
# 1 rows updated
# 3994: Baeckea gunniana / all
# 1 rows updated
# 3995: Baeckea imbricata / all
# 1 rows updated
# 3995: Baeckea imbricata / none
# 1 rows updated
# 3997: Baeckea linifolia / all
# 1 rows updated
# 9836: Baeckea omissa / all
# 1 rows updated
# 4000: Baeckea utilis / all
# 1 rows updated
# 8400: Baloghia inophylla / all
# 1 rows updated
# 8325: Baloghia marmorata / none
# 1 rows updated
# 10605: Baloskion australe / all
# 1 rows updated
# 10606: Baloskion fimbriatum / all
# 1 rows updated
# 10607: Baloskion gracile / half
# 1 rows updated
# 10608: Baloskion longipes / all
# 1 rows updated
# 10609: Baloskion pallens / all
# 1 rows updated
# 10610: Baloskion stenocoleum / all
# 1 rows updated
# 10611: Baloskion tenuiculme / none
# 1 rows updated
# 10614: Baloskion tetraphyllum subsp. meiostachyum / all
# 1 rows updated
# 10614: Baloskion tetraphyllum subsp. meiostachyum / none
# 1 rows updated
# 10613: Baloskion tetraphyllum subsp. tetraphyllum / all
# 1 rows updated
# 10613: Baloskion tetraphyllum subsp. tetraphyllum / none
# 1 rows updated
# 5339: Banksia aemula / all
# 1 rows updated
# 5340: Banksia canei / none
# 1 rows updated
# 7509: Banksia collina / all
# 1 rows updated
# 8595: Banksia cunninghamii / none
# 1 rows updated
# 11049: Banksia ericifolia subsp. ericifolia / none
# 1 rows updated
# 11050: Banksia ericifolia subsp. macrantha / none
# 1 rows updated
# 5343: Banksia integrifolia / all
# 1 rows updated
# 6603: Banksia integrifolia subsp. integrifolia / few
# 1 rows updated
# 10817: Banksia integrifolia subsp. monticola / few
# 1 rows updated
# 5344: Banksia marginata / all
# 1 rows updated
# 5344: Banksia marginata / none
# 1 rows updated
# 14554: Banksia neoanglica / all
# 1 rows updated
# 14554: Banksia neoanglica / all
# 1 rows updated
# 5345: Banksia oblongifolia / all
# 1 rows updated
# 5346: Banksia paludosa / all
# 1 rows updated
# 10873: Banksia paludosa subsp. astrolux / none
# 1 rows updated
# 10874: Banksia paludosa subsp. paludosa / all
# 1 rows updated
# 10872: Banksia penicillata / none
# 1 rows updated
# 5347: Banksia robur / all
# 1 rows updated
# 5348: Banksia serrata / all
# 1 rows updated
# 5349: Banksia spinulosa / all
# 1 rows updated
# 7509: Banksia spinulosa var. collina / all
# 1 rows updated
# 7488: Banksia spinulosa var. spinulosa / all
# 1 rows updated
# 7495: Barbarea grayi / none
# 1 rows updated
# 9188: Bartsia trixago / none
# 1 rows updated
# 2267: Bauera capitata / all
# 1 rows updated
# 7219: Bauera microphylla / all
# 1 rows updated
# 2268: Bauera rubioides / most
# 1 rows updated
# 2268: Bauera rubioides / half
# 1 rows updated
# 2294: Baumea acuta / all
# 1 rows updated
# 2296: Baumea articulata / all
# 1 rows updated
# 2297: Baumea gunnii / all
# 1 rows updated
# 2299: Baumea juncea / all
# 1 rows updated
# 2300: Baumea muelleri / all
# 1 rows updated
# 2301: Baumea nuda / all
# 1 rows updated
# 2302: Baumea rubiginosa / all
# 1 rows updated
# 2303: Baumea teretifolia / all
# 1 rows updated
# 2304: Baumea tetragona / all
# 1 rows updated
# 1282: Bedfordia arborescens / all
# 1 rows updated
# 8440: Berberidopsis beckleri  / none
# 1 rows updated
# 7159: Bertya brownii / none
# 1 rows updated
# 2681: Bertya cunninghamii / none
# 1 rows updated
# 2682: Bertya findlayi / none
# 1 rows updated
# 2691: Beyeria lasiocarpa / none
# 1 rows updated
# 11051: Beyeria leschenaultii / none
# 1 rows updated
# 2693: Beyeria opaca / none
# 1 rows updated
# 2694: Beyeria viscosa / none
# 1 rows updated
# 1283: Bidens pilosa / none
# 1 rows updated
# 1284: Bidens subalternans / none
# 1 rows updated
# 1285: Bidens tripartita / none
# 1 rows updated
# 12236: Billardiera heterophylla / all
# 1 rows updated
# 12235: Billardiera macrantha / all
# 1 rows updated
# 4671: Billardiera scandens / all
# 1 rows updated
# 4671: Billardiera scandens / half
# 1 rows updated
# 3527: Blandfordia cunninghamii / all
# 1 rows updated
# 3528: Blandfordia grandiflora / all
# 1 rows updated
# 3529: Blandfordia nobilis / all
# 1 rows updated
# 8050: Blechnum ambiguum / all
# 1 rows updated
# 8051: Blechnum camfieldii / all
# 1 rows updated
# 8052: Blechnum cartilagineum / all
# 1 rows updated
# 8057: Blechnum indicum / all
# 1 rows updated
# 7760: Blechnum minus / all
# 1 rows updated
# 8058: Blechnum nudum / all
# 1 rows updated
# 8063: Blechnum wattsii / all
# 1 rows updated
# 5732: Boronia algida / few
# 1 rows updated
# 5733: Boronia anemonifolia / none
# 1 rows updated
# 12257: Boronia anemonifolia subsp. anemonifolia / all
# 1 rows updated
# 11607: Boronia anemonifolia subsp. variabilis / none
# 1 rows updated
# 5734: Boronia anethifolia / none
# 1 rows updated
# 10750: Boronia angustisepala / none
# 1 rows updated
# 5735: Boronia barkeriana / all
# 1 rows updated
# 5736: Boronia bipinnata / none
# 1 rows updated
# 10751: Boronia boliviensis / none
# 1 rows updated
# 9098: Boronia chartacea / none
# 1 rows updated
# 10752: Boronia coerulescens subsp. coerulescens / most
# 1 rows updated
# 5739: Boronia falcifolia / all
# 1 rows updated
# 5740: Boronia floribunda / all
# 1 rows updated
# 5741: Boronia fraseri / none
# 1 rows updated
# 5743: Boronia granitica / none
# 1 rows updated
# 5744: Boronia ledifolia / few
# 1 rows updated
# 5745: Boronia microphylla / all
# 1 rows updated
# 5746: Boronia mollis / none
# 1 rows updated
# 5747: Boronia muelleri / all
# 1 rows updated
# 7942: Boronia nana var. hyssopifolia / none
# 1 rows updated
# 5749: Boronia parviflora / most
# 1 rows updated
# 5750: Boronia pinnata / half
# 1 rows updated
# 5751: Boronia polygalifolia / most
# 1 rows updated
# 5755: Boronia rosmarinifolia / all
# 1 rows updated
# 5757: Boronia ruppii / none
# 1 rows updated
# 5758: Boronia safrolifera / all
# 1 rows updated
# 5759: Boronia serrulata / none
# 1 rows updated
# n/a: Boronia sp. aff. microphylla / all
# 7210: Boronia thujona / none
# 1 rows updated
# 9099: Boronia umbellata / none
# 1 rows updated
# 2777: Bossiaea cinerea / all
# 1 rows updated
# 2778: Bossiaea ensata / most
# 1 rows updated
# 2779: Bossiaea foliosa / half
# 1 rows updated
# 2780: Bossiaea heterophylla / most
# 1 rows updated
# 2780: Bossiaea heterophylla / none
# 1 rows updated
# 2781: Bossiaea kiamensis / all
# 1 rows updated
# 2783: Bossiaea neo-anglica / all
# 1 rows updated
# 2784: Bossiaea obcordata / most
# 1 rows updated
# 2786: Bossiaea prostrata / all
# 1 rows updated
# 2787: Bossiaea rhombifolia / half
# 1 rows updated
# 2788: Bossiaea riparia / half
# 1 rows updated
# 2789: Bossiaea scolopendria / most
# 1 rows updated
# 2790: Bossiaea scortechinii / all
# 1 rows updated
# 2791: Bossiaea stephensonii / half
# 1 rows updated
# 2792: Bossiaea walkeri / half
# 1 rows updated
# 4790: Bothriochloa macra / all
# 1 rows updated
# 8144: Botrychium australe / all
# 1 rows updated
# 8145: Botrychium lunaria / none
# 1 rows updated
# 8961: Brachychiton populneus subsp. populneus / all
# 1 rows updated
# 10689: Brachyloma daphnoides subsp. daphnoides / most
# 1 rows updated
# 10690: Brachyloma daphnoides subsp. glabrum / all
# 1 rows updated
# 9295: Brachyloma saxicola / few
# 1 rows updated
# 2587: Brachyloma scortechinii / none
# 1 rows updated
# 7218: Brachyscome aculeata / none
# 1 rows updated
# 7700: Brachyscome angustifolia var. heterophylla / none
# 1 rows updated
# 6914: Brachyscome debilis / none
# 1 rows updated
# 6485: Brachyscome decipiens / few
# 1 rows updated
# 11056: Brachyscome dentata / all
# 1 rows updated
# 11056: Brachyscome dentata / all
# 1 rows updated
# 7562: Brachyscome goniocarpa / none
# 1 rows updated
# 6542: Brachyscome gracilis / none
# 1 rows updated
# 13832: Brachyscome linearifolia / all
# 1 rows updated
# 6861: Brachyscome lineariloba / none
# 1 rows updated
# 7317: Brachyscome multifida / all
# 1 rows updated
# 7264: Brachyscome obovata / all
# 1 rows updated
# 10409: Brachyscome perpusilla var. tenella / none
# 1 rows updated
# 6567: Brachyscome ptychocarpa / none
# 1 rows updated
# 10411: Brachyscome radicans / all
# 1 rows updated
# 6559: Brachyscome rigidula / all
# 1 rows updated
# 7318: Brachyscome scapigera / all
# 1 rows updated
# 7357: Brachyscome spathulata / all
# 1 rows updated
# 7266: Brachyscome tenuiscapa / none
# 1 rows updated
# 7538: Brachyscome tenuiscapa var. pubescens / none
# 1 rows updated
# 1786: Brassica fruticulosa / none
# 1 rows updated
# 1790: Brassica tournefortii / none
# 1 rows updated
# 2695: Breynia oblongifolia / most
# 1 rows updated
# 4800: Briza maxima / none
# 1 rows updated
# 4801: Briza minor / none
# 1 rows updated
# 4804: Bromus arenarius / none
# 1 rows updated
# 4806: Bromus diandrus / none
# 1 rows updated
# 4807: Bromus hordeaceus / none
# 1 rows updated
# 4813: Bromus rubens / none
# 1 rows updated
# 4817: Bromus sterilis / none
# 1 rows updated
# 1863: Brunonia australis / all
# 1 rows updated
# 1003: Brunoniella australis / all
# 1 rows updated
# 1004: Brunoniella pumilio / all
# 1 rows updated
# 9191: Buddleja madagascariensis / all
# 1 rows updated
# 3531: Bulbine bulbosa / all
# 1 rows updated
# 6848: Bulbine glauca / all
# 1 rows updated
# 3532: Bulbine semibarbata / none
# 1 rows updated
# 4364: Bulbophyllum globuliforme / none
# 1 rows updated
# 7748: Bulbostylis barbata / none
# 1 rows updated
# 3533: Burchardia umbellata / all
# 1 rows updated
# 4368: Burnettia cuneata / all
# 1 rows updated
# 4674: Bursaria spinosa / all
# 1 rows updated
# 11018: Bursaria spinosa subsp. spinosa / all
# 1 rows updated
# 6161: Cadellia pentastylis / all
# 1 rows updated
# 3534: Caesia alpina / all
# 1 rows updated
# 6896: Caesia calliantha / most
# 1 rows updated
# 3535: Caesia parviflora / all
# 1 rows updated
# 7183: Caesia parviflora var. parviflora / all
# 1 rows updated
# 7333: Caesia parviflora var. vittata / all
# 1 rows updated
# 1791: Cakile edentula / none
# 1 rows updated
# 6838: Caladenia alata / all
# 1 rows updated
# 10712: Caladenia alpina / all
# 1 rows updated
# 11246: Caladenia capillata / all
# 1 rows updated
# 4373: Caladenia carnea / all
# 1 rows updated
# 6703: Caladenia catenata / all
# 1 rows updated
# 9548: Caladenia clarkiae / all
# 1 rows updated
# 9523: Caladenia concolor / all
# 1 rows updated
# 4376: Caladenia cucullata / all
# 1 rows updated
# 4379: Caladenia dimorpha / all
# 1 rows updated
# 4380: Caladenia filamentosa / none
# 1 rows updated
# 9123: Caladenia gracilis / all
# 1 rows updated
# 9477: Caladenia rosella / all
# 1 rows updated
# 9192: Caladenia sp. A / all
# 1 rows updated
# 4386: Caladenia tessellata / all
# 1 rows updated
# 13313: Caladenia transitoria / all
# 1 rows updated
# 5309: Calandrinia calyptrata / none
# 1 rows updated
# 5312: Calandrinia granulifera / none
# 1 rows updated
# 5314: Calandrinia pickeringii / all
# 1 rows updated
# 2269: Caldcluvia paniculosa / half
# 1 rows updated
# 4389: Caleana major / all
# 1 rows updated
# 10175: Calendula officinalis / none
# 1 rows updated
# 2270: Callicoma serratifolia / all
# 1 rows updated
# 4002: Callistemon acuminatus / all
# 1 rows updated
# 4004: Callistemon citrinus / all
# 1 rows updated
# 4005: Callistemon comboynensis / all
# 1 rows updated
# 4006: Callistemon flavovirens / all
# 1 rows updated
# 4008: Callistemon linearis / all
# 1 rows updated
# 4009: Callistemon montanus / all
# 1 rows updated
# 4010: Callistemon pachyphyllus / all
# 1 rows updated
# 4011: Callistemon pallidus / all
# 1 rows updated
# 4013: Callistemon pinifolius / all
# 1 rows updated
# 7943: Callistemon pityoides / all
# 1 rows updated
# 9126: Callistemon pungens / all
# 1 rows updated
# 9126: Callistemon pungens / all
# 1 rows updated
# 4014: Callistemon rigidus / all
# 1 rows updated
# 4015: Callistemon salignus / all
# 1 rows updated
# 4016: Callistemon shiressii / all
# 1 rows updated
# 4017: Callistemon sieberi / all
# 1 rows updated
# 14189: Callistemon sp. aff. flavovirens / all
# 1 rows updated
# 4018: Callistemon subulatus / all
# 1 rows updated
# 2279: Callitris endlicheri / none
# 1 rows updated
# 6379: Callitris glaucophylla / none
# 1 rows updated
# 2280: Callitris macleayana / none
# 1 rows updated
# 2281: Callitris monticola / none
# 1 rows updated
# 2282: Callitris muelleri / none
# 1 rows updated
# 2283: Callitris oblonga / none
# 1 rows updated
# 9986: Callitris oblonga subsp. parva / none
# 1 rows updated
# 2285: Callitris rhomboidea / none
# 1 rows updated
# 6805: Callitris verrucosa / none
# 1 rows updated
# 1330: Calocephalus citreus / all
# 1 rows updated
# 1331: Calocephalus platycephalus / all
# 1 rows updated
# 4390: Calochilus campestris / all
# 1 rows updated
# 4391: Calochilus gracillimus / none
# 1 rows updated
# 4394: Calochilus paludosus / all
# 1 rows updated
# 4395: Calochilus robertsonii / all
# 1 rows updated
# 8341: Calochlaena dubia / all
# 1 rows updated
# 1333: Calomeria amaranthoides / none
# 1 rows updated
# 3537: Calostemma purpureum / all
# 1 rows updated
# 1335: Calotis anthemoides / all
# 1 rows updated
# 1337: Calotis cuneifolia / none
# 1 rows updated
# 1339: Calotis dentex / none
# 1 rows updated
# 1341: Calotis glandulosa / few
# 1 rows updated
# 1342: Calotis hispidula / none
# 1 rows updated
# 1344: Calotis lappulacea / all
# 1 rows updated
# 2215: Calystegia marginata / none
# 1 rows updated
# 4021: Calytrix tetragona / half
# 1 rows updated
# 1865: Canarium australasicum / all
# 1 rows updated
# 1941: Canna indica / all
# 1 rows updated
# 6374: Capparis lasiantha / none
# 1 rows updated
# 7284: Capparis loranthifolia var. loranthifolia / none
# 1 rows updated
# 1794: Capsella bursa-pastoris / none
# 1 rows updated
# 10566: Cardamine astoniae / all
# 1 rows updated
# 7410: Cardamine flexuosa / none
# 1 rows updated
# 1795: Cardamine hirsuta / none
# 1 rows updated
# 1796: Cardamine lilacina / half
# 1 rows updated
# 10570: Cardamine papillata / none
# 1 rows updated
# 1355: Carduus tenuiflorus / half
# 1 rows updated
# 2310: Carex appressa / all
# 1 rows updated
# 2311: Carex bichenoviana / all
# 1 rows updated
# 2312: Carex blakei / all
# 1 rows updated
# 2313: Carex breviculmis / most
# 1 rows updated
# 2315: Carex canescens / all
# 1 rows updated
# 2316: Carex capillacea / all
# 1 rows updated
# 2317: Carex cephalotes / all
# 1 rows updated
# 2318: Carex chlorantha / all
# 1 rows updated
# 2322: Carex gaudichaudiana / all
# 1 rows updated
# 2324: Carex hebes / all
# 1 rows updated
# 7898: Carex incomitata / all
# 1 rows updated
# 2327: Carex inversa / all
# 1 rows updated
# 2329: Carex jackiana / all
# 1 rows updated
# 2331: Carex longebrachiata / all
# 1 rows updated
# 2336: Carex raleighii / all
# 1 rows updated
# 2338: Carpha alpina / none
# 1 rows updated
# 2339: Carpha nivicola / all
# 1 rows updated
# 1024: Carpobrotus edulis / none
# 1 rows updated
# 1798: Carrichtera annua / none
# 1 rows updated
# 1358: Carthamus lanatus / none
# 1 rows updated
# 9296: Cassia brewsteri var. marksiana / all
# 1 rows updated
# 1360: Cassinia aculeata / none
# 1 rows updated
# 1362: Cassinia arcuata / none
# 1 rows updated
# 1363: Cassinia aureonitens / none
# 1 rows updated
# 1364: Cassinia compacta / none
# 1 rows updated
# 1365: Cassinia cunninghamii / none
# 1 rows updated
# 1366: Cassinia denticulata / none
# 1 rows updated
# 1367: Cassinia laevis / none
# 1 rows updated
# 12706: Cassinia lepschii / all
# 1 rows updated
# 9246: Cassinia leptocephala subsp. leptocephala / none
# 1 rows updated
# 1369: Cassinia longifolia / few
# 1 rows updated
# 12709: Cassinia monticola / half
# 1 rows updated
# 1370: Cassinia quinquefaria / none
# 1 rows updated
# n/a: Cassinia sp. 'Cave Creek' / all
# 12711: Cassinia straminea / none
# 1 rows updated
# 12425: Cassinia telfordii / none
# 1 rows updated
# 1374: Cassinia trinerva / half
# 1 rows updated
# 1375: Cassinia uncata / none
# 1 rows updated
# 7220: Cassytha filiformis / all
# 1 rows updated
# 3467: Cassytha glabella / none
# 1 rows updated
# 3468: Cassytha melantha / none
# 1 rows updated
# 3469: Cassytha pubescens / none
# 1 rows updated
# 2019: Casuarina cristata / none
# 1 rows updated
# 9006: Casuarina cunninghamiana subsp. cunninghamiana / none
# 1 rows updated
# 2022: Casuarina glauca / all
# 1 rows updated
# 11001: Caustis blakei subsp. blakei / all
# 1 rows updated
# 2341: Caustis flexuosa / most
# 1 rows updated
# 2342: Caustis pentandra / most
# 1 rows updated
# 2342: Caustis pentandra / none
# 1 rows updated
# 9315: Caustis recurvata var. recurvata / few
# 1 rows updated
# 6281: Cayratia clematidea / all
# 1 rows updated
# 6794: Celastrus subspicata / none
# 1 rows updated
# 1377: Celmisia longifolia / none
# 1 rows updated
# 10835: Celmisia pugioniformis / all
# 1 rows updated
# 10836: Celmisia tomentella / all
# 1 rows updated
# 1382: Centaurea melitensis / none
# 1 rows updated
# 3131: Centaurium erythraea / few
# 1 rows updated
# 3133: Centaurium tenuiflorum / none
# 1 rows updated
# 1106: Centella asiatica / none
# 1 rows updated
# 1386: Centipeda thespidioides / none
# 1 rows updated
# 10339: Centrolepis aristata / none
# 1 rows updated
# 2038: Centrolepis fascicularis / none
# 1 rows updated
# 2040: Centrolepis polygyna / none
# 1 rows updated
# 8807: Centrolepis strigosa subsp. strigosa / half
# 1 rows updated
# 1206: Cephalaralia cephalobotrys  / all
# 1 rows updated
# 9348: Cerastium balearicum / none
# 1 rows updated
# 1960: Cerastium glomeratum / none
# 1 rows updated
# 10550: Cerastium vulgare / none
# 1 rows updated
# 1388: Ceratogyne obionoides / none
# 1 rows updated
# 2271: Ceratopetalum apetalum / all
# 1 rows updated
# 2272: Ceratopetalum gummiferum / all
# 1 rows updated
# 14091: Cestichis reflexa / all
# 1 rows updated
# 6027: Cestrum parqui / all
# 1 rows updated
# 9737: Chamaecytisus palmensis / none
# 1 rows updated
# 9130: Chamaesyce hirta / none
# 1 rows updated
# 8005: Cheilanthes austrotenuifolia / half
# 1 rows updated
# 6382: Cheilanthes distans / all
# 1 rows updated
# 8007: Cheilanthes sieberi subsp. sieberi / all
# 1 rows updated
# 2084: Chenopodium album / none
# 1 rows updated
# 2089: Chenopodium cristatum / none
# 1 rows updated
# 2091: Chenopodium desertorum / none
# 1 rows updated
# 2093: Chenopodium erosum / none
# 1 rows updated
# 8868: Chiloglottis sphyrnoides / all
# 1 rows updated
# 6881: Chiloglottis sylvestris / all
# 1 rows updated
# 6525: Chiloglottis trilabra / all
# 1 rows updated
# 10289: Chiloglottis valida / all
# 1 rows updated
# 6242: Chloanthes parviflora / none
# 1 rows updated
# 6243: Chloanthes stoechadis / few
# 1 rows updated
# 4831: Chloris gayana / all
# 1 rows updated
# 4833: Chloris truncata / all
# 1 rows updated
# 4834: Chloris ventricosa / all
# 1 rows updated
# 3538: Chlorophytum comosum / all
# 1 rows updated
# 1391: Chondrilla juncea / half
# 1 rows updated
# 13527: Chordifex dimorphus / none
# 1 rows updated
# 13528: Chordifex fastigiatus / all
# 1 rows updated
# 5856: Choretrum candollei / all
# 1 rows updated
# 5857: Choretrum glomeratum / none
# 1 rows updated
# 5858: Choretrum pauciflorum / none
# 1 rows updated
# 4022: Choricarpia leptopetala / all
# 1 rows updated
# 2344: Chorizandra cymbaria / all
# 1 rows updated
# 2345: Chorizandra sphaerocephala / all
# 1 rows updated
# 2797: Chorizema parviflorum / most
# 1 rows updated
# 8188: Christella dentata / all
# 1 rows updated
# 1392: Chrysanthemoides monilifera / half
# 1 rows updated
# 9400: Chrysanthemoides monilifera subsp. monilifera / none
# 1 rows updated
# 8686: Chrysanthemoides monilifera subsp. rotundata / all
# 1 rows updated
# 8559: Chrysocephalum apiculatum / most
# 1 rows updated
# 9609: Chrysocephalum baxteri / few
# 1 rows updated
# 8562: Chrysocephalum semipapposum / most
# 1 rows updated
# 4835: Chrysopogon fallax / all
# 1 rows updated
# 1395: Chthonocephalus pseudevax / none
# 1 rows updated
# 3135: Cicendia quadrangularis / none
# 1 rows updated
# 3471: Cinnamomum camphora / all
# 1 rows updated
# 3472: Cinnamomum oliveri / few
# 1 rows updated
# 1400: Cirsium vulgare / none
# 1 rows updated
# 1400: Cirsium vulgare / few
# 1 rows updated
# 6283: Cissus hypoglauca / all
# 1 rows updated
# 3275: Citronella moorei / none
# 1 rows updated
# 2698: Claoxylon australe / all
# 1 rows updated
# 5493: Clematis aristata / most
# 1 rows updated
# 5494: Clematis fawcettii / none
# 1 rows updated
# 5495: Clematis glycinoides / none
# 1 rows updated
# 6903: Clematis glycinoides var. glycinoides / all
# 1 rows updated
# 13520: Clematis leptophylla / none
# 1 rows updated
# 5496: Clematis microphylla / all
# 1 rows updated
# 12201: Clerodendrum floribundum var. floribundum / all
# 1 rows updated
# 6484: Clerodendrum tomentosum / all
# 1 rows updated
# 3231: Codonocarpus attenuatus / none
# 1 rows updated
# 5531: Coleocarya gracilis / most
# 1 rows updated
# 5252: Comesperma defoliatum / all
# 1 rows updated
# 5253: Comesperma ericinum / few
# 1 rows updated
# 5255: Comesperma retusum / half
# 1 rows updated
# 5256: Comesperma sphaerocarpum / all
# 1 rows updated
# 5257: Comesperma volubile / half
# 1 rows updated
# 2209: Commelina cyanea / half
# 1 rows updated
# n/a: Commersonia amystia / none
# 6129: Commersonia bartramia / all
# 1 rows updated
# 13958: Commersonia breviseta / none
# 1 rows updated
# 5350: Conospermum burgessiorum / none
# 1 rows updated
# 9136: Conospermum ellipticum / all
# 1 rows updated
# 9976: Conospermum ericifolium / none
# 1 rows updated
# 5351: Conospermum longifolium / most
# 1 rows updated
# 5352: Conospermum taxifolium / half
# 1 rows updated
# 5353: Conospermum tenuifolium / all
# 1 rows updated
# 2219: Convolvulus arvensis / all
# 1 rows updated
# 2220: Convolvulus erubescens / most
# 1 rows updated
# 1403: Conyza bilbaoana / none
# 1 rows updated
# 1404: Conyza bonariensis / none
# 1 rows updated
# 10138: Conyza canadensis var. canadensis / all
# 1 rows updated
# 1408: Conyza parva / none
# 1 rows updated
# 10442: Conyza sumatrensis / none
# 1 rows updated
# 3166: Coopernookia barbata / all
# 1 rows updated
# 5670: Coprosma hirtella / all
# 1 rows updated
# 8677: Coprosma nitida / few
# 1 rows updated
# 6557: Coprosma nivalis / none
# 1 rows updated
# 6678: Coprosma perpusilla subsp. perpusilla / none
# 1 rows updated
# 5675: Coprosma quadrifida / half
# 1 rows updated
# 5676: Coprosma repens / all
# 1 rows updated
# 6198: Corchorus cunninghamii / none
# 1 rows updated
# 1409: Coreopsis lanceolata / half
# 1 rows updated
# 13745: Coronidium elatum / none
# 1 rows updated
# 13961: Coronidium oxylepis / few
# 1 rows updated
# 13836: Coronidium scorpioides / most
# 1 rows updated
# 13966: Coronidium waddelliae / none
# 1 rows updated
# 1800: Coronopus didymus / none
# 1 rows updated
# 5769: Correa baeuerlenii / none
# 1 rows updated
# 11022: Correa lawrenceana var. glandulifera / none
# 1 rows updated
# 5772: Correa reflexa / most
# 1 rows updated
# 5772: Correa reflexa (obligate seeder red flowered) / none
# 1 rows updated
# 5772: Correa reflexa (resprouter green flowered) / all
# 1 rows updated
# 8801: Correa reflexa var. reflexa / none
# 1 rows updated
# 4839: Cortaderia selloana / all
# 1 rows updated
# 4404: Corybas aconitiflorus / all
# 1 rows updated
# 4408: Corybas fordhamii / all
# 1 rows updated
# 4409: Corybas hispidus / all
# 1 rows updated
# 9743: Corymbia eximia / all
# 1 rows updated
# 9687: Corymbia gummifera / all
# 1 rows updated
# 9601: Corymbia intermedia / all
# 1 rows updated
# 9692: Corymbia maculata / all
# 1 rows updated
# 9744: Corymbia tessellaris / all
# 1 rows updated
# 6981: Corynocarpus rupestris / all
# 1 rows updated
# 6830: Corynotheca licrota / all
# 1 rows updated
# 1410: Cosmos bipinnatus / none
# 1 rows updated
# 8640: Cotoneaster franchetii / all
# 1 rows updated
# 5612: Cotoneaster glaucophyllus / all
# 1 rows updated
# 1411: Cotula alpina / all
# 1 rows updated
# 1412: Cotula australis / none
# 1 rows updated
# 9952: Craspedia aurantia / all
# 1 rows updated
# 9139: Craspedia canens / all
# 1 rows updated
# 8565: Craspedia coolaminica / all
# 1 rows updated
# 8566: Craspedia jamesii / all
# 1 rows updated
# 10153: Craspedia lamicola / all
# 1 rows updated
# 11656: Craspedia sp. aff. crocata (Bogong Swamp) / all
# 1 rows updated
# 1421: Crassocephalum crepidioides / none
# 1 rows updated
# 7745: Crassula decumbens var. decumbens / none
# 1 rows updated
# 2240: Crassula multicava / all
# 1 rows updated
# 6820: Crassula peduncularis / none
# 1 rows updated
# 2242: Crassula sieberiana / few
# 1 rows updated
# 1422: Cratystylis conocephala / none
# 1 rows updated
# 12520: Crepidomanes venosum / none
# 1 rows updated
# 1423: Crepis capillaris / half
# 1 rows updated
# 10271: Crocosmia X crocosmiiflora / all
# 1 rows updated
# 6901: Crotalaria cunninghamii / all
# 1 rows updated
# 12020: Crotalaria montana var. angustifolia / none
# 1 rows updated
# 2706: Croton verreauxii / none
# 1 rows updated
# 12205: Crowea exalata subsp. magnifolia / none
# 1 rows updated
# 5775: Crowea saligna / none
# 1 rows updated
# 5554: Cryptandra amara / half
# 1 rows updated
# 8611: Cryptandra amara var. amara / all
# 1 rows updated
# 8246: Cryptandra amara var. floribunda / none
# 1 rows updated
# 8784: Cryptandra amara var. longiflora / all
# 1 rows updated
# 5556: Cryptandra ericoides / none
# 1 rows updated
# 5557: Cryptandra lanosiflora / none
# 1 rows updated
# 3477: Cryptocarya foetida / all
# 1 rows updated
# 3478: Cryptocarya foveolata / all
# 1 rows updated
# 3479: Cryptocarya glaucescens / all
# 1 rows updated
# 8756: Cryptocarya meissneriana / all
# 1 rows updated
# 3483: Cryptocarya microneura / none
# 1 rows updated
# 3485: Cryptocarya rigida / all
# 1 rows updated
# 4414: Cryptostylis erecta / all
# 1 rows updated
# 4415: Cryptostylis hunteriana / all
# 1 rows updated
# 4416: Cryptostylis leptochila / all
# 1 rows updated
# 4417: Cryptostylis subulata / all
# 1 rows updated
# 2255: Cucurbita maxima / none
# 1 rows updated
# 10668: Cullen cinereum / none
# 1 rows updated
# 10671: Cullen microcephalum / none
# 1 rows updated
# 9987: Cullen parvum / all
# 1 rows updated
# 10673: Cullen patens / none
# 1 rows updated
# 10674: Cullen tenax / none
# 1 rows updated
# 5884: Cupaniopsis anacardioides / most
# 1 rows updated
# 7384: Cupaniopsis newmanii / all
# 1 rows updated
# 2286: Cuscuta australis / none
# 1 rows updated
# 2287: Cuscuta campestris / none
# 1 rows updated
# 10187: Cuscuta victoriana / none
# 1 rows updated
# 11228: Cyanicula caerulea / all
# 1 rows updated
# 8074: Cyathea australis / all
# 1 rows updated
# 8077: Cyathea cunninghamii / none
# 1 rows updated
# 8079: Cyathea leichhardtiana / few
# 1 rows updated
# 2347: Cyathochaeta diandra / all
# 1 rows updated
# 11599: Cyclophyllum longipetalum / all
# 1 rows updated
# 4419: Cymbidium suave / all
# 1 rows updated
# 1426: Cymbonotus lawsonianus / none
# 1 rows updated
# 1427: Cymbonotus preissianus / all
# 1 rows updated
# 7675: Cymbopogon ambiguus / all
# 1 rows updated
# 4841: Cymbopogon refractus / all
# 1 rows updated
# 14560: Cynanchum viminale subsp. australe / none
# 1 rows updated
# 6540: Cynodon dactylon / all
# 1 rows updated
# 1749: Cynoglossum suaveolens / half
# 1 rows updated
# 4845: Cynosurus echinatus / none
# 1 rows updated
# 2348: Cyperus albostriatus / all
# 1 rows updated
# 2353: Cyperus brevifolius / all
# 1 rows updated
# 2354: Cyperus bulbosus / all
# 1 rows updated
# 2364: Cyperus eragrostis / all
# 1 rows updated
# 2372: Cyperus fulvus / all
# 1 rows updated
# 2374: Cyperus gracilis / all
# 1 rows updated
# 2379: Cyperus laevigatus / all
# 1 rows updated
# 8483: Cyperus polystachyos / none
# 1 rows updated
# 2395: Cyperus sanguinolentus / none
# 1 rows updated
# 9677: Cyperus semifertilis / all
# 1 rows updated
# 7469: Cyperus tenellus / none
# 1 rows updated
# 7617: Cyperus vaginatus / all
# 1 rows updated
# 7342: Cyphanthera albicans subsp. albicans / none
# 1 rows updated
# 11075: Cytisus scoparius subsp. scoparius / none
# 1 rows updated
# 9338: Dactyloctenium aegyptium / none
# 1 rows updated
# 7440: Dampiera fusca / all
# 1 rows updated
# 9745: Dampiera lanceolata var. lanceolata / all
# 1 rows updated
# 3172: Dampiera purpurea / all
# 1 rows updated
# 3173: Dampiera scottiana / all
# 1 rows updated
# 3174: Dampiera stricta / all
# 1 rows updated
# 3911: Daphnandra micrantha / all
# 1 rows updated
# 4024: Darwinia biflora / none
# 1 rows updated
# 4025: Darwinia camptostylis / all
# 1 rows updated
# 4026: Darwinia diminuta / none
# 1 rows updated
# 6508: Darwinia fascicularis subsp. fascicularis / few
# 1 rows updated
# 7135: Darwinia fascicularis subsp. oligantha / half
# 1 rows updated
# 4028: Darwinia glaucophylla / none
# 1 rows updated
# 4029: Darwinia grandiflora / all
# 1 rows updated
# 4030: Darwinia leptantha / none
# 1 rows updated
# 4032: Darwinia procera / none
# 1 rows updated
# 10039: Darwinia taxifolia subsp. macrolaena / none
# 1 rows updated
# 10038: Darwinia taxifolia subsp. taxifolia / none
# 1 rows updated
# 1109: Daucus glochidiatus / none
# 1 rows updated
# 10647: Davallia solida var. pyxidata / none
# 1 rows updated
# 2816: Daviesia acicularis / none
# 1 rows updated
# 2831: Daviesia alata / none
# 1 rows updated
# 6874: Daviesia benthamii subsp. humilis / none
# 1 rows updated
# 2819: Daviesia brevifolia / all
# 1 rows updated
# 2821: Daviesia corymbosa / most
# 1 rows updated
# 8823: Daviesia elliptica / none
# 1 rows updated
# 2822: Daviesia genistifolia / few
# 1 rows updated
# 2823: Daviesia latifolia / most
# 1 rows updated
# 9597: Daviesia leptophylla / all
# 1 rows updated
# 2824: Daviesia mimosoides / all
# 1 rows updated
# 7211: Daviesia mimosoides subsp. mimosoides / all
# 1 rows updated
# 8774: Daviesia nova-anglica / none
# 1 rows updated
# 2826: Daviesia squarrosa / half
# 1 rows updated
# 2827: Daviesia ulicifolia / most
# 1 rows updated
# 10831: Daviesia ulicifolia subsp. ulicifolia / none
# 1 rows updated
# 2828: Daviesia umbellulata / few
# 1 rows updated
# 8592: Daviesia villifera / none
# 1 rows updated
# 2830: Daviesia wyattiana / none
# 1 rows updated
# 4420: Dendrobium aemulum / none
# 1 rows updated
# 4432: Dendrobium speciosum / all
# 1 rows updated
# 4433: Dendrobium striolatum / none
# 1 rows updated
# 6226: Dendrocnide excelsa / none
# 1 rows updated
# 8387: Denhamia celastroides / all
# 1 rows updated
# 8700: Derwentia arcuata / none
# 1 rows updated
# 9775: Derwentia perfoliata / half
# 1 rows updated
# 2834: Desmodium brachypodum / all
# 1 rows updated
# 6621: Desmodium gunnii / all
# 1 rows updated
# 2839: Desmodium rhytidophyllum / most
# 1 rows updated
# 2840: Desmodium varians / all
# 1 rows updated
# 4871: Deyeuxia accedens / none
# 1 rows updated
# 4880: Deyeuxia crassiuscula / all
# 1 rows updated
# 4881: Deyeuxia decipiens / few
# 1 rows updated
# 4884: Deyeuxia imbricata / none
# 1 rows updated
# 10361: Deyeuxia innominata / half
# 1 rows updated
# 6940: Deyeuxia monticola var. monticola / all
# 1 rows updated
# 4889: Deyeuxia nudiflora / none
# 1 rows updated
# 6964: Deyeuxia parviseta var. boormanii / half
# 1 rows updated
# 4891: Deyeuxia quadriseta / all
# 1 rows updated
# 11273: Deyeuxia talariata / none
# 1 rows updated
# 3540: Dianella caerulea / half
# 1 rows updated
# 6811: Dianella caerulea var. assera / all
# 1 rows updated
# 6700: Dianella caerulea var. caerulea / all
# 1 rows updated
# 6789: Dianella caerulea var. cinerascens / all
# 1 rows updated
# 7337: Dianella caerulea var. producta / all
# 1 rows updated
# 7344: Dianella caerulea var. vannata / all
# 1 rows updated
# 7783: Dianella longifolia / all
# 1 rows updated
# 8725: Dianella longifolia var. longifolia / all
# 1 rows updated
# 6912: Dianella prunina / all
# 1 rows updated
# 3542: Dianella revoluta / all
# 1 rows updated
# 7580: Dianella revoluta var. revoluta / all
# 1 rows updated
# 3543: Dianella tasmanica / all
# 1 rows updated
# 4897: Dichelachne crinita / half
# 1 rows updated
# 8748: Dichelachne inaequiglumis / all
# 1 rows updated
# 4898: Dichelachne micrantha / all
# 1 rows updated
# 4899: Dichelachne rara / all
# 1 rows updated
# 9151: Dichelachne sieberiana / all
# 1 rows updated
# 2222: Dichondra repens / few
# 1 rows updated
# 3545: Dichopogon strictus / half
# 1 rows updated
# 8082: Dicksonia antarctica / all
# 1 rows updated
# 8155: Dictymia brownii / none
# 1 rows updated
# 4903: Digitaria coenicola / all
# 1 rows updated
# 4905: Digitaria diffusa / none
# 1 rows updated
# 4907: Digitaria divaricatissima / few
# 1 rows updated
# 4913: Digitaria parviflora / all
# 1 rows updated
# 2841: Dillwynia acicularis / none
# 1 rows updated
# 7556: Dillwynia brunioides / none
# 1 rows updated
# 11077: Dillwynia elegans / none
# 1 rows updated
# 2843: Dillwynia floribunda / none
# 1 rows updated
# 2844: Dillwynia glaberrima / half
# 1 rows updated
# 2845: Dillwynia hispida / most
# 1 rows updated
# 10908: Dillwynia palustris / none
# 1 rows updated
# ...
# 5434: Isopogon dawsonii / none
# 1 rows updated
# 5435: Isopogon fletcheri / all
# 1 rows updated
# 5438: Isopogon petiolaris / all
# 1 rows updated
# 5439: Isopogon prostratus / all
# 1 rows updated
# 1913: Isotoma axillaris / all
# 1 rows updated
# 7964: Isotoma fluviatilis subsp. australis / none
# 1 rows updated
# 2892: Jacksonia scoparia / all
# 1 rows updated
# 2893: Jacksonia stackhousei / few
# 1 rows updated
# 6398: Jasminum lineare / all
# 1 rows updated
# 3313: Juncus amabilis / all
# 1 rows updated
# 3316: Juncus articulatus / all
# 1 rows updated
# 9035: Juncus brevibracteus / all
# 1 rows updated
# 3318: Juncus bufonius / none
# 1 rows updated
# 3324: Juncus capitatus / none
# 1 rows updated
# 3326: Juncus continuus / all
# 1 rows updated
# 3327: Juncus effusus / all
# 1 rows updated
# 3328: Juncus falcatus / all
# 1 rows updated
# 3333: Juncus homalocaulis / all
# 1 rows updated
# 3338: Juncus pallidus / all
# 1 rows updated
# 3339: Juncus pauciflorus / all
# 1 rows updated
# 3340: Juncus planifolius / all
# 1 rows updated
# 8521: Juncus remotiflorus / all
# 1 rows updated
# 3348: Juncus subsecundus / all
# 1 rows updated
# 3350: Juncus usitatus / all
# 1 rows updated
# 13291: Kardomia odontocalyx / none
# 1 rows updated
# 2896: Kennedia prostrata / few
# 1 rows updated
# 2897: Kennedia retrorsa / all
# 1 rows updated
# 2898: Kennedia rubicunda / few
# 1 rows updated
# 9871: Keraudrenia hillii var. hillii / none
# 1 rows updated
# 6973: Korthalsella rubra subsp. rubra / none
# 1 rows updated
# 4204: Kunzea ambigua / none
# 1 rows updated
# 4205: Kunzea bracteolata / none
# 1 rows updated
# 4205: Kunzea bracteolata (resprouter pop.) / all
# 1 rows updated
# 4207: Kunzea capitata / most
# 1 rows updated
# 4208: Kunzea ericoides / all
# 1 rows updated
# 4209: Kunzea muelleri / all
# 1 rows updated
# 8646: Kunzea obovata / none
# 1 rows updated
# 4210: Kunzea opposita / none
# 1 rows updated
# 4211: Kunzea parvifolia / none
# 1 rows updated
# 4212: Kunzea rupestris / all
# 1 rows updated
# 11394: Lachnagrostis aemula / none
# 1 rows updated
# 11388: Lachnagrostis filiformis / most
# 1 rows updated
# 1550: Lactuca serriola / none
# 1 rows updated
# 11959: Lagenophora gracilis / all
# 1 rows updated
# 11960: Lagenophora stipitata / most
# 1 rows updated
# 5440: Lambertia formosa / all
# 1 rows updated
# 6248: Lantana camara / all
# 1 rows updated
# 6139: Lasiopetalum ferrugineum / most
# 1 rows updated
# 9008: Lasiopetalum ferrugineum var. ferrugineum / half
# 1 rows updated
# 6140: Lasiopetalum joyceae / none
# 1 rows updated
# 6142: Lasiopetalum macrophyllum / half
# 1 rows updated
# 6143: Lasiopetalum parviflorum / half
# 1 rows updated
# 8014: Lastreopsis acuminata / all
# 1 rows updated
# 8015: Lastreopsis decomposita / all
# 1 rows updated
# 8016: Lastreopsis hispida / none
# 1 rows updated
# 6752: Laxmannia compacta / none
# 1 rows updated
# 3556: Laxmannia gracilis / few
# 1 rows updated
# 10261: Laxmannia orientalis / none
# 1 rows updated
# 3557: Laxmannia sessiliflora / few
# 1 rows updated
# 3200: Lechenaultia divaricata / all
# 1 rows updated
# 10724: Leionema ambiens / none
# 1 rows updated
# 10725: Leionema carruthersii / all
# 1 rows updated
# 10727: Leionema dentatum / none
# 1 rows updated
# 10728: Leionema diosmeum / none
# 1 rows updated
# 10731: Leionema elatius subsp. beckleri / none
# 1 rows updated
# 10734: Leionema phylicifolium / all
# 1 rows updated
# 10735: Leionema ralstonii / none
# 1 rows updated
# 10736: Leionema rotundifolium / all
# 1 rows updated
# 10736: Leionema rotundifolium / none
# 1 rows updated
# 8291: Lepiderema pulchella / all
# 1 rows updated
# 1816: Lepidium aschersonii / all
# 1 rows updated
# 1822: Lepidium hyssopifolium / none
# 1 rows updated
# 1824: Lepidium monoplocoides / none
# 1 rows updated
# 7033: Lepidium pseudopapillosum / none
# 1 rows updated
# 1830: Lepidium pseudotasmanicum / none
# 1 rows updated
# 8380: Lepidosperma concavum / all
# 1 rows updated
# 8379: Lepidosperma elatius / all
# 1 rows updated
# 2465: Lepidosperma filiforme / most
# 1 rows updated
# 2467: Lepidosperma forsythii / all
# 1 rows updated
# 2468: Lepidosperma gladiatum / all
# 1 rows updated
# 8749: Lepidosperma gunnii / all
# 1 rows updated
# 6402: Lepidosperma laterale / all
# 1 rows updated
# 2469: Lepidosperma limicola / all
# 1 rows updated
# 2470: Lepidosperma longitudinale / all
# 1 rows updated
# 2471: Lepidosperma neesii / all
# 1 rows updated
# 2473: Lepidosperma semiteres / all
# 1 rows updated
# 2474: Lepidosperma tortuosum / all
# 1 rows updated
# 2475: Lepidosperma urophorum / all
# 1 rows updated
# 11028: Lepidosperma viscidum / all
# 1 rows updated
# 8703: Leptinella filicula / all
# 1 rows updated
# 5534: Leptocarpus tenax / all
# 1 rows updated
# 5865: Leptomeria acida / few
# 1 rows updated
# 9176: Leptomeria aphylla / none
# 1 rows updated
# 1554: Leptorhynchos elongatus / all
# 1 rows updated
# 11104: Leptorhynchos scaber / none
# 1 rows updated
# 1557: Leptorhynchos squamatus / all
# 1 rows updated
# 1559: Leptorhynchos waitzia / none
# 1 rows updated
# 4213: Leptospermum arachnoides / most
# 1 rows updated
# 4216: Leptospermum brevipes / all
# 1 rows updated
# 7970: Leptospermum continentale / most
# 1 rows updated
# 4217: Leptospermum coriaceum / all
# 1 rows updated
# 7274: Leptospermum divaricatum / all
# 1 rows updated
# 4218: Leptospermum emarginatum / all
# 1 rows updated
# 7766: Leptospermum grandifolium / all
# 1 rows updated
# 8647: Leptospermum gregarium / all
# 1 rows updated
# 4221: Leptospermum juniperinum / most
# 1 rows updated
# 4222: Leptospermum laevigatum / few
# 1 rows updated
# 4223: Leptospermum lanigerum / all
# 1 rows updated
# 4224: Leptospermum liversidgei / all
# 1 rows updated
# 10036: Leptospermum macrocarpum / all
# 1 rows updated
# 4227: Leptospermum minutifolium / all
# 1 rows updated
# 4228: Leptospermum multicaule / all
# 1 rows updated
# 4229: Leptospermum myrsinoides / all
# 1 rows updated
# 4230: Leptospermum myrtifolium / all
# 1 rows updated
# 8478: Leptospermum novae-angliae / most
# 1 rows updated
# 4232: Leptospermum obovatum / all
# 1 rows updated
# 4233: Leptospermum parvifolium / most
# 1 rows updated
# 4234: Leptospermum petersonii / all
# 1 rows updated
# 8199: Leptospermum polygalifolium subsp. cismontanum / most
# 1 rows updated
# 8198: Leptospermum polygalifolium subsp. montanum / all
# 1 rows updated
# 8197: Leptospermum polygalifolium subsp. polygalifolium / most
# 1 rows updated
# 8201: Leptospermum polygalifolium subsp. transmontanum / all
# 1 rows updated
# 9958: Leptospermum rotundifolium / most
# 1 rows updated
# 4235: Leptospermum scoparium / half
# 1 rows updated
# 4236: Leptospermum semibaccatum / all
# 1 rows updated
# 4237: Leptospermum speciosum / all
# 1 rows updated
# 4239: Leptospermum squarrosum / few
# 1 rows updated
# 8317: Leptospermum thompsonii / none
# 1 rows updated
# 8486: Leptospermum trinervium / all
# 1 rows updated
# 5535: Lepyrodia anarthria / all
# 1 rows updated
# 13531: Lepyrodia imitans / all
# 1 rows updated
# 5540: Lepyrodia muelleri / all
# 1 rows updated
# 5541: Lepyrodia scariosa / all
# 1 rows updated
# 8690: Lespedeza juncea subsp. sericea / all
# 1 rows updated
# 9072: Leucochrysum albicans subsp. alpinum / all
# 1 rows updated
# 8924: Leucochrysum molle / none
# 1 rows updated
# 2610: Leucopogon amplexicaulis / none
# 1 rows updated
# 2611: Leucopogon appressus / none
# 1 rows updated
# 2612: Leucopogon attenuatus / all
# 1 rows updated
# 2613: Leucopogon biflorus / all
# 1 rows updated
# 2613: Leucopogon biflorus / none
# 1 rows updated
# 10194: Leucopogon collinus / none
# 1 rows updated
# 2615: Leucopogon deformis / none
# 1 rows updated
# 2616: Leucopogon ericoides / few
# 1 rows updated
# 2617: Leucopogon esquamatus / none
# 1 rows updated
# 2618: Leucopogon exolasius / none
# 1 rows updated
# 10195: Leucopogon fletcheri subsp. brevisepalus / all
# 1 rows updated
# 2620: Leucopogon fraseri / all
# 1 rows updated
# 2623: Leucopogon juniperinus / few
# 1 rows updated
# 6845: Leucopogon lanceolatus var. gracilis / none
# 1 rows updated
# 6425: Leucopogon lanceolatus var. lanceolatus / all
# 1 rows updated
# 2625: Leucopogon leptospermoides / all
# 1 rows updated
# 2627: Leucopogon margarodes / all
# 1 rows updated
# 2628: Leucopogon melaleucoides / all
# 1 rows updated
# 2629: Leucopogon microphyllus / none
# 1 rows updated
# 7216: Leucopogon microphyllus var. microphyllus / few
# 1 rows updated
# 7287: Leucopogon microphyllus var. pilibundus / few
# 1 rows updated
# 2630: Leucopogon muticus / few
# 1 rows updated
# 2631: Leucopogon neo-anglicus / none
# 1 rows updated
# 2631: Leucopogon neo-anglicus / none
# 1 rows updated
# 2632: Leucopogon parviflorus / all
# 1 rows updated
# 2636: Leucopogon rodwayi / half
# 1 rows updated
# 2637: Leucopogon rufus / half
# 1 rows updated
# 2638: Leucopogon setiger / none
# 1 rows updated
# 9178: Leucopogon sp. aff. appressus / none
# 1 rows updated
# 9842: Leucopogon sp. aff. fraseri  / all
# 1 rows updated
# 2639: Leucopogon virgatus / all
# 1 rows updated
# 6152: Levenhookia dubia / none
# 1 rows updated
# n/a: Lezpedeza juncea subsp. sericea / all
# 4313: Ligustrum sinense / all
# 1 rows updated
# 3359: Lilium formosanum / all
# 1 rows updated
# 5972: Limosella australis / half
# 1 rows updated
# 5978: Linaria pelisseriana / none
# 1 rows updated
# 5979: Linaria vulgaris / none
# 1 rows updated
# 8127: Lindsaea dimorpha / all
# 1 rows updated
# 6406: Lindsaea linearis / all
# 1 rows updated
# 6401: Lindsaea microphylla / all
# 1 rows updated
# 3583: Linum marginale / half
# 1 rows updated
# 3584: Linum trigynum / none
# 1 rows updated
# 10713: Lissanthe strigosa subsp. strigosa / all
# 1 rows updated
# 11108: Lissanthe strigosa subsp. subulata / all
# 1 rows updated
# 3498: Litsea reticulata / none
# 1 rows updated
# 1221: Livistona australis / all
# 1 rows updated
# 10465: Lobelia anceps / half
# 1 rows updated
# 14464: Lobelia andrewsii / none
# 1 rows updated
# 7072: Lobelia dentata / all
# 1 rows updated
# 1917: Lobelia gibbosa / most
# 1 rows updated
# 1833: Lobularia maritima / none
# 1 rows updated
# 3588: Logania albiflora / half
# 1 rows updated
# 3590: Logania pusilla / few
# 1 rows updated
# n/a: Logania sp. aff. albiflora (narrow leaves, rocky habitat) / all
# 5032: Lolium perenne / none
# 1 rows updated
# 5033: Lolium rigidum / none
# 1 rows updated
# 6296: Lomandra brevis / all
# 1 rows updated
# 6297: Lomandra confertifolia / all
# 1 rows updated
# 7546: Lomandra confertifolia subsp. leptostachya / all
# 1 rows updated
# 7709: Lomandra confertifolia subsp. pallida / all
# 1 rows updated
# 7573: Lomandra confertifolia subsp. rubiginosa / all
# 1 rows updated
# 6530: Lomandra confertifolia subsp. similis / all
# 1 rows updated
# 6298: Lomandra cylindrica / all
# 1 rows updated
# 6300: Lomandra effusa / all
# 1 rows updated
# 6301: Lomandra elongata / all
# 1 rows updated
# 6302: Lomandra filiformis / all
# 1 rows updated
# 6511: Lomandra filiformis subsp. coriacea / all
# 1 rows updated
# 7931: Lomandra filiformis subsp. filiformis / all
# 1 rows updated
# 6303: Lomandra fluviatilis / all
# 1 rows updated
# 6304: Lomandra glauca / all
# 1 rows updated
# 6305: Lomandra gracilis / all
# 1 rows updated
# 8469: Lomandra leucocephala subsp. robusta / all
# 1 rows updated
# 6308: Lomandra longifolia / all
# 1 rows updated
# 9082: Lomandra micrantha subsp. tuberculata / all
# 1 rows updated
# 8802: Lomandra multiflora subsp. multiflora / all
# 1 rows updated
# 6312: Lomandra obliqua / most
# 1 rows updated
# 5441: Lomatia arborescens / all
# 1 rows updated
# 5442: Lomatia fraseri / all
# 1 rows updated
# 5443: Lomatia ilicifolia / all
# 1 rows updated
# 5444: Lomatia myricoides / all
# 1 rows updated
# 5445: Lomatia silaifolia / all
# 1 rows updated
# 1952: Lonicera japonica / all
# 1 rows updated
# 4242: Lophostemon confertus / all
# 1 rows updated
# 4243: Lophostemon suaveolens / all
# 1 rows updated
# 2905: Lotus angustissimus / none
# 1 rows updated
# 2906: Lotus australis / all
# 1 rows updated
# 2908: Lotus cruentus / none
# 1 rows updated
# 3353: Luzula alpestris / all
# 1 rows updated
# 3357: Luzula flaccida / all
# 1 rows updated
# 3359: Luzula meridionalis / all
# 1 rows updated
# 8567: Luzula modesta / half
# 1 rows updated
# 3360: Luzula novae-cambriae / all
# 1 rows updated
# 6040: Lycium ferocissimum / all
# 1 rows updated
# 9293: Lycopodiella lateralis / all
# 1 rows updated
# 6409: Lycopodium deuterodensum / all
# 1 rows updated
# 8133: Lycopodium fastigiatum / all
# 1 rows updated
# 4472: Lyperanthus suaveolens / all
# 1 rows updated
# 3623: Lythrum hyssopifolia / none
# 1 rows updated
# 3907: Macarthuria neocambrica / none
# 1 rows updated
# 1737: Macfadyena unguis-cati / all
# 1 rows updated
# 3928: Maclura cochinchinensis / all
# 1 rows updated
# 6327: Macrozamia communis / all
# 1 rows updated
# 10531: Macrozamia plurinervia / all
# 1 rows updated
# 6335: Macrozamia spiralis / all
# 1 rows updated
# 2124: Maireana cheelii / none
# 1 rows updated
# 2130: Maireana erioclada / none
# 1 rows updated
# 2133: Maireana humillima / none
# 1 rows updated
# 2136: Maireana lobiflora / none
# 1 rows updated
# 2142: Maireana pyramidata / none
# 1 rows updated
# 2147: Maireana sedifolia / few
# 1 rows updated
# 2151: Maireana triptera / none
# 1 rows updated
# 2735: Mallotus philippensis / half
# 1 rows updated
# 3657: Malva parviflora / none
# 1 rows updated
# 13837: Malva preissiana / none
# 1 rows updated
# 8908: Marsdenia australis / most
# 1 rows updated
# 1231: Marsdenia flavescens / none
# 1 rows updated
# 1233: Marsdenia longiloba / none
# 1 rows updated
# 1234: Marsdenia rostrata / all
# 1 rows updated
# 1235: Marsdenia suaveolens / all
# 1 rows updated
# 10896: Marsdenia viridiflora subsp. viridiflora / all
# 1 rows updated
# 2032: Maytenus bilocularis / all
# 1 rows updated
# 2035: Maytenus silvestris / all
# 1 rows updated
# 2920: Medicago minima / none
# 1 rows updated
# 2922: Medicago polymorpha / none
# 1 rows updated
# 2926: Medicago truncatula / none
# 1 rows updated
# 5803: Medicosma cunninghamii / all
# 1 rows updated
# 11116: Melaleuca acuminata subsp. acuminata / all
# 1 rows updated
# 11117: Melaleuca armillaris subsp. armillaris / few
# 1 rows updated
# 6809: Melaleuca biconvexa / all
# 1 rows updated
# 4247: Melaleuca capitata / all
# 1 rows updated
# 4248: Melaleuca deanei / all
# 1 rows updated
# 4249: Melaleuca decora / all
# 1 rows updated
# 6391: Melaleuca ericifolia / all
# 1 rows updated
# 4251: Melaleuca glomerata / all
# 1 rows updated
# 4252: Melaleuca groveana / most
# 1 rows updated
# 4254: Melaleuca hypericifolia / few
# 1 rows updated
# 4256: Melaleuca lanceolata / all
# 1 rows updated
# 4257: Melaleuca linariifolia / most
# 1 rows updated
# n/a: Melaleuca linearis / all
# 4258: Melaleuca nodosa / all
# 1 rows updated
# n/a: Melaleuca pallida / all
# n/a: Melaleuca paludicola / all
# n/a: Melaleuca pityoides / all
# 4260: Melaleuca quinquenervia / most
# 1 rows updated
# 4261: Melaleuca sieberi / all
# 1 rows updated
# n/a: Melaleuca sp nov./comboynensis / all
# n/a: Melaleuca sp. aff. comboynensis ('Big Red') / all
# n/a: Melaleuca sp. aff. flavovirens (Torrington) / all
# 4262: Melaleuca squamea / few
# 1 rows updated
# 4263: Melaleuca squarrosa / most
# 1 rows updated
# 4264: Melaleuca styphelioides / all
# 1 rows updated
# 4266: Melaleuca thymifolia / all
# 1 rows updated
# 4268: Melaleuca uncinata / all
# 1 rows updated
# 3675: Melastoma affine / all
# 1 rows updated
# 3680: Melia azedarach / all
# 1 rows updated
# 2644: Melichrus erubescens / half
# 1 rows updated
# 2645: Melichrus procumbens / most
# 1 rows updated
# 2646: Melichrus urceolatus / most
# 1 rows updated
# 8585: Melicope hayesii / all
# 1 rows updated
# 8625: Melicope micrococca / all
# 1 rows updated
# 12061: Melicytus dentatus / all
# 1 rows updated
# 2928: Melilotus indicus / none
# 1 rows updated
# 10904: Melinis repens / none
# 1 rows updated
# 1835: Menkea australis / none
# 1 rows updated
# 3387: Mentha satureioides / all
# 1 rows updated
# 1034: Mesembryanthemum crystallinum / none
# 1 rows updated
# 2736: Micrantheum ericoides / few
# 1 rows updated
# 7707: Microlaena stipoides var. stipoides / all
# 1 rows updated
# 4271: Micromyrtus blakelyi / none
# 1 rows updated
# 4272: Micromyrtus ciliata / half
# 1 rows updated
# 4275: Micromyrtus sessilis / most
# 1 rows updated
# 1566: Microseris lanceolata / all
# 1 rows updated
# 11009: Microsorum pustulatum subsp. pustulatum / none
# 1 rows updated
# 7622: Microtis parviflora / all
# 1 rows updated
# 7101: Microtis rara / all
# 1 rows updated
# 4473: Microtis unifolia / all
# 1 rows updated
# 10160: Millotia macrocarpa / none
# 1 rows updated
# 1568: Millotia myosotidifolia / none
# 1 rows updated
# Database connection closed.

# %%
type(spcode) is str
isinstance(spcode, str)
# Out:
# True

# %%
j=12
varname=ws.cell(row=2, column=j).value
print(varname)


switcher={
    "epicormic": "epicormic",
    "stem buds": "epicormic",
    "apical": "apical",
    "lignotuber": "lignotuber", 
    "rootstock": "lignotuber", 
    "root stock": "lignotuber",
    "basal": "basal",
    "basal buds": "basal",
    "coppice": "basal",
    "tuber": "tuber",
    "taproot": "tuber",
    "tussock": "tussock",
    "rhizome": "short rhizome",
    "root sucker": "long rhizome or root sucker",
    "root suckers": "long rhizome or root sucker",
    "rootsucker": "long rhizome or root sucker",
    "root buds": "long rhizome or root sucker",
    "stolon": "stolon",
    "stolons": "stolon"
}
# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,regenerative_organ) values('%s',%s,'%s') ON CONFLICT (species,species_code) DO UPDATE SET regenerative_organ=EXCLUDED.regenerative_organ"

for i in range(1,1800):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "other")
        if varref is not None:
            print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        else:
            print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur = conn.cursor()
            cur.execute(qrystr % (spname,spcode,transvalue))
            updated_rows = cur.rowcount
            print("%s rows updated" % (updated_rows))
            conn.commit()
            cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Resprout location
# Connecting to the PostgreSQL database...
# Species Code: Current Scientific Name / (Resprout location) other
# 3712: Acacia barringtonensis / (root buds) long rhizome or root sucker
# 1 rows updated
# 11039: Acacia beadleana / (basal buds) basal
# 1 rows updated
# 3716: Acacia binervata / (basal buds) basal
# 1 rows updated
# 3723: Acacia brownii / (basal) basal / References!C2
# 1 rows updated
# 3727: Acacia buxifolia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9282: Acacia buxifolia subsp. pubiflora / (basal buds) basal
# 1 rows updated
# 3742: Acacia cognata / (basal) basal
# 1 rows updated
# 3755: Acacia curranii / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3758: Acacia dealbata / (root suckers / basal) other
# 1 rows updated
# 3769: Acacia elongata / (basal) basal / References!C2
# 1 rows updated
# 3772: Acacia falciformis / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3773: Acacia filicifolia / (root buds) long rhizome or root sucker
# 1 rows updated
# 3777: Acacia floribunda / (basal) basal
# 1 rows updated
# 3788: Acacia harpophylla / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3792: Acacia implexa / (root suckers) long rhizome or root sucker
# 1 rows updated
# 7109: Acacia irrorata subsp. velutinella / (basal) basal
# 1 rows updated
# 3802: Acacia juncifolia / (basal buds) basal
# 1 rows updated
# 6597: Acacia leiocalyx subsp. leiocalyx / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3810: Acacia leptoclada / (basal buds) basal
# 1 rows updated
# 10790: Acacia longifolia subsp. longifolia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 10791: Acacia longifolia subsp. sophorae / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3821: Acacia maidenii / (basal buds) basal
# 1 rows updated
# 3823: Acacia mearnsii / (rootstock & root suckers) other
# 1 rows updated
# 8973: Acacia meiantha / (rootstock) lignotuber
# 1 rows updated
# 3824: Acacia melanoxylon / (lignotuber & root suckers) other / References!C49
# 1 rows updated
# 10058: Acacia mucronata subsp. longifolia / (stem bases) other
# 1 rows updated
# 3835: Acacia neriifolia / (root buds) long rhizome or root sucker
# 1 rows updated
# 11005: Acacia nova-anglica ms / (root buds) long rhizome or root sucker
# 1 rows updated
# 3839: Acacia obtusifolia / (basal & root suckers) other
# 1 rows updated
# 3844: Acacia oxycedrus / (basal) basal
# 1 rows updated
# 3846: Acacia parramattensis / (root suckers & basal & epicormic) other
# 1 rows updated
# 3858: Acacia pruinosa / (basal buds) basal
# 1 rows updated
# 3860: Acacia pubescens / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3862: Acacia pycnostachya / (basal buds) basal
# 1 rows updated
# 3863: Acacia quadrilateralis / (basal) basal
# 1 rows updated
# 12042: Acacia ramulosa var. ramulosa / (rootstock) lignotuber
# 1 rows updated
# 3869: Acacia rubida / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3881: Acacia suaveolens / (root buds) long rhizome or root sucker
# 1 rows updated
# 3885: Acacia terminalis / (basal) basal
# 1 rows updated
# 3886: Acacia tetragonophylla / (basal) basal
# 1 rows updated
# 8865: Acacia venulosa / (basal buds) basal
# 1 rows updated
# 11245: Acacia verticillata subsp. verticillata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 11245: Acacia verticillata subsp. verticillata / (basal) basal
# 1 rows updated
# 3898: Acacia victoriae / (basal) basal
# 1 rows updated
# 3899: Acacia viscidula / (basal buds) basal
# 1 rows updated
# 10796: Acacia williamsiana / (root buds) long rhizome or root sucker
# 1 rows updated
# 5603: Acaena echinata / (basal) basal
# 1 rows updated
# 5604: Acaena novae-zelandiae / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5605: Acaena ovina / (root suckers) long rhizome or root sucker
# 1 rows updated
# 4351: Acianthus caudatus / (tuber) tuber / References!A16
# 1 rows updated
# 4352: Acianthus exsertus / (tuber) tuber / References!C106
# 1 rows updated
# 4353: Acianthus fornicatus / (basal) basal
# 1 rows updated
# 9088: Acianthus pusillus / (tuber) tuber
# 1 rows updated
# 1090: Aciphylla glacialis / (basal) basal
# 1 rows updated
# 3968: Acmena smithii / (lignotuber & epicormic; stem buds) other
# 1 rows updated
# 5719: Acradenia euodiiformis / (root suckers) long rhizome or root sucker
# 1 rows updated
# 8418: Acronychia imperforata / (basal) basal
# 1 rows updated
# 5722: Acronychia oblongifolia / (basal & root suckers) other
# 1 rows updated
# 2265: Acrophyllum australe / (lignotuber) lignotuber
# 1 rows updated
# 11966: Acrothamnus hookeri / (basal buds) basal
# 1 rows updated
# 12059: Acrothamnus montanus / (basal) basal
# 1 rows updated
# 2580: Acrotriche aggregata / (basal buds) basal
# 1 rows updated
# 2583: Acrotriche serrulata / (lignotuber) lignotuber / References!A16
# 1 rows updated
# 7997: Adiantum aethiopicum / (rhizome) short rhizome / References!A20
# 1 rows updated
# 8000: Adiantum hispidulum / (rhizome) short rhizome
# 1 rows updated
# 7459: Aegiceras corniculatum / (basal & epicormic) other
# 1 rows updated
# 12011: Agiortia pedicellata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 8669: Alchornea ilicifolia / (basal) basal
# 1 rows updated
# 5872: Alectryon coriaceus / (basal) basal
# 1 rows updated
# 8979: Alexfloydia repens / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9090: Allocasuarina brachystachya / (basal buds) basal
# 1 rows updated
# 8980: Allocasuarina defungens / (rootstock) lignotuber
# 1 rows updated
# 2010: Allocasuarina distyla / (basal) basal
# 1 rows updated
# 8320: Allocasuarina glareicola / (lignotuber & root suckers) other
# 1 rows updated
# 2011: Allocasuarina inophloia / (stem buds) epicormic
# 1 rows updated
# 2012: Allocasuarina littoralis / (basal; stem buds; swamp form basal buds) other
# 1 rows updated
# 2014: Allocasuarina nana / (lignotuber) lignotuber
# 1 rows updated
# 2015: Allocasuarina paludosa / (rootstock) lignotuber
# 1 rows updated
# 2017: Allocasuarina torulosa / (basal or epicormic) other
# 1 rows updated
# 2018: Allocasuarina verticillata / (basal) basal
# 1 rows updated
# 8368: Almaleea cambagei / (basal buds) basal
# 1 rows updated
# 7686: Alphitonia excelsa / (basal) basal
# 1 rows updated
# 6913: Alpinia arundelliana / (basal) basal
# 1 rows updated
# 6340: Alpinia caerulea / (basal) basal
# 1 rows updated
# 1167: Alyxia ruscifolia / (basal buds) basal
# 1 rows updated
# 9713: Amperea xiphoclada var. xiphoclada / (basal / root suckers) other
# 1 rows updated
# 7650: Amphipogon strictus var. strictus / (rhizome) short rhizome
# 1 rows updated
# 3969: Angophora bakeri / (basal & epicormic) other
# 1 rows updated
# 3970: Angophora costata / (basal & epicormic) other
# 1 rows updated
# 9012: Angophora crassifolia / (basal) basal
# 1 rows updated
# 9717: Angophora euryphylla / (epicormic) epicormic
# 1 rows updated
# 3971: Angophora floribunda / (epicormic) epicormic
# 1 rows updated
# 3972: Angophora hispida / (lignotuber & epicormic) other
# 1 rows updated
# 9619: Angophora inopina / (basal & epicormic) other
# 1 rows updated
# 3974: Angophora subvelutina / (epicormic) epicormic
# 1 rows updated
# 4749: Anisopogon avenaceus / (rhizome) short rhizome
# 1 rows updated
# 3221: Anopterus macleayanus / (basal buds) basal
# 1 rows updated
# 2770: Aotus ericoides / (lignotuber; basal buds) other
# 1 rows updated
# 11046: Aotus subglauca var. subglauca / (basal buds) basal
# 1 rows updated
# 3976: Archirhodomyrtus beckleri / (basal) basal
# 1 rows updated
# 12689: Argyrotegium fordianum / (basal) basal
# 1 rows updated
# 9722: Aristea ecklonii / (rhizome) short rhizome
# 1 rows updated
# 4773: Aristida vagans / (basal) basal
# 1 rows updated
# 2567: Aristotelia australasica / (basal buds) basal
# 1 rows updated
# 3517: Arthropodium milleflorum / (basal) basal
# 1 rows updated
# 3518: Arthropodium minus / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9097: Arthropodium sp. B / (tuber) tuber
# 1 rows updated
# 4777: Arundo donax / (rhizome) short rhizome / References!C130
# 1 rows updated
# 5657: Asperula gunnii / (basal) basal
# 1 rows updated
# 5659: Asperula scoparia / (basal) basal
# 1 rows updated
# 5728: Asterolasia correifolia / (basal buds) basal
# 1 rows updated
# 2584: Astroloma humifusum / (lignotuber) lignotuber
# 1 rows updated
# 1200: Astrotricha crassifolia / (rootstock & root suckers) other
# 1 rows updated
# 1203: Astrotricha ledifolia / (rootstock) lignotuber
# 1 rows updated
# 1205: Astrotricha longifolia / (basal) basal
# 1 rows updated
# 9015: Astrotricha roddii / (basal buds) basal
# 1 rows updated
# 3910: Atherosperma moschatum / (basal) basal
# 1 rows updated
# 7840: Australopyrum velutinum / (basal) basal
# 1 rows updated
# 6594: Austrofestuca littoralis / (basal) basal
# 1 rows updated
# 3982: Austromyrtus tenuifolia / (basal) basal
# 1 rows updated
# 9960: Austrostipa nivicola / (basal) basal
# 1 rows updated
# 10398: Austrostipa rudis subsp. nervosa / (rhizome) short rhizome
# 1 rows updated
# 10394: Austrostipa semibarbata / (rhizome) short rhizome
# 1 rows updated
# 10382: Austrostipa setacea / (basal) basal
# 1 rows updated
# 10427: Avicennia marina subsp. australasica / (basal) basal
# 1 rows updated
# 3984: Backhousia myrtifolia / (basal) basal
# 1 rows updated
# 3986: Baeckea brevifolia / (basal) basal
# 1 rows updated
# 3993: Baeckea diosmifolia / (basal) basal
# 1 rows updated
# 9835: Baeckea frutescens / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3994: Baeckea gunniana / (basal) basal
# 1 rows updated
# 3995: Baeckea imbricata / (basal) basal
# 1 rows updated
# 3997: Baeckea linifolia / (basal / root suckers) other
# 1 rows updated
# 9836: Baeckea omissa / (basal buds) basal
# 1 rows updated
# 10606: Baloskion fimbriatum / (rhizome) short rhizome
# 1 rows updated
# 10607: Baloskion gracile / (rhizome) short rhizome
# 1 rows updated
# 10609: Baloskion pallens / (rhizome) short rhizome
# 1 rows updated
# 10610: Baloskion stenocoleum / (rhizome) short rhizome
# 1 rows updated
# 10613: Baloskion tetraphyllum subsp. tetraphyllum / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5339: Banksia aemula / (epicormic) epicormic
# 1 rows updated
# 7509: Banksia collina / (basal buds) basal
# 1 rows updated
# 5343: Banksia integrifolia / (basal) basal
# 1 rows updated
# 6603: Banksia integrifolia subsp. integrifolia / (epicormic) epicormic
# 1 rows updated
# 10817: Banksia integrifolia subsp. monticola / (basal) basal
# 1 rows updated
# 5344: Banksia marginata / (lignotuber / sometimes suckers) other
# 1 rows updated
# 14554: Banksia neoanglica / (lignotuber) lignotuber / References!C57
# 1 rows updated
# 14554: Banksia neoanglica / (basal buds) basal
# 1 rows updated
# 5345: Banksia oblongifolia / (lignotuber) lignotuber
# 1 rows updated
# 5346: Banksia paludosa / (basal) basal
# 1 rows updated
# 10874: Banksia paludosa subsp. paludosa / (lignotuber) lignotuber
# 1 rows updated
# 5347: Banksia robur / (lignotuber) lignotuber
# 1 rows updated
# 5348: Banksia serrata / (lignotuber & epicormic) other
# 1 rows updated
# 5349: Banksia spinulosa / (lignotuber) lignotuber
# 1 rows updated
# 7509: Banksia spinulosa var. collina / (lignotuber) lignotuber
# 1 rows updated
# 7488: Banksia spinulosa var. spinulosa / (lignotuber) lignotuber
# 1 rows updated
# 2267: Bauera capitata / (basal) basal
# 1 rows updated
# 2268: Bauera rubioides / (basal) basal
# 1 rows updated
# 2294: Baumea acuta / (rhizome) short rhizome
# 1 rows updated
# 2297: Baumea gunnii / (rhizome) short rhizome
# 1 rows updated
# 2299: Baumea juncea / (root suckers/rhizome) other
# 1 rows updated
# 2300: Baumea muelleri / (rhizome) short rhizome
# 1 rows updated
# 2301: Baumea nuda / (rhizome) short rhizome
# 1 rows updated
# 2302: Baumea rubiginosa / (rhizome) short rhizome
# 1 rows updated
# 2303: Baumea teretifolia / (rhizome) short rhizome
# 1 rows updated
# 2304: Baumea tetragona / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1282: Bedfordia arborescens / (lignotuber) lignotuber
# 1 rows updated
# 4671: Billardiera scandens / (basal) basal
# 1 rows updated
# 3527: Blandfordia cunninghamii / (rhizome?) other
# 1 rows updated
# 3529: Blandfordia nobilis / (basal) basal
# 1 rows updated
# 8052: Blechnum cartilagineum / (rhizome) short rhizome
# 1 rows updated
# 8057: Blechnum indicum / (basal) basal
# 1 rows updated
# 7760: Blechnum minus / (basal) basal
# 1 rows updated
# 8058: Blechnum nudum / (epicormic or apical & rhizome) other
# 1 rows updated
# 8063: Blechnum wattsii / (rhizome) short rhizome
# 1 rows updated
# 5732: Boronia algida / (basal buds) basal
# 1 rows updated
# 12257: Boronia anemonifolia subsp. anemonifolia / (basal) basal
# 1 rows updated
# 5739: Boronia falcifolia / (basal) basal
# 1 rows updated
# 5744: Boronia ledifolia / (basal) basal
# 1 rows updated
# 5745: Boronia microphylla / (basal buds) basal
# 1 rows updated
# 5750: Boronia pinnata / (root suckers; basal buds) other
# 1 rows updated
# 5751: Boronia polygalifolia / (basal) basal
# 1 rows updated
# 2778: Bossiaea ensata / (basal) basal
# 1 rows updated
# 2779: Bossiaea foliosa / (basal) basal
# 1 rows updated
# 2780: Bossiaea heterophylla / (basal) basal
# 1 rows updated
# 2781: Bossiaea kiamensis / (rootstock) lignotuber
# 1 rows updated
# 2783: Bossiaea neo-anglica / (basal buds) basal
# 1 rows updated
# 2784: Bossiaea obcordata / (basal) basal
# 1 rows updated
# 2786: Bossiaea prostrata / (basal buds) basal
# 1 rows updated
# 2787: Bossiaea rhombifolia / (basal) basal / References!C2
# 1 rows updated
# 2788: Bossiaea riparia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2789: Bossiaea scolopendria / (basal / root suckers) other
# 1 rows updated
# 2790: Bossiaea scortechinii / (basal buds) basal
# 1 rows updated
# 2791: Bossiaea stephensonii / (basal) basal
# 1 rows updated
# 8144: Botrychium australe / (rhizome) short rhizome / References!C2
# 1 rows updated
# 8961: Brachychiton populneus subsp. populneus / (basal) basal
# 1 rows updated
# 10689: Brachyloma daphnoides subsp. daphnoides / (basal) basal
# 1 rows updated
# 10690: Brachyloma daphnoides subsp. glabrum / (basal buds) basal
# 1 rows updated
# 9295: Brachyloma saxicola / (rootstock) lignotuber
# 1 rows updated
# 11056: Brachyscome dentata / (rhizome) short rhizome / References!C2
# 1 rows updated
# 13832: Brachyscome linearifolia / (stolons) stolon
# 1 rows updated
# 7317: Brachyscome multifida / (basal) basal
# 1 rows updated
# 6559: Brachyscome rigidula / (basal) basal
# 1 rows updated
# 7318: Brachyscome scapigera / (basal) basal
# 1 rows updated
# 7357: Brachyscome spathulata / (basal) basal
# 1 rows updated
# 2695: Breynia oblongifolia / (basal) basal
# 1 rows updated
# 1863: Brunonia australis / (rhizome) short rhizome
# 1 rows updated
# 1003: Brunoniella australis / (basal) basal
# 1 rows updated
# 1004: Brunoniella pumilio / (basal) basal
# 1 rows updated
# 3531: Bulbine bulbosa / (basal) basal
# 1 rows updated
# 3533: Burchardia umbellata / (tuber) tuber / References!B26
# 1 rows updated
# 4368: Burnettia cuneata / (tuber) tuber / References!C22
# 1 rows updated
# 4674: Bursaria spinosa / (lignotuber) lignotuber / References!C49
# 1 rows updated
# 11018: Bursaria spinosa subsp. spinosa / (basal) basal
# 1 rows updated
# 6161: Cadellia pentastylis / (rootstock & coppice) other
# 1 rows updated
# 3534: Caesia alpina / (basal) basal
# 1 rows updated
# 3535: Caesia parviflora / (tuber) tuber / References!A16
# 1 rows updated
# 7183: Caesia parviflora var. parviflora / (rhizome) short rhizome
# 1 rows updated
# 7333: Caesia parviflora var. vittata / (basal) basal
# 1 rows updated
# 6838: Caladenia alata / (a-tuber) other
# 1 rows updated
# 11246: Caladenia capillata / (tuber) tuber / References!A16
# 1 rows updated
# 4373: Caladenia carnea / (tuber) tuber / References!C11
# 1 rows updated
# 6703: Caladenia catenata / (a-tuber) other
# 1 rows updated
# 9523: Caladenia concolor / (a-tuber) other
# 1 rows updated
# 4376: Caladenia cucullata / (basal) basal
# 1 rows updated
# 4379: Caladenia dimorpha / (basal) basal
# 1 rows updated
# 9123: Caladenia gracilis / (a-tuber) other
# 1 rows updated
# 9477: Caladenia rosella / (a-tuber) other
# 1 rows updated
# 9192: Caladenia sp. A / (tuber) tuber
# 1 rows updated
# 13313: Caladenia transitoria / (basal) basal
# 1 rows updated
# 5314: Calandrinia pickeringii / (rhizome) short rhizome
# 1 rows updated
# 2269: Caldcluvia paniculosa / (basal buds) basal
# 1 rows updated
# 4389: Caleana major / (tuber) tuber / References!C11
# 1 rows updated
# 2270: Callicoma serratifolia / (basal & epicormic) other
# 1 rows updated
# 4002: Callistemon acuminatus / (basal) basal
# 1 rows updated
# 4004: Callistemon citrinus / (basal & epicormic) other
# 1 rows updated
# 4005: Callistemon comboynensis / (root suckers) long rhizome or root sucker
# 1 rows updated
# 4009: Callistemon montanus / (root suckers) long rhizome or root sucker
# 1 rows updated
# 4011: Callistemon pallidus / (root suckers) long rhizome or root sucker
# 1 rows updated
# 7943: Callistemon pityoides / (basal) basal
# 1 rows updated
# 9126: Callistemon pungens / (basal buds) basal
# 1 rows updated
# 4014: Callistemon rigidus / (basal) basal
# 1 rows updated
# 4015: Callistemon salignus / (epicormic & basal) other
# 1 rows updated
# 4016: Callistemon shiressii / (epicormic & rootstock) other
# 1 rows updated
# 4017: Callistemon sieberi / (basal) basal
# 1 rows updated
# 14189: Callistemon sp. aff. flavovirens / (basal) basal
# 1 rows updated
# 2281: Callitris monticola / (basal buds) basal
# 1 rows updated
# 4390: Calochilus campestris / (a-tuber) other
# 1 rows updated
# 4391: Calochilus gracillimus / (a-tuber) other
# 1 rows updated
# 4394: Calochilus paludosus / (basal) basal
# 1 rows updated
# 4395: Calochilus robertsonii / (a-tuber) other
# 1 rows updated
# 8341: Calochlaena dubia / (rhizome) short rhizome
# 1 rows updated
# 4021: Calytrix tetragona / (basal) basal
# 1 rows updated
# 2310: Carex appressa / (basal) basal
# 1 rows updated
# 2313: Carex breviculmis / (basal) basal
# 1 rows updated
# 2315: Carex canescens / (basal) basal
# 1 rows updated
# 2316: Carex capillacea / (basal) basal
# 1 rows updated
# 2317: Carex cephalotes / (basal) basal
# 1 rows updated
# 2322: Carex gaudichaudiana / (basal) basal
# 1 rows updated
# 2324: Carex hebes / (basal) basal
# 1 rows updated
# 2329: Carex jackiana / (basal) basal
# 1 rows updated
# 2331: Carex longebrachiata / (rhizome) short rhizome
# 1 rows updated
# 2339: Carpha nivicola / (basal) basal
# 1 rows updated
# 9296: Cassia brewsteri var. marksiana / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1369: Cassinia longifolia / (basal) basal
# 1 rows updated
# 2022: Casuarina glauca / (basal & epicormic) other
# 1 rows updated
# 6281: Cayratia clematidea / (rootstock) lignotuber
# 1 rows updated
# 10835: Celmisia pugioniformis / (basal) basal
# 1 rows updated
# 1206: Cephalaralia cephalobotrys  / (stem buds) epicormic
# 1 rows updated
# 2271: Ceratopetalum apetalum / (basal) basal
# 1 rows updated
# 2272: Ceratopetalum gummiferum / (basal) basal
# 1 rows updated
# 14091: Cestichis reflexa / (a-tuber) other
# 1 rows updated
# 8005: Cheilanthes austrotenuifolia / (rhizome) short rhizome / References!C2
# 1 rows updated
# 6382: Cheilanthes distans / (rhizome) short rhizome
# 1 rows updated
# 8007: Cheilanthes sieberi subsp. sieberi / (rhizome) short rhizome
# 1 rows updated
# 8868: Chiloglottis sphyrnoides / (tuber) tuber
# 1 rows updated
# 6881: Chiloglottis sylvestris / (a-tuber) other
# 1 rows updated
# 6525: Chiloglottis trilabra / (tuber) tuber
# 1 rows updated
# 10289: Chiloglottis valida / (basal) basal
# 1 rows updated
# 6243: Chloanthes stoechadis / (basal) basal
# 1 rows updated
# 4833: Chloris truncata / (basal) basal
# 1 rows updated
# 5856: Choretrum candollei / (root suckers) long rhizome or root sucker
# 1 rows updated
# 4022: Choricarpia leptopetala / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2344: Chorizandra cymbaria / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2345: Chorizandra sphaerocephala / (root suckers) long rhizome or root sucker
# 1 rows updated
# 8188: Christella dentata / (rhizome) short rhizome
# 1 rows updated
# 8562: Chrysocephalum semipapposum / (rootstock / root suckers) other
# 1 rows updated
# 3472: Cinnamomum oliveri / (basal buds) basal
# 1 rows updated
# 6283: Cissus hypoglauca / (rootstock, basal ) other
# 1 rows updated
# 2698: Claoxylon australe / (basal buds) basal
# 1 rows updated
# 5493: Clematis aristata / (root suckers; basal buds) other
# 1 rows updated
# 6903: Clematis glycinoides var. glycinoides / (root suckers) long rhizome or root sucker
# 1 rows updated
# 6484: Clerodendrum tomentosum / (basal) basal
# 1 rows updated
# 5531: Coleocarya gracilis / (rhizome) short rhizome
# 1 rows updated
# 5252: Comesperma defoliatum / (basal buds) basal
# 1 rows updated
# 5253: Comesperma ericinum / (basal) basal
# 1 rows updated
# 5255: Comesperma retusum / (basal buds) basal
# 1 rows updated
# 5256: Comesperma sphaerocarpum / (basal) basal
# 1 rows updated
# 2209: Commelina cyanea / (basal) basal
# 1 rows updated
# 9136: Conospermum ellipticum / (basal) basal
# 1 rows updated
# 5351: Conospermum longifolium / (basal) basal
# 1 rows updated
# 5352: Conospermum taxifolium / (basal buds) basal
# 1 rows updated
# 10138: Conyza canadensis var. canadensis / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5670: Coprosma hirtella / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5675: Coprosma quadrifida / (lignotuber / root suckers; basal buds) other
# 1 rows updated
# 13961: Coronidium oxylepis / (rootstock) lignotuber
# 1 rows updated
# 13836: Coronidium scorpioides / (rhizome) short rhizome
# 1 rows updated
# 5772: Correa reflexa / (lignotuber) lignotuber
# 1 rows updated
# 5772: Correa reflexa (resprouter green flowered) / (basal buds) basal
# 1 rows updated
# 4839: Cortaderia selloana / (rhizome) short rhizome
# 1 rows updated
# 4404: Corybas aconitiflorus / (a-tuber) other
# 1 rows updated
# 4408: Corybas fordhamii / (a-tuber) other
# 1 rows updated
# 4409: Corybas hispidus / (a-tuber) other
# 1 rows updated
# 9743: Corymbia eximia / (epicormic) epicormic
# 1 rows updated
# 9687: Corymbia gummifera / (epicormic & lignotuber) other
# 1 rows updated
# 9601: Corymbia intermedia / (basal) basal
# 1 rows updated
# 9692: Corymbia maculata / (epicormic & lignotuber) other
# 1 rows updated
# 9744: Corymbia tessellaris / (basal) basal
# 1 rows updated
# 6981: Corynocarpus rupestris / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1411: Cotula alpina / (basal) basal
# 1 rows updated
# 9952: Craspedia aurantia / (basal) basal
# 1 rows updated
# 9139: Craspedia canens / (rhizome) short rhizome
# 1 rows updated
# 8565: Craspedia coolaminica / (basal) basal
# 1 rows updated
# 8566: Craspedia jamesii / (basal) basal
# 1 rows updated
# 10271: Crocosmia X crocosmiiflora / (stolon) stolon
# 1 rows updated
# 5554: Cryptandra amara / (basal) basal
# 1 rows updated
# 8611: Cryptandra amara var. amara / (basal) basal
# 1 rows updated
# 8784: Cryptandra amara var. longiflora / (basal buds) basal
# 1 rows updated
# 3478: Cryptocarya foveolata / (basal buds) basal
# 1 rows updated
# 3479: Cryptocarya glaucescens / (basal) basal
# 1 rows updated
# 3485: Cryptocarya rigida / (basal buds) basal
# 1 rows updated
# 4414: Cryptostylis erecta / (rhizome) short rhizome
# 1 rows updated
# 4415: Cryptostylis hunteriana / (rhizome) short rhizome
# 1 rows updated
# 4416: Cryptostylis leptochila / (a-rhizome) other
# 1 rows updated
# 4417: Cryptostylis subulata / (rhizome) short rhizome
# 1 rows updated
# 7384: Cupaniopsis newmanii / (root suckers) long rhizome or root sucker
# 1 rows updated
# 11228: Cyanicula caerulea / (basal) basal
# 1 rows updated
# 8074: Cyathea australis / (rhizome or apical) other
# 1 rows updated
# 2347: Cyathochaeta diandra / (rhizome) short rhizome
# 1 rows updated
# 11599: Cyclophyllum longipetalum / (basal) basal
# 1 rows updated
# 7675: Cymbopogon ambiguus / (basal) basal
# 1 rows updated
# 6540: Cynodon dactylon / (rhizome) short rhizome
# 1 rows updated
# 1749: Cynoglossum suaveolens / (rhizome) short rhizome
# 1 rows updated
# 2348: Cyperus albostriatus / (rhizome) short rhizome
# 1 rows updated
# 2353: Cyperus brevifolius / (rhizome) short rhizome
# 1 rows updated
# 2364: Cyperus eragrostis / (rhizome) short rhizome
# 1 rows updated
# 2372: Cyperus fulvus / (basal) basal
# 1 rows updated
# 7440: Dampiera fusca / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3172: Dampiera purpurea / (basal) basal
# 1 rows updated
# 3173: Dampiera scottiana / (basal) basal
# 1 rows updated
# 3174: Dampiera stricta / (rhizome) short rhizome
# 1 rows updated
# 4025: Darwinia camptostylis / (root suckers) long rhizome or root sucker
# 1 rows updated
# 6508: Darwinia fascicularis subsp. fascicularis / (basal) basal
# 1 rows updated
# 7135: Darwinia fascicularis subsp. oligantha / (basal) basal
# 1 rows updated
# 4029: Darwinia grandiflora / (basal) basal
# 1 rows updated
# 2819: Daviesia brevifolia / (lignotuber) lignotuber
# 1 rows updated
# 2822: Daviesia genistifolia / (basal buds) basal
# 1 rows updated
# 2823: Daviesia latifolia / (basal) basal
# 1 rows updated
# 2824: Daviesia mimosoides / (root suckers) long rhizome or root sucker
# 1 rows updated
# 7211: Daviesia mimosoides subsp. mimosoides / (basal) basal
# 1 rows updated
# 2827: Daviesia ulicifolia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2828: Daviesia umbellulata / (root buds (133) other
# 1 rows updated
# 4432: Dendrobium speciosum / (basal) basal
# 1 rows updated
# 8387: Denhamia celastroides / (basal buds) basal
# 1 rows updated
# 2839: Desmodium rhytidophyllum / (basal) basal
# 1 rows updated
# 2840: Desmodium varians / (basal) basal
# 1 rows updated
# 4880: Deyeuxia crassiuscula / (basal) basal
# 1 rows updated
# 6940: Deyeuxia monticola var. monticola / (basal) basal
# 1 rows updated
# 4891: Deyeuxia quadriseta / (rhizome) short rhizome
# 1 rows updated
# 3540: Dianella caerulea / (basal) basal
# 1 rows updated
# 6700: Dianella caerulea var. caerulea / (basal) basal
# 1 rows updated
# 8725: Dianella longifolia var. longifolia / (rhizome) short rhizome
# 1 rows updated
# 3542: Dianella revoluta / (tuber) tuber / References!A16
# 1 rows updated
# 7580: Dianella revoluta var. revoluta / (rhizome) short rhizome
# 1 rows updated
# 3543: Dianella tasmanica / (rhizome) short rhizome
# 1 rows updated
# 4897: Dichelachne crinita / (basal) basal
# 1 rows updated
# 8748: Dichelachne inaequiglumis / (basal) basal
# 1 rows updated
# 4898: Dichelachne micrantha / (basal) basal
# 1 rows updated
# 4899: Dichelachne rara / (rhizome) short rhizome
# 1 rows updated
# 9151: Dichelachne sieberiana / (basal) basal
# 1 rows updated
# 8082: Dicksonia antarctica / (basal / apical) other
# 1 rows updated
# 2844: Dillwynia glaberrima / (basal) basal
# 1 rows updated
# 2845: Dillwynia hispida / (rootstock) lignotuber
# 1 rows updated
# 7225: Dillwynia phylicoides / (basal buds) basal
# 1 rows updated
# 2851: Dillwynia sericea / (basal) basal
# 1 rows updated
# 8734: Dillwynia sieberi / (basal buds) basal
# 1 rows updated
# 2852: Dillwynia stipulifera / (basal) basal
# 1 rows updated
# 2562: Diospyros australis / (root buds) long rhizome or root sucker
# 1 rows updated
# 11298: Diplaspis nivis / (basal) basal
# 1 rows updated
# 4437: Dipodium hamiltonianum / (a-rootstock) other
# 1 rows updated
# 7887: Dipodium punctatum / (tuber) tuber
# 1 rows updated
# 7888: Dipodium variegatum / (a-rootstock) other
# 1 rows updated
# 5564: Discaria pubescens / (root suckers) long rhizome or root sucker
# 1 rows updated
# 4444: Diuris brevissima / (a-tuber) other
# 1 rows updated
# 9026: Diuris flavescens / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9156: Diuris lanceolata / (basal) basal
# 1 rows updated
# 4446: Diuris longifolia / (a-tuber) other
# 1 rows updated
# 4447: Diuris maculata / (tuber) tuber
# 1 rows updated
# 13970: Diuris orientis / (basal) basal
# 1 rows updated
# 6671: Diuris pauciflora / (a-tuber) other
# 1 rows updated
# 9157: Diuris punctata var. punctata / (a-tuber) other
# 1 rows updated
# 4456: Diuris sulphurea / (a-tuber) other
# 1 rows updated
# 4458: Diuris venosa / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5911: Dodonaea triquetra / (basal buds) basal
# 1 rows updated
# 5913: Dodonaea viscosa / (basal) basal
# 1 rows updated
# n/a: Dodonaea viscosa subsp. Black Fruits / (basal buds) basal
# 7011: Dodonaea viscosa subsp. cuneata / (basal) basal
# 1 rows updated
# 8064: Doodia aspera / (rhizome) short rhizome
# 1 rows updated
# 1019: Doryanthes excelsa / (apical buds) other / References!C107
# 1 rows updated
# 3913: Doryphora sassafras / (basal buds) basal
# 1 rows updated
# 2555: Drosera arcturi / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2556: Drosera auriculata / (tuber) tuber / References!C11
# 1 rows updated
# 2557: Drosera binata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2558: Drosera glanduligera / (tuber) tuber / References!C11
# 1 rows updated
# 2559: Drosera peltata / (tuber) tuber / References!A32
# 1 rows updated
# 2560: Drosera pygmaea / (tuber) tuber / References!C11
# 1 rows updated
# 2561: Drosera spatulata / (basal) basal
# 1 rows updated
# 3546: Drymophila cyanocarpa / (basal) basal
# 1 rows updated
# 3547: Drymophila moorei / (rhizome) short rhizome
# 1 rows updated
# 6036: Duboisia myoporoides / (root suckers; basal buds) other
# 1 rows updated
# 3676: Dysoxylum fraserianum / (basal) basal
# 1 rows updated
# 7593: Echinopogon caespitosus var. caespitosus / (basal) basal
# 1 rows updated
# 4934: Echinopogon ovatus / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2571: Elaeocarpus holopetalus / (lignotuber) lignotuber
# 1 rows updated
# 2574: Elaeocarpus reticulatus / (lignotuber) lignotuber
# 1 rows updated
# 12523: Elaeodendron australe var. australe / (basal) basal
# 1 rows updated
# 6988: Eleocharis sphacelata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 8796: Elymus scaber / (basal) basal
# 1 rows updated
# 5532: Empodisma minus / (rhizome) short rhizome
# 1 rows updated
# 3493: Endiandra muelleri / (basal buds) basal
# 1 rows updated
# 3495: Endiandra sieberi / (apical / basal) other
# 1 rows updated
# 4947: Entolasia stricta / (rhizome) short rhizome
# 1 rows updated
# 2591: Epacris breviflora / (basal) basal
# 1 rows updated
# 10839: Epacris celata / (basal) basal
# 1 rows updated
# 2595: Epacris glacialis / (basal) basal
# 1 rows updated
# 10842: Epacris gunnii / (basal) basal
# 1 rows updated
# 2596: Epacris hamiltonii / (basal & root suckers) other
# 1 rows updated
# 2599: Epacris microphylla / (basal) basal
# 1 rows updated
# n/a: Epacris microphylla = gunnii / (basal buds) basal
# 2603: Epacris paludosa / (basal) basal
# 1 rows updated
# 7952: Epilobium billardiereanum subsp. cinereum / (basal) basal
# 1 rows updated
# 4329: Epilobium gunnianum / (basal) basal
# 1 rows updated
# 7578: Eragrostis benthamii / (basal) basal
# 1 rows updated
# 8602: Eremophila debilis / (rootstock) lignotuber
# 1 rows updated
# 7252: Eremophila deserti / (basal) basal
# 1 rows updated
# 3941: Eremophila latrobei / (basal) basal
# 1 rows updated
# 3942: Eremophila longifolia / (basal) basal
# 1 rows updated
# 3944: Eremophila mitchellii / (basal) basal
# 1 rows updated
# 3949: Eremophila sturtii / (basal) basal
# 1 rows updated
# 11025: Erigeron bellidioides / (basal) basal
# 1 rows updated
# 4460: Eriochilus cucullatus / (tuber) tuber / References!A16
# 1 rows updated
# 4035: Eucalyptus acaciiformis / (basal buds) basal
# 1 rows updated
# 7027: Eucalyptus acmenoides / (basal & epicormic) other
# 1 rows updated
# 4037: Eucalyptus agglomerata / (basal & epicormic) other
# 1 rows updated
# 4038: Eucalyptus aggregata / (epicormic) epicormic
# 1 rows updated
# 9007: Eucalyptus amplifolia subsp. amplifolia / (epicormic) epicormic
# 1 rows updated
# 8617: Eucalyptus ancophila / (epicormic) epicormic
# 1 rows updated
# 4043: Eucalyptus apiculata / (lignotuber) lignotuber
# 1 rows updated
# 7189: Eucalyptus baueriana / (epicormic) epicormic
# 1 rows updated
# 4053: Eucalyptus baxteri / (epicormic / lignotuber) other
# 1 rows updated
# 8330: Eucalyptus bensonii / (basal) basal
# 1 rows updated
# 4055: Eucalyptus benthamii / (basal & epicormic) other
# 1 rows updated
# 8356: Eucalyptus beyeriana / (epicormic) epicormic
# 1 rows updated
# 8450: Eucalyptus bicostata / (epicormic & lignotuber) other
# 1 rows updated
# 4057: Eucalyptus blakelyi / (epicormic) epicormic
# 1 rows updated
# 4058: Eucalyptus blaxlandii / (epicormic) epicormic
# 1 rows updated
# 4059: Eucalyptus bosistoana / (basal & epicormic) other
# 1 rows updated
# 4060: Eucalyptus botryoides / (epicormic & lignotuber) other
# 1 rows updated
# 4061: Eucalyptus bridgesiana / (epicormic) epicormic
# 1 rows updated
# 8681: Eucalyptus brunnea / (stem buds) epicormic
# 1 rows updated
# 4062: Eucalyptus burgessiana / (lignotuber) lignotuber
# 1 rows updated
# 9517: Eucalyptus caleyi subsp. ovendenii / (basal & epicormic) other
# 1 rows updated
# 4064: Eucalyptus caliginosa / (basal buds) basal
# 1 rows updated
# 6360: Eucalyptus camaldulensis / (coppice / epicormic) other
# 1 rows updated
# 4066: Eucalyptus cameronii / (stem buds) epicormic
# 1 rows updated
# 4067: Eucalyptus camfieldii / (lignotuber & epicormic) other
# 1 rows updated
# 8652: Eucalyptus campanulata / (stem buds) epicormic
# 1 rows updated
# 8326: Eucalyptus cannonii / (epicormic) epicormic
# 1 rows updated
# 4069: Eucalyptus capitellata / (epicormic) epicormic
# 1 rows updated
# 8328: Eucalyptus codonocarpa / (basal buds) basal
# 1 rows updated
# 4073: Eucalyptus consideniana / (lignotuber & epicormic) other
# 1 rows updated
# 10020: Eucalyptus corticosa / (epicormic & lignotuber) other
# 1 rows updated
# 12178: Eucalyptus costata subsp. murrayana / (lignotuber) lignotuber
# 1 rows updated
# 4074: Eucalyptus crebra / (epicormic) epicormic
# 1 rows updated
# 8352: Eucalyptus croajingolensis / (lignotuber & epicormic) other
# 1 rows updated
# 6473: Eucalyptus cunninghamii / (basal) basal
# 1 rows updated
# 4075: Eucalyptus cypellocarpa / (epicormic & lignotuber) other
# 1 rows updated
# 7309: Eucalyptus dalrympleana subsp. dalrympleana / (lignotuber & epicormic) other
# 1 rows updated
# 4079: Eucalyptus deanei / (epicormic) epicormic
# 1 rows updated
# 4082: Eucalyptus dives / (lignotuber & epicormic) other
# 1 rows updated
# 4083: Eucalyptus dumosa / (lignotuber) lignotuber
# 1 rows updated
# 4086: Eucalyptus elata / (epicormic) epicormic
# 1 rows updated
# 8682: Eucalyptus elliptica / (basal & epicormic) other
# 1 rows updated
# 4087: Eucalyptus eugenioides / (lignotuber & epicormic) other
# 1 rows updated
# 4090: Eucalyptus fastigata / (epicormic) epicormic
# 1 rows updated
# 8355: Eucalyptus fergusonii subsp. fergusonii / (epicormic) epicormic
# 1 rows updated
# 4091: Eucalyptus fibrosa / (epicormic) epicormic
# 1 rows updated
# 4096: Eucalyptus glaucina / (epicormic) epicormic
# 1 rows updated
# 4097: Eucalyptus globoidea / (lignotuber & epicormic) other
# 1 rows updated
# 4100: Eucalyptus gracilis / (lignotuber) lignotuber
# 1 rows updated
# 4101: Eucalyptus grandis / (coppice) basal
# 1 rows updated
# 4104: Eucalyptus haemastoma / (lignotuber & epicormic) other
# 1 rows updated
# 4112: Eucalyptus laevopinea / (lignotuber and coppice; stem buds) other
# 1 rows updated
# 10030: Eucalyptus laophila / (basal) basal
# 1 rows updated
# 4113: Eucalyptus largeana / (epicormic) epicormic
# 1 rows updated
# 8498: Eucalyptus leptophylla / (lignotuber) lignotuber
# 1 rows updated
# 4117: Eucalyptus ligustrina / (stem buds) epicormic
# 1 rows updated
# 4118: Eucalyptus longifolia / (lignotuber & epicormic) other
# 1 rows updated
# 4116: Eucalyptus luehmanniana / (lignotuber / epicormic) other
# 1 rows updated
# 4120: Eucalyptus macrorhyncha / (lignotuber & epicormic) other
# 1 rows updated
# 7827: Eucalyptus mannifera subsp. mannifera / (rootstock) lignotuber
# 1 rows updated
# 4123: Eucalyptus mckieana / (basal & epicormic) other
# 1 rows updated
# 4125: Eucalyptus melliodora / (lignotuber & epicormic) other
# 1 rows updated
# 4127: Eucalyptus microcarpa / (lignotuber & epicormic) other
# 1 rows updated
# 4128: Eucalyptus microcorys / (epicormic) epicormic
# 1 rows updated
# 4129: Eucalyptus moluccana / (epicormic & basal) other
# 1 rows updated
# 4130: Eucalyptus moorei / (lignotuber) lignotuber
# 1 rows updated
# 4132: Eucalyptus muelleriana / (lignotuber & epicormic) other
# 1 rows updated
# 4133: Eucalyptus multicaulis / (lignotuber) lignotuber
# 1 rows updated
# 4134: Eucalyptus nicholii / (basal & epicormic) other
# 1 rows updated
# 4138: Eucalyptus notabilis / (stem buds) epicormic
# 1 rows updated
# 4140: Eucalyptus obliqua / (epicormic & lignotuber) other
# 1 rows updated
# 4141: Eucalyptus oblonga / (epicormic & lignotuber) other
# 1 rows updated
# 10029: Eucalyptus obstans / (lignotuber & epicormic) other
# 1 rows updated
# 9029: Eucalyptus ophitica / (basal) basal
# 1 rows updated
# 4145: Eucalyptus oreades / (epicormic) epicormic
# 1 rows updated
# 4146: Eucalyptus ovata / (epicormic & lignotuber) other
# 1 rows updated
# 8831: Eucalyptus paniculata subsp. paniculata / (epicormic & basal) other
# 1 rows updated
# 8959: Eucalyptus parramattensis subsp. parramattensis / (epicormic) epicormic
# 1 rows updated
# 4151: Eucalyptus pauciflora / (epicormic & lignotuber) other
# 1 rows updated
# 4155: Eucalyptus pilularis / (epicormic) epicormic
# 1 rows updated
# 4156: Eucalyptus piperita / (epicormic & lignotuber) other
# 1 rows updated
# 9613: Eucalyptus polyanthemos subsp. vestita / (lignotuber & epicormic) other
# 1 rows updated
# 8721: Eucalyptus prava / (basal buds) basal
# 1 rows updated
# 4162: Eucalyptus propinqua / (lignotuber and coppice) other
# 1 rows updated
# 4163: Eucalyptus pulverulenta / (epicormic & lignotuber) other
# 1 rows updated
# 4165: Eucalyptus punctata / (epicormic & lignotuber) other
# 1 rows updated
# 4166: Eucalyptus pyrocarpa / (stem buds) epicormic
# 1 rows updated
# 4167: Eucalyptus quadrangulata / (epicormic) epicormic
# 1 rows updated
# 4168: Eucalyptus racemosa / (epicormic & basal) other
# 1 rows updated
# 7338: Eucalyptus radiata subsp. radiata / (epicormic) epicormic
# 1 rows updated
# 8696: Eucalyptus radiata subsp. sejuncta / (stem buds) epicormic
# 1 rows updated
# 9450: Eucalyptus resinifera subsp. resinifera / (epicormic & basal) other
# 1 rows updated
# 9520: Eucalyptus robertsonii subsp. hemisphaerica / (epicormic) epicormic
# 1 rows updated
# 4171: Eucalyptus robusta / (epicormic) epicormic
# 1 rows updated
# 4172: Eucalyptus rossii / (epicormic & lignotuber) other
# 1 rows updated
# 4173: Eucalyptus rubida / (epicormic & lignotuber) other
# 1 rows updated
# 9750: Eucalyptus rubida subsp. rubida / (lignotuber & epicormic) other
# 1 rows updated
# 4177: Eucalyptus saligna / (epicormic) epicormic
# 1 rows updated
# 4178: Eucalyptus sclerophylla / (epicormic & lignotuber) other
# 1 rows updated
# 4181: Eucalyptus sideroxylon / (epicormic & lignotuber) other
# 1 rows updated
# 4182: Eucalyptus sieberi / (epicormic & lignotuber) other
# 1 rows updated
# 4185: Eucalyptus socialis / (lignotuber) lignotuber
# 1 rows updated
# 8353: Eucalyptus sparsifolia / (epicormic & lignotuber) other
# 1 rows updated
# 4186: Eucalyptus squamosa / (epicormic & lignotuber) other
# 1 rows updated
# 4189: Eucalyptus stricta / (lignotuber) lignotuber
# 1 rows updated
# 4190: Eucalyptus sturgissiana / (lignotuber) lignotuber
# 1 rows updated
# 4191: Eucalyptus tereticornis / (epicormic) epicormic
# 1 rows updated
# 9304: Eucalyptus tricarpa / (epicormic & lignotuber) other
# 1 rows updated
# 4196: Eucalyptus umbra / (lignotuber & epicormic) other
# 1 rows updated
# 4197: Eucalyptus viminalis / (lignotuber & epicormic) other
# 1 rows updated
# 4199: Eucalyptus youmanii / (basal & epicormic) other
# 1 rows updated
# 9691: Euchiton gymnocephalus / (basal) basal
# 1 rows updated
# 5958: Euphrasia collina / (basal) basal
# 1 rows updated
# 2768: Eupomatia laurina / (lignotuber) lignotuber
# 1 rows updated
# 7734: Euroschinus falcatus var. falcatus / (stem buds) epicormic
# 1 rows updated
# 10615: Eurychorda complanata / (rhizome) short rhizome
# 1 rows updated
# 6015: Eustrephus latifolius / (basal) basal
# 1 rows updated
# 5859: Exocarpos aphyllus / (basal) basal
# 1 rows updated
# 5860: Exocarpos cupressiformis / (root suckers / lignotuber & epicormic) other
# 1 rows updated
# 5864: Exocarpos strictus / (basal) basal
# 1 rows updated
# 4992: Festuca muelleri / (basal) basal
# 1 rows updated
# 12416: Ficinia nodosa / (basal) basal
# 1 rows updated
# 7479: Ficus coronata / (basal) basal
# 1 rows updated
# 5354: Floydia praealta / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1118: Foeniculum vulgare / (basal) basal
# 1 rows updated
# 2432: Gahnia clarkei / (rhizome) short rhizome
# 1 rows updated
# 2439: Gahnia melanocarpa / (basal) basal
# 1 rows updated
# 2441: Gahnia radula / (rhizome) short rhizome
# 1 rows updated
# 2442: Gahnia sieberiana / (rhizome) short rhizome
# 1 rows updated
# 5687: Galium murale / (rootstock) lignotuber
# 1 rows updated
# 6016: Geitonoplesium cymosum / (basal) basal
# 1 rows updated
# 9197: Genoplesium archeri / (tuber) tuber
# 1 rows updated
# 8951: Genoplesium despectans / (tuber) tuber
# 1 rows updated
# 9785: Genoplesium morrisii / (tuber) tuber
# 1 rows updated
# 8873: Genoplesium nudiscapum / (a-tuber) other
# 1 rows updated
# 9199: Genoplesium nudum / (a-tuber) other
# 1 rows updated
# 9200: Genoplesium pumilum / (a-tuber) other
# 1 rows updated
# 9201: Genoplesium rufum / (a-tuber) other
# 1 rows updated
# 9543: Genoplesium sagittiferum / (a-tuber) other
# 1 rows updated
# 9544: Genoplesium woollsii / (tuber) tuber
# 1 rows updated
# 3148: Geranium homeanum / (basal) basal
# 1 rows updated
# 3152: Geranium potentilloides / (basal) basal
# 1 rows updated
# 8226: Geranium solanderi var. solanderi / (root stock) lignotuber
# 1 rows updated
# 7138: Gleichenia dicarpa / (rhizome) short rhizome
# 1 rows updated
# 6708: Gleichenia microphylla / (rhizome) short rhizome
# 1 rows updated
# 9360: Glochidion ferdinandi var. ferdinandi / (basal & some epicormic) other
# 1 rows updated
# 4465: Glossodia major / (a-tuber) other
# 1 rows updated
# 4466: Glossodia minor / (a-tuber) other
# 1 rows updated
# 2860: Glycine clandestina / (basal) basal
# 1 rows updated
# 2861: Glycine tabacina / (basal) basal
# 1 rows updated
# 2865: Gompholobium grandiflorum / (basal) basal
# 1 rows updated
# 6921: Gompholobium huegelii / (basal buds) basal
# 1 rows updated
# 11026: Gompholobium inconspicuum / (basal buds) basal
# 1 rows updated
# 2866: Gompholobium latifolium / (basal) basal
# 1 rows updated
# 2869: Gompholobium uncinatum / (basal buds) basal
# 1 rows updated
# 3241: Gonocarpus humilis / (rhizome) short rhizome
# 1 rows updated
# 3247: Gonocarpus tetragynus / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3248: Gonocarpus teucrioides / (basal) basal
# 1 rows updated
# 8711: Goodenia bellidifolia subsp. bellidifolia / (basal) basal
# 1 rows updated
# 9757: Goodenia delicata / (rhizome) short rhizome
# 1 rows updated
# 3180: Goodenia elongata / (basal) basal
# 1 rows updated
# 7958: Goodenia hederacea subsp. alpestris / (basal) basal
# 1 rows updated
# 9279: Goodenia hederacea subsp. hederacea / (rootstock / root suckers) other
# 1 rows updated
# 10197: Goodenia heterophylla subsp. heterophylla / (basal) basal
# 1 rows updated
# 3191: Goodenia humilis / (basal) basal
# 1 rows updated
# 7057: Goodenia paniculata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2871: Goodia lotifolia / (root buds) long rhizome or root sucker
# 1 rows updated
# 10744: Goodia lotifolia var. pubescens / (basal) basal
# 1 rows updated
# 8768: Grevillea acanthifolia subsp. stenomera / (basal buds) basal
# 1 rows updated
# 5357: Grevillea alpina / (basal) basal
# 1 rows updated
# 10769: Grevillea arenaria subsp. canescens / (rhizome) short rhizome
# 1 rows updated
# 6441: Grevillea australis / (basal) basal
# 1 rows updated
# 5364: Grevillea buxifolia / (basal) basal
# 1 rows updated
# 10956: Grevillea floribunda subsp. floribunda / (lignotuber) lignotuber
# 1 rows updated
# 9480: Grevillea guthrieana / (basal) basal
# 1 rows updated
# 10960: Grevillea humilis subsp. humilis / (rhizome) short rhizome
# 1 rows updated
# 5374: Grevillea ilicifolia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 10963: Grevillea imberbis / (root suckers & rhizome) other
# 1 rows updated
# 10965: Grevillea irrasa subsp. irrasa / (basal) basal
# 1 rows updated
# 5375: Grevillea johnsonii / (rootstock) lignotuber
# 1 rows updated
# 10967: Grevillea juniperina subsp. allojohnsonii / (basal buds) basal
# 1 rows updated
# 9676: Grevillea kedumbensis / (lignotuber) lignotuber
# 1 rows updated
# 5378: Grevillea kennedyana / (lignotuber & root suckers) other
# 1 rows updated
# 5379: Grevillea lanigera / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5381: Grevillea linearifolia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9481: Grevillea masonii / (lignotuber / rootuckers) other
# 1 rows updated
# 5384: Grevillea montana / (lignotuber & root suckers) other
# 1 rows updated
# 5386: Grevillea nematophylla / (basal) basal
# 1 rows updated
# 9791: Grevillea obtusiflora subsp. fecunda / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9626: Grevillea obtusiflora subsp. obtusiflora / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5388: Grevillea oleoides / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5389: Grevillea parviflora / (root suckers) long rhizome or root sucker
# 1 rows updated
# 10009: Grevillea parviflora subsp. parviflora / (rhizome) short rhizome
# 1 rows updated
# 10777: Grevillea parviflora subsp. supplicans / (rhizome) short rhizome
# 1 rows updated
# 10977: Grevillea patulifolia / (rootsuckers &/or rhizome) other
# 1 rows updated
# 9298: Grevillea quadricauda / (basal) basal
# 1 rows updated
# 10978: Grevillea ramosissima subsp. ramosissima / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5394: Grevillea renwickiana / (root suckers) long rhizome or root sucker
# 1 rows updated
# 9299: Grevillea rhizomatosa / (root suckers) long rhizome or root sucker
# 1 rows updated
# 10958: Grevillea rosmarinifolia subsp. glabella / (root suckers) long rhizome or root sucker
# 1 rows updated
# 10957: Grevillea rosmarinifolia subsp. rosmarinifolia / (rhizome) short rhizome
# 1 rows updated
# 8799: Grevillea scortechinii subsp. sarmentosa / (root buds) long rhizome or root sucker
# 1 rows updated
# 8799: Grevillea scortechinii subsp. sarmentosa / (root buds) long rhizome or root sucker
# 1 rows updated
# 5399: Grevillea sericea / (basal / root suckers) other
# 1 rows updated
# 5401: Grevillea speciosa / (root suckers / basal) other
# 1 rows updated
# 5402: Grevillea sphacelata / (lignotuber) lignotuber
# 1 rows updated
# 5404: Grevillea striata / (epicormic) epicormic
# 1 rows updated
# 5405: Grevillea triternata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 10985: Grevillea viridiflava / (basal buds) basal
# 1 rows updated
# 5917: Guioa semiglauca / (basal) basal
# 1 rows updated
# 2445: Gymnoschoenus sphaerocephalus / (basal) basal
# 1 rows updated
# 3639: Gynatrix pulchella / (root suckers) long rhizome or root sucker
# 1 rows updated
# 6435: Haemodorum corymbosum / (basal) basal
# 1 rows updated
# 3236: Haemodorum planifolium / (rootstock) lignotuber
# 1 rows updated
# 9114: Hakea bakeriana / (lignotuber) lignotuber
# 1 rows updated
# 5412: Hakea eriantha / (basal buds) basal
# 1 rows updated
# 10803: Hakea laevipes subsp. graniticola / (basal buds) basal
# 1 rows updated
# 10804: Hakea laevipes subsp. laevipes / (lignotuber) lignotuber
# 1 rows updated
# 5420: Hakea microcarpa / (basal) basal
# 1 rows updated
# 10699: Hardenbergia comptoniana / (basal) basal
# 1 rows updated
# 2873: Hardenbergia violacea / (basal) basal
# 1 rows updated
# 3914: Hedycarya angustifolia / (basal) basal
# 1 rows updated
# 6787: Hedychium gardnerianum / (rhizome) short rhizome
# 1 rows updated
# 1494: Helichrysum leucopsideum / (rhizome) short rhizome
# 1 rows updated
# 1502: Helichrysum rutidolepis / (rhizome) short rhizome
# 1 rows updated
# 7871: Hemarthria uncinata var. uncinata / (rhizome) short rhizome
# 1 rows updated
# 3376: Hemigenia purpurea / (basal) basal
# 1 rows updated
# 3549: Herpolirion novae-zelandiae / (basal) basal
# 1 rows updated
# 6601: Heteropogon contortus / (basal) basal
# 1 rows updated
# 2526: Hibbertia acicularis / (rootstock) lignotuber
# 1 rows updated
# 2527: Hibbertia aspera / (basal buds) basal
# 1 rows updated
# 10554: Hibbertia aspera subsp. aspera / (basal) basal
# 1 rows updated
# 2528: Hibbertia bracteata / (basal) basal
# 1 rows updated
# 2529: Hibbertia calycina / (root suckers / lignotuber) other
# 1 rows updated
# 10556: Hibbertia cistiflora subsp. cistiflora / (basal) basal
# 1 rows updated
# 2532: Hibbertia dentata / (basal) basal
# 1 rows updated
# 2535: Hibbertia empetrifolia / (basal buds) basal
# 1 rows updated
# 10863: Hibbertia empetrifolia subsp. empetrifolia / (basal) basal
# 1 rows updated
# 2536: Hibbertia fasciculata / (basal) basal
# 1 rows updated
# 9696: Hibbertia incana / (lignotuber) lignotuber
# 1 rows updated
# 2539: Hibbertia linearis / (basal) basal
# 1 rows updated
# 8591: Hibbertia marginata / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2542: Hibbertia obtusifolia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2544: Hibbertia procumbens / (rootstock) lignotuber
# 1 rows updated
# 2545: Hibbertia riparia / (lignotuber) lignotuber
# 1 rows updated
# n/a: Hibbertia riparia 'Gibraltar Range' / (basal buds) basal
# n/a: Hibbertia riparia 'Grassy woodlands' / (basal buds) basal
# 2548: Hibbertia scandens / (basal) basal
# 1 rows updated
# 12913: Hibbertia scandens var. glabra / (stem buds) epicormic
# 1 rows updated
# n/a: Hibbertia scandens var. scandens / (basal buds) basal
# 2550: Hibbertia serpyllifolia / (basal) basal
# 1 rows updated
# n/a: Hibbertia sp. aff. rufa / (basal buds) basal
# 2551: Hibbertia vestita / (basal buds) basal
# 1 rows updated
# 9398: Hibbertia virgata subsp. virgata / (basal) basal
# 1 rows updated
# 3641: Hibiscus diversifolius / (basal) basal
# 1 rows updated
# n/a: Homalanthus nutans / (basal buds) basal
# 11947: Homalanthus populifolius / (basal buds) basal
# 1 rows updated
# 11015: Hovea heterophylla / (basal buds) basal
# 1 rows updated
# 2875: Hovea lanceolata / (basal buds) basal
# 1 rows updated
# 2876: Hovea linearis / (basal) basal
# 1 rows updated
# 9768: Hovea montana / (root suckers) long rhizome or root sucker
# 1 rows updated
# 7959: Hydrocotyle acutiloba / (rhizome) short rhizome
# 1 rows updated
# 1123: Hydrocotyle bonariensis / (basal) basal
# 1 rows updated
# 8461: Hydrocotyle hirta / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1128: Hydrocotyle laxiflora / (rhizome) short rhizome
# 1 rows updated
# 4678: Hymenosporum flavum / (basal buds) basal
# 1 rows updated
# 2203: Hypericum japonicum / (basal) basal
# 1 rows updated
# 5533: Hypolaena fastigiata / (rhizome) short rhizome
# 1 rows updated
# 7749: Hypolepis muelleri / (rhizome) short rhizome
# 1 rows updated
# 7653: Hypolepis rugosula / (rhizome) short rhizome
# 1 rows updated
# 6803: Imperata cylindrica / (rhizome) short rhizome
# 1 rows updated
# 6803: Imperata cylindrica / (rhizome) short rhizome
# 1 rows updated
# 7544: Indigofera adesmiifolia / (basal buds) basal
# 1 rows updated
# 2882: Indigofera australis / (root suckers / basal) other
# 1 rows updated
# 2454: Isolepis inundata / (rhizome) short rhizome
# 1 rows updated
# 2455: Isolepis marginata / (rhizome) short rhizome
# 1 rows updated
# 5433: Isopogon anemonifolius / (lignotuber) lignotuber
# 1 rows updated
# 6839: Isopogon anethifolius / (basal) basal
# 1 rows updated
# 5435: Isopogon fletcheri / (basal) basal
# 1 rows updated
# 5438: Isopogon petiolaris / (basal buds) basal
# 1 rows updated
# 5439: Isopogon prostratus / (lignotuber) lignotuber
# 1 rows updated
# 1913: Isotoma axillaris / (basal) basal
# 1 rows updated
# 2892: Jacksonia scoparia / (root suckers) long rhizome or root sucker
# 1 rows updated
# 3313: Juncus amabilis / (rhizome) short rhizome
# 1 rows updated
# 3316: Juncus articulatus / (rhizome) short rhizome
# 1 rows updated
# 3326: Juncus continuus / (rhizome) short rhizome
# 1 rows updated
# 3328: Juncus falcatus / (basal) basal
# 1 rows updated
# 3333: Juncus homalocaulis / (basal) basal
# 1 rows updated
# 3339: Juncus pauciflorus / (rhizome) short rhizome
# 1 rows updated
# 3340: Juncus planifolius / (rhizome) short rhizome
# 1 rows updated
# 2898: Kennedia rubicunda / (basal buds) basal
# 1 rows updated
# 4204: Kunzea ambigua / (basal) basal
# 1 rows updated
# 4205: Kunzea bracteolata (resprouter pop.) / (basal buds) basal
# 1 rows updated
# 4207: Kunzea capitata / (basal) basal
# 1 rows updated
# 4208: Kunzea ericoides / (lignotuber) lignotuber
# 1 rows updated
# 4209: Kunzea muelleri / (basal & stolons) other
# 1 rows updated
# 4212: Kunzea rupestris / (basal) basal
# 1 rows updated
# 11388: Lachnagrostis filiformis / (rhizome) short rhizome / References!A16
# 1 rows updated
# 11959: Lagenophora gracilis / (rhizome) short rhizome
# 1 rows updated
# 11960: Lagenophora stipitata / (rhizome) short rhizome
# 1 rows updated
# 5440: Lambertia formosa / (lignotuber) lignotuber
# 1 rows updated
# 6248: Lantana camara / (basal) basal
# 1 rows updated
# 6139: Lasiopetalum ferrugineum / (basal) basal
# 1 rows updated
# 6142: Lasiopetalum macrophyllum / (basal buds) basal
# 1 rows updated
# 8014: Lastreopsis acuminata / (has rhizome) other
# 1 rows updated
# 3556: Laxmannia gracilis / (rhizome) short rhizome
# 1 rows updated
# 10734: Leionema phylicifolium / (basal) basal
# 1 rows updated
# 10736: Leionema rotundifolium / (basal buds) basal
# 1 rows updated
# 8291: Lepiderema pulchella / (root suckers) long rhizome or root sucker
# 1 rows updated
# 8380: Lepidosperma concavum / (rhizome) short rhizome
# 1 rows updated
# 8379: Lepidosperma elatius / (rhizome) short rhizome
# 1 rows updated
# 2465: Lepidosperma filiforme / (rhizome) short rhizome
# 1 rows updated
# 2467: Lepidosperma forsythii / (rhizome) short rhizome
# 1 rows updated
# 2468: Lepidosperma gladiatum / (basal) basal
# 1 rows updated
# 6402: Lepidosperma laterale / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2469: Lepidosperma limicola / (root suckers) long rhizome or root sucker
# 1 rows updated
# 2470: Lepidosperma longitudinale / (basal) basal
# 1 rows updated
# 2471: Lepidosperma neesii / (rhizome) short rhizome
# 1 rows updated
# 2474: Lepidosperma tortuosum / (root suckers) long rhizome or root sucker
# 1 rows updated
# 11028: Lepidosperma viscidum / (basal) basal
# 1 rows updated
# 8703: Leptinella filicula / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5534: Leptocarpus tenax / (root suckers) long rhizome or root sucker
# 1 rows updated
# 5865: Leptomeria acida / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1554: Leptorhynchos elongatus / (root suckers) long rhizome or root sucker
# 1 rows updated
# 1557: Leptorhynchos squamatus / (rhizome) short rhizome
# 1 rows updated
# 4213: Leptospermum arachnoides / (basal) basal
# 1 rows updated
# 4216: Leptospermum brevipes / (basal buds) basal
# 1 rows updated
# 7970: Leptospermum continentale / (basal) basal
# 1 rows updated
# 7274: Leptospermum divaricatum / (basal buds) basal
# 1 rows updated
# 8647: Leptospermum gregarium / (basal buds) basal
# 1 rows updated
# 4221: Leptospermum juniperinum / (lignotuber) lignotuber
# 1 rows updated
# 4223: Leptospermum lanigerum / (basal) basal
# 1 rows updated
# 4224: Leptospermum liversidgei / (basal) basal
# 1 rows updated
# 10036: Leptospermum macrocarpum / (basal) basal
# 1 rows updated
# 4227: Leptospermum minutifolium / (basal buds) basal
# 1 rows updated
# 4228: Leptospermum multicaule / (basal) basal
# 1 rows updated
# 4229: Leptospermum myrsinoides / (lignotuber) lignotuber
# 1 rows updated
# 8478: Leptospermum novae-angliae / (basal buds) basal
# 1 rows updated
# Database connection closed.

# %%
j=13
varname=ws.cell(row=2, column=j).value
print(varname)


switcher={
    "canopy":"canopy",
    "canopy - transient":"canopy",
    "persistent":"soil-persistent",
    "peristent":"soil-persistent",
    "persistent soil":"soil-persistent", 
    "a-persistent soil":"soil-persistent", 
    "soil":"soil-persistent",
    "transient":"transient", 
    "none":"transient",
    "shed at maturity":"transient", 
    "viviparous":"transient",
    "canopy / released at maturity":"transient",
    "canopy / regularly without fire":"transient",
    "not canopy":"non-canopy",
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,seedbank_type) values('%s',%s,'%s') ON CONFLICT (species,species_code) DO UPDATE SET seedbank_type=EXCLUDED.seedbank_type"

for i in range(1300,2800):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "other")
        if varref is not None:
            print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        else:
            print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur = conn.cursor()
            cur.execute(qrystr % (spname,spcode,transvalue))
            updated_rows = cur.rowcount
            # print("%s rows updated" % (updated_rows))
            conn.commit()
            cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Seed storage
# Connecting to the PostgreSQL database...
# 11667: Euryomyrtus denticulata / (persistent soil) soil-persistent
# 2855: Eutaxia microphylla / (a-persistent soil) soil-persistent
# 5863: Exocarpos sparteus / (soil) soil-persistent / References!C94
# 12416: Ficinia nodosa / (persistent soil) soil-persistent
# 7479: Ficus coronata / (transient?) other / References!C2
# 8333: Fontainea australis / (transient) transient
# 2436: Gahnia grandis / (persistent soil) soil-persistent
# 2442: Gahnia sieberiana / (persistent soil) soil-persistent
# 10145: Gamochaeta americana / (transient) transient
# 14493: Gamochaeta coarctata / (transient) transient
# 2666: Gaultheria appressa / (persistent soil) soil-persistent
# 2858: Genista monspessulana / (persistent soil) soil-persistent
# 7631: Gentiana wingecarribiensis / (persistent soil) soil-persistent
# 3146: Geranium antrorsum / (persistent soil) soil-persistent
# 3152: Geranium potentilloides / (persistent soil) soil-persistent
# 7107: Geranium potentilloides var. potentilloides / (persistent soil) soil-persistent
# 1120: Gingidia harveyana / (transient) transient
# 7138: Gleichenia dicarpa / (transient) transient
# 6708: Gleichenia microphylla / (transient) transient
# 8093: Gleichenia rupestris / (transient) transient
# 9360: Glochidion ferdinandi var. ferdinandi / (persistent soil) soil-persistent
# 4465: Glossodia major / (transient) transient
# 4466: Glossodia minor / (transient) transient
# 2859: Glycine canescens / (a-persistent soil) soil-persistent
# 2860: Glycine clandestina / (persistent soil) soil-persistent / References!C2
# 7208: Glycine microphylla / (a-persistent soil) soil-persistent
# 2861: Glycine tabacina / (persistent soil) soil-persistent
# 13008: Gompholobium aspalathoides / (a-persistent soil) soil-persistent
# 2864: Gompholobium glabratum / (persistent soil) soil-persistent
# 2865: Gompholobium grandiflorum / (persistent soil) soil-persistent
# 6921: Gompholobium huegelii / (persistent soil) soil-persistent
# 11026: Gompholobium inconspicuum / (persistent soil) soil-persistent
# 2866: Gompholobium latifolium / (persistent soil) soil-persistent
# 2867: Gompholobium minus / (persistent soil) soil-persistent
# 2868: Gompholobium pinnatum / (persistent soil) soil-persistent
# 2869: Gompholobium uncinatum / (soil) soil-persistent
# 2870: Gompholobium virgatum / (persistent soil) soil-persistent
# 2870: Gompholobium virgatum / (a-persistent soil) soil-persistent
# 3241: Gonocarpus humilis / (persistent soil) soil-persistent
# 3243: Gonocarpus micranthus / (persistent soil) soil-persistent
# 3244: Gonocarpus montanus / (persistent soil) soil-persistent
# 3246: Gonocarpus salsoloides / (persistent soil) soil-persistent
# 3247: Gonocarpus tetragynus / (persistent soil) soil-persistent
# 3248: Gonocarpus teucrioides / (persistent soil) soil-persistent
# 8711: Goodenia bellidifolia subsp. bellidifolia / (persistent soil) soil-persistent
# 8874: Goodenia dimorpha var. dimorpha / (persistent soil) soil-persistent
# 3180: Goodenia elongata / (persistent soil) soil-persistent
# 7958: Goodenia hederacea subsp. alpestris / (persistent soil) soil-persistent
# 9279: Goodenia hederacea subsp. hederacea / (persistent soil) soil-persistent / References!C10
# 8755: Goodenia heterophylla subsp. eglandulosa / (persistent soil) soil-persistent
# 3191: Goodenia humilis / (persistent soil) soil-persistent
# 9168: Goodenia macbarronii / (persistent soil) soil-persistent
# 3192: Goodenia ovata / (persistent soil) soil-persistent
# 3197: Goodenia stelligera / (persistent soil) soil-persistent
# 2871: Goodia lotifolia / (persistent soil) soil-persistent
# 10744: Goodia lotifolia var. pubescens / (persistent soil) soil-persistent
# 2872: Goodia medicaginea / (a-persistent soil) soil-persistent
# 8875: Grevillea acanthifolia subsp. acanthifolia / (persistent soil) soil-persistent
# 8264: Grevillea acanthifolia subsp. paludosa / (persistent soil) soil-persistent
# 8292: Grevillea acerata / (persistent soil) soil-persistent
# 5357: Grevillea alpina / (persistent soil) soil-persistent
# 10768: Grevillea arenaria subsp. arenaria / (persistent soil) soil-persistent
# 10769: Grevillea arenaria subsp. canescens / (persistent soil) soil-persistent
# 5360: Grevillea aspleniifolia / (soil) soil-persistent
# 6441: Grevillea australis / (persistent soil) soil-persistent
# 9301: Grevillea banyabba / (persistent soil) soil-persistent
# 9956: Grevillea baueri subsp. baueri / (persistent soil) soil-persistent
# 8293: Grevillea beadleana / (persistent soil) soil-persistent
# 5364: Grevillea buxifolia / (persistent soil) soil-persistent
# 8409: Grevillea buxifolia subsp. buxifolia / (persistent soil) soil-persistent
# 10953: Grevillea buxifolia subsp. ecorniculata / (persistent soil) soil-persistent
# 5365: Grevillea caleyi / (persistent soil) soil-persistent
# 5366: Grevillea capitellata / (persistent soil) soil-persistent
# 8993: Grevillea diffusa subsp. diffusa / (persistent soil) soil-persistent
# 8994: Grevillea diffusa subsp. filipendula / (persistent soil) soil-persistent
# 5369: Grevillea evansiana / (persistent soil) soil-persistent
# 9541: Grevillea granulifera / (persistent soil) soil-persistent
# 9480: Grevillea guthrieana / (soil) soil-persistent
# 9480: Grevillea guthrieana / (persistent soil) soil-persistent
# 10965: Grevillea irrasa subsp. irrasa / (persistent soil) soil-persistent
# 5375: Grevillea johnsonii / (persistent soil) soil-persistent
# 5380: Grevillea laurifolia / (persistent soil) soil-persistent
# 5381: Grevillea linearifolia / (persistent soil) soil-persistent
# 8306: Grevillea linsmithii / (short-lived soil) other / References!C90
# 5382: Grevillea longifolia / (persistent soil) soil-persistent
# 8307: Grevillea molyneuxii / (persistent soil) soil-persistent
# 5385: Grevillea mucronulata / (persistent soil) soil-persistent
# 9791: Grevillea obtusiflora subsp. fecunda / (persistent soil) soil-persistent
# 9626: Grevillea obtusiflora subsp. obtusiflora / (not known to set seed) other
# 8308: Grevillea oldei / (persistent soil) soil-persistent
# 5388: Grevillea oleoides / (persistent soil) soil-persistent
# 5389: Grevillea parviflora / (persistent soil) soil-persistent
# 10009: Grevillea parviflora subsp. parviflora / (persistent soil) soil-persistent
# 10777: Grevillea parviflora subsp. supplicans / (persistent soil) soil-persistent
# 10977: Grevillea patulifolia / (persistent soil) soil-persistent
# 5390: Grevillea phylicoides / (persistent soil) soil-persistent
# 9298: Grevillea quadricauda / (persistent soil) soil-persistent
# 10978: Grevillea ramosissima subsp. ramosissima / (persistent soil) soil-persistent
# 9678: Grevillea raybrownii / (persistent soil) soil-persistent
# 5394: Grevillea renwickiana / (sets no seed) other
# 9299: Grevillea rhizomatosa / (sets no seed) other
# 5395: Grevillea rivularis / (persistent soil) soil-persistent
# 10957: Grevillea rosmarinifolia subsp. rosmarinifolia / (persistent soil) soil-persistent
# 5399: Grevillea sericea / (persistent soil) soil-persistent
# 5400: Grevillea shiressii / (persistent soil) soil-persistent
# 5401: Grevillea speciosa / (persistent soil) soil-persistent
# 5402: Grevillea sphacelata / (persistent soil) soil-persistent
# 5405: Grevillea triternata / (persistent soil) soil-persistent
# 3639: Gynatrix pulchella / (persistent soil) soil-persistent
# 6435: Haemodorum corymbosum / (transient) transient
# 9114: Hakea bakeriana / (serotinous canopy) other
# 5408: Hakea constablei / (serotinous canopy) other
# 5409: Hakea dactyloides / (serotinous canopy) other
# 10802: Hakea dohertyi / (serotinous canopy) other
# 5412: Hakea eriantha / (serotinous canopy) other
# 5413: Hakea eyreana / (a-canopy) other
# 8594: Hakea florulenta / (a-canopy) other
# 5415: Hakea gibbosa / (serotinous canopy (retention >8y; 20)) other
# 10804: Hakea laevipes subsp. laevipes / (serotinous canopy) other
# 5417: Hakea leucoptera / (a-canopy) other
# 5419: Hakea macraeana / (a-canopy) other
# 9602: Hakea macrorrhyncha / (serotinous canopy) other
# 5420: Hakea microcarpa / (canopy) canopy
# 5421: Hakea propinqua / (serotinous canopy) other
# 10806: Hakea salicifolia subsp. salicifolia / (serotinous canopy (max retention 15y)) other / References!C21
# 5425: Hakea sericea / (serotinous canopy (retention >8y; 20)) other
# 5426: Hakea tephrosperma / (a-canopy) other
# 5427: Hakea teretifolia / (serotinous canopy) other
# 5429: Hakea ulicina / (canopy) canopy
# 9172: Haloragis exalata subsp. velutina / (persistent soil) soil-persistent
# 3252: Haloragis heterophylla / (persistent soil) soil-persistent / References!N43
# 3258: Haloragodendron monospermum / (persistent soil) soil-persistent
# 10699: Hardenbergia comptoniana / (a-persistent soil) soil-persistent
# 2873: Hardenbergia violacea / (persistent soil) soil-persistent
# 2873: Hardenbergia violacea (obligate seeder pop.) / (soil) soil-persistent
# 13289: Harmogia densifolia / (persistent soil) soil-persistent
# 3376: Hemigenia purpurea / (persistent soil) soil-persistent
# 2526: Hibbertia acicularis / (persistent soil) soil-persistent
# 10554: Hibbertia aspera subsp. aspera / (persistent soil) soil-persistent
# 2528: Hibbertia bracteata / (persistent soil?) other / C92
# 2529: Hibbertia calycina / (persistent soil) soil-persistent
# 10556: Hibbertia cistiflora subsp. cistiflora / (persistent soil) soil-persistent
# 2532: Hibbertia dentata / (persistent soil) soil-persistent
# 2533: Hibbertia diffusa / (persistent soil) soil-persistent
# 10863: Hibbertia empetrifolia subsp. empetrifolia / (persistent soil) soil-persistent
# 2536: Hibbertia fasciculata / (persistent soil) soil-persistent
# 2537: Hibbertia hermanniifolia / (persistent soil) soil-persistent
# 9696: Hibbertia incana / (persistent soil) soil-persistent
# 2539: Hibbertia linearis / (persistent soil) soil-persistent
# 2542: Hibbertia obtusifolia / (persistent soil) soil-persistent
# 2543: Hibbertia pedunculata / (persistent soil) soil-persistent
# 2544: Hibbertia procumbens / (persistent soil) soil-persistent
# 10558: Hibbertia rhynchocalyx / (soil) soil-persistent
# 2545: Hibbertia riparia / (persistent soil) soil-persistent
# 2546: Hibbertia rufa / (persistent soil) soil-persistent
# 2547: Hibbertia saligna / (persistent soil) soil-persistent
# 2548: Hibbertia scandens / (persistent soil) soil-persistent
# 2550: Hibbertia serpyllifolia / (persistent soil) soil-persistent
# n/a: Hibbertia sp. aff. obtusifolia / (soil) soil-persistent
# 9565: Hibbertia sp. B / (soil) soil-persistent
# 2551: Hibbertia vestita / (persistent soil) soil-persistent
# 9398: Hibbertia virgata subsp. virgata / (persistent soil) soil-persistent
# 3641: Hibiscus diversifolius / (persistent soil) soil-persistent
# 8877: Hibiscus heterophyllus subsp. heterophyllus / (persistent soil) soil-persistent
# 3645: Hibiscus splendens / (persistent soil) soil-persistent
# 7271: Histiopteris incisa / (transient) transient
# 9268: Homoranthus biflorus / (soil) soil-persistent
# 11251: Homoranthus binghiensis / (persistent soil) soil-persistent
# 9034: Homoranthus lunatus / (soil) soil-persistent / References!C94
# 4203: Homoranthus virgatus / (persistent soil) soil-persistent
# 11619: Hovea apiculata / (persistent soil) soil-persistent
# 12176: Hovea graniticola / (persistent soil) soil-persistent
# 2875: Hovea lanceolata / (persistent soil) soil-persistent
# 2876: Hovea linearis / (persistent soil) soil-persistent
# 2877: Hovea longifolia / (persistent soil) soil-persistent
# 9768: Hovea montana / (persistent soil) soil-persistent
# 11014: Hovea pedunculata / (soil) soil-persistent
# 2880: Hovea purpurea / (a-persistent soil) soil-persistent
# 2880: Hovea purpurea / (soil) soil-persistent / References!C94
# 3649: Howittia trilocularis / (persistent soil) soil-persistent
# 6266: Hybanthus monopetalus / (persistent soil) soil-persistent
# 1124: Hydrocotyle callicarpa / (persistent soil) soil-persistent
# 1126: Hydrocotyle geraniifolia / (persistent soil) soil-persistent
# 8461: Hydrocotyle hirta / (transient) transient
# 8104: Hymenophyllum australe / (transient) transient / References!A10
# 8107: Hymenophyllum cupressiforme / (transient?) other / References!C2
# 7240: Hypericum gramineum / (persistent soil) soil-persistent
# 2203: Hypericum japonicum / (persistent soil) soil-persistent
# 5533: Hypolaena fastigiata / (persistent soil) soil-persistent
# 7749: Hypolepis muelleri / (transient?) other
# 7653: Hypolepis rugosula / (transient?) other / References!C2
# 7544: Indigofera adesmiifolia / (a-persistent soil) soil-persistent
# 2882: Indigofera australis / (persistent soil) soil-persistent
# 5433: Isopogon anemonifolius / (serotinous canopy) other
# 6839: Isopogon anethifolius / (serotinous canopy) other
# 5434: Isopogon dawsonii / (serotinous canopy) other
# 5435: Isopogon fletcheri / (canopy) canopy
# 5438: Isopogon petiolaris / (canopy) canopy
# 5439: Isopogon prostratus / (canopy) canopy
# 7964: Isotoma fluviatilis subsp. australis / (transient) transient
# 2892: Jacksonia scoparia / (persistent soil) soil-persistent
# 2893: Jacksonia stackhousei / (persistent soil) soil-persistent
# 13291: Kardomia odontocalyx / (soil) soil-persistent
# 2896: Kennedia prostrata / (persistent soil) soil-persistent
# 2897: Kennedia retrorsa / (persistent soil) soil-persistent / References!B56
# 2898: Kennedia rubicunda / (persistent soil) soil-persistent
# 9871: Keraudrenia hillii var. hillii / (soil) soil-persistent
# 6973: Korthalsella rubra subsp. rubra / (transient) transient / References!C39
# 4204: Kunzea ambigua / (persistent soil) soil-persistent
# 4205: Kunzea bracteolata / (persistent soil / canopy) other
# 4207: Kunzea capitata / (persistent soil) soil-persistent
# 4208: Kunzea ericoides / (canopy / persistent soil (84)) other
# 8646: Kunzea obovata / (soil) soil-persistent
# 4210: Kunzea opposita / (canopy) canopy
# 4211: Kunzea parvifolia / (persistent soil) soil-persistent
# 4212: Kunzea rupestris / (persistent soil?) other / References!C2
# 5440: Lambertia formosa / (canopy) canopy
# 6139: Lasiopetalum ferrugineum / (persistent soil) soil-persistent
# 6143: Lasiopetalum parviflorum / (persistent soil) soil-persistent
# 8014: Lastreopsis acuminata / (transient?) other
# 8015: Lastreopsis decomposita / (transient?) other / References!C2
# 8016: Lastreopsis hispida / (transient?) other
# 6752: Laxmannia compacta / (persistent soil) soil-persistent
# 3556: Laxmannia gracilis / (persistent soil) soil-persistent
# 10724: Leionema ambiens / (persistent soil) soil-persistent
# 10727: Leionema dentatum / (soil) soil-persistent
# 10728: Leionema diosmeum / (persistent soil) soil-persistent
# 10731: Leionema elatius subsp. beckleri / (persistent soil, exhausted by disturbance) other
# 10734: Leionema phylicifolium / (persistent soil) soil-persistent
# 10735: Leionema ralstonii / (persistent soil) soil-persistent
# 10736: Leionema rotundifolium / (persistent soil) soil-persistent
# 8291: Lepiderema pulchella / (a-persistent soil) soil-persistent
# 1816: Lepidium aschersonii / (persistent soil) soil-persistent
# 1822: Lepidium hyssopifolium / (persistent soil) soil-persistent
# 1830: Lepidium pseudotasmanicum / (persistent soil) soil-persistent
# 8380: Lepidosperma concavum / (persistent soil) soil-persistent
# 8379: Lepidosperma elatius / (persistent soil) soil-persistent
# 8749: Lepidosperma gunnii / (persistent soil) soil-persistent
# 6402: Lepidosperma laterale / (persistent soil) soil-persistent
# 2471: Lepidosperma neesii / (persistent soil) soil-persistent
# 2474: Lepidosperma tortuosum / (persistent soil) soil-persistent
# 2475: Lepidosperma urophorum / (persistent soil) soil-persistent
# 11028: Lepidosperma viscidum / (persistent soil) soil-persistent
# 8703: Leptinella filicula / (persistent soil) soil-persistent / References!C10
# 5534: Leptocarpus tenax / (persistent soil) soil-persistent
# 5865: Leptomeria acida / (persistent soil) soil-persistent
# 1557: Leptorhynchos squamatus / (short-lived persistent soil) other / References!C48
# 4213: Leptospermum arachnoides / (canopy) canopy
# 4216: Leptospermum brevipes / (not canopy) non-canopy / References!C2
# 7970: Leptospermum continentale / (canopy) canopy
# 7274: Leptospermum divaricatum / (canopy) canopy
# 4218: Leptospermum emarginatum / (canopy) canopy
# 7766: Leptospermum grandifolium / (canopy) canopy
# 8647: Leptospermum gregarium / (canopy) canopy
# 4221: Leptospermum juniperinum / (canopy) canopy
# 4222: Leptospermum laevigatum / (canopy - transient) canopy / References!C84
# 4223: Leptospermum lanigerum / (canopy) canopy
# 4224: Leptospermum liversidgei / (canopy) canopy
# 10036: Leptospermum macrocarpum / (canopy) canopy
# 4229: Leptospermum myrsinoides / (persistent soil) soil-persistent
# 4230: Leptospermum myrtifolium / (canopy) canopy
# 8478: Leptospermum novae-angliae / (canopy) canopy
# 4232: Leptospermum obovatum / (canopy) canopy
# 4233: Leptospermum parvifolium / (transient) transient
# 4234: Leptospermum petersonii / (canopy) canopy
# 8199: Leptospermum polygalifolium subsp. cismontanum / (canopy?) other
# 8198: Leptospermum polygalifolium subsp. montanum / (canopy) canopy
# 8197: Leptospermum polygalifolium subsp. polygalifolium / (canopy) canopy
# 9958: Leptospermum rotundifolium / (canopy) canopy
# 4235: Leptospermum scoparium / (canopy) canopy
# 4236: Leptospermum semibaccatum / (persistent soil) soil-persistent
# 4239: Leptospermum squarrosum / (canopy) canopy
# 8317: Leptospermum thompsonii / (persistent soil?) other
# 8486: Leptospermum trinervium / (transient / persistent soil) other
# 5541: Lepyrodia scariosa / (persistent soil) soil-persistent
# 8690: Lespedeza juncea subsp. sericea / (persistent soil) soil-persistent
# 9072: Leucochrysum albicans subsp. alpinum / (transient) transient
# 2610: Leucopogon amplexicaulis / (persistent soil) soil-persistent
# 2612: Leucopogon attenuatus / (persistent soil) soil-persistent
# 2613: Leucopogon biflorus / (soil) soil-persistent
# 10194: Leucopogon collinus / (persistent soil) soil-persistent
# 2615: Leucopogon deformis / (persistent soil) soil-persistent
# 2616: Leucopogon ericoides / (persistent soil) soil-persistent
# 2617: Leucopogon esquamatus / (persistent soil) soil-persistent
# 2620: Leucopogon fraseri / (persistent soil) soil-persistent / References!C10
# 2623: Leucopogon juniperinus / (persistent soil) soil-persistent
# 6845: Leucopogon lanceolatus var. gracilis / (persistent soil) soil-persistent
# 6425: Leucopogon lanceolatus var. lanceolatus / (persistent soil) soil-persistent
# 2625: Leucopogon leptospermoides / (persistent soil) soil-persistent
# 2629: Leucopogon microphyllus / (persistent soil) soil-persistent
# 7216: Leucopogon microphyllus var. microphyllus / (persistent soil) soil-persistent
# 2630: Leucopogon muticus / (persistent soil) soil-persistent
# 2631: Leucopogon neo-anglicus / (persistent soil) soil-persistent
# 2631: Leucopogon neo-anglicus / (soil) soil-persistent
# 2632: Leucopogon parviflorus / (persistent soil) soil-persistent / References!C10
# 2636: Leucopogon rodwayi / (persistent soil) soil-persistent
# 2638: Leucopogon setiger / (persistent soil) soil-persistent
# 9178: Leucopogon sp. aff. appressus / (soil) soil-persistent
# 2639: Leucopogon virgatus / (persistent soil) soil-persistent
# 6152: Levenhookia dubia / (transient) transient
# 8127: Lindsaea dimorpha / (transient?) other
# 6406: Lindsaea linearis / (transient) transient
# 6401: Lindsaea microphylla / (transient) transient
# 3583: Linum marginale / (soil) soil-persistent / References!C94
# 3498: Litsea reticulata / (soil) soil-persistent
# 1221: Livistona australis / (transient) transient
# 1917: Lobelia gibbosa / (persistent soil) soil-persistent
# 3590: Logania pusilla / (persistent soil) soil-persistent
# 6296: Lomandra brevis / (persistent soil) soil-persistent
# 6298: Lomandra cylindrica / (persistent soil) soil-persistent
# 6301: Lomandra elongata / (persistent soil) soil-persistent
# 6302: Lomandra filiformis / (persistent soil) soil-persistent
# 6511: Lomandra filiformis subsp. coriacea / (persistent soil) soil-persistent
# 7931: Lomandra filiformis subsp. filiformis / (persistent soil) soil-persistent
# 6304: Lomandra glauca / (persistent soil) soil-persistent
# 6305: Lomandra gracilis / (persistent soil) soil-persistent
# 6308: Lomandra longifolia / (persistent soil) soil-persistent / References!C10
# 8802: Lomandra multiflora subsp. multiflora / (persistent soil) soil-persistent
# 6312: Lomandra obliqua / (persistent soil) soil-persistent
# 5443: Lomatia ilicifolia / (soil) soil-persistent / References!C2
# 5444: Lomatia myricoides / (soil) soil-persistent / References!C2
# 5445: Lomatia silaifolia / (transient) transient
# 2906: Lotus australis / (persistent soil) soil-persistent
# 2908: Lotus cruentus / (a-persistent soil) soil-persistent
# 3357: Luzula flaccida / (persistent soil) soil-persistent
# 3359: Luzula meridionalis / (persistent soil) soil-persistent
# 8567: Luzula modesta / (persistent soil) soil-persistent / References!C10
# 3360: Luzula novae-cambriae / (persistent soil) soil-persistent / References!C10
# 9293: Lycopodiella lateralis / (transient) transient
# 6409: Lycopodium deuterodensum / (transient) transient / References!C10
# 8133: Lycopodium fastigiatum / (transient) transient
# 3907: Macarthuria neocambrica / (persistent soil) soil-persistent
# 3928: Maclura cochinchinensis / (transient?) other / References!C2
# 6327: Macrozamia communis / (transient) transient / References!C2
# 6335: Macrozamia spiralis / (transient) transient
# 2735: Mallotus philippensis / (transient?) other / References!C2
# 1233: Marsdenia longiloba / (short-lived soil) other
# 11117: Melaleuca armillaris subsp. armillaris / (canopy) canopy
# 6809: Melaleuca biconvexa / (shed at maturity) transient / References!C2
# 4248: Melaleuca deanei / (canopy) canopy
# 4249: Melaleuca decora / (canopy) canopy
# 6391: Melaleuca ericifolia / (canopy) canopy
# 4252: Melaleuca groveana / (canopy) canopy
# 4254: Melaleuca hypericifolia / (canopy) canopy
# 4257: Melaleuca linariifolia / (canopy / persistent soil) other
# n/a: Melaleuca linearis / (canopy) canopy
# 4258: Melaleuca nodosa / (canopy) canopy / References!A10
# n/a: Melaleuca pallida / (canopy) canopy
# n/a: Melaleuca paludicola / (canopy) canopy
# n/a: Melaleuca pityoides / (canopy) canopy
# 4260: Melaleuca quinquenervia / (canopy) canopy
# 4261: Melaleuca sieberi / (canopy (1; 9) / soil (6)) other
# n/a: Melaleuca sp nov./comboynensis / (canopy) canopy
# n/a: Melaleuca sp. aff. comboynensis ('Big Red') / (canopy) canopy
# n/a: Melaleuca sp. aff. flavovirens (Torrington) / (canopy) canopy
# 4262: Melaleuca squamea / (canopy) canopy
# 4263: Melaleuca squarrosa / (canopy) canopy
# 4264: Melaleuca styphelioides / (canopy) canopy
# 4266: Melaleuca thymifolia / (canopy) canopy
# 3680: Melia azedarach / (transient) transient / References!C2
# 2645: Melichrus procumbens / (persistent soil) soil-persistent
# 2646: Melichrus urceolatus / (persistent soil) soil-persistent
# 12061: Melicytus dentatus / (persistent soil) soil-persistent / References!C10
# 10904: Melinis repens / (persistent soil) soil-persistent
# 2736: Micrantheum ericoides / (persistent soil) soil-persistent
# 7707: Microlaena stipoides var. stipoides / (persistent soil) soil-persistent
# 4271: Micromyrtus blakelyi / (persistent soil) soil-persistent
# 1566: Microseris lanceolata / (transient) transient / References!C10
# 2936: Mirbelia platylobioides / (persistent soil) soil-persistent
# 2937: Mirbelia pungens / (persistent soil) soil-persistent
# 2938: Mirbelia rubiifolia / (persistent soil) soil-persistent
# 7736: Mirbelia speciosa subsp. speciosa / (persistent soil) soil-persistent
# 3592: Mitrasacme paludosa / (persistent soil) soil-persistent
# 3595: Mitrasacme polymorpha / (persistent soil) soil-persistent
# 8290: Monotoca rotundifolia / (persistent soil) soil-persistent
# 2649: Monotoca scoparia / (persistent soil) soil-persistent
# 5269: Muehlenbeckia adpressa / (soil) soil-persistent
# 8218: Myoporum bateae / (persistent soil) soil-persistent
# 3950: Myoporum betcheanum / (soil) soil-persistent
# 3953: Myoporum floribundum / (requires recolonisation from unburnt sites) other
# 1765: Myosotis australis / (transient) transient
# 11948: Myrsine howittiana / (transient) transient
# 8088: Nephrolepis cordifolia / (persistent soil) soil-persistent
# 11957: Niemeyera whitei / (transient) transient / References!C90
# 6279: Notothixos subaureus / (transient) transient
# 1176: Ochrosia moorei / (transient) transient
# 6949: Ochrosperma citriodorum / (persistent soil) soil-persistent
# 6474: Ochrosperma lineare / (persistent soil) soil-persistent
# 4307: Olax retusa / (persistent soil) soil-persistent
# 6407: Olax stricta / (persistent soil) soil-persistent
# 1578: Olearia algida / (transient) transient / References!C10
# 1582: Olearia axillaris / (persistent soil / transient) other
# 11642: Olearia brevipedunculata / (transient) transient
# 1591: Olearia erubescens / (transient) transient / References!C10
# 1595: Olearia gravis / (soil) soil-persistent / References!C94
# 1605: Olearia nernstii / (soil) soil-persistent
# 11302: Olearia phlogopappa subsp. flavescens / (transient) transient
# 1611: Olearia ramulosa / (persistent soil) soil-persistent
# n/a: Olearia secundiflorus / (transient) transient
# 1617: Olearia tomentosa / (transient) transient
# 5697: Opercularia aspera / (persistent soil) soil-persistent
# 5698: Opercularia diphylla / (persistent soil) soil-persistent
# 5701: Opercularia varia / (persistent soil) soil-persistent
# 1135: Oreomyrrhis argentea / (persistent soil) soil-persistent
# 1137: Oreomyrrhis ciliata / (persistent soil) soil-persistent
# 1138: Oreomyrrhis eriopoda / (persistent soil) soil-persistent
# 5448: Orites excelsus / (soil) soil-persistent
# 5449: Orites lancifolius / (persistent soil) soil-persistent / References!C10
# 4476: Orthoceras strictum / (transient) transient / References!C10
# 3682: Owenia cepiodora / (short-lived soil, exhausted by disturbance) other / References!C90
# 4615: Oxalis exilis / (persistent soil) soil-persistent
# 2948: Oxylobium arborescens / (persistent soil) soil-persistent
# 2948: Oxylobium arborescens (Tall form) / (soil) soil-persistent
# 2950: Oxylobium ellipticum / (persistent soil) soil-persistent
# 2953: Oxylobium pulteneae / (a-persistent soil) soil-persistent
# 9404: Ozothamnus argophyllus / (transient) transient
# 9610: Ozothamnus conditus / (transient) transient
# 9611: Ozothamnus cuneifolius / (transient) transient
# 8557: Ozothamnus diosmifolius / (persistent soil) soil-persistent
# 9999: Ozothamnus obcordatus / (transient) transient
# 8915: Ozothamnus obcordatus subsp. obcordatus / (persistent soil) soil-persistent
# 8664: Ozothamnus vagans / (persistent soil) soil-persistent
# 9349: Pandanus tectorius var. australianus / (persistent soil) soil-persistent
# 10485: Pandorea pandorana subsp. pandorana / (persistent soil) soil-persistent
# 5066: Panicum simile / (persistent soil) soil-persistent
# 4477: Papillilabium beckleri / (transient) transient
# 5993: Parentucellia viscosa / (none) transient
# 9505: Parsonsia dorrigoensis / (persistent soil) soil-persistent
# 1181: Parsonsia lanceolata / (persistent soil) soil-persistent
# 4642: Passiflora cinnabarina / (persistent soil) soil-persistent
# 3300: Patersonia fragilis / (persistent soil) soil-persistent
# 3301: Patersonia glabrata / (persistent soil) soil-persistent
# 3302: Patersonia longifolia / (persistent soil) soil-persistent
# 3303: Patersonia sericea / (persistent soil) soil-persistent
# 3158: Pelargonium capitatum / (persistent soil) soil-persistent
# 3160: Pelargonium helmsii / (persistent soil) soil-persistent / References!C10
# 8444: Pellaea falcata / (transient?) other
# 5450: Persoonia acerosa / (persistent soil) soil-persistent / References!C2
# 8363: Persoonia asperula / (persistent soil) soil-persistent
# 9527: Persoonia bargoensis / (persistent soil) soil-persistent / References!C2
# 5452: Persoonia chamaepeuce / (persistent soil) soil-persistent
# 5453: Persoonia chamaepitys / (persistent soil) soil-persistent
# 5454: Persoonia confertiflora / (transient) transient
# 8597: Persoonia conjuncta / (soil) soil-persistent
# 7677: Persoonia glaucescens / (persistent soil) soil-persistent
# 5458: Persoonia hirsuta / (persistent soil) soil-persistent / References!C2
# 8414: Persoonia isophylla / (persistent soil) soil-persistent
# 5459: Persoonia juniperina / (persistent soil) soil-persistent
# 5460: Persoonia lanceolata / (persistent soil) soil-persistent
# 5461: Persoonia laurina / (a-persistent soil) soil-persistent
# 9824: Persoonia laurina subsp. intermedia / (persistent soil) soil-persistent
# 9823: Persoonia laurina subsp. laurina / (persistent soil) soil-persistent
# 9081: Persoonia laurina subsp. leiogyna / (persistent soil) soil-persistent
# 5462: Persoonia levis / (persistent soil) soil-persistent
# 5463: Persoonia linearis / (persistent soil) soil-persistent
# 5464: Persoonia marginata / (persistent soil) soil-persistent
# 8684: Persoonia media / (soil) soil-persistent
# 8990: Persoonia mollis subsp. caleyi / (persistent soil) soil-persistent
# 8991: Persoonia mollis subsp. ledifolia / (persistent soil) soil-persistent
# 9005: Persoonia mollis subsp. leptophylla / (persistent soil) soil-persistent
# 9003: Persoonia mollis subsp. livens / (persistent soil) soil-persistent
# 8995: Persoonia mollis subsp. maxima / (persistent soil) soil-persistent
# 9000: Persoonia mollis subsp. mollis / (persistent soil) soil-persistent
# 8996: Persoonia mollis subsp. nectens / (persistent soil) soil-persistent
# 8997: Persoonia mollis subsp. revoluta / (persistent soil) soil-persistent
# 5467: Persoonia nutans / (persistent soil) soil-persistent
# 5468: Persoonia oblongata / (persistent soil) soil-persistent
# 7428: Persoonia oxycoccoides / (persistent soil) soil-persistent
# 5469: Persoonia pinifolia / (persistent soil) soil-persistent
# 5471: Persoonia rigida / (persistent soil) soil-persistent
# 8624: Persoonia rufa / (persistent soil) soil-persistent
# 5473: Persoonia silvatica / (persistent soil) soil-persistent
# 9048: Persoonia terminalis subsp. terminalis / (persistent soil) soil-persistent
# 5476: Persoonia virgata / (persistent soil) soil-persistent
# 5477: Petrophile canescens / (canopy) canopy
# 5478: Petrophile pedunculata / (canopy) canopy
# 5479: Petrophile pulchella / (serotinous canopy) other
# 5480: Petrophile sessilis / (canopy) canopy
# 9419: Phebalium glandulosum subsp. eglandulosum / (persistent soil) soil-persistent
# 5826: Phebalium squamulosum / (persistent soil) soil-persistent
# 8374: Phebalium squamulosum subsp. squamulosum / (soil) soil-persistent
# n/a: Phebalium sylvestre ms / (soil) soil-persistent
# 5830: Phebalium woombye / (soil) soil-persistent
# 12430: Pherosphaera fitzgeraldii / (canopy?) other
# 10577: Philotheca buxifolia / (persistent soil) soil-persistent
# 12004: Philotheca epilosa / (soil) soil-persistent
# 12004: Philotheca epilosa / (persistent soil) soil-persistent
# 10586: Philotheca hispidula / (persistent soil) soil-persistent
# 10593: Philotheca myoporoides subsp. myoporoides / (persistent soil) soil-persistent
# 10594: Philotheca obovalis / (persistent soil) soil-persistent
# 10596: Philotheca salsolifolia subsp. salsolifolia / (persistent soil) soil-persistent
# 10599: Philotheca scabra subsp. scabra / (persistent soil) soil-persistent
# 10601: Philotheca virgata / (persistent soil) soil-persistent
# 8216: Phyllanthus hirtellus / (persistent (6) / transient (49)) other
# 6676: Phyllanthus similis / (persistent soil) soil-persistent
# 6751: Phyllanthus virgatus / (persistent soil) soil-persistent
# 2957: Phyllota humifusa / (a-persistent soil) soil-persistent
# 2958: Phyllota phylicoides / (persistent soil) soil-persistent
# 2959: Phyllota squarrosa / (persistent soil) soil-persistent
# 11235: Picris angustifolia subsp. merxmuelleri / (transient) transient
# 6233: Pilea microphylla / (persistent soil) soil-persistent
# 6475: Pimelea latifolia subsp. hirsuta / (persistent soil) soil-persistent
# 7643: Pimelea ligustrina subsp. hypericina / (soil) soil-persistent
# 6182: Pimelea linifolia / (persistent soil) soil-persistent
# 6635: Pimelea linifolia subsp. collina / (persistent soil) soil-persistent
# 6814: Pimelea linifolia subsp. linifolia / (persistent soil) soil-persistent
# 6186: Pimelea pauciflora / (persistent soil) soil-persistent
# n/a: Pimelea sp. 'Long Point' / (soil) soil-persistent
# 4679: Pittosporum bicolor / (transient) transient
# 4685: Pittosporum undulatum / (transient) transient
# 4691: Plantago debilis / (persistent soil) soil-persistent
# 8159: Platycerium bifurcatum / (transient) transient
# 2961: Platylobium formosum / (persistent soil) soil-persistent
# 8614: Platylobium formosum subsp. parviflorum / (persistent soil) soil-persistent
# 1142: Platysace clelandii / (persistent soil) soil-persistent
# 1143: Platysace ericoides / (persistent soil) soil-persistent
# 11142: Platysace heterophylla var. heterophylla / (persistent soil) soil-persistent
# 1144: Platysace lanceolata / (persistent soil) soil-persistent
# 1145: Platysace linearifolia / (persistent soil) soil-persistent
# 3391: Plectranthus alloplectus / (persistent soil) soil-persistent
# 3397: Plectranthus parviflorus / (persistent soil) soil-persistent
# 5126: Poa costiniana / (persistent soil) soil-persistent
# 5128: Poa fawcettiae / (persistent soil) soil-persistent
# 5131: Poa hiemata / (persistent soil) soil-persistent
# 11196: Poa labillardierei var. labillardierei / (persistent soil) soil-persistent
# 5136: Poa phillipsiana / (persistent soil) soil-persistent
# 8743: Poa sieberiana var. cyanophylla / (persistent soil) soil-persistent
# 5247: Podocarpus lawrencei / (transient) transient / References!C10
# 5248: Podocarpus spinulosus / (transient or canopy?) other / References!C2
# 1630: Podolepis canescens / (soil) soil-persistent / References!C94
# 10705: Podolobium aciculiferum / (a-persistent soil) soil-persistent
# 10706: Podolobium alpestre / (persistent soil) soil-persistent
# 9912: Podolobium ilicifolium / (persistent soil) soil-persistent
# 10708: Podolobium scandens / (persistent soil) soil-persistent
# 10708: Podolobium scandens / (persistent soil) soil-persistent
# 5259: Polygala japonica / (transient) transient
# 2231: Polymeria calycina / (a-persistent soil) soil-persistent
# 1209: Polyscias elegans / (soil) soil-persistent
# 1211: Polyscias sambucifolia / (persistent soil) soil-persistent
# 8025: Polystichum formosum / (transient?) other
# n/a: Pomaderiris (long Point small leaf) / (soil) soil-persistent
# 5567: Pomaderris andromedifolia / (soil) soil-persistent
# 5568: Pomaderris angustifolia / (persistent soil) soil-persistent
# 5571: Pomaderris aspera / (persistent soil) soil-persistent
# 5572: Pomaderris betulina / (soil) soil-persistent
# 9865: Pomaderris betulina subsp. betulina / (persistent soil) soil-persistent
# 6979: Pomaderris brogoensis / (persistent soil) soil-persistent
# 5573: Pomaderris brunnea / (persistent soil) soil-persistent
# 5575: Pomaderris costata / (persistent soil) soil-persistent
# 5576: Pomaderris cotoneaster / (persistent soil) soil-persistent
# 9853: Pomaderris crassifolia / (a-persistent soil) soil-persistent
# 9484: Pomaderris elachophylla / (persistent soil) soil-persistent
# 5578: Pomaderris eriocephala / (persistent soil) soil-persistent
# 5579: Pomaderris ferruginea / (persistent soil) soil-persistent
# 7979: Pomaderris intermedia / (persistent soil) soil-persistent
# 5581: Pomaderris lanigera / (persistent soil) soil-persistent
# 5585: Pomaderris nitidula / (soil) soil-persistent
# 8339: Pomaderris parrisiae / (persistent soil) soil-persistent
# 5589: Pomaderris pauciflora / (persistent soil) soil-persistent
# 5590: Pomaderris phylicifolia / (persistent soil) soil-persistent
# 5591: Pomaderris prunifolia / (soil) soil-persistent
# 7336: Pomaderris virgata / (persistent soil) soil-persistent
# 5703: Pomax umbellata / (persistent soil) soil-persistent
# 2753: Poranthera corymbosa / (persistent soil) soil-persistent
# 2754: Poranthera ericifolia / (persistent soil) soil-persistent
# 7395: Poranthera microphylla / (persistent soil) soil-persistent
# 4491: Prasophyllum australe / (transient) transient
# 4494: Prasophyllum brevilabre / (transient) transient
# 3401: Prostanthera cineolifera / (persistent soil) soil-persistent
# 3403: Prostanthera cuneata / (a-persistent soil) soil-persistent
# 3405: Prostanthera denticulata / (transient) transient
# 3413: Prostanthera incisa / (soil) soil-persistent
# 9884: Prostanthera junonis / (transient) transient
# 3415: Prostanthera lasianthos / (persistent soil) soil-persistent / References!C101
# 3417: Prostanthera linearis / (persistent soil) soil-persistent / References!C10
# 3421: Prostanthera nivea / (soil) soil-persistent
# 9380: Prostanthera nivea var. nivea / (persistent soil) soil-persistent
# 3423: Prostanthera ovalifolia / (soil) soil-persistent
# 3429: Prostanthera saxicola / (persistent soil) soil-persistent
# 3430: Prostanthera scutellarioides / (persistent soil) soil-persistent
# 3436: Prostanthera teretifolia / (persistent soil) soil-persistent
# 3438: Prostanthera walteri / (persistent soil) soil-persistent
# 2755: Pseudanthus divaricatissimus / (persistent soil) soil-persistent
# 2756: Pseudanthus orientalis / (persistent soil) soil-persistent
# 12971: Pseudanthus pauciflorus / (soil) soil-persistent
# 2757: Pseudanthus pimeleoides / (persistent soil) soil-persistent
# 1010: Pseuderanthemum variabile / (persistent soil) soil-persistent
# 7780: Pseudognaphalium luteoalbum / (persistent soil) soil-persistent
# 8165: Psilotum nudum / (transient?) other
# 5706: Psychotria loniceroides / (transient) transient
# 13524: Psychrophila introloba / (persistent soil) soil-persistent
# 6403: Pteridium esculentum / (transient) transient
# 8175: Pteris tremula / (transient?) other
# 8177: Pteris vittata / (transient?) other / References!C2
# 4544: Pterostylis concinna / (transient) transient
# 4553: Pterostylis gibbosa / (transient) transient
# 4566: Pterostylis parviflora / (transient) transient
# 8956: Ptilothrix deusta / (persistent soil) soil-persistent
# 2973: Pultenaea altissima / (a-persistent soil) soil-persistent
# 2974: Pultenaea aristata / (persistent soil) soil-persistent
# 2976: Pultenaea benthamii / (persistent soil) soil-persistent
# 2977: Pultenaea blakelyi / (persistent soil) soil-persistent
# 2985: Pultenaea daphnoides / (persistent soil) soil-persistent
# 2986: Pultenaea dentata / (persistent soil) soil-persistent
# 2987: Pultenaea divaricata / (persistent soil) soil-persistent
# 2992: Pultenaea ferruginea / (a-persistent soil) soil-persistent
# 2993: Pultenaea flexilis / (persistent soil) soil-persistent
# 2994: Pultenaea foliolosa / (a-persistent soil) soil-persistent
# 2995: Pultenaea glabra / (a-persistent soil) soil-persistent
# 2997: Pultenaea hispidula / (persistent soil) soil-persistent
# 3000: Pultenaea largiflorens / (a-persistent soil) soil-persistent
# 3002: Pultenaea linophylla / (persistent soil) soil-persistent / References!C2
# 3003: Pultenaea microphylla / (persistent soil) soil-persistent
# 11407: Pultenaea mollis / (persistent soil) soil-persistent
# 3004: Pultenaea myrtoides / (a-persistent soil) soil-persistent
# 12224: Pultenaea parrisiae / (persistent soil) soil-persistent
# 3007: Pultenaea parviflora / (persistent soil) soil-persistent
# 3008: Pultenaea pedunculata / (a-persistent soil) soil-persistent
# 3011: Pultenaea polifolia / (persistent soil) soil-persistent
# 3012: Pultenaea procumbens / (a-persistent soil) soil-persistent
# 3013: Pultenaea pycnocephala / (persistent soil) soil-persistent
# 3014: Pultenaea retusa / (persistent soil) soil-persistent / References!C2
# 3015: Pultenaea rosmarinifolia / (persistent soil) soil-persistent
# 3016: Pultenaea scabra / (persistent soil) soil-persistent
# 11810: Pultenaea setulosa / (a-persistent soil) soil-persistent
# 3017: Pultenaea spinosa / (persistent soil) soil-persistent
# 3018: Pultenaea stipularis / (persistent soil) soil-persistent
# 3020: Pultenaea subspicata / (persistent soil) soil-persistent
# 12552: Pultenaea tarik / (soil) soil-persistent
# 11386: Pultenaea tuberculata / (persistent soil) soil-persistent
# 3022: Pultenaea villifera / (persistent soil) soil-persistent
# 3023: Pultenaea villosa / (persistent soil) soil-persistent
# 3025: Pultenaea vrolandii / (a-persistent soil) soil-persistent
# 10853: Pyrorchis nigricans / (transient) transient
# 8163: Pyrrosia rupestris / (transient?) other / References!C2
# 3228: Quintinia sieberi / (transient?) other
# 5505: Ranunculus graniticola / (persistent soil) soil-persistent / References!C10
# 5506: Ranunculus gunnianus / (persistent soil) soil-persistent / References!C10
# 5508: Ranunculus lappaceus / (transient) transient
# 5509: Ranunculus millanii / (persistent soil) soil-persistent
# 5517: Ranunculus pimpinellifolius / (persistent soil) soil-persistent
# 5521: Ranunculus repens / (persistent soil) soil-persistent
# 5525: Ranunculus sessiliflorus / (transient) transient
# 7808: Rhagodia candolleana subsp. candolleana / (transient) transient
# 8563: Rhodanthe anthemoides / (transient) transient / References!C10
# 2484: Rhynchospora rubra / (persistent soil) soil-persistent
# 8623: Rhytidosporum procumbens / (persistent soil) soil-persistent
# 2651: Richea continentis / (persistent soil) soil-persistent
# 2759: Ricinocarpos pinifolius / (persistent soil) soil-persistent
# 5642: Rubus parvifolius / (transient) transient
# 6146: Rulingia hermanniifolia / (persistent soil) soil-persistent
# 1644: Rutidosis leiolepis / (transient) transient
# 1645: Rutidosis leptorrhynchoides / (transient) transient / References!C43
# 14312: Rytidosperma longifolium / (persistent soil) soil-persistent
# 10638: Rytidosperma nudiflorum / (persistent soil) soil-persistent
# 14314: Rytidosperma pallidum / (persistent soil) soil-persistent
# 14316: Rytidosperma pilosum / (persistent soil) soil-persistent
# 14323: Rytidosperma tenuius / (persistent soil) soil-persistent
# 3444: Salvia plebeia / (transient) transient
# 5868: Santalum acuminatum / (soil) soil-persistent
# 5870: Santalum obtusifolium / (transient) transient
# 4579: Sarcochilus australis / (transient) transient
# 4583: Sarcochilus fitzgeraldii / (transient) transient
# 4584: Sarcochilus hartmannii / (transient) transient
# 6489: Sarcochilus parviflorus / (transient) transient
# 7144: Sarcochilus spathulatus / (transient) transient
# 4587: Sarcochilus weinthalii / (transient) transient
# 8842: Sarcomelicope simplicifolia subsp. simplicifolia / (transient) transient
# 3208: Scaevola ramosissima / (persistent soil) soil-persistent
# 8181: Schizaea bifida / (transient) transient
# 8182: Schizaea dichotoma / (transient?) other
# 2275: Schizomeria ovata / (persistent soil) soil-persistent
# 2491: Schoenus apogon / (persistent soil) soil-persistent
# 2492: Schoenus brevifolius / (persistent soil) soil-persistent
# 2495: Schoenus ericetorum / (persistent soil) soil-persistent
# 2496: Schoenus imberbis / (persistent soil) soil-persistent
# 2500: Schoenus melanostachys / (persistent soil) soil-persistent
# 2504: Schoenus paludosus / (persistent soil) soil-persistent
# 2507: Schoenus turbinatus / (persistent soil) soil-persistent
# 1985: Scleranthus biflorus / (persistent soil) soil-persistent / References!C10
# 1989: Scleranthus singuliflorus / (persistent soil) soil-persistent / References!C10
# 3110: Scolopia braunii / (transient) transient
# 8185: Selaginella gracillima / (none) transient
# 8187: Selaginella uliginosa / (transient) transient
# 11635: Senecio extensus / (transient) transient
# 7097: Senecio garlandii / (persistent soil) soil-persistent
# 1663: Senecio gunnii / (transient) transient
# 1664: Senecio hispidulus / (persistent soil) soil-persistent
# 11636: Senecio lageniformis / (transient) transient
# 1667: Senecio linearifolius / (persistent soil / transient) other
# 11632: Senecio longipilus / (transient) transient
# 1671: Senecio minimus / (none) transient
# 14039: Senecio pinnatifolius var. alpinus / (transient) transient / References!C10
# 1675: Senecio quadridentatus / (none) transient
# 8772: Senna acclinis / (persistent soil) soil-persistent
# 14539: Senna artemisioides subsp. X artemisioides / (a-persistent soil) soil-persistent
# 12484: Senna form taxon 'helmsii' / (a-persistent soil) soil-persistent
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /var/folders/14/vyrp_30975d7y17lqxjblf2c0000gn/T/ipykernel_37471/2865481493.py in <module>
#      39         if spcode.isnumeric():
#      40             cur = conn.cursor()
# ---> 41             cur.execute(qrystr % (spname,spcode,transvalue))
#      42             updated_rows = cur.rowcount
#      43             # print("%s rows updated" % (updated_rows))
#
# SyntaxError: syntax error at or near "helmsii"
# LINE 1: ...ies_code,seedbank_type) values('Senna form taxon 'helmsii'',...
#                                                              ^

# %%
j=22
varname=ws.cell(row=2, column=j).value
print(varname)

switcher={
    "prolific":"abundant",
    "abundant":"abundant",
    "common":"abundant",
    "high":"abundant",
    "substantial":"abundant",
    "vigourous":"abundant",
    "1-4 seedlings/m2":"abundant",
    "no":"absent",
    "none observed":"absent"
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,postfire_seedling_recruitment) values('%s',%s,'%s') ON CONFLICT (species,species_code) DO UPDATE SET postfire_seedling_recruitment=EXCLUDED.postfire_seedling_recruitment"

for i in range(3,3000):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "present")
        if varref is not None:
            print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        else:
            print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur = conn.cursor()
            cur.execute(qrystr % (spname,spcode,transvalue))
            updated_rows = cur.rowcount
            # print("%s rows updated" % (updated_rows))
            conn.commit()
            cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Post-fire recruitment
# Connecting to the PostgreSQL database...
# Species Code: Current Scientific Name / (Post-fire recruitment) present
# 3632: Abutilon oxycarpum / (yes) present / References!C96
# 3705: Acacia aneura / (prolific (FO1) / moderate (HG)) present
# 7581: Acacia aulacocarpa / (yes) present / References!C93
# 3716: Acacia binervata / (prolific) abundant / References!C106
# 3725: Acacia burbidgeae / (abundant) abundant / References!C70
# 3727: Acacia buxifolia / (yes) present / References!S51
# 9282: Acacia buxifolia subsp. pubiflora / (<1 seedling per adult) present
# 3755: Acacia curranii / (post-fire pulse) present
# 3758: Acacia dealbata / (<1 seedling per adult) present / References!C101
# 8269: Acacia deanei subsp. deanei / (yes) present / References!N40
# 3772: Acacia falciformis / (yes (95) / >1 seedling per adult (100)) present
# 3773: Acacia filicifolia / (<1 seedling per adult) present / References!C101
# 3774: Acacia fimbriata / (>1 seedling per adult) present / References!C101
# 3780: Acacia fulva / (yes; no seedlings in unburnt areas) present / References!C72
# 3784: Acacia granitica / (>1 seedling per adult) present
# 3785: Acacia gunnii / (yes) present / References!S51
# 3797: Acacia jennerae / (yes) present / References!S30
# 9983: Acacia kulnurensis / (yes) present
# 3807: Acacia latisepala / (>1 seedling per adult) present / References!C101
# 10790: Acacia longifolia subsp. longifolia / (>1 seedling per adult) present / References!C101
# 3820: Acacia macnuttiana / (>1 seedling per adult) present / References!C101
# 3821: Acacia maidenii / (yes) present / References!C106
# 3823: Acacia mearnsii / (yes) present / References!C85
# 3824: Acacia melanoxylon / (8 seedlings/m2 (HR); 232 seedlings/ha (CT)) present
# 3832: Acacia murrayana / (yes) present / References!S30
# 3834: Acacia myrtifolia / (yes) present / References!C106
# 3845: Acacia paradoxa / (present at all sites) present / References!C79
# 3857: Acacia prominens / (even aged stands) present / References!C72
# 3858: Acacia pruinosa / (<1 seedling per adult) present / References!C101
# 3861: Acacia pycnantha / (present at all sites) present / References!C79
# 12042: Acacia ramulosa var. ramulosa / (yes (FO1) / no) present
# 3873: Acacia saligna / (yes) present / References!C2
# 3885: Acacia terminalis / (prolific) abundant / References!C106
# 3886: Acacia tetragonophylla / (absent-infrequent) present / References!S30
# 3888: Acacia torringtonensis / (>1 seedling per adult) present / References!C101
# 8865: Acacia venulosa / (>1 seedling per adult) present / References!C101
# 3895: Acacia verniciflua / (present at all sites) present / References!C79
# 3898: Acacia victoriae / (absent-infrequent) present
# 3899: Acacia viscidula / (>1 seedling per adult) present / References!C101
# 5603: Acaena echinata / (minor (79) / no) present
# 4351: Acianthus caudatus / (no) absent
# 4352: Acianthus exsertus / (no) absent
# 9088: Acianthus pusillus / (no) absent
# 3968: Acmena smithii / (904 seedlings/ha) present / References!S25
# 11966: Acrothamnus hookeri / (<1 seedling per adult) present / References!C101
# 2580: Acrotriche aggregata / (<1 seedling per adult) present
# 2583: Acrotriche serrulata / (yes) present / References!C106
# 1092: Actinotus forsythii / (yes, but generally in autumn regardless of fire season) present
# 1093: Actinotus gibbonsii / (yes) present / References!C2
# 4729: Agrostis venusta / (no / yes) present
# 6639: Alectryon oleifolius subsp. canescens / (no) absent
# 2010: Allocasuarina distyla / (yes) present / References!C106
# 2012: Allocasuarina littoralis / (yes) present / References!C93
# 2018: Allocasuarina verticillata / (present at 78% of sites) present / References!C79
# 7289: Alloteropsis semialata / (no) absent
# 8368: Almaleea cambagei / (<1 seedling per adult) present
# 5553: Alphitonia petriei / (high) abundant / References!C93
# 6340: Alpinia caerulea / (yes) present / References!C36
# 1165: Alyxia buxifolia / (no) absent
# 9713: Amperea xiphoclada var. xiphoclada / (no / yes (10) / <1 seedling per adult (100)) present
# 3969: Angophora bakeri / (yes) present / References!S14
# 3970: Angophora costata / (yes) present / References!C2
# 4749: Anisopogon avenaceus / (moderate) present / References!C58
# 11046: Aotus subglauca var. subglauca / (<1 seedling per adult) present / References!C101
# 6955: Aotus subspinescens / (no) absent
# 9722: Aristea ecklonii / (fruiting 11 months post-fire) present / References!C129
# 3518: Arthropodium minus / (yes) present
# 8851: Asterolasia elegans / (only a few seedlings between fires, best recruitment after moderate to high intensity fire) present
# 2584: Astroloma humifusum / (present at 43% of sites) present / References!C79
# 1203: Astrotricha ledifolia / (yes) present / References!S51
# 3910: Atherosperma moschatum / (1-4 seedlings/m2) abundant / References!S36
# 2078: Atriplex vesicaria / (low) present / References!S32
# 10393: Austrostipa mollis / (yes) present / References!C79
# 10375: Austrostipa nitida / (present at 50% of sites) present
# 9817: Babingtonia odontocalyx / (prolific (69) / >1 seedling per adult (100)) present
# 9836: Baeckea omissa / (yes (74) / <1 seedling per adult (100)) present
# 5339: Banksia aemula / (yes) present / References!S14
# 11049: Banksia ericifolia subsp. ericifolia / (vigorous) present / References!A101
# 5343: Banksia integrifolia / (yes) present
# 14554: Banksia neoanglica / (>1 seedling per adult) present / References!C101
# 5345: Banksia oblongifolia / (yes) present / References!A64
# 5346: Banksia paludosa / (some) present / References!C106
# 5348: Banksia serrata / (yes) present / References!B64
# 5349: Banksia spinulosa / (better after autumn burn cf spring) present / References!C58
# 2294: Baumea acuta / (most recruitment postfire) present / References!C129
# 2297: Baumea gunnii / (most recruitment postfire) present / References!C129
# 2299: Baumea juncea / (no) absent
# 1282: Bedfordia arborescens / (abundant) abundant / References!S47
# 4671: Billardiera scandens / (yes) present / References!B28
# 3529: Blandfordia nobilis / (yes) present / References!C106
# 10752: Boronia coerulescens subsp. coerulescens / (present at all sites) present / References!C79
# 5743: Boronia granitica / (low) present / References!C70
# 5744: Boronia ledifolia / (>1 seedling per adult) present / References!C101
# 5745: Boronia microphylla / (<1 seedling per adult) present / References!C101
# 5759: Boronia serrulata / (germinates within 2 years of fire (126)) present
# n/a: Boronia sp. aff. microphylla / (none observed) absent / References!C70
# 7210: Boronia thujona / (seedlings 5 months after high intensity fire) present
# 2778: Bossiaea ensata / (few seedlings) present / References!C106
# 2780: Bossiaea heterophylla / (high) abundant / References!C58
# 2783: Bossiaea neo-anglica / (>1 seedling per adult) present
# 2784: Bossiaea obcordata / (yes (57) / <1 seedling per adult (100)) present
# 2789: Bossiaea scolopendria / (yes) present / References!C53
# 2790: Bossiaea scortechinii / (>1 seedling per adult) present / References!C101
# 10689: Brachyloma daphnoides subsp. daphnoides / (yes) present / References!A71
# 10690: Brachyloma daphnoides subsp. glabrum / (<1 seedling per adult) present / References!C101
# 9295: Brachyloma saxicola / (low (69) / >1 seedling per adult (100)) present
# 6542: Brachyscome gracilis / (yes) present
# 2695: Breynia oblongifolia / (few seedlings) present / References!C106
# 1863: Brunonia australis / (yes) present / References!N43
# 1004: Brunoniella pumilio / (high, seedling survival better after autumn burn cf spring) present / References!C58
# 3531: Bulbine bulbosa / (high) abundant / References!C58
# 3533: Burchardia umbellata / (no) absent
# 4674: Bursaria spinosa / (present at 43% of sites) present / References!C79
# 11018: Bursaria spinosa subsp. spinosa / (<1 seedling per adult) present / References!C101
# 6896: Caesia calliantha / (no / yes) present
# 3535: Caesia parviflora / (no) absent
# 11246: Caladenia capillata / (no) absent / References!S51
# 4373: Caladenia carnea / (no) absent / References!S51
# 6703: Caladenia catenata / (no) absent
# 9523: Caladenia concolor / (yes) present / References!N40
# 4376: Caladenia cucullata / (no) absent
# 4379: Caladenia dimorpha / (no) absent
# 9123: Caladenia gracilis / (no) absent
# 9192: Caladenia sp. A / (no) absent
# 5314: Calandrinia pickeringii / (prolific) abundant / References!C2
# 2270: Callicoma serratifolia / (few seedlings) present / References!C106
# 4006: Callistemon flavovirens / (yes) present
# 4010: Callistemon pachyphyllus / (no) absent
# 7943: Callistemon pityoides / (<1 seedling per adult) present / References!C101
# 9126: Callistemon pungens / (>1 seedling per adult) present / References!C101
# 4015: Callistemon salignus / (yes) present / References!C36
# 14189: Callistemon sp. aff. flavovirens / (none observed) absent
# 2283: Callitris oblonga / (>1 seedling per adult) present / References!C101
# 2285: Callitris rhomboidea / (yes (45) / present at 33% of sites (78)) present
# 6805: Callitris verrucosa / (present at all sites) present
# 1330: Calocephalus citreus / (none observed (78) / minor (79)) present
# 3537: Calostemma purpureum / (no) absent
# 2215: Calystegia marginata / (prolific) abundant / References!S25
# 4021: Calytrix tetragona / (present at 42% of sites (78), <1 seedling per adult (100), few seedlings (105)) present
# 1865: Canarium australasicum / (yes) present
# 2311: Carex bichenoviana / (no) absent
# 2313: Carex breviculmis / (no) absent
# 1360: Cassinia aculeata / (333 seedlings/ha) present / References!S25
# 1367: Cassinia laevis / (<1 seedling per adult) present / References!C101
# 9246: Cassinia leptocephala subsp. leptocephala / (<1 seedling per adult) present / References!C101
# 1369: Cassinia longifolia / (53 seedlings/ha) present / References!S25
# 1370: Cassinia quinquefaria / (<1 seedling per adult) present / References!C101
# 7220: Cassytha filiformis / (no) absent
# 3467: Cassytha glabella / (few seedlings) present / References!C106
# 2342: Caustis pentandra / (no / yes) present
# 8807: Centrolepis strigosa subsp. strigosa / (no) absent
# 8005: Cheilanthes austrotenuifolia / (none observed) absent / References!C79
# 6242: Chloanthes parviflora / (>1 seedling per adult) present / References!C101
# 1391: Chondrilla juncea / (yes) present
# 13527: Chordifex dimorphus / (yes) present
# 1392: Chrysanthemoides monilifera / (present at 50% of sites) present
# 8559: Chrysocephalum apiculatum / (minor (79) / yes / no) present
# 1400: Cirsium vulgare / (few seedlings seen) present / References!C106
# 6283: Cissus hypoglauca / (rare (M), few seedlings (105)) present
# 5493: Clematis aristata / (few seedlings) present / References!C106
# 5496: Clematis microphylla / (none observed) absent
# 5253: Comesperma ericinum / (better after spring burn cf autumn) present / References!C58
# 5257: Comesperma volubile / (none after autumn burn, moderate after spring burn) present / References!C58
# n/a: Commersonia amystia / (abundant seedlings after fire (135)) present
# 6129: Commersonia bartramia / (yes) present / References!C93
# 13958: Commersonia breviseta / (abundant seedlings after fire (135)) present
# 5352: Conospermum taxifolium / (yes (BN) / <1 seedling per adult (100)) present
# 2220: Convolvulus erubescens / (no / yes) present
# 5675: Coprosma quadrifida / (200 seedlings/ha) present / References!S25
# 6198: Corchorus cunninghamii / (yes; some germination in undisturbed sites) present
# 13961: Coronidium oxylepis / (yes) present / References!S51
# 5772: Correa reflexa / (present at 44% of sites) present / References!C79
# 9687: Corymbia gummifera / (yes (52), prolific (105)) present
# 9692: Corymbia maculata / (few with low-intensity, prolific with high intensity) present / References!C106
# 10271: Crocosmia X crocosmiiflora / (fruiting 10 months post-fire) present / References!C129
# 5775: Crowea saligna / (Frequent seedlings 5 months post intense fire) present / References!C128
# 5554: Cryptandra amara / (<1 seedling per adult) present / References!C101
# 4415: Cryptostylis hunteriana / (yes) present / References!N42
# 11228: Cyanicula caerulea / (no) absent
# 8074: Cyathea australis / (common) abundant / References!S47
# 2347: Cyathochaeta diandra / (moderate) present / References!C58
# 3174: Dampiera stricta / (yes) present / References!C106
# 4024: Darwinia biflora / (yes) present / References!C14
# 4026: Darwinia diminuta / (yes) present / References!C14
# 4028: Darwinia glaucophylla / (yes) present / References!C14
# 4030: Darwinia leptantha / (yes) present / References!C106
# 4032: Darwinia procera / (yes) present / References!C14
# 2819: Daviesia brevifolia / (yes) present / References!C34
# 2823: Daviesia latifolia / (yes (95) / <1 seedling per adult (100)) present
# 9597: Daviesia leptophylla / (yes) present / References!C79
# 2824: Daviesia mimosoides / (yes) present / References!S51
# 2828: Daviesia umbellulata / (>1 seedling per adult) present / References!C101
# 6621: Desmodium gunnii / (yes) present
# 3542: Dianella revoluta / (no) absent
# 4897: Dichelachne crinita / (no) absent
# 3545: Dichopogon strictus / (no / yes) present
# 8082: Dicksonia antarctica / (147 seedlings/ha) present / References!S25
# 7556: Dillwynia brunioides / (yes) present / References!C106
# 2844: Dillwynia glaberrima / (yes) present / References!A102
# 2845: Dillwynia hispida / (yes (33) / present at all sites (78)) present
# 7225: Dillwynia phylicoides / (>1 seedling per adult) present / References!C101
# 12383: Dillwynia retorta species complex / (high, better after autumn burn cf spring) present / References!C58
# 7836: Diplarrena moraea / (no) absent
# 4437: Dipodium hamiltonianum / (minimal) present
# 7887: Dipodium punctatum / (no) absent
# 5564: Discaria pubescens / (yes) present / References!N43
# 4446: Diuris longifolia / (no) absent
# 4447: Diuris maculata / (no) absent / References!S51
# 6671: Diuris pauciflora / (no) absent
# 9157: Diuris punctata var. punctata / (yes) present / References!N40
# 4456: Diuris sulphurea / (no) absent
# 5892: Dodonaea boroniifolia / (yes) present
# 5897: Dodonaea hirsuta / (yes) present / References!C70
# 5898: Dodonaea lobulata / (yes) present / References!S30
# 5911: Dodonaea triquetra / (<1 seedling per adult (100), prolific (105)) present
# 5913: Dodonaea viscosa / (yes) present
# 7830: Dodonaea viscosa subsp. angustissima / (high) abundant / References!S32
# 1019: Doryanthes excelsa / (first seedlings observed 2.5 years post-fire) present / References!C107
# 2556: Drosera auriculata / (no / yes) present
# 2558: Drosera glanduligera / (no / yes) present
# 2559: Drosera peltata / (no / yes) present
# 2560: Drosera pygmaea / (no / yes) present
# 11864: Drypetes deplanchei / (yes) present
# 6035: Duboisia hopwoodii / (yes) present
# 7593: Echinopogon caespitosus var. caespitosus / (yes) present / References!C106
# 2574: Elaeocarpus reticulatus / (rare: 5 seedlings/ha) present / References!S25
# 5532: Empodisma minus / (no) absent
# 4946: Entolasia marginata / (yes) present
# 4947: Entolasia stricta / (high) abundant / References!C58
# 2596: Epacris hamiltonii / (prolific) abundant
# 2597: Epacris impressa / (present at all sites) present / References!C79
# 2602: Epacris obtusifolia / (>1 seedling per adult (100), high (105)) present
# 7952: Epilobium billardiereanum subsp. cinereum / (yes) present / References!S51
# 4329: Epilobium gunnianum / (yes) present / References!C75
# 7578: Eragrostis benthamii / (yes) present / References!B104
# 4956: Eragrostis eriopoda / (none observed) absent / References!C79
# 7252: Eremophila deserti / (weak) present
# 3938: Eremophila gilesii / (moderate) present / References!S32
# 3939: Eremophila glabra / (present at 50% of sites) present
# 3941: Eremophila latrobei / (no / weak (HG)) present
# 3942: Eremophila longifolia / (yes (FO1) / weak (HG)) present
# 3944: Eremophila mitchellii / (no) absent
# 3949: Eremophila sturtii / (low) present
# 4460: Eriochilus cucullatus / (no) absent
# 5776: Eriostemon australasius / (better after spring burn cf autumn (57); prolific recruitment after high intensity fire (125)) present / References!C58
# 3142: Erodium crinitum / (yes) present / References!C79
# 4038: Eucalyptus aggregata / (yes) present / References!N38
# 4053: Eucalyptus baxteri / (no / yes (10) / none observed (78)) present
# 4054: Eucalyptus behriana / (no) absent
# 4055: Eucalyptus benthamii / (no) absent / References!C77
# 4059: Eucalyptus bosistoana / (5 seedlings/ha) present / References!S25
# 9517: Eucalyptus caleyi subsp. ovendenii / (none observed) absent
# 4065: Eucalyptus calycogona / (none observed) absent / References!C79
# 6360: Eucalyptus camaldulensis / (yes) present / References!S30
# 12178: Eucalyptus costata subsp. murrayana / (7000 seedlings/ha; recruitment doesn't follows c.10% of fires (33); present at 50% of sites (78)) present
# 4075: Eucalyptus cypellocarpa / (118 seedlings/ha) present / References!S25
# 4083: Eucalyptus dumosa / (yes) present / References!C79
# 4086: Eucalyptus elata / (0.5seedlings/10m2 in WSF, 2.6 seedlings/10m2 in RF) present / References!S47
# 4087: Eucalyptus eugenioides / (yes) present / References!C106
# 4090: Eucalyptus fastigata / (232 seedlings/ha) present / References!S25
# 4097: Eucalyptus globoidea / (few seedlings) present / References!C106
# 4099: Eucalyptus goniocalyx / (yes) present / References!C79
# 4100: Eucalyptus gracilis / (no) absent
# 8498: Eucalyptus leptophylla / (no / present at 50% of sites (78)) present
# 6961: Eucalyptus leucoxylon subsp. pruinosa / (present at 75% of sites) present / References!C79
# 4116: Eucalyptus luehmanniana / (low levels of emergence) present / References!C82
# 4127: Eucalyptus microcarpa / (present at all sites) present / References!C79
# 4132: Eucalyptus muelleriana / (5 seedlings/ha) present / References!S25
# 4140: Eucalyptus obliqua / (yes (10) / 43.2 seedlings/10m2 in WSF, 2.2 seedlings/10m2 in RF (M)) present
# 4141: Eucalyptus oblonga / (yes) present / References!C53
# 8831: Eucalyptus paniculata subsp. paniculata / (yes) present / References!C106
# 8959: Eucalyptus parramattensis subsp. parramattensis / (yes) present / References!S14
# 4165: Eucalyptus punctata / (few seedlings) present / References!C106
# 9450: Eucalyptus resinifera subsp. resinifera / (yes) present / References!C106
# 9750: Eucalyptus rubida subsp. rubida / (yes) present / References!C79
# 4178: Eucalyptus sclerophylla / (yes) present / References!A102
# 4181: Eucalyptus sideroxylon / (yes) present / References!C11
# 4185: Eucalyptus socialis / (none observed) absent / References!C79
# 4197: Eucalyptus viminalis / (yes) present / References!B71
# 9690: Euchiton sphaericus / (few seedlings) present / References!C106
# 9166: Euphrasia collina subsp. muelleri / (yes) present
# 2768: Eupomatia laurina / (no) absent / References!S25
# 6015: Eustrephus latifolius / (rare) present / References!S47
# 5859: Exocarpos aphyllus / (no) absent
# 5860: Exocarpos cupressiformis / (present at 75% of sites (78) / yes (P)) present
# 6383: Exocarpos latifolius / (yes) present
# 12416: Ficinia nodosa / (present at 66% of sites (78) / no) present
# 10698: Freesia hybrid / (fruiting 10 months post-fire) present / References!C129
# 2438: Gahnia lanigera / (no) absent
# 2441: Gahnia radula / (no / yes) present
# 2442: Gahnia sieberiana / (no / yes (R42)) present
# 4463: Gastrodia sesamoides / (no) absent
# 8951: Genoplesium despectans / (no) absent
# 9201: Genoplesium rufum / (no) absent
# 3238: Glischrocaryon behrii / (yes) present
# 4465: Glossodia major / (no) absent / References!S51
# 2864: Gompholobium glabratum / (high (57, 105), better after autumn burn cf spring (57)) present
# 2865: Gompholobium grandiflorum / (yes) present / References!B49
# 3247: Gonocarpus tetragynus / (no / present at all sites (78)) present
# 8711: Goodenia bellidifolia subsp. bellidifolia / (high) abundant / References!C58
# 9279: Goodenia hederacea subsp. hederacea / (yes (P) / high (57)) present
# 9168: Goodenia macbarronii / (yes) present / References!N40
# 3193: Goodenia pinnatifida / (none observed) absent / References!C79
# 8875: Grevillea acanthifolia subsp. acanthifolia / (9-25 seedlings/m2) present / References!C2
# 8292: Grevillea acerata / (yes) present / References!C75
# 5357: Grevillea alpina / (yes) present / References!S51
# 5364: Grevillea buxifolia / (>1 seedling per adult) present / References!C101
# 5365: Grevillea caleyi / (post-fire recruitment abundant, seedling survival high) present / References!N5
# 5374: Grevillea ilicifolia / (yes) present / References!C79
# 9676: Grevillea kedumbensis / (yes) present / References!B84
# 5382: Grevillea longifolia / (yes) present / References!C14
# 8307: Grevillea molyneuxii / (yes) present / References!C103
# 5385: Grevillea mucronulata / (yes) present / References!B17
# 5386: Grevillea nematophylla / (yes) present / References!S30
# 5395: Grevillea rivularis / (yes) present / References!C103
# 5401: Grevillea speciosa / (strong post-fire pulse) present / References!C2
# 5404: Grevillea striata / (no / yes) present
# 10985: Grevillea viridiflava / (>1 seedling per adult) present
# 6435: Haemodorum corymbosum / (no) absent
# 9114: Hakea bakeriana / (seedlings rare after fire) present / References!C2
# 5408: Hakea constablei / (may be poor) present
# 10802: Hakea dohertyi / (yes) present
# 10803: Hakea laevipes subsp. graniticola / (>1 seedling per adult) present
# 9602: Hakea macrorrhyncha / (>1 seedling per adult) present / References!C101
# 5420: Hakea microcarpa / (>1 seedling per adult) present / References!C101
# 5425: Hakea sericea / (may not be very successful (1); no seedlings seen after prescribed fire, a few seen after wildfire (103)) present
# 5427: Hakea teretifolia / (all recruitment within 9 months of fire) present / References!C2
# 3252: Haloragis heterophylla / (no) absent
# 2873: Hardenbergia violacea / (yes (70, P) / >1 seedling per adult (100)) present
# 13289: Harmogia densifolia / (<1 seedling per adult) present / References!C101
# 3914: Hedycarya angustifolia / (11 seedlings/ha) present / References!S25
# 2526: Hibbertia acicularis / (yes (78) / <1 seedling per adult (100)) present
# 10554: Hibbertia aspera subsp. aspera / (yes) present / References!C79
# 2529: Hibbertia calycina / (yes) present / References!S51
# 2531: Hibbertia cistoidea / (<1 seedling per adult) present / References!C101
# 2539: Hibbertia linearis / (<1 seedling per adult) present / References!C101
# 2542: Hibbertia obtusifolia / (yes (P) / <1 seedling per adult (100)) present
# 2545: Hibbertia riparia / (present at 57% of sites (78) / <1 seedling per adult (100)) present
# 2550: Hibbertia serpyllifolia / (moderate (57)  <1 seedling per adult (100)) present
# 2551: Hibbertia vestita / (<1 seedling per adult) present / References!C101
# 5002: Hierochloe rariflora / (no) absent
# 11251: Homoranthus binghiensis / (>1 seedling per adult) present / References!C101
# 9034: Homoranthus lunatus / (>1 seedling per adult) present / References!C101
# 12176: Hovea graniticola / (>1 seedling per adult) present / References!C101
# 2876: Hovea linearis / (yes) present / References!B28
# 6267: Hybanthus vernonii / (high) abundant / References!C58
# 1126: Hydrocotyle geraniifolia / (prolific) abundant / References!C106
# 1128: Hydrocotyle laxiflora / (yes) present / References!N43
# 7240: Hypericum gramineum / (high) abundant / References!C106
# 8788: Hypochaeris radicata / (yes) present / References!B102
# 5533: Hypolaena fastigiata / (present at 67% of sites) present / References!C79
# 7493: Hypoxis glabella var. glabella / (no) absent
# 7648: Hypoxis hygrometrica var. hygrometrica / (Recruitment mostly after fire (126)) present
# 7544: Indigofera adesmiifolia / (<1 seedling per adult) present / References!C101
# 2882: Indigofera australis / (yes (P) / <1 seedling per adult (100)) present
# 2453: Isolepis hystrix / (no) absent
# 2454: Isolepis inundata / (no) absent
# 5433: Isopogon anemonifolius / (yes (29, BN) / low (57)) present
# 6839: Isopogon anethifolius / (yes) present / References!A103
# 5439: Isopogon prostratus / (yes) present / References!N39
# 2892: Jacksonia scoparia / (<1 seedling per adult) present / References!C101
# 6398: Jasminum lineare / (yes) present
# 3318: Juncus bufonius / (Fruiting 38 weeks after fire) present
# 3326: Juncus continuus / (Fruiting 42 weeks after fire) present
# 3339: Juncus pauciflorus / (no) absent
# 3340: Juncus planifolius / (recruitment mostly after fire (126)) present
# 3350: Juncus usitatus / (no) absent
# 2896: Kennedia prostrata / (yes) present / References!C106
# 4205: Kunzea bracteolata / (abundant (69) / >1 seedling per adult (100)) present
# 4207: Kunzea capitata / (yes) present / References!C106
# 4212: Kunzea rupestris / (yes) present / References!N32
# 11960: Lagenophora stipitata / (none observed) absent / SpeciesData!C79
# 5440: Lambertia formosa / (yes) present / References!C53
# 6139: Lasiopetalum ferrugineum / (yes) present / References!C106
# 9008: Lasiopetalum ferrugineum var. ferrugineum / (Seedlings prolific after high intensity fire (127)) present
# 6140: Lasiopetalum joyceae / (germinates readily after fire, seedling survivial <10% (127)) present
# 10724: Leionema ambiens / (yes) present
# 10736: Leionema rotundifolium / (yes) present
# 1816: Lepidium aschersonii / (yes) present
# 1830: Lepidium pseudotasmanicum / (yes) present / References!N43
# 8380: Lepidosperma concavum / (no) absent
# 2465: Lepidosperma filiforme / (recruitment mostly post-fire) present / References!C129
# 2467: Lepidosperma forsythii / (recruitment mostly post-fire) present / References!C129
# 6402: Lepidosperma laterale / (no) absent
# 2470: Lepidosperma longitudinale / (no) absent
# 2471: Lepidosperma neesii / (no) absent
# 2473: Lepidosperma semiteres / (no) absent
# 11028: Lepidosperma viscidum / (no / present at 33% of sites (78)) present
# 1554: Leptorhynchos elongatus / (yes) present / References!N43
# 1557: Leptorhynchos squamatus / (minor (79) / none observed (78)) present
# 7970: Leptospermum continentale / (none observed (78)) present
# 4217: Leptospermum coriaceum / (present at 38% of sites) present
# 4221: Leptospermum juniperinum / (present at 50% of sites (78)) present
# 4228: Leptospermum multicaule / (yes) present
# 4229: Leptospermum myrsinoides / (yes (33) / present at 4% of sites (78)) present
# 9958: Leptospermum rotundifolium / (few seedlings) present / References!C106
# 8317: Leptospermum thompsonii / (prone to detrimental competition) present
# 8486: Leptospermum trinervium / (yes) present / References!C53
# 2613: Leucopogon biflorus / (<1 seedling per adult) present / References!C101
# 2618: Leucopogon exolasius / (may be delayed after mid-winter burn) present / References!C108
# 6425: Leucopogon lanceolatus var. lanceolatus / (<1 seedling per adult) present / References!C101
# 2628: Leucopogon melaleucoides / (<1 seedling per adult) present / References!C101
# 7287: Leucopogon microphyllus var. pilibundus / (<1 seedling per adult) present
# 2631: Leucopogon neo-anglicus / (>1 seedling per adult) present / References!C101
# 2632: Leucopogon parviflorus / (present at 40% of sites) present / References!C79
# 11108: Lissanthe strigosa subsp. subulata / (<1 seedling per adult) present / References!C101
# 1917: Lobelia gibbosa / (no / yes) present
# 6297: Lomandra confertifolia / (no) absent
# 7546: Lomandra confertifolia subsp. leptostachya / (no) absent
# 6298: Lomandra cylindrica / (yes) present / References!C58
# 6300: Lomandra effusa / (no) absent
# 6302: Lomandra filiformis / (moderate-high (57) / no) present
# 6304: Lomandra glauca / (no) absent
# 8469: Lomandra leucocephala subsp. robusta / (none observed) absent
# 6308: Lomandra longifolia / (no) absent
# 9082: Lomandra micrantha subsp. tuberculata / (no) absent
# 8802: Lomandra multiflora subsp. multiflora / (no) absent
# 6312: Lomandra obliqua / (moderate) present / References!C58
# 5442: Lomatia fraseri / (<1 seedling per adult) present / References!C101
# 5445: Lomatia silaifolia / (<1 seedling per adult) present / References!C101
# 2908: Lotus cruentus / (yes) present
# 6040: Lycium ferocissimum / (yes) present
# 2142: Maireana pyramidata / (none observed) absent / References!C79
# 2147: Maireana sedifolia / (none observed (78)) present
# 1234: Marsdenia rostrata / (rare) present / References!S47
# 10896: Marsdenia viridiflora subsp. viridiflora / (no) absent
# 11116: Melaleuca acuminata subsp. acuminata / (none observed) absent
# 6809: Melaleuca biconvexa / (few seedlings) present / References!C106
# 4252: Melaleuca groveana / (yes) present / References!C75
# 4256: Melaleuca lanceolata / (present at 63% of sites) present / References!C79
# 4268: Melaleuca uncinata / (present at all sites) present / References!C79
# 3675: Melastoma affine / (yes) present / References!C93
# 2645: Melichrus procumbens / (<1 seedling per adult) present / References!C101
# 2646: Melichrus urceolatus / (<1 seedling per adult) present / References!C101
# 7707: Microlaena stipoides var. stipoides / (high) abundant / References!C58
# 7622: Microtis parviflora / (no) absent / References!S51
# 4473: Microtis unifolia / (no) absent
# 7736: Mirbelia speciosa subsp. speciosa / (>1 seedling per adult) present / References!C101
# 3595: Mitrasacme polymorpha / (high) abundant / References!C106
# 2649: Monotoca scoparia / (yes (52) / none observed (78) / <1 seedling per adult (100)) present
# 3954: Myoporum insulare / (yes) present / References!C79
# 3957: Myoporum platycarpum / (none observed) absent
# 11948: Myrsine howittiana / (16 seedlings/ha) present / References!S25
# 6695: Notelaea microcarpa var. microcarpa / (yes) present
# 7688: Olea europaea subsp. europaea / (none observed) absent
# 1580: Olearia argophylla / (abundant) abundant / References!S47
# 1597: Olearia lepidophylla / (no) absent
# 1604: Olearia myrsinoides / (<1 seedling per adult) present / References!C101
# 1611: Olearia ramulosa / (observed at 83% of sites (78)) present
# 1612: Olearia rosmarinifolia / (<1 seedling per adult) present
# 1618: Olearia viscidula / (<1 seedling per adult) present / References!C101
# 5697: Opercularia aspera / (prolific) abundant / References!C106
# 5701: Opercularia varia / (high) abundant / References!C106
# 4476: Orthoceras strictum / (no) absent
# 4613: Oxalis corniculata / (yes) present
# 4621: Oxalis perennans / (minor (79), high (105)) present
# 2948: Oxylobium arborescens / (>1 seedling per adult) present
# 9611: Ozothamnus cuneifolius / (substantial) abundant / References!S47
# 8557: Ozothamnus diosmifolius / (<1 seedling per adult) present / References!C101
# 10485: Pandorea pandorana subsp. pandorana / (rare (M)) present
# 1177: Parsonsia brownii / (yes) present / References!C75
# 9505: Parsonsia dorrigoensis / (yes) present
# 3300: Patersonia fragilis / (no) absent
# 3301: Patersonia glabrata / (few seedlings) present / References!C106
# 3303: Patersonia sericea / (moderate after spring burn, high after autumn burn) present / References!C58
# 3157: Pelargonium australe / (yes) present / References!C96
# 5455: Persoonia cornifolia / (<1 seedling per adult) present
# 5459: Persoonia juniperina / (none observed (78)) present
# 5462: Persoonia levis / (yes) present / References!C53
# 8995: Persoonia mollis subsp. maxima / (yes) present / References!N3
# 9048: Persoonia terminalis subsp. terminalis / (none observed (69) / <1 seedlingper adult (100)) present
# 5477: Petrophile canescens / (<1 seedling per adult) present / References!C101
# 5480: Petrophile sessilis / (yes, related to rainfall) present / References!C2
# 9419: Phebalium glandulosum subsp. eglandulosum / (yes) present / References!C70
# 10601: Philotheca virgata / (590/ha) present / References!S47
# 8216: Phyllanthus hirtellus / (yes) present / References!C58
# 6058: Physalis peruviana / (high) abundant / References!C106
# 4658: Phytolacca octandra / (high) abundant
# 6774: Pimelea curviflora var. divergens / (>1 seedling per adult) present
# 6179: Pimelea humilis / (no / yes) present
# 6182: Pimelea linifolia / (high) abundant / References!C58
# 6635: Pimelea linifolia subsp. collina / (high) abundant / References!C106
# 6814: Pimelea linifolia subsp. linifolia / (high) abundant / References!C106
# 6186: Pimelea pauciflora / (yes) present
# 6190: Pimelea spicata / (yes) present
# 11202: Pittosporum angustifolium / (no / yes) present
# 4685: Pittosporum undulatum / (22 seedlings/ha) present / References!S25
# 4699: Plantago lanceolata / (no) absent
# 9354: Platylobium formosum subsp. formosum / (yes) present
# 1143: Platysace ericoides / (high) abundant / References!C58
# 1144: Platysace lanceolata / (yes) present / References!C47
# 8742: Poa sieberiana var. sieberiana / (no) absent
# 9912: Podolobium ilicifolium / (high (95) / <1 seedling per adult (100)) present
# 1088: Polyalthia nitidissima / (yes) present
# 1211: Polyscias sambucifolia / (yes (R42) / 40 seedlings/ha (CT) / <1 seedling per adult (100)) present
# 5571: Pomaderris aspera / (1373 seedlings/ha (CT) / abundant (M)) present
# 5590: Pomaderris phylicifolia / (yes) present / References!N43
# 4494: Prasophyllum brevilabre / (no) absent / References!S51
# 4497: Prasophyllum elatum / (no) absent
# 4516: Prasophyllum odoratum / (no) absent
# 11301: Prasophyllum retroflexum / (yes) present
# 3415: Prostanthera lasianthos / (substantial) abundant / References!S47
# 3429: Prostanthera saxicola / (>1 seedling per adult) present
# 3430: Prostanthera scutellarioides / (>1 seedling per adult) present / References!C101
# 3436: Prostanthera teretifolia / (yes (69) / >1 seedling per adult (100)) present
# 3438: Prostanthera walteri / (370/ha) present / References!S47
# 11944: Psydrax latifolia / (rare) present
# 6403: Pteridium esculentum / (no) absent
# 7895: Pterostylis cycnocephala / (no) absent
# 4547: Pterostylis decurva / (no) absent
# 4559: Pterostylis longifolia / (no) absent
# 4560: Pterostylis mutica / (no) absent
# 4561: Pterostylis nana / (no) absent
# 4562: Pterostylis nutans / (no) absent
# 4566: Pterostylis parviflora / (no) absent
# 4575: Pterostylis truncata / (yes) present
# 8956: Ptilothrix deusta / (recruitment mostly post-fire) present / References!C129
# 1070: Ptilotus erubescens / (minimal) present
# 1079: Ptilotus obovatus / (yes (FO1) / none observed (78)) present
# 2976: Pultenaea benthamii / (3520/ha) present / References!S47
# 2985: Pultenaea daphnoides / (substantial (M), present at 75% of sites (78), high (105)) present
# 2994: Pultenaea foliolosa / (yes (69) / >1 seedling per adult (100)) present
# 3003: Pultenaea microphylla / (<1 seedling per adult) present / References!C101
# 3012: Pultenaea procumbens / (yes) present / References!S51
# 11810: Pultenaea setulosa / (<1 seedling per adult) present / References!C101
# 10853: Pyrorchis nigricans / (no / yes) present
# 2482: Rhynchospora brownii / (no) absent
# 6145: Rulingia dasyphylla / (yes) present
# 14314: Rytidosperma pallidum / (yes) present / References!S51
# 14316: Rytidosperma pilosum / (yes) present / References!S51
# 10639: Rytidosperma procerum / (yes) present / References!N43
# 6384: Santalum lanceolatum / (minimal) present / References!N40
# 3209: Scaevola spinescens / (no / yes) present
# 8181: Schizaea bifida / (no) absent
# 2491: Schoenus apogon / (no / yes) present
# 2492: Schoenus brevifolius / (no, recruitment mostly post-fire (126)) present
# 2495: Schoenus ericetorum / (recruitment mostly post-fire (126)) present
# 2498: Schoenus latelaminatus / (no) absent
# 9057: Schoenus lepidosperma subsp. pachylepis / (recruitment mostly post-fire (126)) present
# 2499: Schoenus maschalinus / (no) absent
# 2500: Schoenus melanostachys / (no) absent
# 2504: Schoenus paludosus / (recruitment mostly post-fire (126)) present
# 2506: Schoenus subaphyllus / (no) absent
# 8187: Selaginella uliginosa / (no) absent
# 7097: Senecio garlandii / (22.7/m2) present
# 11164: Senecio picridioides / (present at 50% of sites) present
# 8772: Senna acclinis / (yes) present
# 14539: Senna artemisioides subsp. X artemisioides / (yes (FO1) / none observed (78)) present
# 12484: Senna form taxon 'helmsii' / (yes (FO1) / no) present
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /var/folders/14/vyrp_30975d7y17lqxjblf2c0000gn/T/ipykernel_37471/1763881493.py in <module>
#      33         if spcode.isnumeric():
#      34             cur = conn.cursor()
# ---> 35             cur.execute(qrystr % (spname,spcode,transvalue))
#      36             updated_rows = cur.rowcount
#      37             # print("%s rows updated" % (updated_rows))
#
# SyntaxError: syntax error at or near "helmsii"
# LINE 1: ...e_seedling_recruitment) values('Senna form taxon 'helmsii'',...
#                                                              ^
