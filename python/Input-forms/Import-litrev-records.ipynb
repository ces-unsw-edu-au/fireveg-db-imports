# %%
import openpyxl
from pathlib import Path
import os
from datetime import datetime
from configparser import ConfigParser
import psycopg2
from psycopg2.extras import DictCursor
from psycopg2.extensions import AsIs

# %%
repodir = Path("../../") 
inputdir = repodir / "data" / "input-form"

# %%
os.listdir(inputdir)
# Out:
# ['fireveg-trait-input-spreadsheet_V3_DE_trial.xlsx']

# %%
inputfile=inputdir / 'fireveg-trait-input-spreadsheet_V3_DE_trial.xlsx'
wb = openpyxl.load_workbook(inputfile,data_only=True)
wb.worksheets
# Out:
# [<Worksheet "Instructions">,
#  <Worksheet "Input table">,
#  <Worksheet "traits">,
#  <Worksheet "references">,
#  <Worksheet "species codes">,
#  <Worksheet "vocabularies">]

# %% [markdown]
# ### References table

# %%
ws=wb["references"]

# %%
for table in ws.tables:
    print(table)
# Out:
# list_refs

# %%
table = ws.tables['list_refs']

# %%
tbl=ws[table.ref]

# %%
for cell in tbl[0]:
    print(cell.value)
# Out:
# ref_number
# ref_code
# ref_info
# DOI
# original_ref_code
# original_ref_info

# %%
for cell in tbl[len(tbl)-1]:
    print(cell.value)
# Out:
# 272
# Sheringham 2022
# Sheringham, P. 2022. Post Fire Response of Plant species in the Gibraltar Range.  Unpublished report
# None
# None
# None

# %% [markdown]
# ### Input table

# %%
ws=wb["Input table"]

# %%
ws['A1':'B7']
# Out:
# ((<Cell 'Input table'.A1>, <Cell 'Input table'.B1>),
#  (<Cell 'Input table'.A2>, <Cell 'Input table'.B2>),
#  (<Cell 'Input table'.A3>, <Cell 'Input table'.B3>),
#  (<Cell 'Input table'.A4>, <Cell 'Input table'.B4>),
#  (<Cell 'Input table'.A5>, <Cell 'Input table'.B5>),
#  (<Cell 'Input table'.A6>, <Cell 'Input table'.B6>),
#  (<Cell 'Input table'.A7>, <Cell 'Input table'.B7>))

# %%
for table in ws.tables:
    print(table)
    table.values()
# Out:
# input_table
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <module>
#       1 for table in ws.tables:
#       2     print(table)
# ----> 3     table.values()
#
# AttributeError: 'str' object has no attribute 'values'

# %%
table = ws.tables['input_table']

# %%
for row in table:
    print(row)
# Out:
# ('id', '24')
# ('name', 'input_table')
# ('displayName', 'input_table')
# ('ref', 'A1:O46')
# ('headerRowCount', '1')
# ('totalsRowShown', '0')
# ('headerRowDxfId', '36')
# ('dataDxfId', '34')
# ('headerRowBorderDxfId', '35')
# ('tableBorderDxfId', '33')

# %%
table.ref
# Out:
# 'A1:O46'

# %%
for row in ws[table.ref]:
    for cell in row:
        print(cell.value)
# Out:
# main_source
# original_sources
# original_species_name
# species_code
# species name
# Trait code
# Trait name
# Trait type
# raw_value
# norm_value
# Best
# Lower
# Upper
# method_of_estimation
# notes
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia anemonifolia subsp. anemonifolia
# 12257
# Boronia anemonifolia subsp. anemonifolia
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# Most
# None
# None
# None
# Direct observation (many)
# None
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia floribunda
# 5740
# Boronia floribunda
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# Most
# None
# None
# None
# Direct observation (many)
# None
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia fraseri
# 5741
# Boronia fraseri
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# None
# None
# None
# None
# Direct observation (many)
# None
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia ledifolia
# 5744
# Boronia ledifolia
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# None
# None
# None
# None
# Direct observation (many)
# None
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia pinnata
# 5750
# Boronia pinnata
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# Most
# None
# None
# None
# Direct observation (many)
# None
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia serrulata
# 5759
# Boronia serrulata
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# None
# None
# None
# None
# Direct observation (many)
# None
# MacKenzie Auld Keith Ooi 2021
# None
# Boronia thujona
# 7210
# Boronia thujona
# surv1
# Resprouting - full canopy scorch
# categorical
# None
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Acacia barringtonensis
# 3712
# Acacia barringtonensis
# surv4
# Regenerative Organ
# categorical
# Resprouts from the base post fire
# Basal
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Acacia barringtonensis
# 3712
# Acacia barringtonensis
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Acacia beadleana
# 11039
# Acacia beadleana
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Acacia cangaiensis
# 9085
# Acacia cangaiensis
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# Most
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Boronia angustisepala
# 10750
# Boronia angustisepala
# surv1
# Resprouting - full canopy scorch
# categorical
# s-
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Boronia inflexa subsp. inflexa
# 12356
# Boronia inflexa subsp. inflexa
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Callistemon flavovirens
# 4006
# Callistemon flavovirens
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (few)
# None
# Sheringham 2022
# None
# Callitris monticola
# 2281
# Callitris monticola
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Dillwynia rupestris
# 12302
# Dillwynia rupestris
# surv1
# Resprouting - full canopy scorch
# categorical
# s and r
# Half
# None
# None
# None
# Direct observation (few)
# None
# Sheringham 2022
# None
# Dodonaea serratifolia
# 5907
# Dodonaea serratifolia
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (few)
# An obligate seeding shrub. Only two seedlings have been seen since fire. Not observed recruiting in known locations in Gibraltar Range National Park.
# Sheringham 2022
# None
# Eucalyptus dissita
# 9719
# Eucalyptus dissita
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Hakea macrorrhyncha
# 9602
# Hakea macrorrhyncha
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Hibbertia rhynchocalyx
# 10558
# Hibbertia rhynchocalyx
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Hibbertia villosa
# 8590
# Hibbertia villosa
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Hovea pedunculata
# 11014
# Hovea pedunculata
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Genoplesium bishopii
# 12408
# Genoplesium bishopii
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (few)
# None
# Sheringham 2022
# None
# Grevillea acanthifolia
# 5355
# Grevillea acanthifolia
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Grevillea acerata
# 8292
# Grevillea acerata
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Grevillea mollis
# 9297
# Grevillea mollis
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Grevillea rhizomatosa
# 9299
# Grevillea rhizomatosa
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Leionema ambiens
# 10724
# Leionema ambiens
# surv1
# Resprouting - full canopy scorch
# categorical
# Population lost to fire, obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Leptospermum benwellii
# 12325
# Leptospermum benwellii
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Melaleuca tortifolia
# 7695
# Melaleuca tortifolia
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Persoonia rufa
# 8624
# Persoonia rufa
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Podolobium aestivum
# 9913
# Podolobium aestivum
# surv1
# Resprouting - full canopy scorch
# categorical
# r
# All
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Prostanthera rhombea
# 3426
# Prostanthera rhombea
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Prostanthera saxicola var. major
# 9207
# Prostanthera saxicola var. major
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Pseudanthus pauciflorus
# 12971
# Pseudanthus pauciflorus
# surv1
# Resprouting - full canopy scorch
# categorical
# s
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Pultenaea tarik
# 12552
# Pultenaea tarik
# surv1
# Resprouting - full canopy scorch
# categorical
# s - obligate seeder
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Telopea aspera
# 9685
# Telopea aspera
# surv1
# Resprouting - full canopy scorch
# categorical
# R, s Resprouts post fire. A small number of seedling recruits (7) seen
# Most
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Acacia beadleana
# 11039
# Acacia beadleana
# surv4
# Regenerative Organ
# categorical
# Photo of resprouting at ground level
# Basal
# None
# None
# None
# Inferred from plant morphology
# Photo of resprouts
# Sheringham 2022
# None
# Acacia cangaiensis
# 9085
# Acacia cangaiensis
# surv4
# Regenerative Organ
# categorical
# A few plants resprouted from the base post fire
# Basal
# None
# None
# None
# Inferred from plant morphology
# None
# Sheringham 2022
# None
# Dillwynia rupestris
# 12302
# Dillwynia rupestris
# surv4
# Regenerative Organ
# categorical
# None
# Basal
# None
# None
# None
# Inferred from plant morphology
# Resprouting individuals were sheltered from high intensity fire by rock outcrops
# Sheringham 2022
# None
# Eucalyptus dissita
# 9719
# Eucalyptus dissita
# surv4
# Regenerative Organ
# categorical
# None
# Lignotuber
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Eucalyptus dissita
# 9719
# Eucalyptus dissita
# repr3a
# Time to first postfire reproduction (from resprouts)
# numerical
# None
# None
# None
# 4.5
# None
# Inferred from plant morphology
# None
# Sheringham 2022
# None
# Hakea macrorrhyncha
# 9602
# Hakea macrorrhyncha
# surv1
# Resprouting - full canopy scorch
# categorical
# Hakea macrorryncha is an obligate seeding species, Four mature plants were observed to survive fire
# None
# None
# None
# None
# Direct observation (many)
# None
# Sheringham 2022
# None
# Dillwynia rupestris
# 12302
# Dillwynia rupestris
# surv4
# Regenerative Organ
# categorical
# Several plants also observed  resprouting from the base in areas sheltered by rocks and protected from high intensity fire
# Basal
# None
# None
# None
# Inferred from plant morphology
# None
# Sheringham 2022
# None
# Telopea aspera
# 9685
# Telopea aspera
# repr3a
# Time to first postfire reproduction (from resprouts)
# numerical
# None
# None
# 1
# None
# None
# Direct observation (many)
# None

# %%
dir(table)
# Out:
# ['__add__',
#  '__attrs__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__elements__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__namespaced__',
#  '__ne__',
#  '__nested__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_initialise_columns',
#  '_path',
#  '_rel_id',
#  '_rel_type',
#  '_write',
#  'autoFilter',
#  'column_names',
#  'comment',
#  'connectionId',
#  'dataCellStyle',
#  'dataDxfId',
#  'displayName',
#  'extLst',
#  'from_tree',
#  'headerRowBorderDxfId',
#  'headerRowCellStyle',
#  'headerRowCount',
#  'headerRowDxfId',
#  'id',
#  'idx_base',
#  'insertRow',
#  'insertRowShift',
#  'mime_type',
#  'name',
#  'namespace',
#  'path',
#  'published',
#  'ref',
#  'sortState',
#  'tableBorderDxfId',
#  'tableColumns',
#  'tableStyleInfo',
#  'tableType',
#  'tagname',
#  'to_tree',
#  'totalsRowBorderDxfId',
#  'totalsRowCellStyle',
#  'totalsRowCount',
#  'totalsRowDxfId',
#  'totalsRowShown']

# %%
table.column_names
# Out:
# ['main_source',
#  'original_sources',
#  'original_species_name',
#  'species_code',
#  'species name',
#  'Trait code',
#  'Trait name',
#  'Trait type',
#  'raw_value',
#  'norm_value',
#  'Best',
#  'Lower',
#  'Upper',
#  'method_of_estimation',
#  'notes']

# %%
table.headerRowCount
# Out:
# 1

# %%
tbl=ws[table.ref]
hdr=table.column_names
surv1=list()
surv4=list()
records=list()
for k in range(1,len(tbl)):
    record=dict()
    for j in range(0,len(hdr)):
        record[hdr[j]]=tbl[k][j].value
    if record['Trait code']=='surv1':
        surv1.append(record)
    elif record['Trait code']=='surv4':
        surv4.append(record)
    else: 
        records.append(record)

# %%
surv1
# Out:
# [{'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia anemonifolia subsp. anemonifolia',
#   'species_code': 12257,
#   'species name': 'Boronia anemonifolia subsp. anemonifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia floribunda',
#   'species_code': 5740,
#   'species name': 'Boronia floribunda',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia fraseri',
#   'species_code': 5741,
#   'species name': 'Boronia fraseri',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia ledifolia',
#   'species_code': 5744,
#   'species name': 'Boronia ledifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia pinnata',
#   'species_code': 5750,
#   'species name': 'Boronia pinnata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia serrulata',
#   'species_code': 5759,
#   'species name': 'Boronia serrulata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia thujona',
#   'species_code': 7210,
#   'species name': 'Boronia thujona',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Acacia barringtonensis',
#   'species_code': 3712,
#   'species name': 'Acacia barringtonensis',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Acacia beadleana',
#   'species_code': 11039,
#   'species name': 'Acacia beadleana',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Acacia cangaiensis',
#   'species_code': 9085,
#   'species name': 'Acacia cangaiensis',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Boronia angustisepala',
#   'species_code': 10750,
#   'species name': 'Boronia angustisepala',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's-',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Boronia inflexa subsp. inflexa',
#   'species_code': 12356,
#   'species name': 'Boronia inflexa subsp. inflexa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Callistemon flavovirens',
#   'species_code': 4006,
#   'species name': 'Callistemon flavovirens',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Callitris monticola',
#   'species_code': 2281,
#   'species name': 'Callitris monticola',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Dillwynia rupestris',
#   'species_code': 12302,
#   'species name': 'Dillwynia rupestris',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's and r',
#   'norm_value': 'Half',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Dodonaea serratifolia',
#   'species_code': 5907,
#   'species name': 'Dodonaea serratifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': 'An obligate seeding shrub. Only two seedlings have been seen since fire. Not observed recruiting in known locations in Gibraltar Range National Park. '},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Eucalyptus dissita',
#   'species_code': 9719,
#   'species name': 'Eucalyptus dissita',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hakea macrorrhyncha',
#   'species_code': 9602,
#   'species name': 'Hakea macrorrhyncha',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hibbertia rhynchocalyx',
#   'species_code': 10558,
#   'species name': 'Hibbertia rhynchocalyx',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hibbertia villosa',
#   'species_code': 8590,
#   'species name': 'Hibbertia villosa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hovea pedunculata',
#   'species_code': 11014,
#   'species name': 'Hovea pedunculata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Genoplesium bishopii',
#   'species_code': 12408,
#   'species name': 'Genoplesium bishopii',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea acanthifolia',
#   'species_code': 5355,
#   'species name': 'Grevillea acanthifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea acerata',
#   'species_code': 8292,
#   'species name': 'Grevillea acerata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea mollis',
#   'species_code': 9297,
#   'species name': 'Grevillea mollis',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea rhizomatosa',
#   'species_code': 9299,
#   'species name': 'Grevillea rhizomatosa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Leionema ambiens',
#   'species_code': 10724,
#   'species name': 'Leionema ambiens',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'Population lost to fire, obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Leptospermum benwellii',
#   'species_code': 12325,
#   'species name': 'Leptospermum benwellii',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Melaleuca tortifolia',
#   'species_code': 7695,
#   'species name': 'Melaleuca tortifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Persoonia rufa',
#   'species_code': 8624,
#   'species name': 'Persoonia rufa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Podolobium aestivum',
#   'species_code': 9913,
#   'species name': 'Podolobium aestivum',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r ',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Prostanthera rhombea',
#   'species_code': 3426,
#   'species name': 'Prostanthera rhombea',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Prostanthera saxicola var. major',
#   'species_code': 9207,
#   'species name': 'Prostanthera saxicola var. major',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Pseudanthus pauciflorus',
#   'species_code': 12971,
#   'species name': 'Pseudanthus pauciflorus',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Pultenaea tarik',
#   'species_code': 12552,
#   'species name': 'Pultenaea tarik',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Telopea aspera',
#   'species_code': 9685,
#   'species name': 'Telopea aspera',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'R, s Resprouts post fire. A small number of seedling recruits (7) seen',
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hakea macrorrhyncha',
#   'species_code': 9602,
#   'species name': 'Hakea macrorrhyncha',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'Hakea macrorryncha is an obligate seeding species, Four mature plants were observed to survive fire',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None}]

# %%
hdr 'surv1'
# Out:
# False
