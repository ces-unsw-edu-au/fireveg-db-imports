# %% [markdown]
# # Add XML nodes for austraits data
#
# We will download data from [AusTraits](https://austraits.org/) ([pre-print](https://www.biorxiv.org/content/10.1101/2021.01.04.425314v1)) and add nodes for each species.
#
# Let's start loading the libraries

# %%
from pathlib import Path
import os
import json
import urllib
from zipfile import ZipFile
import pandas as pd
import xml.etree.cElementTree as ET
import numpy as np
from xml.dom import minidom

# %% [markdown]
# ## Species list from NSW
#
# The previous version of the CAPS (whatever that means) table was available from this (non-permanent?) url:

# %%
CAPSurl = 'https://www.environment.nsw.gov.au/resources/wildlifelicences/CAPS.xls'
#CAPS = pd.read_excel(CAPSurl, index_col=0)

# %% [markdown]
# But we got an updated version from a BioNET export prepared by Renee:

# %%
repodir = Path("../") 
inputdir = repodir / "data/"
CAPS = pd.read_excel(inputdir / 'vis-survey-datasheet-6000.PowerQuery.20210708.xlsx')

# %%
CAPS
# Out:
#        speciesID taxonRank  classID  class  orderID  order  familyID  \
# 0           2358   Species       38  Flora      137  Flora       155
# 1           2359   Species       38  Flora      137  Flora       156
# 2           2360   Species       38  Flora      137  Flora       156
# 3           2361   Species       38  Flora      137  Flora       157
# 4           2362   Species       38  Flora      137  Flora       157
# ...          ...       ...      ...    ...      ...    ...       ...
# 15727      24289   Species       38  Flora      137  Flora       170
# 15728      24291   Species       38  Flora      137  Flora       203
# 15729      24292   Species       38  Flora      137  Flora       214
# 15730      24293   Species       38  Flora      137  Flora       206
# 15731      24294   Species       38  Flora      137  Flora       202
#
#                family  sortOrder  genusID  ...      stateConservation  \
# 0        Brassicaceae       7878   3019.0  ...             Not Listed
# 1           Myrtaceae      13245   2638.0  ...             Not Listed
# 2           Myrtaceae      13447   3165.0  ...             Not Listed
# 3            Apiaceae       6031   1823.0  ...             Not Listed
# 4            Apiaceae       6046   1944.0  ...             Not Listed
# ...               ...        ...      ...  ...                    ...
# 15727     Orchidaceae      14157   3583.0  ...             Not Listed
# 15728      Araliaceae       6378   3931.0  ...             Not Listed
# 15729  Pittosporaceae      14710   3474.0  ...  Critically Endangered
# 15730       Malvaceae      12327   1825.0  ...             Not Listed
# 15731     Sapindaceae      17375   2532.0  ...             Not Listed
#
#        protectedInNSW sensitivityClass TSProfileID countryConservation  \
# 0               False    Not Sensitive         NaN          Not Listed
# 1               False    Not Sensitive         NaN          Not Listed
# 2               False    Not Sensitive         NaN          Not Listed
# 3                True    Not Sensitive         NaN          Not Listed
# 4               False    Not Sensitive         NaN          Not Listed
# ...               ...              ...         ...                 ...
# 15727           False    Not Sensitive         NaN          Not Listed
# 15728           False    Not Sensitive         NaN          Not Listed
# 15729           False    Not Sensitive     20378.0          Not Listed
# 15730           False    Not Sensitive         NaN          Not Listed
# 15731           False    Not Sensitive         NaN          Not Listed
#
#        highThreatWeed widelyCultivatedNativeSpecies  CAMBA  JAMBA ROKAMBA
# 0                 NaN                           NaN  False  False   False
# 1                 NaN                           NaN  False  False   False
# 2                 NaN                           NaN  False  False   False
# 3                 NaN                           NaN  False  False   False
# 4                 NaN                           NaN  False  False   False
# ...               ...                           ...    ...    ...     ...
# 15727             NaN                           NaN  False  False   False
# 15728             NaN                           NaN  False  False   False
# 15729             NaN                           NaN  False  False   False
# 15730             NaN                           NaN  False  False   False
# 15731             NaN                           NaN  False  False   False
#
# [15732 rows x 43 columns]

# %%
CAPS.columns
# Out:
# Index(['speciesID', 'taxonRank', 'classID', 'class', 'orderID', 'order',
#        'familyID', 'family', 'sortOrder', 'genusID', 'genus',
#        'parentSpeciesID', 'specificEpithet', 'infraspecificEpithet',
#        'scientificNameAuthorship', 'scientificNameID', 'speciesCode_Synonym',
#        'scientificName', 'scientificNameHTML', 'vernacularName',
#        'otherVernacularNames', 'taxonID', 'currentScientificNameCode',
#        'currentScientificName', 'currentVernacularName', 'isCurrent',
#        'generalTypeID', 'generalType', 'establishmentMeans',
#        'primaryGrowthForm', 'primaryGrowthFormGroup', 'secondaryGrowthForms',
#        'secondaryGrowthFormGroups', 'stateConservation', 'protectedInNSW',
#        'sensitivityClass', 'TSProfileID', 'countryConservation',
#        'highThreatWeed', 'widelyCultivatedNativeSpecies', 'CAMBA', 'JAMBA',
#        'ROKAMBA'],
#       dtype='object')

# %%
target = CAPS[CAPS['scientificName'] == "Actinotus helianthi"] 
target
# Out:
#    speciesID taxonRank  classID  class  orderID  order  familyID    family  \
# 3       2361   Species       38  Flora      137  Flora       157  Apiaceae
#
#    sortOrder  genusID  ... stateConservation  protectedInNSW sensitivityClass  \
# 3       6031   1823.0  ...        Not Listed            True    Not Sensitive
#
#   TSProfileID countryConservation  highThreatWeed  \
# 3         NaN          Not Listed             NaN
#
#   widelyCultivatedNativeSpecies  CAMBA  JAMBA ROKAMBA
# 3                           NaN  False  False   False
#
# [1 rows x 43 columns]

# %% [markdown]
# ## Read _austraits_ data
# We will download the file from the [Zenodo repository](https://zenodo.org/record/5112001) using the API url and saving this under the data folder.

# %%
repodir = Path("../") 
dataset = "https://zenodo.org/api/records/3568417"
outputdir = repodir / "data/austraits/"

if not os.path.isdir(outputdir):
    os.makedirs(outputdir)

# %% [markdown]
# We use urllib to open the url and read the data (if successfully connected!)

# %%
def getResponse(url):
    operUrl = urllib.request.urlopen(url)
    if(operUrl.getcode()==200):
       data = operUrl.read()
    else:
       print("Error receiving data", operUrl.getcode())
    return data
zrecord = getResponse(dataset)

# %% [markdown]
# Response data is in json format, need to parse it:

# %%
jsonData = json.loads(zrecord)

# %%
jsonData
# Out:
# {'conceptdoi': '10.5281/zenodo.3568417',
#  'conceptrecid': '3568417',
#  'created': '2021-07-18T06:32:30.575319+00:00',
#  'doi': '10.5281/zenodo.5112001',
#  'files': [{'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:cd7ba1c395b976a02fd4c3c772d88d78',
#    'key': 'austraits-3.0.2.rds',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/austraits-3.0.2.rds'},
#    'size': 12325324,
#    'type': 'rds'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:ed44176eb71466fe9a4ca1773d6b5961',
#    'key': 'austraits-3.0.2.zip',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/austraits-3.0.2.zip'},
#    'size': 14738862,
#    'type': 'zip'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:7047ae5b30b1727140000a4daa484722',
#    'key': 'dictionary.html',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/dictionary.html'},
#    'size': 1677858,
#    'type': 'html'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:483881222a0c9635ba01b3f0d802730f',
#    'key': 'NEWS.md',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/NEWS.md'},
#    'size': 37782,
#    'type': 'md'},
#   {'bucket': '9c997956-8254-4fcc-a17b-5fe1fd079022',
#    'checksum': 'md5:eaee76500f89c73dc515f233a9f6053d',
#    'key': 'readme.txt',
#    'links': {'self': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022/readme.txt'},
#    'size': 9904,
#    'type': 'txt'}],
#  'id': 5112001,
#  'links': {'badge': 'https://zenodo.org/badge/doi/10.5281/zenodo.5112001.svg',
#   'bucket': 'https://zenodo.org/api/files/9c997956-8254-4fcc-a17b-5fe1fd079022',
#   'conceptbadge': 'https://zenodo.org/badge/doi/10.5281/zenodo.3568417.svg',
#   'conceptdoi': 'https://doi.org/10.5281/zenodo.3568417',
#   'doi': 'https://doi.org/10.5281/zenodo.5112001',
#   'html': 'https://zenodo.org/record/5112001',
#   'latest': 'https://zenodo.org/api/records/5112001',
#   'latest_html': 'https://zenodo.org/record/5112001',
#   'self': 'https://zenodo.org/api/records/5112001'},
#  'metadata': {'access_right': 'open',
#   'access_right_category': 'success',
#   'communities': [{'id': 'austraits'}],
#   'contributors': [{'affiliation': 'National Herbarium of New South Wales, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Sauquet, Hervé',
#     'orcid': '0000-0001-8305-3236',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Wright, Ian J.',
#     'orcid': '0000-0001-8338-9143',
#     'type': 'ProjectMember'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Indiarto, Dony',
#     'orcid': '0000-0001-9546-8201',
#     'type': 'ProjectMember'},
#    {'affiliation': 'CSIRO',
#     'name': 'Andrew, Sam',
#     'orcid': '0000-0003-4589-2746',
#     'type': 'ProjectMember'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Baxter, Caitlan',
#     'type': 'ProjectMember'},
#    {'affiliation': 'NSW Department of Primary Industries',
#     'name': 'Lawson, James',
#     'orcid': '0000-0001-7983-4443',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Allen, Stuart',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Fuchs, Anne',
#     'orcid': '0000-0001-5737-8803',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Monro, Anna',
#     'type': 'ProjectMember'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Kar, Fonti',
#     'orcid': '0000-0002-2760-3974',
#     'type': 'ProjectMember'},
#    {'affiliation': 'Swinburne University of Technology',
#     'name': 'Adams, Mark A',
#     'orcid': '0000-0002-8154-0097',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Ahrens, Collin W.',
#     'orcid': '0000-0002-0614-9928',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Alfonzetti, Matthew',
#     'orcid': '0000-0002-0064-6368',
#     'type': 'DataCollector'},
#    {'name': 'Amini, Sophia', 'type': 'DataCollector'},
#    {'affiliation': 'La Trobe University',
#     'name': 'Angevin, Tara',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Rainforest Studies, School for Field Studies, Yungaburra, Queensland',
#     'name': 'Apgaua, Deborah M.G.',
#     'orcid': '0000-0002-6303-6989',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Arndt, Stefan',
#     'orcid': '0000-0001-7086-9375',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Ash, Julian',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Atkin, Owen K.',
#     'orcid': '0000-0003-1041-5202',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Atkinson, Joe',
#     'orcid': '0000-0001-9232-4421',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Planning Industry and Environment',
#     'name': 'Auld, Tony',
#     'orcid': '0000-0002-8766-2829',
#     'type': 'DataCollector'},
#    {'affiliation': 'Southern Cross University',
#     'name': 'Baker, Andrew',
#     'orcid': '0000-0002-0658-3767',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Vienna',
#     'name': 'Balthazar, Maria von',
#     'type': 'DataCollector'},
#    {'affiliation': 'Queensland Herbarium',
#     'name': 'Bean, Anthony',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Blackman, Chris J.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Imperial College',
#     'name': 'Bloomfield, Keith',
#     'type': 'DataCollector'},
#    {'name': 'Boreham, Tara', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Bowman, David M. J. S.',
#     'orcid': '0000-0001-8075-124X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Wollongong',
#     'name': 'Bradstock, Ross',
#     'orcid': '0000-0002-6904-2394',
#     'type': 'DataCollector'},
#    {'affiliation': 'Australian Institute of Botanical Science, Royal Botanic Gardens and Domain Trust',
#     'name': 'Bragg, Jason',
#     'orcid': '0000-0002-7621-7295',
#     'type': 'DataCollector'},
#    {'affiliation': 'Max-Planck Institute for Biogeochemistry, Germany',
#     'name': 'Brand, Willi A.',
#     'type': 'DataCollector'},
#    {'name': 'Briggs, Amber', 'type': 'DataCollector'},
#    {'name': 'Brock, John', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Brodribb, Timothy J.',
#     'orcid': '0000-0002-4964-6107',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Buckton, Genevieve',
#     'type': 'DataCollector'},
#    {'affiliation': 'Charles Sturt University',
#     'name': 'Burrows, Geoff',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Butler, Don',
#     'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Caldwell, Elizabeth',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Melbourne',
#     'name': 'Camac, James',
#     'orcid': '0000-0003-4785-0742',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Carpenter, Raymond',
#     'orcid': '0000-0001-7129-2870',
#     'type': 'DataCollector'},
#    {'affiliation': "King's College London",
#     'name': 'Catford, Jane A.',
#     'orcid': '0000-0003-0582-5960',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Cawthray, Gregory R.',
#     'orcid': '0000-0003-1150-6675',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Cernusak, Lucas A.',
#     'orcid': '0000-0002-7575-5526',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Agriculture, Australia',
#     'name': 'Chandler, Gregory',
#     'orcid': '0000-0002-0905-6823',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium',
#     'name': 'Chapman, Alex R.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Federation University',
#     'name': 'Cheal, David',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Cheesman, Alexander W.',
#     'orcid': '0000-0003-3931-5766',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Chen, Si-Chong',
#     'orcid': '0000-0002-6855-2595',
#     'type': 'DataCollector'},
#    {'affiliation': 'State Herbarium of South Australia',
#     'name': 'Chinnock, Robert',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Choat, Brendan',
#     'orcid': '0000-0002-9105-640X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New England',
#     'name': 'Clarke, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Clayton, Derek',
#     'type': 'DataCollector'},
#    {'affiliation': 'Brooklyn Botanic Garden',
#     'name': 'Clemants, Steven',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Clifford, Harold Trevor',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Clinton, Brook',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Clode, Peta L.',
#     'orcid': '0000-0002-5188-4737',
#     'type': 'DataCollector'},
#    {'name': 'Cochrane, Michelle', 'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium',
#     'name': 'Coleman, Helen',
#     'type': 'DataCollector'},
#    {'name': 'Collins, Bronwyn', 'type': 'DataCollector'},
#    {'name': 'Conti, Alessandro', 'type': 'DataCollector'},
#    {'name': 'Cooper, Wendy', 'type': 'DataCollector'},
#    {'name': 'Cooper, William', 'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Cornwell, William K.',
#     'orcid': '0000-0003-4080-4073',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Cosgrove, Meredith',
#     'type': 'DataCollector'},
#    {'affiliation': 'Northern Territory Herbarium',
#     'name': 'Cowie, Ian',
#     'type': 'DataCollector'},
#    {'affiliation': 'Australian National Herbarium',
#     'name': 'Craven, Lyn',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Crisp, Michael',
#     'orcid': '0000-0002-8255-6349',
#     'type': 'DataCollector'},
#    {'affiliation': 'Charles Sturt University',
#     'name': 'Cross, Erika',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Crous, Kristine Y.',
#     'orcid': '0000-0001-9478-7593',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Cunningham, Saul',
#     'orcid': '0000-0003-0703-6893',
#     'type': 'DataCollector'},
#    {'affiliation': 'Lincoln University',
#     'name': 'Curran, Timothy',
#     'orcid': '0000-0001-8817-4360',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney',
#     'name': 'Curtis, Ellen',
#     'type': 'DataCollector'},
#    {'name': 'Davidson, Ian', 'type': 'DataCollector'},
#    {'affiliation': 'Environment Department, Alcoa of Australia',
#     'name': 'Daws, Matthew I.',
#     'orcid': '0000-0002-9120-4724',
#     'type': 'DataCollector'},
#    {'affiliation': 'Tasmanian Herbarium',
#     'name': 'de Salas, Miguel',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Liege',
#     'name': 'de Tombeur, Félix',
#     'orcid': '0000-0002-6012-8458',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'DeGabriel, Jane L.',
#     'orcid': '0000-0003-1245-5291',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Denton, Matthew D.',
#     'orcid': '0000-0002-2804-0384',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Dong, Ning',
#     'orcid': '0000-0003-0793-8854',
#     'type': 'DataCollector'},
#    {'affiliation': 'Lanzhou University',
#     'name': 'Du, Pengzhen',
#     'type': 'DataCollector'},
#    {'affiliation': 'Guizhou University',
#     'name': 'Duan, Honglang',
#     'orcid': '0000-0003-3761-6936',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Duncan, David H.',
#     'orcid': '0000-0003-4411-8214',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Canberra',
#     'name': 'Duncan, Richard P.',
#     'orcid': '0000-0003-2295-449X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Duretto, Marco',
#     'orcid': '0000-0003-1013-4291',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Dwyer, John M.',
#     'orcid': '0000-0001-7389-5528',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney, Australia',
#     'name': 'Eamus, Derek',
#     'orcid': '0000-0003-2765-8040',
#     'type': 'DataCollector'},
#    {'affiliation': 'Melbourne Water',
#     'name': 'Edwards, Cheryl',
#     'type': 'DataCollector'},
#    {'affiliation': 'Conservation Commission of the Northern Territory',
#     'name': 'Egan, Judy',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Esperon-Rodriguez, Manuel',
#     'orcid': '0000-0003-3649-2134',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Evans, John R.',
#     'orcid': '0000-0003-1379-3532',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Everingham, Susan E.',
#     'orcid': '0000-0002-4780-2700',
#     'type': 'DataCollector'},
#    {'name': 'Fahey, Chris', 'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Falster, Daniel',
#     'orcid': '0000-0002-9814-092X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Farrell, Claire',
#     'orcid': '0000-0002-5822-7529',
#     'type': 'DataCollector'},
#    {'affiliation': 'Queensland University of Technology',
#     'name': 'Firn, Jennifer',
#     'orcid': '0000-0001-6026-8912',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidade Federal do Rio Grande do Norte, Natal, Brazil',
#     'name': 'Fonseca, Carlos Roberto',
#     'orcid': '0000-0003-0292-0399',
#     'type': 'DataCollector'},
#    {'affiliation': 'Queensland Herbarium, Australia',
#     'name': 'Forster, Paul Irwin',
#     'type': 'DataCollector'},
#    {'name': 'Foster, John', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'French, Ben J.',
#     'orcid': '0000-0001-5046-4047',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'French, Tony',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Frith, Allison',
#     'type': 'DataCollector'},
#    {'affiliation': 'Pathways Bushland and Environment Consultancy',
#     'name': 'Frood, Doug',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of California, Davis',
#     'name': 'Funk, Jennifer L.',
#     'orcid': '0000-0002-1916-5513',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Gallagher, Rachael',
#     'orcid': '0000-0002-4680-8115',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Gardiner, Ronald',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Geange, Sonya R.',
#     'orcid': '0000-0001-5344-7234',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Ghannoum, Oula',
#     'orcid': '0000-0002-1341-0741',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Gill, Malcolm',
#     'type': 'DataCollector'},
#    {'affiliation': 'USDA-ARS, WMSRU',
#     'name': 'Gleason, Sean M.',
#     'orcid': '0000-0002-5607-4741',
#     'type': 'DataCollector'},
#    {'name': 'Goble-Garratt, Ethel', 'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Gosper, Carl R.',
#     'orcid': '0000-0002-0962-5117',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Gray, Emma',
#     'orcid': '0000-0002-5352-0398',
#     'type': 'DataCollector'},
#    {'affiliation': 'Curtin University',
#     'name': 'Groom, Philip K.',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Grootemaat, Saskia',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New England',
#     'name': 'Gross, Caroline',
#     'orcid': '0000-0001-8014-1548',
#     'type': 'DataCollector'},
#    {'affiliation': 'Cambridge University',
#     'name': 'Grubb, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Adelaide',
#     'name': 'Guerin, Greg',
#     'orcid': '0000-0002-2104-6695',
#     'type': 'DataCollector'},
#    {'affiliation': 'Massachusetts Institute of Technology',
#     'name': 'Guilherme Pereira, Caio',
#     'orcid': '0000-0003-3288-8553',
#     'type': 'DataCollector'},
#    {'name': 'Guinane, Chris', 'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Guja, Lydia',
#     'orcid': '0000-0001-5945-438X',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Melbourne',
#     'name': 'Hahs, Amy K.',
#     'orcid': '0000-0003-0163-6732',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO, Australia',
#     'name': 'Hall, TJ',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Hallet, Monique',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Harrison, Matthew Tom',
#     'orcid': '0000-0001-7425-452X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Haslehurst, Tammy',
#     'type': 'DataCollector'},
#    {'name': 'Hassiotou, Foteini', 'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Hayes, Patrick E.',
#     'orcid': '0000-0001-7554-4588',
#     'type': 'DataCollector'},
#    {'affiliation': 'Parks Australia, Department of Agriculture, Water and the Environment',
#     'name': 'Henery, Martin',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Herbohn, John',
#     'orcid': '0000-0001-5701-4882',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Hochuli, Dieter',
#     'orcid': '0000-0002-6673-4475',
#     'type': 'DataCollector'},
#    {'affiliation': 'Murdoch University',
#     'name': 'Hocking, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'Berowa NSW',
#     'name': 'Howell, Jocelyn',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Hu, Jing',
#     'type': 'DataCollector'},
#    {'affiliation': 'Nanchang Institute of Technology',
#     'name': 'Huang, Guomin',
#     'orcid': '0000-0002-7597-9386',
#     'type': 'DataCollector'},
#    {'name': 'Hughes, Kate', 'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Hughes, Lesley',
#     'orcid': '0000-0003-0313-9780',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Huisman, John',
#     'orcid': '0000-0002-5255-8423',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Ilic, Jugoslav',
#     'orcid': '0000-0001-5692-5596',
#     'type': 'DataCollector'},
#    {'name': 'Islam, Muhammad', 'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Jagdish, Ashika',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Jin, Daniel',
#     'orcid': '0000-0001-7492-9830',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Jordan, Gregory',
#     'orcid': '0000-0002-6033-2766',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidad Autonoma de Nuevo Leon, Mexico',
#     'name': 'Jurado, Enrique',
#     'orcid': '0000-0002-4043-5549',
#     'type': 'DataCollector'},
#    {'affiliation': 'Australian Wildlife Conservancy',
#     'name': 'Kanowski, John',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Kasel, Sabine',
#     'orcid': '0000-0001-8188-1089',
#     'type': 'DataCollector'},
#    {'name': 'Kealley, Ian',
#     'orcid': '0000-0003-2747-3927',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, WA',
#     'name': 'Keighery, Greg',
#     'type': 'DataCollector'},
#    {'affiliation': 'State Herbarium of South Australia',
#     'name': 'Kellermann, Jürgen',
#     'orcid': '0000-0001-9124-9802',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Rural Fire Service',
#     'name': 'Kenny, Belinda',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Kirkpatrick, James',
#     'type': 'DataCollector'},
#    {'name': 'Knox, Kirsten', 'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'Kohout, Michele',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Kooyman, Robert M.',
#     'orcid': '0000-0003-1985-9547',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Goettingen',
#     'name': 'Kotowska, Martyna M.',
#     'orcid': '0000-0002-2283-5979',
#     'type': 'DataCollector'},
#    {'name': 'Kovac, Luka', 'type': 'DataCollector'},
#    {'name': 'Kreger, Kaely',
#     'orcid': '0000-0002-5010-5797',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Kuo, John',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Canterbury',
#     'name': 'Lai, Hao Ran',
#     'orcid': '0000-0001-6871-0146',
#     'type': 'DataCollector'},
#    {'affiliation': 'Université de Montréal',
#     'name': 'Laliberté, Etienne',
#     'orcid': '0000-0002-3167-2622',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Lambers, Hans',
#     'orcid': '0000-0002-4118-2272',
#     'type': 'DataCollector'},
#    {'name': 'Lambert, Martin',
#     'orcid': '0000-0003-2515-7904',
#     'type': 'DataCollector'},
#    {'affiliation': 'Curtin University',
#     'name': 'Lamont, Byron B.',
#     'orcid': '0000-0001-9279-7149',
#     'type': 'DataCollector'},
#    {'name': 'Lanceman, Dana', 'type': 'DataCollector'},
#    {'affiliation': 'Australian National University',
#     'name': 'Lanfear, Robert',
#     'orcid': '0000-0002-1140-2596',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Wyoming',
#     'name': 'Laughlin, Daniel C.',
#     'orcid': '0000-0002-9651-5732',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Laugier-Kitchener, Bree-Anne',
#     'type': 'DataCollector'},
#    {'affiliation': 'James Cook University',
#     'name': 'Laurance, Susan',
#     'orcid': '0000-0002-2831-2933',
#     'type': 'DataCollector'},
#    {'name': 'Lawes, Michael',
#     'orcid': '0000-0002-2381-6147',
#     'type': 'DataCollector'},
#    {'name': 'Laws, Claire', 'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Primary Industries',
#     'name': 'Lawson, James',
#     'orcid': '0000-0001-7983-4443',
#     'type': 'DataCollector'},
#    {'name': 'Laxton, Emma', 'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Garden Edinburgh',
#     'name': 'Lehmann, Caroline E. R.',
#     'orcid': '0000-0002-6825-124X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney',
#     'name': 'Leigh, Andrea',
#     'orcid': '0000-0003-3568-2606',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Leishman, Michelle R.',
#     'orcid': '0000-0003-4830-5797',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Lenz, Tanja',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'Lepschi, Brendan',
#     'orcid': '0000-0002-3281-2973',
#     'type': 'DataCollector'},
#    {'affiliation': 'Fordham University',
#     'name': 'Lewis, James D.',
#     'orcid': '0000-0002-7347-9513',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Lim, Felix',
#     'orcid': '0000-0003-1227-460X',
#     'type': 'DataCollector'},
#    {'name': 'Lindsay, Liz', 'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Liu, Udayangani',
#     'orcid': '0000-0002-6192-1319',
#     'type': 'DataCollector'},
#    {'name': 'Londono, Daniel Montoya', 'type': 'DataCollector'},
#    {'affiliation': 'Universidad Nacional Autónoma de México',
#     'name': 'López Martinez, Andrea',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Otago',
#     'name': 'Lord, Janice',
#     'orcid': '0000-0001-8314-0428',
#     'type': 'DataCollector'},
#    {'name': 'Ludwig, Christiane', 'type': 'DataCollector'},
#    {'affiliation': 'Charles Sturt University',
#     'name': 'Lunt, Ian',
#     'orcid': '0000-0002-2059-899X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Waikato',
#     'name': 'Lusk, Christopher H.',
#     'orcid': '0000-0002-9037-7957',
#     'type': 'DataCollector'},
#    {'name': 'Maconochie, Mary', 'type': 'DataCollector'},
#    {'affiliation': 'University of Auckland',
#     'name': 'Macinnis-Ng, Cate',
#     'orcid': '0000-0003-3935-9814',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'McPherson, Hannah',
#     'orcid': '0000-0003-0254-4573',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidad Nacional Autónoma de México',
#     'name': 'Magallón, Susana',
#     'orcid': '0000-0002-6838-7497',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Manea, Anthony',
#     'orcid': '0000-0002-0956-4529',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Marais, Karen',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Maslin, Bruce',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Mason, Riah',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Mayfield, Margaret',
#     'orcid': '0000-0002-5101-6542',
#     'type': 'DataCollector'},
#    {'affiliation': 'Biodiversity and Conservation Science, Department of Biodiversity, Conservation and Attractions, WA',
#     'name': 'Mazanec, Richard',
#     'type': 'DataCollector'},
#    {'affiliation': 'Manaaki Whenua – Landcare Research, Lincoln, New Zealand',
#     'name': 'McC Overton, Jacob',
#     'type': 'DataCollector'},
#    {'affiliation': 'Manaaki Whenua – Landcare Research, Lincoln, New Zealand',
#     'name': 'McCarthy, James K.',
#     'orcid': '0000-0003-3060-1678',
#     'type': 'DataCollector'},
#    {'name': 'McFarlane, Elissa', 'type': 'DataCollector'},
#    {'affiliation': 'Cumberland Ecology, Australia',
#     'name': 'Meers, Trevor',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water',
#     'name': 'Metcalfe, Daniel',
#     'orcid': '0000-0001-6853-7072',
#     'type': 'DataCollector'},
#    {'affiliation': 'Linkoping University',
#     'name': 'Milberg, Per',
#     'orcid': '0000-0001-6128-1051',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water',
#     'name': 'Mokany, Karel',
#     'orcid': '0000-0003-4199-3697',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Moles, Angela T.',
#     'orcid': '0000-0003-2041-7762',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Moore, Ben D.',
#     'orcid': '0000-0002-6995-4721',
#     'type': 'DataCollector'},
#    {'affiliation': 'La Trobe University',
#     'name': 'Moore, Nicholas',
#     'orcid': '0000-0002-9087-7580',
#     'type': 'DataCollector'},
#    {'name': 'Morgan, Huw', 'type': 'DataCollector'},
#    {'affiliation': 'La Trobe University',
#     'name': 'Morgan, John W.',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Morris, William',
#     'orcid': '0000-0002-8686-4154',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'Muir, Annette',
#     'orcid': '0000-0001-9383-6613',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Adelaide',
#     'name': 'Munroe, Samantha',
#     'orcid': '0000-0001-7827-1028',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Myerscough, Peter',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO', 'name': 'Nelson, Des', 'type': 'DataCollector'},
#    {'name': 'Neyland, Dominic', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Nicholson, Áine',
#     'type': 'DataCollector'},
#    {'affiliation': 'Currency Creek Arboretum, Australia',
#     'name': 'Nicolle, Dean',
#     'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Nicotra, Adrienne B.',
#     'orcid': '0000-0001-6578-369X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Estonian University of Life Sciences',
#     'name': 'Niinemets, Ülo',
#     'orcid': '0000-0002-3078-2192',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Australian National Biodiversity Research',
#     'name': 'North, Tom',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Canberra',
#     'name': "O'Reilly-Nugent, Andrew",
#     'orcid': '0000-0003-2071-6279',
#     'type': 'DataCollector'},
#    {'affiliation': 'Leistershire County Council, Leicester, United Kingdom',
#     'name': "O'Sullivan, Odhran S.",
#     'orcid': '0000-0002-1448-1066',
#     'type': 'DataCollector'},
#    {'affiliation': 'New College of Florida',
#     'name': 'Oberle, Brad',
#     'orcid': '0000-0002-4227-3352',
#     'type': 'DataCollector'},
#    {'name': 'Olsen, Mike', 'type': 'DataCollector'},
#    {'affiliation': 'Kyoto University',
#     'name': 'Onoda, Yusuke',
#     'orcid': '0000-0001-6245-2342',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Ooi, Mark K. J.',
#     'orcid': '0000-0002-3046-0417',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Planning Industry and Environment',
#     'name': 'Orscheg, Corinna',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Sheffield',
#     'name': 'Osborne, Colin P.',
#     'orcid': '0000-0002-7423-3718',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Paczkowska, Grazyna',
#     'type': 'DataCollector'},
#    {'name': 'Peeters, Paula', 'type': 'DataCollector'},
#    {'affiliation': 'Istanbul Technical University',
#     'name': 'Pekin, Burak',
#     'orcid': '0000-0002-4797-6962',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Aukland',
#     'name': 'Perry, George',
#     'orcid': '0000-0001-9672-9135',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Phillips, Aaron',
#     'orcid': '0000-0002-1351-0291',
#     'type': 'DataCollector'},
#    {'affiliation': 'Griffith University',
#     'name': 'Pickering, Catherine',
#     'orcid': '0000-0002-3731-5407',
#     'type': 'DataCollector'},
#    {'affiliation': 'Greening Australia',
#     'name': 'Pickup, Melinda',
#     'orcid': '0000-0001-6118-0541',
#     'type': 'DataCollector'},
#    {'name': 'Pollitt, Loren', 'type': 'DataCollector'},
#    {'affiliation': 'McGill University',
#     'name': 'Pollock, Laura J.',
#     'orcid': '0000-0002-6004-4027',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Polmear, Rob',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Poot, Pieter',
#     'orcid': '0000-0001-7721-0696',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Possingham, Hugh',
#     'orcid': '0000-0001-7755-996X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Powell, Jeff R.',
#     'orcid': '0000-0003-1091-2452',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Power, Sally A.',
#     'orcid': '0000-0002-2723-8671',
#     'type': 'DataCollector'},
#    {'affiliation': 'Imperial College, London',
#     'name': 'Prentice, Iain Colin',
#     'orcid': '0000-0002-1296-6764',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Price, Aina',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Prior, Lynda',
#     'orcid': '0000-0002-5511-2320',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water, Australia',
#     'name': 'Prober, Suzanne M.',
#     'orcid': '0000-0002-6518-239X',
#     'type': 'DataCollector'},
#    {'name': 'Pyne, Thomas', 'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Read, Jennifer',
#     'orcid': '0000-0002-4727-3482',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Reynolds, Victoria',
#     'orcid': '0000-0002-6071-9303',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Rice, Barbara',
#     'type': 'DataCollector'},
#    {'affiliation': 'CSIRO Land and Water, Australia',
#     'name': 'Richards, Anna E.',
#     'orcid': '0000-0002-2934-5497',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Richardson, Ben',
#     'orcid': '0000-0002-6108-0572',
#     'type': 'DataCollector'},
#    {'affiliation': 'Elizabeth Macarthur Agricultural Institute, NSW Department of Primary Industries',
#     'name': 'Rigg, Jessica L.',
#     'orcid': '0000-0002-0124-1645',
#     'type': 'DataCollector'},
#    {'name': 'Roberts, Bryan', 'type': 'DataCollector'},
#    {'affiliation': 'The Australian National University',
#     'name': 'Roderick, Michael L.',
#     'orcid': '0000-0002-3630-7739',
#     'type': 'DataCollector'},
#    {'affiliation': 'Universidad Nacional Autónoma de México',
#     'name': 'Rosell, Julieta A.',
#     'orcid': '0000-0001-5741-8027',
#     'type': 'DataCollector'},
#    {'affiliation': 'National Herbarium of New South Wales, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Rossetto, Maurizio',
#     'orcid': '0000-0002-4878-9114',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Rye, Barbara',
#     'orcid': '0000-0003-1254-5940',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Rymer, Paul D.',
#     'orcid': '0000-0003-0988-4351',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Helsinki, Helsinki Institute of Sustainability Science',
#     'name': 'Salomaa, Anna',
#     'orcid': '0000-0002-0509-4873',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Sams, Michael A.',
#     'orcid': '0000-0003-3311-4891',
#     'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Sanson, Gordon',
#     'type': 'DataCollector'},
#    {'affiliation': 'National Herbarium of New South Wales, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'Sauquet, Hervé',
#     'orcid': '0000-0001-8305-3236',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Schmidt, Susanne',
#     'orcid': '0000-0001-8369-1238',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Vienna',
#     'name': 'Schöenenberger, Jürg',
#     'orcid': '0000-0001-6791-2731',
#     'type': 'DataCollector'},
#    {'affiliation': 'Max-Planck Institute for Biogeochemistry',
#     'name': 'Schulze, Ernst-Detlef',
#     'orcid': '0000-0001-6188-9219',
#     'type': 'DataCollector'},
#    {'affiliation': 'Max-Planck Institute for Biogeochemistry, Germany',
#     'name': 'Schulze, Inge',
#     'type': 'DataCollector'},
#    {'affiliation': 'University Hohenheim, Germany',
#     'name': 'Schulze, Waltraud',
#     'orcid': '0000-0001-9957-7245',
#     'type': 'DataCollector'},
#    {'name': 'Scott, Andrew John', 'type': 'DataCollector'},
#    {'affiliation': 'Rider University',
#     'name': 'Sendall, Kerrie',
#     'orcid': '0000-0001-6175-0954',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of the Sunshine Coast',
#     'name': 'Shapcott, Alison',
#     'type': 'DataCollector'},
#    {'name': 'Shaw, Veronica', 'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Shoo, Luke',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'Sinclair, Steve',
#     'orcid': '0000-0002-4282-1021',
#     'type': 'DataCollector'},
#    {'name': 'Sjostrom, Anne', 'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Smith, Benjamin',
#     'orcid': '0000-0002-6987-5337',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Smith, Renee',
#     'type': 'DataCollector'},
#    {'affiliation': 'Bern University, Switzerland',
#     'name': 'Soliveres, Santiago',
#     'orcid': '0000-0001-9661-7192',
#     'type': 'DataCollector'},
#    {'affiliation': 'McGill University',
#     'name': 'Soper, Fiona',
#     'orcid': '0000-0002-9910-9377',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Adelaide',
#     'name': 'Sparrow, Ben',
#     'orcid': '0000-0003-2566-1895',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Spooner, Amanda',
#     'type': 'DataCollector'},
#    {'affiliation': 'Murdoch University',
#     'name': 'Standish, Rachel J.',
#     'orcid': '0000-0001-8118-1904',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Staples, Timothy L.',
#     'orcid': '0000-0002-8550-2661',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Stephens, Ruby',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Stewart, George',
#     'type': 'DataCollector'},
#    {'affiliation': 'Academy of Science Czech Republic',
#     'name': 'Suda, Jan',
#     'orcid': '0000-0001-8964-9153',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Szota, Christopher',
#     'orcid': '0000-0002-8837-591X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Adelaide',
#     'name': 'Tait, Catherine',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Taseski, Guy',
#     'type': 'DataCollector'},
#    {'affiliation': 'NSW Department of Planning Industry and Environment',
#     'name': 'Tasker, Elizabeth',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Technology Sydney',
#     'name': 'Taylor, Daniel',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Thomas, Freya',
#     'orcid': '0000-0001-9926-6295',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Thompson, Ian',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Tissue, David T.',
#     'orcid': '0000-0002-8497-2047',
#     'type': 'DataCollector'},
#    {'affiliation': 'Hawkesbury Institute for the Environment, Western Sydney University',
#     'name': 'Tjoelker, Mark G.',
#     'orcid': '0000-0003-4607-5238',
#     'type': 'DataCollector'},
#    {'affiliation': 'Centre for Rainforest Studies, School for Field Studies, Yungaburra, Queensland',
#     'name': 'Tng, David Yue Phin',
#     'orcid': '0000-0001-5135-0922',
#     'type': 'DataCollector'},
#    {'affiliation': 'State Herbarium of South Australia',
#     'name': 'Toelken, Hellmut R.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Xishuangbanna Tropical Botanic Garden',
#     'name': 'Tomlinson, Kyle',
#     'orcid': '0000-0003-3039-6766',
#     'type': 'DataCollector'},
#    {'affiliation': 'Western Australian Herbarium, Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Trudgen, Malcolm',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Turner, Neil C.',
#     'orcid': '0000-0002-2982-0411',
#     'type': 'DataCollector'},
#    {'affiliation': 'Research Centre for Ecosystem Resilience, Royal Botanic Gardens and Domain Trust, Sydney',
#     'name': 'van der Merwe, Marlien',
#     'orcid': '0000-0003-1307-5143',
#     'type': 'DataCollector'},
#    {'affiliation': 'Wageningen University',
#     'name': 'van Langevelde, Frank',
#     'orcid': '0000-0001-8870-0797',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Veneklaas, Erik J.',
#     'orcid': '0000-0002-7030-4056',
#     'type': 'DataCollector'},
#    {'affiliation': 'Deakin University',
#     'name': 'Venn, Susanna',
#     'orcid': '0000-0002-7433-0120',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Vesk, Peter',
#     'orcid': '0000-0003-2008-7062',
#     'type': 'DataCollector'},
#    {'affiliation': 'Monash University',
#     'name': 'Vlasveld, Carolyn',
#     'orcid': '0000-0001-6445-7067',
#     'type': 'DataCollector'},
#    {'affiliation': 'Royal Botanic Gardens, Kew',
#     'name': 'Vorontsova, Maria S.',
#     'orcid': '0000-0003-0899-1120',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Warren, Charles A.',
#     'orcid': '0000-0002-0788-4713',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of New England',
#     'name': 'Warwick, Nigel',
#     'orcid': '0000-0001-7009-3183',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Peradeniya',
#     'name': 'Weerasinghe, Lasantha K.',
#     'orcid': '0000-0002-5173-8000',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Wells, Jessie',
#     'orcid': '0000-0002-3555-5108',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Queensland',
#     'name': 'Westman, W. E.',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Westoby, Mark',
#     'orcid': '0000-0001-7690-4530',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria',
#     'name': 'White, Matthew',
#     'orcid': '0000-0003-2120-0071',
#     'type': 'DataCollector'},
#    {'name': 'Williams, Erica', 'type': 'DataCollector'},
#    {'affiliation': 'University of Melbourne',
#     'name': 'Williams, Nicholas S. G.',
#     'orcid': '0000-0001-6291-9483',
#     'type': 'DataCollector'},
#    {'name': 'Williams, R. J.', 'type': 'DataCollector'},
#    {'affiliation': 'University of Tasmania',
#     'name': 'Willis, Kathryn',
#     'orcid': '0000-0001-7614-1027',
#     'type': 'DataCollector'},
#    {'affiliation': 'The University of Sydney',
#     'name': 'Wills, Jarrah',
#     'orcid': '0000-0002-0235-7690',
#     'type': 'DataCollector'},
#    {'affiliation': 'Botany Department, University of Otago, Dunedin, New Zealand',
#     'name': 'Wilson, J. Barstow',
#     'type': 'DataCollector'},
#    {'affiliation': 'National Herbarium of NSW and Royal Botanic Gardens and Domain Trust',
#     'name': 'Wilson, Peter G.',
#     'orcid': '0000-0001-8581-318X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Wright, Ian J.',
#     'orcid': '0000-0001-8338-9143',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Biodiversity, Conservation and Attractions, Western Australia',
#     'name': 'Yates, Colin',
#     'orcid': '0000-0003-2286-8700',
#     'type': 'DataCollector'},
#    {'affiliation': 'Department of Environment, Land, Water and Planning, Victoria, Australia',
#     'name': 'Yen, Jian',
#     'orcid': '0000-0001-7964-923X',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Miami, Coral Gables',
#     'name': 'Zanne, Amy E.',
#     'orcid': '0000-0001-6379-9452',
#     'type': 'DataCollector'},
#    {'affiliation': 'University of Western Australia',
#     'name': 'Zemunik, Graham',
#     'orcid': '0000-0002-6064-345X',
#     'type': 'DataCollector'},
#    {'affiliation': 'Université de Montpellier',
#     'name': 'Ziemińska, Kasia',
#     'orcid': '0000-0001-7750-4758',
#     'type': 'DataCollector'}],
#   'creators': [{'affiliation': 'University of New South Wales',
#     'name': 'Falster, Daniel',
#     'orcid': '0000-0002-9814-092X'},
#    {'affiliation': 'Macquarie University',
#     'name': 'Gallagher, Rachael',
#     'orcid': '0000-0002-4680-8115'},
#    {'affiliation': 'University of New South Wales',
#     'name': 'Wenk, Elizabeth',
#     'orcid': '0000-0001-5640-5910'}],
#   'description': '<p><strong>INTRODUCTION</strong></p>\n\n<p>AusTraits is a transformative database, containing measurements on the traits of Australia&rsquo;s plant taxa, standardised from hundreds of disconnected primary sources. So far, data have been assembled from &gt; 250 distinct sources, describing &gt; 400 plant traits and &gt; 26,000 taxa.</p>\n\n<p>To handle the harmonising of diverse data sources, we use a reproducible workflow to implement the various changes required for each source to reformat it suitable for incorporation in AusTraits. Such changes include restructuring datasets, renaming variables, changing variable units, changing taxon names. While this repository contains the harmonised data, the raw data and code used to build the resource are also available on the project&rsquo;s GitHub repository, <a href="http://traitecoevo.github.io/austraits.build/">http://traitecoevo.github.io/austraits.build/</a>.</p>\n\n<p>Further information on the project is available in the associated publication and at the project website <a href="https://austraits.org">austraits.org</a>.</p>\n\n<blockquote>\n<p>Falster, Gallagher et al (2021) <em>AusTraits, a curated plant trait database for the Australian flora</em>. Scientific Data 8: 254, <a href="https://doi.org/10.1038/s41597-021-01006-6">https://doi.org/10.1038/s41597-021-01006-6</a></p>\n</blockquote>\n\n<p><strong>CONTRIBUTORS</strong></p>\n\n<p>The project is jointly led by Dr Daniel Falster (UNSW Sydney), Dr Rachael Gallagher (Western Sydney University), Dr Elizabeth Wenk (UNSW Sydney), and Dr Herv&eacute; Sauquet (Royal Botanic Gardens and Domain Trust Sydney), with input from &gt; 300 contributors from over &gt; 100 institutions (see full list above). The project was initiated by Dr Rachael Gallagher and Prof Ian Wright while at Macquarie University.</p>\n\n<p>We are grateful to the following institutions for contributing data Australian National Botanic Garden, Brisbane Rainforest Action and Information Network, Kew Botanic Gardens, National Herbarium of NSW, Northern Territory Herbarium, Queensland Herbarium, Western Australian Herbarium, South Australian Herbarium, State Herbarium of South Australia, Tasmanian Herbarium, Department of Environment, Land, Water and Planning, Victoria.</p>\n\n<p>AusTraits has been supported by investment from the Australian Research Data Commons (ARDC), via their &ldquo;Transformative data collections&rdquo; (<a href="https://doi.org/10.47486/TD044">https://doi.org/10.47486/TD044</a>) and &ldquo;Data Partnerships&rdquo; (<a href="https://doi.org/10.47486/DP720">https://doi.org/10.47486/DP720</a>) programs; fellowship grants from Australian Research Council to Falster (FT160100113), Gallagher (DE170100208) and Wright (FT100100910), a grant from Macquarie University to Gallagher. The ARDC is enabled by National Collaborative Research Investment Strategy (NCRIS).</p>\n\n<p><strong>ACCESSING AND USE OF DATA</strong></p>\n\n<p>The compiled AusTraits database is released under an open source licence (CC-BY), enabling re-use by the community.</p>\n\n<p>A requirement of use is that users cite the AusTraits resource paper, which includes all contributors as co-authors:</p>\n\n<blockquote>\n<p>Falster, Gallagher et al (2021) <em>AusTraits, a curated plant trait database for the Australian flora</em>. Scientific Data 8: 254, <a href="https://doi.org/10.1038/s41597-021-01006-6">https://doi.org/10.1038/s41597-021-01006-6</a></p>\n</blockquote>\n\n<p>In addition, we encourage users you to cite the original data sources, wherever possible.</p>\n\n<p>Note that under the license data may be redistributed, provided the attribution is maintained.</p>\n\n<p>The downloads below provide the data in two formats:</p>\n\n<ul>\n\t<li><code>austraits-3.0.2.zip</code>: data in plain text format (.csv, .bib, .yml files). Suitable for anyone, including those using Python.</li>\n\t<li><code>austraits-3.0.2.rds</code>: data as compressed R object. Suitable for us ...
#   'doi': '10.5281/zenodo.5112001',
#   'grants': [{'acronym': '',
#     'code': 'DE170100208',
#     'funder': {'acronyms': [],
#      'doi': '10.13039/501100000923',
#      'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000923'},
#      'name': 'Australian Research Council'},
#     'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000923::DE170100208'},
#     'program': 'Discovery Early Career Researcher Award',
#     'title': 'Discovery Early Career Researcher Award - Grant ID: DE170100208'},
#    {'acronym': '',
#     'code': 'FT160100113',
#     'funder': {'acronyms': [],
#      'doi': '10.13039/501100000923',
#      'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000923'},
#      'name': 'Australian Research Council'},
#     'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000923::FT160100113'},
#     'program': 'Future Fellowships',
#     'title': 'Future Fellowships - Grant ID: FT160100113'},
#    {'acronym': '',
#     'code': 'FT100100910',
#     'funder': {'acronyms': [],
#      'doi': '10.13039/501100000923',
#      'links': {'self': 'https://zenodo.org/api/funders/10.13039/501100000923'},
#      'name': 'Australian Research Council'},
#     'links': {'self': 'https://zenodo.org/api/grants/10.13039/501100000923::FT100100910'},
#     'program': 'Future Fellowships',
#     'title': 'Towards a trait-based plant ecology: new directions in leaf economics research'}],
#   'keywords': ['plant', 'trait', 'biodiversity'],
#   'language': 'eng',
#   'license': {'id': 'CC-BY-4.0'},
#   'notes': 'The AusTraits project received investment (https://doi.org/10.47486/TD044, https:// doi.org/10.47486/DP720) from the Australian Research Data Commons (ARDC). The ARDC is funded by the National Collaborative Research Infrastructure Strategy (NCRIS).',
#   'publication_date': '2021-07-14',
#   'references': ['Falster, Gallagher et al (2021) *AusTraits, a curated plant trait database for the Australian flora*. Scientific Data 8: 254, https://doi.org/10.1038/s41597-021-01006-6'],
#   'related_identifiers': [{'identifier': 'https://github.com/traitecoevo/austraits.build/tree/v3.0.2',
#     'relation': 'isCompiledBy',
#     'resource_type': 'dataset',
#     'scheme': 'url'},
#    {'identifier': '10.1101/2021.01.04.425314',
#     'relation': 'isCitedBy',
#     'resource_type': 'publication-preprint',
#     'scheme': 'doi'},
#    {'identifier': '10.1101/2021.01.04.425314',
#     'relation': 'isPartOf',
#     'resource_type': 'publication-preprint',
#     'scheme': 'doi'},
#    {'identifier': '10.1038/s41597-021-01006-6',
#     'relation': 'isCitedBy',
#     'resource_type': 'publication-article',
#     'scheme': 'doi'},
#    {'identifier': '10.1038/s41597-021-01006-6',
#     'relation': 'isPublishedIn',
#     'resource_type': 'publication-article',
#     'scheme': 'doi'},
#    {'identifier': '10.47486/DP720',
#     'relation': 'cites',
#     'resource_type': 'other',
#     'scheme': 'doi'},
#    {'identifier': '10.47486/TD044',
#     'relation': 'cites',
#     'resource_type': 'other',
#     'scheme': 'doi'},
#    {'identifier': '10.5281/zenodo.3568417',
#     'relation': 'isVersionOf',
#     'scheme': 'doi'}],
#   'relations': {'version': [{'count': 8,
#      'index': 7,
#      'is_last': True,
#      'last_child': {'pid_type': 'recid', 'pid_value': '5112001'},
#      'parent': {'pid_type': 'recid', 'pid_value': '3568417'}}]},
#   'resource_type': {'title': 'Dataset', 'type': 'dataset'},
#   'title': 'AusTraits: a curated plant trait database for the Australian flora',
#   'version': 'v3.0.2'},
#  'owners': [18887],
#  'revision': 19,
#  'stats': {'downloads': 896.0,
#   'unique_downloads': 542.0,
#   'unique_views': 805.0,
#   'version_downloads': 1149.0,
#   'version_unique_downloads': 676.0,
#   'version_unique_views': 2186.0,
#   'version_views': 2914.0,
#   'version_volume': 12459512991.0,
#   'views': 989.0,
#   'volume': 9958704872.0},
#  'updated': '2022-02-18T04:53:14.178881+00:00'}

# %% [markdown]
# The json data includes a list of files:

# %%
for files in jsonData['files']:
    print(files['key'])
# Out:
# austraits-3.0.2.rds
# austraits-3.0.2.zip
# dictionary.html
# NEWS.md
# readme.txt

# %% [markdown]
# We want to download the zip file with the csv_files

# %%
outputfile = outputdir / jsonData['files'][1]['key']

if os.path.isfile(outputfile):
    print('File exists')
else:
    resp = getResponse(jsonData['files'][1]['links']['self'])
    output = open(outputfile,'wb')
    output.write(resp)
    output.close()
# Out:
# File exists

# %% [markdown]
# We will read from the zipfile the data that we need:

# %%
zfobj = ZipFile(outputfile)
zfobj.namelist()
# Out:
# ['austraits-3.0.2/',
#  'austraits-3.0.2/taxa.csv',
#  'austraits-3.0.2/methods.csv',
#  'austraits-3.0.2/definitions.yml',
#  'austraits-3.0.2/build_info.md',
#  'austraits-3.0.2/contributors.csv',
#  'austraits-3.0.2/contexts.csv',
#  'austraits-3.0.2/excluded_data.csv',
#  'austraits-3.0.2/traits.csv',
#  'austraits-3.0.2/taxonomic_updates.csv',
#  'austraits-3.0.2/sites.csv',
#  'austraits-3.0.2/sources.bib']

# %% [markdown]
# ### Definitions

# %%
import yaml

with zfobj.open('austraits-3.0.2/definitions.yml') as file:
    try:
        ATdefinitions = yaml.safe_load(file)   
        print(ATdefinitions.keys())
    except yaml.YAMLError as exc:
        print(exc)
# Out:
# dict_keys(['traits', 'value_type', 'austraits', 'metadata'])

# %%
ATdefinitions['traits']['elements'].keys()
# Out:
# dict_keys(['accessory_cost_mass', 'accessory_cost_fraction', 'bark_delta13C', 'bark_delta15N', 'bark_mass_area', 'bark_density', 'bark_C_per_dry_mass', 'bark_N_per_dry_mass', 'bark_P_per_dry_mass', 'bark_K_per_dry_mass', 'bark_Al_per_dry_mass', 'bark_B_per_dry_mass', 'bark_Ca_per_dry_mass', 'bark_Cu_per_dry_mass', 'bark_Fe_per_dry_mass', 'bark_Mg_per_dry_mass', 'bark_Mn_per_dry_mass', 'bark_Na_per_dry_mass', 'bark_S_per_dry_mass', 'bark_Zn_per_dry_mass', 'bark_morphology', 'bark_thickness', 'bark_ash_content_per_dry_mass', 'bark_cellulose_per_dry_mass', 'bark_lignin_per_dry_mass', 'bark_tannin_per_dry_mass', 'branch_mass_fraction', 'sprout_depth', 'calcicole_status', 'carotenoid_per_area', 'carotenoid_per_dry_mass', 'cell_cross-sectional_area', 'cell_epidermis_Ca_per_fresh_mass', 'cell_hypodermis_Ca_per_fresh_mass', 'cell_internal_parenchyma_Ca_per_fresh_mass', 'cell_palisade_mesophyll_Ca_per_fresh_mass', 'cell_sclerenchyma_Ca_per_fresh_mass', 'cell_spongy_mesophyll_Ca_per_fresh_mass', 'cell_epidermis_P_per_fresh_mass', 'cell_hypodermis_P_per_fresh_mass', 'cell_internal_parenchyma_P_per_fresh_mass', 'cell_palisade_mesophyll_P_per_fresh_mass', 'cell_rubisco_concentration', 'cell_rubisco_N_per_total_N', 'cell_sclerenchyma_P_per_fresh_mass', 'cell_spongy_mesophyll_P_per_fresh_mass', 'cell_thylakoid_N_per_total_N', 'chlorophyll_per_area', 'chlorophyll_A_per_area', 'chlorophyll_B_per_area', 'chlorophyll_per_dry_mass', 'chlorophyll_A_per_dry_mass', 'chlorophyll_B_per_dry_mass', 'chlorophyll_A_B_ratio', 'ca', 'cc', 'ci_at_ambient', 'ci_at_Amax', 'ci_at_Asat', 'ci_over_ca', 'competitive_stratum', 'cotyledon_function', 'cotyledon_position', 'cotyledon_type', 'seedling_germination_location', 'establishment_light_environment_index', 'reproductive_light_environment_index', 'upper_cuticle_thickness', 'lower_cuticle_thickness', 'diaspore_mass', 'dispersal_appendage', 'dispersal_syndrome', 'dispersers', 'dormancy_type', 'embryo_colour', 'epidermal_cell_density_abaxial', 'epidermal_cell_density_adaxial', 'epidermal_cell_density_both_sides', 'epidermis_thickness', 'epidermis_thickness_upper_leaf_surface', 'epidermis_thickness_lower_leaf_surface', 'fire_response', 'fire_response_detailed', 'fire_response_juvenile', 'fire_response_on_maturity', 'fire_cued_seeding', 'fire_and_establishing', 'fire_flame_duration', 'fire_fuel_bed_bulk_density', 'fire_fuel_comsumption', 'fire_rate_of_spread', 'fire_smoulder_duration', 'fire_total_burn_duration', 'fire_time_to_ignition', 'flower_colour', 'flower_count_maximum', 'flower_N_per_dry_mass', 'flowering_time', 'flower_structural_sex_type', 'flower_ovary_position', 'flower_perianth_parts_count', 'flower_perianth_fusion', 'flower_perianth_symmetry', 'flower_perianth_phyllotaxis', 'flower_perianth_whorls_count', 'flower_perianth_merism', 'flower_perianth_differentiation', 'flower_fertile_stamens_count', 'flower_filament', 'flower_filament_fusion', 'flower_filament_fusion_to_inner_perianth', 'flower_anther_orientation', 'flower_anther_attachment', 'flower_anther_dehiscence', 'flower_anther_connective_extension', 'flower_androecium_structural_phyllotaxis', 'flower_androecium_structural_whorls_count', 'flower_androecium_structural_merism', 'flower_gynoecium_phyllotaxis', 'flower_structural_carpels_count', 'flower_ovary_fusion', 'flower_style_differentiation', 'flower_style_fusion', 'flower_ovules_per_functional_carpel_count', 'flower_gynoecium_placentation', 'flower_pollen_apertures_count', 'flower_pollen_aperture_shape', 'fluorescence_Jmax_per_mass', 'fluorescence_Vcmax_per_mass', 'fluorescence_Jmax_over_Vcmax', 'Jmax_per_area', 'Vcmax_per_area', 'fruit_colour', 'fruit_mass', 'fruit_wall_width', 'fruit_width', 'fruit_length', 'fruit_breadth', 'fruit_N_per_dry_mass', 'fruit_P_per_dry_mass', 'fruit_Mg_per_dry_mass', 'fruit_Ca_per_dry_mass', 'fruit_K_per_dry_mass', 'fruit_S_per_dry_mass', 'fruit_type', 'fruit_type_botanical', 'fruit_type_functional', 'fruiting_time', 'time_from_fire_to_fruit', 'fv_over_fm', 'germin ...

# %%
print(ATdefinitions['traits']['elements']['fire_response'].keys())
# Out:
# dict_keys(['description', 'type', 'label', 'values'])

# %%
print(ATdefinitions['traits']['elements']['fire_response']['values'])
# Out:
# {'fire_killed': 'Plants killed by hot fires', 'resprouts': "Plants resprout from underground storage organ following fire. (For studies that don't differentiate between respouting strength)", 'not_fire_killed_does_not_resprout': 'Plants that are rarely killed by a moderate-intensity fire, but do not resprout', 'fire_not_relevant': 'Plant never affected by fire (for aquatic taxon)', 'unknown': 'Fire status assessed, but unknown'}

# %% [markdown]
# ### References

# %%
from pybtex.database.input import bibtex
parser = bibtex.Parser()

bib_data = parser.parse_bytes(zfobj.open('austraits-3.0.2/sources.bib').read())

# %%
#bib_data.entries.keys()
#for key in bib_data.entries.keys():
#    print(key)
bib_data.entries['Adams_1984']
# dir(bib_data.entries['Adams_1984'])
# Out:
# Entry('article',
#   fields=[
#     ('year', '1984'),
#     ('journal', 'Australian Journal of Botany'),
#     ('title', '{Role of Acacia spp. in nutrient balance and cycling in regenerating Eucalyptus regnans F. Muell. forests. I. Temporal changes in biomass and nutrient content}'),
#     ('volume', '32'),
#     ('number', '2'),
#     ('pages', '205--215'),
#     ('doi', '10.1071/bt9840205')],
#   persons=OrderedCaseInsensitiveDict([('author', [Person('Adams, M. A.'), Person('M, P.'), Person('{Attiwill}')])]))

# %%
print(bib_data.entries['Adams_1984'].fields['year'])
##''.join(person for person in bib_data.entries['Adams_1984'].persons['author'])
for person in bib_data.entries['Adams_1984'].persons['author']:
    print(person)

dir(person)
person.__str__()
# Out:
# 1984
# Adams, M. A.
# M, P.
# {Attiwill}
# '{Attiwill}'

# %%
import io
import pybtex.database.input.bibtex
import pybtex.plugin
style = pybtex.plugin.find_plugin('pybtex.style.formatting', 'plain')()
citation = style.format_entries(bib_data.entries['Adams_1984'])
print(citation)
#pybtex_html_backend = pybtex.plugin.find_plugin('pybtex.backends', 'html')()
#pybtex_backend = pybtex.plugin.find_plugin('pybtex.backends', 'text')()
#output = io.StringIO()
#pybtex_backend.write_to_stream(citation, output)
#print(output.getvalue())
# Out:
# <generator object BaseStyle.format_entries at 0x11a989af0>

# %% [markdown]
# ### Traits data

# %%
ATtraits = pd.read_csv(zfobj.open('austraits-3.0.2/traits.csv'),low_memory=False)

# %%
sppname='Actinotus helianthi'
traits=('fire_response_juvenile','fire_response','fire_cued_seeding')

ss = (ATtraits['taxon_name']==sppname) & (ATtraits['trait_name'].isin(traits))
ATtraits[ss]
# Out:
#             dataset_id           taxon_name    site_name context_name  \
# 217795  Falster_2005_2  Actinotus helianthi  Myall_Lakes          NaN
# 454654     NSWFRD_2014  Actinotus helianthi          NaN          NaN
#
#            observation_id     trait_name        value unit     date  \
# 217795  Falster_2005_2_05  fire_response  fire_killed  NaN  2002-09
# 454654   NSWFRD_2014_0177  fire_response  fire_killed  NaN      NaN
#
#          value_type replicates        original_name
# 217795  expert_mean        NaN  Actinotus helianthi
# 454654  expert_mean        NaN  Actinotus helianthi

# %% [markdown]
# ### Taxonomic data

# %% [markdown]
# We will read this into a pandas data frame:

# %%
df = pd.read_csv(zfobj.open('austraits-3.0.2/taxa.csv'))

# %% [markdown]
# Check information from one species

# %%
target = df[df['taxon_name'] == "Actinotus helianthi"] 
target
# Out:
#                taxon_name source  \
# 1665  Actinotus helianthi    APC
#
#                                    acceptedNameUsageID  \
# 1665  https://id.biodiversity.org.au/node/apni/2895645
#
#      scientificNameAuthorship taxonRank taxonomicStatus    family  \
# 1665                  Labill.   Species        accepted  Apiaceae
#
#                 taxonDistribution  \
# 1665  Qld, NSW, Vic (naturalised)
#
#                                        ccAttributionIRI      genus
# 1665  https://id.biodiversity.org.au/tree/51354547/5...  Actinotus

# %%
spp_info = CAPS[CAPS['scientificName'] == "Actinotus helianthi"] 
spp_info.transpose()
# Out:
#                                                           3
# speciesID                                              2361
# taxonRank                                           Species
# classID                                                  38
# class                                                 Flora
# orderID                                                 137
# order                                                 Flora
# familyID                                                157
# family                                             Apiaceae
# sortOrder                                              6031
# genusID                                              1823.0
# genus                                             Actinotus
# parentSpeciesID                                      2361.0
# specificEpithet                                   helianthi
# infraspecificEpithet                                    NaN
# scientificNameAuthorship                            Labill.
# scientificNameID                                       2361
# speciesCode_Synonym                                    1094
# scientificName                          Actinotus helianthi
# scientificNameHTML             <em>Actinotus helianthi</em>
# vernacularName                               Flannel Flower
# otherVernacularNames                                    NaN
# taxonID                                                2361
# currentScientificNameCode                              1094
# currentScientificName                   Actinotus helianthi
# currentVernacularName                        Flannel Flower
# isCurrent                                              True
# generalTypeID                                           NaN
# generalType                                             NaN
# establishmentMeans                     Alive in NSW, Native
# primaryGrowthForm                                      Forb
# primaryGrowthFormGroup                            Forb (FG)
# secondaryGrowthForms                                    NaN
# secondaryGrowthFormGroups                               NaN
# stateConservation                                Not Listed
# protectedInNSW                                         True
# sensitivityClass                              Not Sensitive
# TSProfileID                                             NaN
# countryConservation                              Not Listed
# highThreatWeed                                          NaN
# widelyCultivatedNativeSpecies                           NaN
# CAMBA                                                 False
# JAMBA                                                 False
# ROKAMBA                                               False

# %%
qry = target['acceptedNameUsageID'].values[0]+".json"
qry
#apniData=json.loads(qry) # error?
# Out:
# 'https://id.biodiversity.org.au/node/apni/2895645.json'

# %%
apniData = json.loads(getResponse(qry))
apniData
# Out:
# {'treeElement': {'class': 'au.org.biodiversity.nsl.TreeElement',
#   '_links': {'elementLink': 'https://id.biodiversity.org.au/tree/51662411/51242199',
#    'taxonLink': 'https://id.biodiversity.org.au/node/apni/2895645',
#    'parentElementLink': 'https://id.biodiversity.org.au/tree/51662411/51375672',
#    'nameLink': 'https://id.biodiversity.org.au/name/apni/75081',
#    'instanceLink': 'https://id.biodiversity.org.au/instance/apni/755469',
#    'sourceElementLink': None},
#   'tree': {'class': 'au.org.biodiversity.nsl.Tree',
#    '_links': {'permalinks': [{'link': 'https://id.biodiversity.org.au/tree/apni/APC',
#       'preferred': True,
#       'resources': 1}]},
#    'audit': None,
#    'name': 'APC'},
#   'simpleName': 'Actinotus helianthi',
#   'namePath': 'Plantae/Charophyta/Equisetopsida/Magnoliidae/Asteranae/Apiales/Apiaceae/Actinotus/helianthi',
#   'treePath': '/51209397/51209398/51209399/51210622/51236316/51241866/51242182/51375672/51242199',
#   'displayHtml': '<data><scientific><name data-id=\'75081\'><scientific><name data-id=\'75003\'><element>Actinotus</element></name></scientific> <element>helianthi</element> <authors><author data-id=\'6858\' title=\'Labillardiere, J.J.H. de\'>Labill.</author></authors></name></scientific><name-status class="legitimate">, legitimate</name-status> <citation><ref data-id=\'49840\'><ref-section><author>CHAH</author> <year>(2011)</year>, <par-title><i>Australian Plant Census</i></par-title></ref-section></ref></citation></data>',
#   'sourceShard': 'APNI',
#   'synonymsHtml': '<synonyms><tax><scientific><name data-id=\'73577\'><scientific><name data-id=\'73549\'><element>Eriocalia</element></name></scientific> <element>major</element> <authors><author data-id=\'6895\' title=\'Smith, J.E\'>Sm.</author></authors></name></scientific><name-status class="legitimate">, legitimate</name-status> <year>(1806)</year> <type>taxonomic synonym</type></tax></synonyms>',
#   'synonyms': {'list': [{'mis': False,
#      'nom': False,
#      'tax': True,
#      'host': 'https://id.biodiversity.org.au',
#      'type': 'taxonomic synonym',
#      'year': 1806.0,
#      'cites': 'Smith, J.E (1806), Exotic Botany 2',
#      'name_id': 73577.0,
#      'name_link': '/name/apni/73577',
#      'cites_html': "<ref data-id='53070'><ref-section><author>Smith, J.E</author> <year>(1806)</year>, <par-title><i>Exotic Botany</i></par-title> <volume>2</volume></ref-section></ref>",
#      'cites_link': '/reference/apni/53070',
#      'instance_id': 939294.0,
#      'simple_name': 'Eriocalia major',
#      'concept_link': '/instance/apni/755445',
#      'instance_link': '/instance/apni/939294',
#      'full_name_html': "<scientific><name data-id='73577'><scientific><name data-id='73549'><element>Eriocalia</element></name></scientific> <element>major</element> <authors><author data-id='6895' title='Smith, J.E'>Sm.</author></authors></name></scientific>"}]},
#   'profile': {'APC Dist.': {'value': 'Qld, NSW, Vic (naturalised)',
#     'created_at': '2012-09-26T00:00:00+10:00',
#     'created_by': 'AWHEELER',
#     'updated_at': '2012-09-26T00:00:00+10:00',
#     'updated_by': 'AWHEELER',
#     'source_link': 'https://id.biodiversity.org.au/instanceNote/apni/1127144'}},
#   'children': [{'displayHtml': '<data><scientific><name data-id=\'75081\'><scientific><name data-id=\'75003\'><element>Actinotus</element></name></scientific> <element>helianthi</element> <authors><author data-id=\'6858\' title=\'Labillardiere, J.J.H. de\'>Labill.</author></authors></name></scientific><name-status class="legitimate">, legitimate</name-status> <citation><ref data-id=\'49840\'><ref-section><author>CHAH</author> <year>(2011)</year>, <par-title><i>Australian Plant Census</i></par-title></ref-section></ref></citation></data>',
#     'elementLink': 'https://id.biodiversity.org.au/tree/51662411/51242199',
#     'nameLink': 'https://id.biodiversity.org.au/name/apni/75081',
#     'instanceLink': 'https://id.biodiversity.org.au/instance/apni/755469',
#     'excluded': False,
#     'depth': 9,
#     'synonymsHtml': '<synonyms><tax><scientific><name data-id=\'73577\'><scientific><name data-id=\'73549\'><element>Eriocalia</element></name></scientific> <element>major</element> <authors><author data-id=\'6895\' title=\'Smith, J.E\'>Sm.</author></authors></name></scientific><name-status class="legitimate">, legitimate</name-status> <year>(1806)</year> <type>taxonomic synonym</type></tax></synonyms>'}],
#   'versionUpdatedBy': 'import',
#   'versionUpdatedAt': '2018-06-05T14:00:00Z',
#   'elementUpdatedBy': 'import',
#   'elementUpdatedAt': '2018-06-12T19:34:59Z'}}

# %% [markdown]
# ## Explore traits

# %%
ATtraits['trait_name'].unique()
# Out:
# array(['leaf_area', 'leaf_delta13C', 'leaf_N_per_dry_mass', 'leaf_PRI',
#        'modified_NDVI', 'specific_leaf_area', 'water_band_index',
#        'wood_density', 'seed_length', 'seed_shape', 'seed_texture',
#        'seed_width', 'seed_mass', 'germination_treatment',
#        'dispersal_appendage', 'dispersal_syndrome',
#        'leaf_dry_matter_content', 'plant_growth_form', 'plant_height',
#        'leaf_length', 'leaf_thickness', 'leaf_width',
#        'sapwood_specific_conductivity_theoretical', 'vessel_density',
#        'vessel_diameter', 'vessel_lumen_fraction',
#        'vessel_diameter_hydraulic', 'vessel_multiple_fraction',
#        'water_use_efficiency_intrinsic', 'leaf_hairs_adult', 'leaf_shape',
#        'fire_response', 'regen_strategy', 'fire_cued_seeding',
#        'leaf_compoundness', 'seed_breadth', 'leaf_phenology',
#        'flowering_time', 'life_history', 'leaf_type',
#        'leaf_hydraulic_conductivity', 'leaf_hydraulic_vulnerability',
#        'leaf_turgor_loss_point', 'ci_at_Amax', 'ci_at_Asat', 'ci_over_ca',
#        'leaf_dark_respiration_per_area',
#        'leaf_dark_respiration_per_dry_mass',
#        'leaf_dark_transpiration_per_area', 'leaf_N_per_area',
#        'leaf_P_per_area', 'leaf_P_per_dry_mass',
#        'leaf_photosynthetic_nitrogen_use_efficiency_saturated',
#        'leaf_photosynthetic_phosphorus_use_efficiency_saturated',
#        'leaf_transpiration_at_Amax', 'leaf_transpiration_at_Asat',
#        'N_to_P_ratio', 'photosynthetic_rate_per_area_maximum',
#        'photosynthetic_rate_per_area_saturated',
#        'photosynthetic_rate_per_dry_mass_maximum',
#        'photosynthetic_rate_per_dry_mass_saturated',
#        'stomatal_conductance_per_area_at_Amax',
#        'stomatal_conductance_per_area_at_Asat',
#        'water_use_efficiency_photosynthetic', 'woodiness', 'parasitic',
#        'leaf_C_per_dry_mass', 'leaf_CN_ratio', 'leaf_delta15N',
#        'leaf_dry_mass', 'leaf_fresh_mass', 'stem_water_delta18O',
#        'wood_C_per_dry_mass', 'wood_delta13C', 'wood_delta15N',
#        'wood_N_per_dry_mass', 'leaf_water_content_per_dry_mass',
#        'flood_regime_classification', 'growth_habit',
#        'vegetative_regeneration', 'stem_respiration_per_dry_mass',
#        'bark_thickness', 'huber_value', 'Jmax_per_area', 'Vcmax_per_area',
#        'fire_and_establishing', 'fire_response_juvenile',
#        'fire_response_on_maturity', 'lifespan', 'reproductive_maturity',
#        'seed_longevity', 'life_form', 'fruit_length', 'fruit_type',
#        'fruit_type_botanical', 'fruit_type_functional', 'fruit_width',
#        'leaf_transpiration', 'photosynthetic_rate_per_area_ambient',
#        'stomatal_conductance_per_area_ambient', 'water_potential_midday',
#        'water_potential_predawn', 'leaf_specific_conductivity',
#        'sapwood_specific_conductivity', 'stem_hydraulic_conductivity',
#        'water_potential_50percent_lost_conductivity',
#        'hydraulic_safety_margin_50',
#        'water_potential_88percent_lost_conductivity', 'fruiting_time',
#        'basal_diameter', 'dispersers', 'plant_width', 'leaf_margin',
#        'leaf_light_respiration_per_area', 'senesced_leaf_N_per_dry_mass',
#        'senesced_leaf_P_per_dry_mass', 'wood_P_per_dry_mass',
#        'cell_cross-sectional_area',
#        'epidermis_thickness_lower_leaf_surface',
#        'epidermis_thickness_upper_leaf_surface',
#        'lower_cuticle_thickness', 'lower_palisade_cell_thickness',
#        'nitrogen_fixing', 'photosynthetic_pathway',
#        'spongy_mesophyll_thickness', 'upper_cuticle_thickness',
#        'upper_palisade_cell_thickness', 'upper_hypodermis_thickness',
#        'lower_hypodermis_thickness', 'leaf_angle',
#        'stomatal_resistance_conductance_ambient', 'leaf_reflectance',
#        'leaf_reflectance_near_infrared',
#        'leaf_water_content_per_fresh_mass', 'pendulous_leaves',
#        'leaf_lifespan', 'seed_P_concentration', 'serotiny',
#        'leaf_B_per_dry_mass', 'leaf_Ca_per_dry_mass',
#        'leaf_Cu_per_dry_mass', 'leaf_Fe_per_dry_mass',
#        'leaf_K_per_dry_mass', 'leaf_Mg_per_dry_mass',
#        'leaf_Mn_per_dry_mass', 'leaf_Ni_per_dry_mass',
#        'leaf_S_per_dry_mass', 'leaf_Zn_per_dry_mass',
#        'leaf_Mo_per_dry_mass', 'leaf_ash_content_per_dry_mass',
#        'leaf_phenol_content_per_dry_mass', 'leaf_Si_per_dry_mass',
#        'leaf_area_ratio', 'whole_plant_transpiration',
#        'bulk_modulus_of_elasticity',
#        'leaf_relative_water_content_at_turgor_loss_point',
#        'osmotic_potential_at_full_turgor', 'root_shoot_ratio',
#        'leaf_soluable_starch_per_mass', 'leaf_soluable_sugars_per_mass',
#        'root_soluable_starch_per_mass', 'root_soluable_sugars_per_mass',
#        'stem_soluable_starch_per_mass', 'stem_soluable_sugars_per_mass',
#        'leaf_work_to_punch', 'leaf_work_to_punch_adjusted',
#        'leaf_work_to_shear', 'leaf_work_to_shear_adjusted',
#        'leaf_work_to_tear_adjusted', 'flower_style_differentiation',
#        'flower_perianth_merism', 'flower_perianth_symmetry',
#        'flower_androecium_structural_merism',
#        'flower_structural_carpels_count', 'flower_gynoecium_placentation',
#        'flower_ovules_per_functional_carpel_count',
#        'flower_ovary_position', 'flower_perianth_fusion',
#        'flower_perianth_parts_count', 'flower_structural_sex_type',
#        'flower_filament_fusion_to_inner_perianth',
#        'flower_fertile_stamens_count', 'flower_filament_fusion',
#        'flower_anther_attachment', 'flower_anther_orientation',
#        'flower_filament', 'flower_pollen_apertures_count',
#        'flower_pollen_aperture_shape', 'flower_perianth_phyllotaxis',
#        'flower_perianth_whorls_count', 'flower_perianth_differentiation',
#        'flower_androecium_structural_phyllotaxis',
#        'flower_androecium_structural_whorls_count',
#        'flower_gynoecium_phyllotaxis', 'flower_ovary_fusion',
#        'flower_style_fusion', 'flower_anther_connective_extension',
#        'flower_anther_dehiscence', 'fv_over_fm', 'osmotic_potential',
#        'leaflet_area', 'leaflet_dry_mass', 'stem_density', 'germination',
#        'seed_viability', 'root_mass_fraction', 'stem_mass_fraction',
#        'branch_mass_fraction', 'leaf_water_content_per_area',
#        'leaf_mass_fraction', 'leaf_relative_water_content_predawn',
#        'water_use_efficiency_integrated', 'stomatal_density_abaxial',
#        'stomatal_density_adaxial', 'stomatal_density_average',
#        'resprouting_proportion_individuals', 'root_morphology',
#        'root_structure', 'specific_root_length', 'genome_size',
#        'vine_climbing_mechanism', 'root_wood_density',
#        'leaf_water_content_per_saturated_mass', 'chlorophyll_A_B_ratio',
#        'chlorophyll_per_area', 'soluable_protein_per_area',
#        'soluable_starch_per_area', 'soluable_sugars_per_area',
#        'fruit_mass', 'fruit_P_per_dry_mass', 'competitive_stratum',
#        'soil_seedbank', 'time_from_fire_to_fruit', 'pollination_syndrome',
#        'fire_flame_duration', 'fire_smoulder_duration',
#        'fire_time_to_ignition', 'fire_total_burn_duration',
#        'leaf_lignin_per_dry_mass', 'leaf_tannin_per_dry_mass',
#        'leaf_density', 'leaf_cellulose_per_dry_mass',
#        'senesced_leaf_Al_per_dry_mass', 'senesced_leaf_B_per_dry_mass',
#        'senesced_leaf_C_per_dry_mass', 'senesced_leaf_Ca_per_dry_mass',
#        'senesced_leaf_Cu_per_dry_mass', 'senesced_leaf_Fe_per_dry_mass',
#        'senesced_leaf_K_per_dry_mass', 'senesced_leaf_Mg_per_dry_mass',
#        'senesced_leaf_Mn_per_dry_mass', 'senesced_leaf_Na_per_dry_mass',
#        'senesced_leaf_S_per_dry_mass', 'senesced_leaf_Zn_per_dry_mass',
#        'bark_Al_per_dry_mass', 'bark_ash_content_per_dry_mass',
#        'bark_B_per_dry_mass', 'bark_C_per_dry_mass',
#        'bark_Ca_per_dry_mass', 'bark_cellulose_per_dry_mass',
#        'bark_Cu_per_dry_mass', 'bark_density', 'bark_Fe_per_dry_mass',
#        'bark_K_per_dry_mass', 'bark_lignin_per_dry_mass',
#        'bark_Mg_per_dry_mass', 'bark_Mn_per_dry_mass',
#        'bark_N_per_dry_mass', 'bark_Na_per_dry_mass',
#        'bark_P_per_dry_mass', 'bark_S_per_dry_mass',
#        'bark_tannin_per_dry_mass', 'bark_water_content_per_dry_mass',
#        'bark_Zn_per_dry_mass', 'leaf_curliness',
#        'fire_fuel_bed_bulk_density', 'fire_fuel_comsumption',
#        'fire_rate_of_spread', 'sex_type', 'leaf_Al_per_dry_mass',
#        'leaf_fresh_mass_per_area',
#        'leaf_photosynthetic_nitrogen_use_efficiency_maximum',
#        'leaf_photosynthetic_phosphorus_use_efficiency_maximum',
#        'resorption_leaf_N', 'resorption_leaf_P',
#        'leaf_cell_wall_fraction', 'leaf_cell_wall_N',
#        'leaf_cell_wall_N_fraction', 'senesced_leaf_Mo_per_dry_mass',
#        'cell_epidermis_Ca_per_fresh_mass',
#        'cell_epidermis_P_per_fresh_mass',
#        'cell_internal_parenchyma_Ca_per_fresh_mass',
#        'cell_internal_parenchyma_P_per_fresh_mass',
#        'cell_palisade_mesophyll_Ca_per_fresh_mass',
#        'cell_palisade_mesophyll_P_per_fresh_mass',
#        'cell_sclerenchyma_Ca_per_fresh_mass',
#        'cell_sclerenchyma_P_per_fresh_mass',
#        'cell_hypodermis_Ca_per_fresh_mass',
#        'cell_hypodermis_P_per_fresh_mass',
#        'cell_spongy_mesophyll_Ca_per_fresh_mass',
#        'cell_spongy_mesophyll_P_per_fresh_mass', 'leaf_Na_per_dry_mass',
#        'accessory_cost_fraction', 'accessory_cost_mass',
#        'fruit_Ca_per_dry_mass', 'fruit_K_per_dry_mass',
#        'fruit_Mg_per_dry_mass', 'fruit_N_per_dry_mass',
#        'fruit_S_per_dry_mass', 'seed_Ca_concentration',
#        'seed_K_concentration', 'seed_Mg_concentration',
#        'seed_N_concentration', 'seed_S_concentration',
#        'leaf_Cl_per_dry_mass', 'ploidy', 'guard_cell_length',
#        'leaf_division', 'stomatal_distribution', 'epidermis_thickness',
#        'palisade_cell_width', 'vein_density', 'leaf_Cr_per_dry_mass',
#        'leaf_Co_per_dry_mass', 'leaf_Se_per_dry_mass',
#        'seed_protein_content', 'plant_type_by_resource_use',
#        'salt_tolerance', 'soil_salinity_tolerance', 'seed_oil_content',
#        'bark_mass_area', 'wood_axial_parenchyma_fraction',
#        'wood_conduit_fraction', 'wood_fibre_fraction',
#        'wood_ray_fraction', 'stem_dry_matter_content',
#        'stem_C_per_dry_mass', 'stem_N_per_dry_mass',
#        'leaf_mass_to_stem_mass', 'flower_N_per_dry_mass', 'diaspore_mass',
#        'root_C_per_dry_mass', 'root_delta13C', 'root_delta15N',
#        'root_N_per_dry_mass', 'epidermal_cell_density_abaxial',
#        'epidermal_cell_density_adaxial', 'vessel_non_lumen_fraction',
#        'transverse_branch_area_specific_conductivity', 'physical_defence',
#        'fruit_breadth', 'thickest_root_diameter',
#        'root_dry_matter_content', 'root_fine_root_coarse_root_ratio',
#        'specific_root_area', 'root_distribution_coefficient', 'tap_root',
#        'leaf_hairs_juvenile', 'spinescence', 'resprouting_strength',
#        'flower_count_maximum', 'ca', 'cc', 'fluorescence_Jmax_over_Vcmax',
#        'fluorescence_Jmax_per_mass', 'fluorescence_Vcmax_per_mass',
#        'leaf_mesophyll_conductance_per_area',
#        'leaf_mesophyll_conductance_per_mass', 'fire_response_detailed',
#        'seed_storage_location', 'glaucous', 'modulus_of_elasticity_bark',
#        'modulus_of_elasticity_stem', 'modulus_of_elasticity_xylem',
#        'modulus_of_rupture', 'dormancy_type', 'fruit_wall_width',
#        'chlorophyll_per_dry_mass', 'flower_colour', 'leaf_arrangement',
#        'leaf_work_to_tear', 'stem_water_content_per_saturated_mass',
#        'wood_Ca_per_dry_mass', 'wood_K_per_dry_mass',
#        'wood_Mg_per_dry_mass', 'dead_wood_Ca_per_dry_mass',
#        'dead_wood_K_per_dry_mass', 'dead_wood_Mg_per_dry_mass',
#        'dead_wood_N_per_dry_mass', 'dead_wood_Na_per_dry_mass',
#        'dead_wood_P_per_dry_mass', 'wood_Na_per_dry_mass',
#        'photosynthetic_bark', 'support_fraction',
#        'chlorophyll_A_per_dry_mass', 'chlorophyll_B_per_dry_mass',
#        'epidermal_cell_density_both_sides', 'insoluable_protein_per_area',
#        'palisade_cell_length', 'palisade_layer_number', 'starch_per_area',
#        'leaf_xylem_delta15N', 'root_xylem_delta15N', 'leaf_K_per_area',
#        'specific_taproot_length', 'stem_count_categorical',
#        'sprout_depth', 'vein_angle_secondary', 'leaf_delta18O',
#        'carotenoid_per_dry_mass', 'cell_rubisco_concentration',
#        'cell_rubisco_N_per_total_N', 'cell_thylakoid_N_per_total_N',
#        'leaf_total_non-structural_carbohydrates_per_area',
#        'leaf_total_non-structural_carbohydrates_per_mass',
#        'cotyledon_function', 'cotyledon_position',
#        'establishment_light_environment_index',
#        'reproductive_light_environment_index',
#        'seedling_germination_location', 'seed_mass_reserve', 'twig_area',
#        'twig_length', 'vessel_density_leaves', 'vessel_diameter_leaves',
#        'inundation_tolerance', 'seed_release', 'snow_tolerance',
#        'water_logging_tolerance', 'calcicole_status', 'bark_morphology',
#        'pollination_system', 'seed_volume', 'cotyledon_type',
#        'embryo_colour', 'hypocotyl_type', 'seedling_first_leaf',
#        'seedling_first_node', 'bark_water_content_per_saturated_mass',
#        'carotenoid_per_area', 'chlorophyll_A_per_area',
#        'chlorophyll_B_per_area', 'leaf_absorption', 'leaf_transmission',
#        'bark_delta13C', 'bark_delta15N', 'vessel_wall_fraction',
#        'wood_tracheid_fraction'], dtype=object)

# %%
ss = (ATtraits['trait_name']=='resprouting_proportion_individuals' )
ATtraits[ss]
ss = (ATtraits['trait_name']=='fire_response' )
ATtraits[ss]
# Out:
#         dataset_id               taxon_name  \
# 15332   Baker_2019    Commersonia bartramia
# 15334   Baker_2019    Denhamia celastroides
# 15336   Baker_2019  Blechnum neohollandicum
# 15338   Baker_2019    Pittosporum undulatum
# 15340   Baker_2019   Polyscias sambucifolia
# ...            ...                      ...
# 959253  White_2020            Roepera ovata
# 959272  White_2020    Roepera prismatotheca
# 959291  White_2020          Roepera similis
# 959310  White_2020        Roepera ammophila
# 959328  White_2020          Zygophyllum sp.
#
#                                    site_name context_name   observation_id  \
# 15332   Bogangar -28.3303611_and_153.5519444          NaN    Baker_2019_01
# 15334   Bogangar -28.3303611_and_153.5519444          NaN    Baker_2019_02
# 15336   Bogangar -28.3303611_and_153.5519444          NaN    Baker_2019_03
# 15338   Bogangar -28.3303611_and_153.5519444          NaN    Baker_2019_04
# 15340   Main Arm -28.4936667_and_153.3923611          NaN    Baker_2019_05
# ...                                      ...          ...              ...
# 959253                                   NaN          NaN  White_2020_7923
# 959272                                   NaN          NaN  White_2020_7924
# 959291                                   NaN          NaN  White_2020_7925
# 959310                                   NaN          NaN  White_2020_7926
# 959328                                   NaN          NaN  White_2020_7927
#
#            trait_name        value unit date   value_type replicates  \
# 15332   fire_response    resprouts  NaN  NaN  expert_mean        NaN
# 15334   fire_response    resprouts  NaN  NaN  expert_mean        NaN
# 15336   fire_response    resprouts  NaN  NaN  expert_mean        NaN
# 15338   fire_response    resprouts  NaN  NaN  expert_mean        NaN
# 15340   fire_response    resprouts  NaN  NaN  expert_mean        NaN
# ...               ...          ...  ...  ...          ...        ...
# 959253  fire_response  fire_killed  NaN  NaN  expert_mean        NaN
# 959272  fire_response  fire_killed  NaN  NaN  expert_mean        NaN
# 959291  fire_response  fire_killed  NaN  NaN  expert_mean        NaN
# 959310  fire_response  fire_killed  NaN  NaN  expert_mean        NaN
# 959328  fire_response  fire_killed  NaN  NaN  expert_mean        NaN
#
#                           original_name
# 15332             Commersonia bartramia
# 15334             Denhamia celastroides
# 15336                     Doodia aspera
# 15338             Pittosporum undulatum
# 15340            Polyscias sambucifolia
# ...                                 ...
# 959253               Zygophyllum ovatum
# 959272       Zygophyllum prismatothecum
# 959291               Zygophyllum simile
# 959310  Zygophyllum sp. aff. ammophilum
# 959328                 Zygophyllum spp.
#
# [18344 rows x 12 columns]

# %%
ATtraits[ss]['value'].unique()
# Out:
# array(['resprouts', 'fire_killed', 'unknown', 'fire_killed resprouts',
#        'not_fire_killed_does_not_resprout', 'fire_not_relevant',
#        'fire_not_relevant resprouts',
#        'fire_not_relevant not_fire_killed_does_not_resprout',
#        'fire_killed fire_not_relevant'], dtype=object)

# %%
# ATtraits['trait_name'].unique()
ss = (ATtraits['trait_name']=='photosynthetic_pathway' )
ATtraits[ss]
# Out:
#              dataset_id            taxon_name  \
# 175021  Cunningham_1999      Acacia binervata
# 175037  Cunningham_1999   Acacia brachybotrya
# 175052  Cunningham_1999         Acacia rigens
# 175068  Cunningham_1999        Acacia stricta
# 175083  Cunningham_1999     Boronia ledifolia
# ...                 ...                   ...
# 969325    Williams_2011  Austrostipa muelleri
# 969334    Williams_2011        Deyeuxia minor
# 969360    Williams_2011   Aphanes australiana
# 969371    Williams_2011   Lomandra filiformis
# 969380    Williams_2011      Xyris operculata
#
#                               site_name       context_name  \
# 175021     Cunningham_Knights Hill_665m                NaN
# 175037        Cunningham_Nombinnie_160m                NaN
# 175052  Cunningham_Rankins-Springs_170m                NaN
# 175068           Cunningham_Narooma_25m                NaN
# 175083      Cunningham_KNP-Waratah_165m                NaN
# ...                                 ...                ...
# 969325                              NaN  grows in Adelaide
# 969334                              NaN  grows in Adelaide
# 969360                              NaN  grows in Adelaide
# 969371                              NaN  grows in Adelaide
# 969380                              NaN  grows in Adelaide
#
#             observation_id              trait_name value unit date  \
# 175021  Cunningham_1999_01  photosynthetic_pathway    c3  NaN  NaN
# 175037  Cunningham_1999_02  photosynthetic_pathway    c3  NaN  NaN
# 175052  Cunningham_1999_03  photosynthetic_pathway    c3  NaN  NaN
# 175068  Cunningham_1999_04  photosynthetic_pathway    c3  NaN  NaN
# 175083  Cunningham_1999_05  photosynthetic_pathway    c3  NaN  NaN
# ...                    ...                     ...   ...  ...  ...
# 969325   Williams_2011_947  photosynthetic_pathway    c4  NaN  NaN
# 969334   Williams_2011_948  photosynthetic_pathway    c4  NaN  NaN
# 969360   Williams_2011_951  photosynthetic_pathway    c3  NaN  NaN
# 969371   Williams_2011_952  photosynthetic_pathway    c3  NaN  NaN
# 969380   Williams_2011_953  photosynthetic_pathway    c3  NaN  NaN
#
#          value_type replicates         original_name
# 175021  expert_mean        NaN      Acacia binervata
# 175037  expert_mean        NaN   Acacia brachybotrya
# 175052  expert_mean        NaN         Acacia rigens
# 175068  expert_mean        NaN        Acacia stricta
# 175083  expert_mean        NaN     Boronia ledifolia
# ...             ...        ...                   ...
# 969325  expert_mean        NaN  Austrostipa muelleri
# 969334  expert_mean        NaN        Deyeuxia minor
# 969360  expert_mean        NaN   Aphanes australiana
# 969371  expert_mean        NaN   Lomandra filiformis
# 969380  expert_mean        NaN      Xyris operculata
#
# [13547 rows x 12 columns]

# %% [markdown]
# ### Dormancy type

# %%
ss = (ATtraits['trait_name']=='dormancy_type' )
ATtraits[ss]
# Out:
#        dataset_id              taxon_name                    site_name  \
# 479894   Ooi_2007        Acacia binervata                Fredericktown
# 481466   Ooi_2007        Angophora bakeri   Agnes Banks to Castlereagh
# 488008   Ooi_2007  Isopogon anemonifolius  Cordeaux Cataract Catchment
# 489445   Ooi_2007         Bulbine bulbosa                    Blacktown
# 489745   Ooi_2007      Calotis cuneifolia                      Ashford
#
#        context_name  observation_id     trait_name  \
# 479894          NaN  Ooi_2007_00001  dormancy_type
# 481466          NaN  Ooi_2007_01580  dormancy_type
# 488008          NaN  Ooi_2007_08122  dormancy_type
# 489445          NaN  Ooi_2007_09558  dormancy_type
# 489745          NaN  Ooi_2007_09858  dormancy_type
#
#                                      value unit        date   value_type  \
# 479894                   physical_dormancy  NaN  1978-11-21  expert_mean
# 481466                         non_dormant  NaN  1977-02-18  expert_mean
# 488008              physiological_dormancy  NaN  1975-08-12  expert_mean
# 489445        morphophysiological_dormancy  NaN  1974-12-04  expert_mean
# 489745  non_dormant physiological_dormancy  NaN  1978-11-25  expert_mean
#
#        replicates           original_name
# 479894        NaN        Acacia binervata
# 481466        NaN        Angophora bakeri
# 488008        NaN  Isopogon anemonifolius
# 489445        NaN         Bulbine bulbosa
# 489745        NaN      Calotis cuneifolia

# %% [markdown]
# ## Start XML file here

# %%
frdbCode='test'
frdbVersion='0.1'
frdbDate='2021-09-29'
sppname='Actinotus helianthi'


# write xml file
xml_dir = repodir / "xml"
if not os.path.isdir(xml_dir):
    os.makedirs(xml_dir)

file_name = xml_dir / sppname.replace(" ","_").replace(".","_").replace("/","_")
xml_file = file_name.with_suffix(".xml")

# %%
if os.path.isfile(xml_file):
    print('File exists')
else:
    root = ET.Element("SpeciesList")
    spp = ET.SubElement(root, "Species",code=frdbCode,version=frdbVersion,
                    update=frdbDate)
    ET.SubElement(spp, "Name").text = sppname
    ET.SubElement(spp, "Nomenclature")
    ET.SubElement(spp, "ImportedTraits")
    xmlstr = minidom.parseString(ET.tostring(root)).toprettyxml(indent=" ")
    with open(xml_file,"w") as f:
        f.write(xmlstr) #xmlstr.encode('utf-8')
# Out:
# File exists

# %%
tree = ET.parse(xml_file)
root = tree.getroot()

# %%
for spp in root.iter('Species'):
    impTraits = spp.find('ImportedTraits')

# %%
list(impTraits)
traitIds=[]
for trait in impTraits.iter('trait'):
    traitIds.append(trait.get('id'))
set(traitIds)
# Out:
# {'Falster_2005_2_05', 'NSWFRD_2014_0177'}

# %%
traits=('fire_response_juvenile','fire_response','fire_cued_seeding')
ss = (ATtraits['taxon_name']==sppname) & (ATtraits['trait_name'].isin(traits))
tgtTraits = ATtraits[ss]
tgtTraits
# Out:
#             dataset_id           taxon_name    site_name context_name  \
# 217795  Falster_2005_2  Actinotus helianthi  Myall_Lakes          NaN
# 454654     NSWFRD_2014  Actinotus helianthi          NaN          NaN
#
#            observation_id     trait_name        value unit     date  \
# 217795  Falster_2005_2_05  fire_response  fire_killed  NaN  2002-09
# 454654   NSWFRD_2014_0177  fire_response  fire_killed  NaN      NaN
#
#          value_type replicates        original_name
# 217795  expert_mean        NaN  Actinotus helianthi
# 454654  expert_mean        NaN  Actinotus helianthi

# %% [markdown]
# Function to add traits based on _austraits_ trait table:

# %%
def addTraitNode(node,record):
    item=ET.SubElement(node,'trait',source='AusTraits',version='???',id=record['observation_id'],
                       name_used=record['original_name'])
    ET.SubElement(item,'name').text=record['trait_name'] 
    if ~np.isnan(record['unit']):
        ET.SubElement(item,'value',type=record['value_type'],unit=record['unit']).text=record['value']
    else:
        ET.SubElement(item,'value',type=record['value_type']).text=record['value'] 
    if ~np.isnan(record['replicates']):
        print('replicates')
    ET.SubElement(item,'dataset').text=record['dataset_id']
    if (isinstance(record['site_name'],str)):
        if record['site_name'] != '':
            ET.SubElement(item,'site').text=record['site_name'] 
    if (isinstance(record['date'],str)):
        if record['date'] != '':
            ET.SubElement(item,'date').text=record['date']

# %%
for index, row in tgtTraits.iterrows():
    if row['observation_id'] in set(traitIds):
        print('skipping existing trait record')
    else:
        addTraitNode(impTraits,row)
# Out:
# skipping existing trait record
# skipping existing trait record

# %%
list(impTraits)
# Out:
# [<Element 'trait' at 0x119e27e20>, <Element 'trait' at 0x119e26890>]

# %%
xmlstr = minidom.parseString(ET.tostring(root)).toprettyxml(indent=" ")

# %%
with open(xml_file,"w") as f:
    f.write(xmlstr) #xmlstr.encode('utf-8')
