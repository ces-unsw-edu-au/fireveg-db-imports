# %% [markdown]
# # Read NSWFRD 2014
# Read the spreadsheet from NSW Flora Fire response database and extract hyperlinks that point to references.
# We will use the _openpyxl_ library in ***python***

# %%
import openpyxl
from pathlib import Path
import os

# %%
repodir = Path("../..") 
inputdir = repodir / "data/"

# %% [markdown]
# ## Open the workbook and read main spreadsheet
# Here we will load the workbook:

# %%
wb = openpyxl.load_workbook(inputdir / "NSWFFRDv2.1.xlsx")

# %% [markdown]
# List all worksheets:

# %%
for k in wb.worksheets:
    print(k)
# Out:
# <Worksheet "Read Me">
# <Worksheet "SpeciesData">
# <Worksheet "References">
# <Worksheet "Notes">
# <Worksheet "VA Groups">

# %%
ws = wb['Read Me']

# %%
ws
# Out:
# <Worksheet "Read Me">

# %% [markdown]
# Use the sheet name to read data

# %%
ws = wb['SpeciesData']

# %% [markdown]
# Let's look at all the values in the second column (Species code)

# %%
ws['B2'].value
# Out:
# 'Species Code'

# %% [markdown]
# We want to count the number of unique values:

# %%
row_count = ws.max_row
column_count = ws.max_column
j=2
unique_list = list()
unique_items = 0
for i in range(1, row_count + 1):
    item = ws.cell(row=i, column=j).value
    if item not in unique_list and item is not None:
        unique_list.append(item)
        unique_items += 1
print(unique_items)
# Out:
# 3000

# %% [markdown]
# Which columns include information on traits? this will print out the names in the second row...:

# %%
for j in range(1, column_count + 1):
    print(ws.cell(row=2, column=j).value)
# Out:
# Current Scientific Name
# Species Code
# Legal Status
# Exotic
# 2010 Update
# Notes on Name / Synonym as used in source reference
# Family
# Group
# Life form
# Fireresponse
# Comments on regeneration
# Resprout location
# Seed storage
# Seed dispersal mechanism
# Seed dispersal distance
# Seed weight / size
# Seed viability
# Dormancy
# Germination cue
# Fecundity
# Seed predation
# Post-fire recruitment
# Establishment
# Post-fire flowering
# Flowering time
# Primary juvenile period
# Secondary juvenile period
# Seed set
# Seed-bank developed
# Fire tolerance
# Life span
# Seed-bank longevity
# "Maturity" (from source)
# "Extinction" (from source)
# "Rec. min fire interval" (from source)
# "Rec. max fire interval" (from source)
# NC
# CC
# SC
# NT
# CT
# ST
# NWS
# CWS
# SWS
# NWP
# SWP
# NFWP
# SFWP
# Distribution: extra NSW
# Vegetation
# Rainforest
# Wet Sclerophyll Forest (Shrubby)
# Wet Sclerophyll Forest (Grassy)
# Grassy Woodland
# Grassland
# Dry Sclerophyll Forest (Shrub/Grass)
# Dry Sclerophyll Forest (Shrubby)
# Heathland
# Alpine Complex
# Freshwater Wetland
# Forested Wetlands
# Saline Wetland
# Semi-arid Woodland
# Arid & Semi-arid Shrubland
# NFRR data
# Additional fire response data
# Other data
# VA group
# Sensitivity: frequent
# Sensitivity: infrequent
# Minimum maturity
# Maximum maturity
# Lifespan > than
# Lifespan < than
# Lifespan + seed-bank
# VA Data
# Establishment Data
# Maturity Data
# Lifespan Data
# Lifespan 2 Data
# Seedbank Data
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
ws.cell(row=2, column=31).value
# Out:
# 'Life span'

# %% [markdown]
# ## Dealing with hyperlinks
#
# The cell Q6 has a hyperlink. We can use cell rows and columns or cell name:

# %%
type(ws.cell(row=6, column=17).hyperlink)
# same as 
type(ws['Q6'].hyperlink)
# Out:
# openpyxl.worksheet.hyperlink.Hyperlink

# %% [markdown]
# If the cell is a hyperlink it will have a value to "display" and will point to a "location" within the workbook:

# %%
ws.cell(row=6, column=17).hyperlink.display
# Out:
# 'viability average-very good'

# %%
# This will fail if there is no hyperlink 
print(ws.cell(row=6, column=17).hyperlink.location)
# Out:
# References!C94

# %% [markdown]
# Let's see the value of this reference:

# %%
hlink = ws.cell(row=6, column=17).hyperlink.location
hlink = hlink.split("!")

# %% [markdown]
# This gives the name of the target sheet and the corresponding cell. We need to read the cell to its right side (add one to the column number) to get the information we need.

# %%
ref = wb[hlink[0]]
print("Cell value is :: " + str(ref[hlink[1]].value))
nlink = ref.cell(row=ref[hlink[1]].row,column=ref[hlink[1]].col_idx + 1)

print("Reference data is :: " + nlink.value)
# Out:
# Cell value is :: 93
# Reference data is :: Mortlock, W. & Lloyd, MV (Eds) (2001) Floradata - A guide to collection, storage and propogation of Australian native plant seed. AUsttralian Centre for Mining Environmental Research, Brisbane; Australian National Botanic Gardens, CSIRO Forestry and Forest Products and Greening Australia Limited, Canberra. Searchable Database February 2001. a=survey data, b=test data

# %% [markdown]
# If there is no hyperlink, it will result in NoneType

# %%
type(ws.cell(row=5, column=17).hyperlink)
# Out:
# NoneType

# %%
type(ws.cell(row=5, column=17))
# Out:
# openpyxl.cell.cell.Cell

# %%
ws.cell(row=5, column=17)
# Out:
# <Cell 'SpeciesData'.Q5>

# %% [markdown]
# ## Read data from a column
# For a selected variable (column), we can query data for the list of species.

# %%
ws['Q6']
# Out:
# <Cell 'SpeciesData'.Q6>

# %%
ws.cell(row=2, column=31).value
# Out:
# 'Life span'

# %%
ws.cell(row=16, column=31).value

# %% [markdown]
# Example loop for querying values from one variable for all species in a range of cells:

# %%
i=3
j=31
varname=ws.cell(row=2, column=j).value
print(varname)
for i in range(13,40):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (spcode,spname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (spcode,spname,varvalue))
# Out:
# Life span
# 3710: Acacia baileyana / 20-30 / References!C2
# 3716: Acacia binervata / 20
# 3717: Acacia binervia / 50-100 / References!C2
# 8601: Acacia bulgaensis / c. 20-40
# 3747: Acacia constablei / short? / References!N16

# %% [markdown]
# ## Read data for a row
# We can now do the same for a single species (row) and query values of each variable in a range. For example:

# %%
# for j in 17
i=18
spname=ws.cell(row=i, column=1).value
spcode=ws.cell(row=i, column=2).value
print("%s: %s" %(spcode,spname))
    
for j in range(3,30):
    varname=ws.cell(row=2, column=j).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (j,varname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (j,varname,varvalue))
# Out:
# 3716: Acacia binervata
# 7: Family / Fabaceae: Mimosoideae
# 8: Group / D
# 9: Life form / T
# 10: Fireresponse / Sr
# 11: Comments on regeneration / Resprouting form in northern tablelands (134)
# 12: Resprout location / basal buds
# 13: Seed storage / persistent soil
# 14: Seed dispersal mechanism / a-ant / References!C56
# 18: Dormancy / hard seed coat
# 19: Germination cue / heat / References!C94
# 22: Post-fire recruitment / prolific / References!C106
# 23: Establishment / I / References!A94
# 25: Flowering time / Aug-Nov
# 26: Primary juvenile period / 5 / References!C36
# 27: Secondary juvenile period / References!C36 / References!C36
# 28: Seed set / 6 / References!C36
# 29: Seed-bank developed / 10 / References!C36

# %% [markdown]
# ## Search for a species code
# Here we try to locate the species code and then return the values for that row:

# %%
for cell in ws['A']:
    if(cell.value is not None): #We need to check that the cell is not empty.
        if 'Eryngium vesiculosum' in cell.value: #Check if the value of the cell contains the text 'Table'
            print('Found header with name: {} at row: {} and column: {}. In cell {}'.format(cell.value,cell.row,cell.column,cell))
# Out:
# Found header with name: Eryngium vesiculosum at row: 1123 and column: 1. In cell <Cell 'SpeciesData'.A1123>

# %%
# for j in 17
i=1123
spname=ws.cell(row=i, column=1).value
spcode=ws.cell(row=i, column=2).value
print("%s: %s" %(spcode,spname))
    
for j in range(3,50):
    varname=ws.cell(row=2, column=j).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if varref is not None:
            print("%s: %s / %s / %s" % (j,varname,varvalue, varref.location))
        else:
            print("%s: %s / %s " % (j,varname,varvalue))
# Out:
# 1117: Eryngium vesiculosum
# 7: Family / Apiaceae
# 8: Group / D
# 9: Life form / H
# 10: Fireresponse / R
# 25: Flowering time / Dec-Mar
# 27: Secondary juvenile period / <1 / References!C80
# 31: Life span / short / References!C2
# 37: NC / -
# 38: CC / -
# 39: SC / -
# 40: NT / 1
# 41: CT / 1
# 42: ST / 1
# 43: NWS / 1
# 44: CWS / -
# 45: SWS / 1
# 46: NWP / -
# 47: SWP / -
# 48: NFWP / -
# 49: SFWP / -

# %% [markdown]
# ## Populate the 'blue table'
# Select one column, translate the values to the accepted range and update entries into the table

# %%
from configparser import ConfigParser

filename = repodir / 'secrets' / 'database.ini'
section = 'aws-lght-sl'

# create a parser
parser = ConfigParser()
# read config file
parser.read(filename)

# get section, default to postgresql
db = {}
if parser.has_section(section):
    params = parser.items(section)
    for param in params:
        db[param[0]] = param[1]
else:
    raise Exception('Section {0} not found in the {1} file'.format(section, filename))

# %%
import psycopg2
params = db

# %%
from psycopg2.extras import DictCursor
conn = psycopg2.connect(**params)

#ON CONFLICT ON CONSTRAINT traits_ref_fkey DO NOTHING 
qry = "SELECT \"currentScientificNameCode\",\"currentScientificName\" from species.caps"
cur = conn.cursor(cursor_factory=DictCursor)
cur.execute(qry)
valid = cur.fetchall()
cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Database connection closed.

# %%
sppnames=pd.DataFrame(valid)

# %%
sppnames
# Out:
#            0                                       1
# 0       1826                     Lepidium oxytrichum
# 1       8683                 Eucalyptus williamsiana
# 2       4251                     Melaleuca glomerata
# 3       1094                     Actinotus helianthi
# 4       1104                        Apium prostratum
# ...      ...                                     ...
# 15727  15221                      Pterostylis crebra
# 15728  15222  Trachymene sp. NSW Northern Tablelands
# 15729  15223           Pittosporum sp. Coffs Harbour
# 15730  15224                      Adansonia gregorii
# 15731  15225                     Dodonaea crucifolia
#
# [15732 rows x 2 columns]

# %%
import pandas as pd
conn = psycopg2.connect(**params)
result_df = pd.read_sql_query(qry, conn)
if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# /Users/jferrer/miniconda3/envs/jptr/lib/python3.10/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Database connection closed.

# %%
result_df['speciesID']
# Out:
# 0         2358
# 1         2359
# 2         2360
# 3         2361
# 4         2362
#          ...
# 15727    24289
# 15728    24291
# 15729    24292
# 15730    24293
# 15731    24294
# Name: speciesID, Length: 15732, dtype: int64

# %%
2358 in result_df.speciesID.values
# Out:
# True

# %%
2358 in pd.DataFrame(valid)[0]
# Out:
# True

# %% [markdown]
# ### Survival traits

# %%
ws.cell(row=2, column=67).value
# Out:
# 'Additional fire response data'

# %%
ws = wb['SpeciesData']
va_groups = wb['VA Groups']
references = wb['References']

# %%
references.cell(row=1, column=20).value
# Out:
# 'NFRR Reference details'

# %%
NFRR_refs=references[2]
NFRR_refs
# Out:
# (<Cell 'References'.A2>,
#  <Cell 'References'.B2>,
#  <Cell 'References'.C2>,
#  <Cell 'References'.D2>,
#  <Cell 'References'.E2>,
#  <Cell 'References'.F2>,
#  <Cell 'References'.G2>,
#  <Cell 'References'.H2>,
#  <Cell 'References'.I2>,
#  <Cell 'References'.J2>,
#  <Cell 'References'.K2>,
#  <Cell 'References'.L2>,
#  <Cell 'References'.M2>,
#  <Cell 'References'.N2>,
#  <Cell 'References'.O2>,
#  <Cell 'References'.P2>,
#  <Cell 'References'.Q2>,
#  <Cell 'References'.R2>,
#  <Cell 'References'.S2>,
#  <Cell 'References'.T2>,
#  <Cell 'References'.U2>,
#  <Cell 'References'.V2>,
#  <Cell 'References'.W2>,
#  <Cell 'References'.X2>,
#  <Cell 'References'.Y2>,
#  <Cell 'References'.Z2>,
#  <Cell 'References'.AA2>,
#  <Cell 'References'.AB2>,
#  <Cell 'References'.AC2>,
#  <Cell 'References'.AD2>,
#  <Cell 'References'.AE2>,
#  <Cell 'References'.AF2>,
#  <Cell 'References'.AG2>,
#  <Cell 'References'.AH2>,
#  <Cell 'References'.AI2>,
#  <Cell 'References'.AJ2>,
#  <Cell 'References'.AK2>,
#  <Cell 'References'.AL2>,
#  <Cell 'References'.AM2>,
#  <Cell 'References'.AN2>,
#  <Cell 'References'.AO2>,
#  <Cell 'References'.AP2>,
#  <Cell 'References'.AQ2>,
#  <Cell 'References'.AR2>,
#  <Cell 'References'.AS2>,
#  <Cell 'References'.AT2>,
#  <Cell 'References'.AU2>,
#  <Cell 'References'.AV2>,
#  <Cell 'References'.AW2>,
#  <Cell 'References'.AX2>,
#  <Cell 'References'.AY2>,
#  <Cell 'References'.AZ2>,
#  <Cell 'References'.BA2>,
#  <Cell 'References'.BB2>,
#  <Cell 'References'.BC2>,
#  <Cell 'References'.BD2>,
#  <Cell 'References'.BE2>,
#  <Cell 'References'.BF2>,
#  <Cell 'References'.BG2>,
#  <Cell 'References'.BH2>,
#  <Cell 'References'.BI2>,
#  <Cell 'References'.BJ2>,
#  <Cell 'References'.BK2>,
#  <Cell 'References'.BL2>,
#  <Cell 'References'.BM2>,
#  <Cell 'References'.BN2>,
#  <Cell 'References'.BO2>)

# %%
from psycopg2.extensions import AsIs

# for i in 3:3088
# for j in 10
row_count = ws.max_row
row_min=3
row_max=row_count
i=3
j=10
varname=ws.cell(row=2, column=j).value
print(varname)

switcher={
    "S": "none",
    "Sr": "few",
    "S/R": "half",
    "Rs": "most",
    "R": "all"
}
row_min=3
row_max=10

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
cur = conn.cursor()


for i in range(row_min,row_max):
    record={"proximate_source":"NSWFFRD", "raw_value":[varname],"original_sources":list()}
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    
    NFRRdata=ws.cell(row=i, column=66).value
    
    AdditionalData=ws.cell(row=i, column=67).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        record["raw_value"].append(varvalue)
        transvalue=switcher.get(varvalue, "unknown")
        record["norm_value"]=transvalue
        if spcode is not None:
            record["species_code"]=spcode
        if spname is not None:
            record["species"]=spname
        if varref is not None:
            record["original_sources"].append(varref)
        if NFRRdata is not None:
            record["original_sources"].append('NFRR' % NFRRdata)
        if AdditionalData is not None:
            record["original_sources"].append(AdditionalData)
        if len(record["original_sources"])==0:
            record["original_sources"]=None

        print(record)
        
        insert_statement = 'insert into litrev.resprouting (%s) values %s ON CONFLICT DO NOTHING'
        #print(i)
        #print(cur.mogrify(insert_statement, (AsIs(','.join(record.keys())), tuple(record.values()))))
        cur.execute(insert_statement, (AsIs(','.join(record.keys())), tuple(record.values())))

conn.commit()
cur.close()
#print("total number of lines updated: %s" % totalupdates)

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Fireresponse
# Connecting to the PostgreSQL database...
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': ['8CN'], 'norm_value': 'none', 'species_code': '7184', 'species': 'Abutilon otocarpum'}
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': ['8BD', 'II-95b'], 'norm_value': 'none', 'species_code': '3632', 'species': 'Abutilon oxycarpum'}
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': ['8C'], 'norm_value': 'none', 'species_code': '3698', 'species': 'Acacia acanthoclada'}
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': ['8W 8WA', 'II-38d'], 'norm_value': 'none', 'species_code': '3699', 'species': 'Acacia acinacea'}
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': ['IId-38d; III-67'], 'norm_value': 'none', 'species_code': '3700', 'species': 'Acacia aculeatissima'}
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': ['II'], 'norm_value': 'none', 'species_code': '3701', 'species': 'Acacia adunca'}
# {'proximate_source': 'NSWFFRD', 'raw_value': ['Fireresponse', 'S'], 'original_sources': None, 'norm_value': 'none', 'species_code': '3702', 'species': 'Acacia alpina'}
# Database connection closed.

# %%
totalupdates=0
includedcodes=list()
excludedcodes=list()

#ON CONFLICT ON CONSTRAINT traits_ref_fkey DO NOTHING 
qrystr= "INSERT INTO litrev.resprouting(species,species_code,resprouting,proximate_source) values(%s,%s,%s) ON CONFLICT DO NOTHING"
for i in range(3,row_count):
    record={"proximate_source":"NSWFFRD", "raw value":(varname)}
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if spcode is not None:
            record["species_code"]=spcode
        
        if spname is not None:
            record["species"]=spname
        includedcodes.append(spcode)
            transvalue=switcher.get(varvalue, "unknown")
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = cur.rowcount
            if updated_rows > 0:
                totalupdates=totalupdates+1
# Out:
# Fireresponse
# Connecting to the PostgreSQL database...
# total number of lines updated: 3049
# Database connection closed.

# %%
print("%s excluded / %s included" % (len(set(excludedcodes)), len(set(includedcodes))))
# Out:
# 2998 excluded / 0 included

# %%
int(spcode)
# Out:
# 6354

# %%
j=12
varname=ws.cell(row=2, column=j).value
print(varname)


switcher={
    "epicormic": "epicormic",
    "stem buds": "epicormic",
    "apical": "apical",
    "lignotuber": "lignotuber", 
    "rootstock": "lignotuber", 
    "root stock": "lignotuber",
    "basal": "basal",
    "basal buds": "basal",
    "coppice": "basal",
    "tuber": "tuber",
    "taproot": "tuber",
    "tussock": "tussock",
    "rhizome": "short rhizome",
    "root sucker": "long rhizome or root sucker",
    "root suckers": "long rhizome or root sucker",
    "rootsucker": "long rhizome or root sucker",
    "root buds": "long rhizome or root sucker",
    "stolon": "stolon",
    "stolons": "stolon"
}
# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
cur = conn.cursor()

qrystr= "INSERT INTO litrev.survival_traits(species,species_code,regenerative_organ) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET regenerative_organ=EXCLUDED.regenerative_organ"
updated_rows=0
for i in range(3,row_count):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "other")
        if spcode.isnumeric():
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = updated_rows + cur.rowcount

print("Total of %s rows updated" % (updated_rows))
conn.commit()
cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Resprout location
# Connecting to the PostgreSQL database...
# Total of 1242 rows updated
# Database connection closed.

# %%
j=31
varname=ws.cell(row=2, column=j).value
print(varname)

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
cur = conn.cursor()

qrystr= "INSERT INTO litrev.survival_traits(species,species_code,standing_plant_longevity) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET standing_plant_longevity=EXCLUDED.standing_plant_longevity"
updated_rows=0
includedcodes=list()
excludedcodes=list()
for i in range(3,row_count):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        if spcode.isnumeric():
            if (isinstance(varvalue, str) and varvalue.isnumeric()) or isinstance(varvalue,int):
                #print("%s : %s (numeric)" % (spcode,varvalue))
                cur.execute(qrystr, (spname,int(spcode),int(varvalue)))
                updated_rows = updated_rows + cur.rowcount
                includedcodes.append(spcode)
            else:
                transvalue=varvalue.split("-")
                if len(transvalue)>1 and transvalue[1].isnumeric:
                    print("%s : %s (orig. string %s)" % (spcode,transvalue[1],varvalue))
                    try:
                        cur.execute(qrystr, (spname,int(spcode),int(transvalue[1])))
                        updated_rows = updated_rows + cur.rowcount
                        includedcodes.append(spcode)
                    except:
                        print("This did not work > %s : %s (orig. string %s)" % (spcode,transvalue[1],varvalue))
                        excludedcodes.append(spcode)                
                else:
                    print("%s : %s (string)" % (spcode,varvalue))
                    excludedcodes.append(spcode)

print("Total of %s rows updated" % (updated_rows))
print("%s excluded / %s included" % (len(set(excludedcodes)), len(set(includedcodes))))
conn.commit()
cur.close()

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Life span
# Connecting to the PostgreSQL database...
# 3632 : 10 (orig. string 4-10)
# 3710 : 30 (orig. string 20-30)
# 3717 : 100 (orig. string 50-100)
# 8601 : 40 (orig. string c. 20-40)
# 3747 : short? (string)
# 3762 : 30 (orig. string 15-30)
# 3768 : 50? (string)
# 3771 : 20 (orig. string 5-20)
# 3777 : 60 (orig. string 25-60)
# 3780 : 30 (orig. string c. 20-30)
# 3782 : long (string)
# 3790 : <10 (string)
# 3792 : <50? (string)
# 3797 : <15? (string)
# 9983 : 25 (orig. string c. 15-25)
# 3807 : >10 (string)
# 3814 : 15 (orig. string c.10-15)
# 10790 : 60 (orig. string 20-60)
# 10791 : 30 (orig. string 5-30)
# 3821 : c. 20 (string)
# 3822 : 4y (orig. string c.8; high attrition at 2-4y)
# This did not work > 3822 : 4y (orig. string c.8; high attrition at 2-4y)
# 3823 : 20 (84) / short (1) (string)
# 3824 : 100 (M) (orig. string 50 (1) / 90 (CT) / 50-100 (M))
# This did not work > 3824 : 100 (M) (orig. string 50 (1) / 90 (CT) / 50-100 (M))
# 3832 : 25 (orig. string 15-25)
# 3834 : 25 (1) / c. 30 (101) (orig. string 5-25 (1) / c. 30 (101))
# This did not work > 3834 : 25 (1) / c. 30 (101) (orig. string 5-25 (1) / c. 30 (101))
# 3844 : 30 (orig. string 20-30)
# 3846 : suckering may extend lifespan of individual (orig. string stems live up to 25y, root-suckering may extend lifespan of individual)
# This did not work > 3846 : suckering may extend lifespan of individual (orig. string stems live up to 25y, root-suckering may extend lifespan of individual)
# 3857 : 35 (orig. string c. 25-35)
# 3860 : 35 (71) / >50 (R21) (orig. string 50 (1) / c. 25-35 (71) / >50 (R21))
# This did not work > 3860 : 35 (71) / >50 (R21) (orig. string 50 (1) / c. 25-35 (71) / >50 (R21))
# 3869 : 60 (orig. string 25-60)
# 3873 : 30 (orig. string 5-30)
# 3881 : 25 y (28) / 5 (orig. string populations reduced after 10 y, max ls 20-25 y (28) / 5-25 (9) / 5-10, maximum 15-25 (1c) / absent or rare in 10 yo site (46) / plants uncommon (<5% cover) but still flowering at sites 15, 22, 25 years since fire (105))
# This did not work > 3881 : 25 y (28) / 5 (orig. string populations reduced after 10 y, max ls 20-25 y (28) / 5-25 (9) / 5-10, maximum 15-25 (1c) / absent or rare in 10 yo site (46) / plants uncommon (<5% cover) but still flowering at sites 15, 22, 25 years since fire (105))
# 3885 : 25 (9), plants still present and flowering at sites 22, 25 years post (orig. string 5-25 (9), plants still present and flowering at sites 22, 25 years post-fire (105))
# This did not work > 3885 : 25 (9), plants still present and flowering at sites 22, 25 years post (orig. string 5-25 (9), plants still present and flowering at sites 22, 25 years post-fire (105))
# 3893 : fire (105) (orig. string 25 (1), plants still present and flowering at sites 25 years post-fire (105))
# This did not work > 3893 : fire (105) (orig. string 25 (1), plants still present and flowering at sites 25 years post-fire (105))
# 5603 : long (string)
# 5604 : 10? (string)
# 5605 : 10? (string)
# 1090 : 15? (string)
# 3968 : 200 (orig. string 100-200)
# 2265 : medium (string)
# 12059 : 50? (string)
# 2581 : 100? (orig. string 20-100?)
# This did not work > 2581 : 100? (orig. string 20-100?)
# 2583 : <15? (37), common and flowering at sites 22 yo site (105) (string)
# 2675 : >50 (string)
# 1253 : annual (string)
# 1092 : annual (string)
# 1093 : annual (string)
# 1094 : 5 some plants up to 15 (1) / absent or rare in 10 yo heath (46), 5 (orig. string generally 4-5 some plants up to 15 (1) / absent or rare in 10 yo heath (46), 5-10 (9))
# This did not work > 1094 : 5 some plants up to 15 (1) / absent or rare in 10 yo heath (46), 5 (orig. string generally 4-5 some plants up to 15 (1) / absent or rare in 10 yo heath (46), 5-10 (9))
# 1095 : 60 (9), absent or rare in 10 yo heath (46), common at 15 and 22 yo sites (105) (orig. string 25-60 (9), absent or rare in 10 yo heath (46), common at 15 and 22 yo sites (105))
# This did not work > 1095 : 60 (9), absent or rare in 10 yo heath (46), common at 15 and 22 yo sites (105) (orig. string 25-60 (9), absent or rare in 10 yo heath (46), common at 15 and 22 yo sites (105))
# 7997 : indefinite (string)
# 7998 : indefinite (string)
# 8000 : indefinite (string)
# 7459 : long (string)
# 4726 : annual (string)
# 4729 : annual (string)
# 4731 : annual (string)
# 3371 : 3 (1) (orig. string 10? (58) / c. 2-3 (1))
# This did not work > 3371 : 3 (1) (orig. string 10? (58) / c. 2-3 (1))
# 8669 : >30 (string)
# 5875 : >30 (string)
# 2010 : 40 (1), 40 (orig. string 25-40 (1), 40-60 (9), still present and with fruit at 22 and 25 yo sites (105))
# This did not work > 2010 : 40 (1), 40 (orig. string 25-40 (1), 40-60 (9), still present and with fruit at 22 and 25 yo sites (105))
# 8320 : indefinite (string)
# 2012 : 60 (9), present at 20 (orig. string c. 70 (17) , 40-60 (9), present at 20-25 yo sites (105))
# This did not work > 2012 : 60 (9), present at 20 (orig. string c. 70 (17) , 40-60 (9), present at 20-25 yo sites (105))
# 2013 : >50 (string)
# 2014 : 100? (orig. string 50-100?)
# This did not work > 2014 : 100? (orig. string 50-100?)
# 2015 : 100 (orig. string 60-100)
# 2017 : 100? (orig. string 50-100?)
# This did not work > 2017 : 100? (orig. string 50-100?)
# 2018 : >90 (string)
# 8365 : 10? (string)
# 8364 : 25 (orig. string 5-25)
# 1775 : annual (string)
# 1165 : 30 (orig. string 5-30)
# 1259 : annual (string)
# 9713 : 25 yo sites (105) (orig. string indefinite (1), present and flowering at 20-25 yo sites (105))
# This did not work > 9713 : 25 yo sites (105) (orig. string indefinite (1), present and flowering at 20-25 yo sites (105))
# 7539 : >25 (string)
# 1268 : annual (string)
# 3969 : >100 (string)
# 3970 : >100 (string)
# 9012 : >100 (string)
# 9717 : >100 (string)
# 3971 : >100 (string)
# 3972 : 100 (1) / 100 (orig. string 50-100 (1) / 100-200 (9))
# This did not work > 3972 : 100 (1) / 100 (orig. string 50-100 (1) / 100-200 (9))
# 9619 : >200 (string)
# 3974 : >200 (string)
# 4749 : indefinite (string)
# 1269 : annual (string)
# 2770 : 60 (orig. string 25-60)
# 8221 : biennual (string)
# 5609 : annual (string)
# 2037 : annual (string)
# 11824 : biennial (string)
# 1273 : annual (string)
# 9721 : 4 (orig. string 3-4)
# 12689 : 10? (string)
# 7537 : annual (string)
# 4773 : present at 20 yo site (string)
# 4774 : 25 (orig. string 5-25)
# 5943 : short (string)
# 5657 : 5? (string)
# 5659 : 5? (string)
# 3524 : annual (string)
# 8031 : long (string)
# 8866 : indefinite (string)
# 9259 : 40? (orig. string 15-40?)
# This did not work > 9259 : 40? (orig. string 15-40?)
# 5730 : 50? (58) / >40 (80) (string)
# 1200 : indefinite? (string)
# 1202 : <10? (string)
# 1205 : indefinite (string)
# 3611 : 20? (string)
# 2050 : annual (string)
# 2078 : 30 (orig. string 20-30)
# 7840 : 5? (string)
# 8667 : <5 (string)
# 6594 : <5 (string)
# 3979 : 30 (orig. string 5-30)
# 3982 : 50? (orig. string 25-50?)
# This did not work > 3982 : 50? (orig. string 25-50?)
# 9960 : 10? (string)
# 10398 : common at 20 yo site (string)
# 10394 : >25 (string)
# 4780 : annual (string)
# 9817 : >10? (string)
# 3984 : >100 (string)
# 3986 : 60 (orig. string 25-60)
# 3994 : 50? (string)
# 3995 : 70 (orig. string 40-70)
# 3997 : 70 (orig. string 40-70)
# 4000 : common at 22 yo site (string)
# 10605 : 15? (string)
# 5339 : >100 (string)
# 8595 : 50? (orig. string 30-50?)
# This did not work > 8595 : 50? (orig. string 30-50?)
# 11049 : 50 (9) / 30 (orig. string 40-50 (9) / 30-50 (30))
# This did not work > 11049 : 50 (9) / 30 (orig. string 40-50 (9) / 30-50 (30))
# 6603 : 150? (1), present at 20 yo site (105) (orig. string >30 (96), 100-150? (1), present at 20 yo site (105))
# This did not work > 6603 : 150? (1), present at 20 yo site (105) (orig. string >30 (96), 100-150? (1), present at 20 yo site (105))
# 5344 : >50 (9) / parent plants die out about 25yo, leaving vigorous suckers (33) (string)
# 5345 : 80 (orig. string 40-80)
# 5346 : 80 (orig. string 40-80)
# 10872 : 50? (orig. string 30-50?)
# This did not work > 10872 : 50? (orig. string 30-50?)
# 5347 : 80 (orig. string 40-80)
# 5348 : >80 (29) / 75 (38) / 100 (1) (orig. string 70->80 (29) / 75 (38) / 100 (1))
# This did not work > 5348 : >80 (29) / 75 (38) / 100 (1) (orig. string 70->80 (29) / 75 (38) / 100 (1))
# 7488 : 100 (orig. string 50-100)
# 7495 : annual (string)
# 9188 : annual (string)
# 7219 : 60 (orig. string 25-60)
# 2294 : indefinite (string)
# 2296 : >30 (string)
# 2297 : indefinite (string)
# 2302 : indefinite (string)
# 2303 : indefinite (string)
# 1282 : c. 100 (string)
# 2691 : 20? (orig. string 10-20?)
# This did not work > 2691 : 20? (orig. string 10-20?)
# 2694 : c.50 (string)
# 1283 : annual (string)
# 1284 : annual (string)
# 1285 : annual (string)
# 4671 : 22 yo sites (orig. string present at 20-22 yo sites)
# This did not work > 4671 : 22 yo sites (orig. string present at 20-22 yo sites)
# 4671 : >30 (string)
# 3529 : 60 (orig. string 25-60)
# 8052 : 100? (R42) (orig. string indefinite (1) / 25-100? (R42))
# This did not work > 8052 : 100? (R42) (orig. string indefinite (1) / 25-100? (R42))
# 7760 : indefinite (string)
# 8058 : indefinite (string)
# 8063 : indefinite (string)
# 10752 : >25 (string)
# 5743 : estimated about 15 y (string)
# 5749 : 25 (orig. string 5-25)
# 2778 : indefinite (string)
# 2779 : 60? (string)
# 2780 : medium (1), absent or rare in 10 yo heath (46), common and flowering at 30 yo site (105) (orig. string short-medium (1), absent or rare in 10 yo heath (46), common and flowering at 30 yo site (105))
# This did not work > 2780 : medium (1), absent or rare in 10 yo heath (46), common and flowering at 30 yo site (105) (orig. string short-medium (1), absent or rare in 10 yo heath (46), common and flowering at 30 yo site (105))
# 2784 : indefinite (1), present at 20 yo site (105) (string)
# 2787 : long (orig. string medium-long)
# This did not work > 2787 : long (orig. string medium-long)
# 2789 : 25 (orig. string 5-25)
# 8144 : indefinite (string)
# 10689 : indefinite (string)
# 9295 : >20 (string)
# 7700 : indefinite (string)
# 6914 : annual (string)
# 6485 : 10? (string)
# 7562 : annual (string)
# 6542 : annual (string)
# 13832 : indefinite (string)
# 6861 : annual (string)
# 7317 : annual (string)
# 10409 : annual (string)
# 6567 : annual (string)
# 6559 : 10? (string)
# 7318 : 10? (string)
# 7357 : 10? (string)
# 7266 : 10? (string)
# 1790 : annual (string)
# 2695 : >20 (1), >30 (35), present at 20 yo site (105) (string)
# 4800 : annual (string)
# 4801 : annual (string)
# 4804 : annual (string)
# 4806 : annual (string)
# 4813 : annual (string)
# 4817 : annual (string)
# 1003 : indefinite (string)
# 1004 : 25 (orig. string 5-25)
# 3532 : annual (string)
# 7748 : annual (string)
# 3533 : 60 (9), present and flowering at 25 yo site (105) (orig. string 25-60 (9), present and flowering at 25 yo site (105))
# This did not work > 3533 : 60 (9), present and flowering at 25 yo site (105) (orig. string 25-60 (9), present and flowering at 25 yo site (105))
# 4368 : 4 (orig. string 2-4)
# 11018 : 60 (orig. string 25-60)
# 3534 : 5? (string)
# 3535 : 60 (orig. string 25-60)
# 1791 : annual (string)
# 9523 : long (string)
# 5309 : annual (string)
# 5312 : annual (string)
# 5314 : annual (string)
# 2269 : >100 (string)
# 10175 : annual (string)
# 2270 : >50 (string)
# 4004 : 80 (orig. string 40-80)
# 7943 : 50? (string)
# 4015 : >30 (35) / 50 (1) (string)
# 4016 : 80 (1) / 20? (71) (orig. string 50-80 (1) / 20? (71))
# This did not work > 4016 : 80 (1) / 20? (71) (orig. string 50-80 (1) / 20? (71))
# 2282 : 50? (orig. string 25-50?)
# This did not work > 2282 : 50? (orig. string 25-50?)
# 2285 : >40 (41) / 50? (1) (string)
# 1330 : >5 (string)
# 1331 : annual (string)
# 8341 : indefinite (string)
# 1342 : annual (string)
# 2215 : <5 (string)
# 1794 : annual (string)
# 7410 : annual (string)
# 1795 : annual (string)
# 1796 : 5 (1, 58) (orig. string annual / 1-5 (1, 58))
# This did not work > 1796 : 5 (1, 58) (orig. string annual / 1-5 (1, 58))
# 1355 : annual (string)
# 2310 : 10? (string)
# 2313 : 10? (string)
# 2315 : 10? (string)
# 2316 : 10? (string)
# 2317 : 10? (string)
# 2322 : 10? (string)
# 2324 : 10? (string)
# 2329 : 10? (string)
# 2339 : 10? (string)
# 1798 : annual (string)
# 1358 : annual (string)
# 1360 : 30 (101) / <30? (CT) (orig. string >36 (1) / 25-30 (101) / <30? (CT))
# This did not work > 1360 : 30 (101) / <30? (CT) (orig. string >36 (1) / 25-30 (101) / <30? (CT))
# 1362 : 20 (orig. string c.10-20)
# 1369 : <30? (string)
# 3467 : indefinite (9), present and flowering at 25 yo site (string)
# 3468 : 20? (string)
# 3469 : 30 (orig. string 5-30)
# 9006 : 100 (orig. string 50-100)
# 2022 : 200 (orig. string 100-200)
# 2341 : indefinite (string)
# 2342 : indefinite (string)
# 9315 : 60 (orig. string 25-60)
# 6794 : long (string)
# 10835 : 15? (string)
# 1382 : annual (string)
# 3131 : annual (string)
# 10339 : annual (string)
# 2040 : annual (string)
# 8807 : annual (string)
# 9348 : annual (string)
# 1960 : annual (string)
# 1388 : annual (string)
# 2272 : 100? (string)
# 9130 : annual (string)
# 8005 : indefinite (string)
# 6382 : 20? (orig. string 5-20?)
# This did not work > 6382 : 20? (orig. string 5-20?)
# 8007 : indefinite (string)
# 2084 : annual (string)
# 2089 : annual (string)
# 2093 : annual (string)
# 4833 : 3 (orig. string 2-3)
# 1391 : annual (string)
# 13528 : indefinite (string)
# 4022 : 100 (orig. string 25-100)
# 2344 : indefinite (string)
# 2345 : indefinite (string)
# 8188 : indefinite (string)
# 1395 : annual (string)
# 3472 : long (string)
# 1400 : annual (string)
# 6283 : 30 (orig. string 5-30)
# 2698 : >20 (string)
# 6903 : 20? (orig. string 10-20?)
# This did not work > 6903 : 20? (orig. string 10-20?)
# 3231 : short (string)
# 5252 : 25 (orig. string 5-25)
# 5255 : 60 (orig. string 25-60)
# 2209 : <5 (96), common at 22 yo site (105) (string)
# 9136 : 60 (orig. string 25-60)
# 5352 : 60 (orig. string 25-60)
# 5353 : 60 (orig. string 25-60)
# 1403 : annual (string)
# 1404 : annual (string)
# 10138 : annual (string)
# 1408 : annual (string)
# 10442 : annual (string)
# 6198 : 4? (orig. string 3-4?)
# This did not work > 6198 : 4? (orig. string 3-4?)
# 13836 : short? (string)
# 13966 : annual (string)
# 1800 : annual (string)
# 5772 : 30 (orig. string 5-30)
# 4408 : indefinite (string)
# 9743 : >100 (string)
# 9687 : 300 (orig. string 200-300)
# 9601 : >30 (string)
# 9692 : >100 (string)
# 1410 : annual (string)
# 1411 : indefinite (string)
# 1412 : annual (string)
# 9952 : 10? (string)
# 8565 : 10? (string)
# 8566 : 10? (string)
# 1421 : annual (string)
# 7745 : annual (string)
# 6820 : annual (string)
# 2242 : 3 (orig. string 1-3)
# 12520 : indefinite (string)
# 12020 : annual (string)
# 2706 : >30 (string)
# 5775 : absent or rare in 10 yo heath (string)
# 5554 : 20? (string)
# 5556 : 60 (1), common and flowering at 22 yo site (105) (orig. string 25-60 (1), common and flowering at 22 yo site (105))
# This did not work > 5556 : 60 (1), common and flowering at 22 yo site (105) (orig. string 25-60 (1), common and flowering at 22 yo site (105))
# 3479 : long (string)
# 3483 : long (string)
# 4417 : indefinite (string)
# 10668 : annual (string)
# 5884 : >30 (string)
# 2286 : annual (string)
# 2287 : annual (string)
# 8074 : 400 (orig. string 300-400)
# 2347 : indefinite (string)
# 4419 : present at 22 yo site (string)
# 1427 : long (string)
# 4845 : annual (string)
# 2348 : indefinite (string)
# 2353 : indefinite (string)
# 2364 : indefinite (string)
# 8483 : absent or rare in 10 yo heath (string)
# 2395 : annual (string)
# 11075 : >20 (string)
# 9338 : annual (string)
# 3174 : indefinite (string)
# 4024 : 10 (1, 13) / c. 15 (orig. string 5-10 (1, 13) / c. 15-20 (R34))
# This did not work > 4024 : 10 (1, 13) / c. 15 (orig. string 5-10 (1, 13) / c. 15-20 (R34))
# 4025 : 10 (1), present at 15 and 22 yo sites (105) (orig. string c. 5-10 (1), present at 15 and 22 yo sites (105))
# This did not work > 4025 : 10 (1), present at 15 and 22 yo sites (105) (orig. string c. 5-10 (1), present at 15 and 22 yo sites (105))
# 6508 : 60 (orig. string 25-60)
# 7135 : 25 (orig. string 5-25)
# 4029 : 60 (orig. string 25-60)
# 4032 : c. 30 (string)
# 10038 : 25 (orig. string 5-25)
# 1109 : annual (string)
# 10647 : indefinite (string)
# 2827 : medium (string)
# 2830 : 20? (string)
# 4880 : 5? (string)
# 4881 : 5 (orig. string 1-5)
# 10361 : 5? (string)
# 6940 : 5? (string)
# 3540 : 30 (orig. string 5-30)
# 6700 : common in 22 yo site (string)
# 8725 : >10 (R42), present at 22 yo site (105) (string)
# 4897 : 10? (58) / <5 (96) (string)
# 8748 : 5? (string)
# 9151 : annual (string)
# 2222 : 5? (58), common at 22 yo site (105) (string)
# 8082 : 500 (orig. string 100-500)
# 2843 : 30 (orig. string 5-30)
# 7225 : common at 20 yo site (string)
# 12383 : 25 (orig. string 5-25)
# 2851 : present at 22 yo site (string)
# 8734 : 25? (orig. string 20-25?)
# This did not work > 8734 : 25? (orig. string 20-25?)
# 2852 : c. 15 (string)
# 2853 : 30? (1) / 10 (orig. string 20-30? (1) / 10-15? (71))
# This did not work > 2853 : 30? (1) / 10 (orig. string 20-30? (1) / 10-15? (71))
# 11298 : 10? (string)
# 7887 : annual (string)
# 2854 : References!C10 (string)
# 5564 : long (R38) / 30 (R42) (string)
# 2103 : annual (string)
# 5911 : common in 25 yo site (string)
# 3913 : long (string)
# 1806 : short (string)
# 2589 : 25 (orig. string 5-25)
# 2556 : indefinite (string)
# 2557 : indefinite (string)
# 2558 : <1? (1) / ephemeral (56) (string)
# 2559 : 25 (9) / indefinite (1) (orig. string 5-25 (9) / indefinite (1))
# This did not work > 2559 : 25 (9) / indefinite (1) (orig. string 5-25 (9) / indefinite (1))
# 2560 : 25 (orig. string 5-25)
# 2561 : 25 (orig. string 5-25)
# 3676 : long (string)
# 2105 : annual (string)
# 7593 : 22 yo sites (orig. string present at 20-22 yo sites)
# This did not work > 7593 : 22 yo sites (orig. string present at 20-22 yo sites)
# 1751 : annual (string)
# 4938 : annual (string)
# 2571 : >100 (string)
# 2572 : >100 (string)
# 2574 : 22 yo sites (orig. string present in 20-22 yo sites)
# This did not work > 2574 : 22 yo sites (orig. string present in 20-22 yo sites)
# 12523 : >100 (string)
# 6988 : indefinite (string)
# 5532 : 15? (string)
# 3489 : long (string)
# 3495 : long (string)
# 6720 : annual (string)
# 4943 : annual (string)
# 4946 : 22 yo sites (orig. string present in 20-22 yo sites)
# This did not work > 4946 : 22 yo sites (orig. string present in 20-22 yo sites)
# 4947 : indefinite (string)
# 2591 : 50? (string)
# 10839 : 50? (string)
# 2595 : 50? (string)
# 10842 : 50? (string)
# 2596 : >15 (string)
# 2599 : 20 (1), present and flowering in 20, 22, 25 yo sites (105) (orig. string 5-20 (1), present and flowering in 20, 22, 25 yo sites (105))
# This did not work > 2599 : 20 (1), present and flowering in 20, 22, 25 yo sites (105) (orig. string 5-20 (1), present and flowering in 20, 22, 25 yo sites (105))
# 2602 : 20 (1) / 5 (orig. string 10-20 (1) / 5-25 (9))
# This did not work > 2602 : 20 (1) / 5 (orig. string 10-20 (1) / 5-25 (9))
# 2603 : 60 (9) (orig. string >60 (1) / 25-60 (9))
# This did not work > 2603 : 60 (9) (orig. string >60 (1) / 25-60 (9))
# 2605 : 20 (1), common in 22 yo site (105) (orig. string 10-20 (1), common in 22 yo site (105))
# This did not work > 2605 : 20 (1), common in 22 yo site (105) (orig. string 10-20 (1), common in 22 yo site (105))
# 7752 : 20 (orig. string 5-20)
# 2608 : 25 (orig. string 5-25)
# 4329 : 10? (string)
# 7578 : 22 yo sites (orig. string present in 20-22 yo sites)
# This did not work > 7578 : 22 yo sites (orig. string present in 20-22 yo sites)
# 1439 : annual (string)
# 4979 : indefinite (string)
# 11025 : 10? (string)
# 4460 : 15? (string)
# 3142 : annual (string)
# 1117 : short (string)
# 7027 : >100 (string)
# 4037 : >100 (string)
# 4038 : >100 (string)
# 9007 : >100 (string)
# 4043 : indefinite (string)
# 4047 : >100 (string)
# 7189 : >200 (string)
# 4055 : >250 (string)
# 4057 : >100 (string)
# 4058 : >100 (string)
# 4059 : >100 (string)
# 4061 : 200 (orig. string 100-200)
# 4062 : indefinite (string)
# 4067 : >100; may be disadvantaged by competion with absence of fire for 30 y (1) (string)
# 12178 : >100 (string)
# 4074 : >100 (string)
# 6473 : indefinite (string)
# 4075 : >100 (string)
# 4079 : 300 (orig. string 100-300)
# 4082 : >100 (string)
# 4086 : 60 (orig. string 40-60)
# 4087 : >100 (string)
# 4090 : >100 (string)
# 8354 : 250 (orig. string c. 200-250)
# 4091 : >100 (string)
# 4097 : >100 (string)
# 4104 : 300 (orig. string 200-300)
# 4112 : >100 (string)
# 10030 : >100 (string)
# 4117 : indefinite (string)
# 4118 : >100 (string)
# 4116 : indefinite (string)
# 4119 : >100 (string)
# 4120 : >100 (string)
# 4125 : >100 (string)
# 4126 : 250 (71) (orig. string >100 (1) / c. 200-250 (71))
# This did not work > 4126 : 250 (71) (orig. string >100 (1) / c. 200-250 (71))
# 4127 : >100 (string)
# 4128 : >100 (string)
# 4129 : >100 (string)
# 4130 : >100 (string)
# 4132 : >100 (string)
# 4133 : indefinite (string)
# 4140 : >100 (string)
# 4141 : >100 (string)
# 10029 : >100 (string)
# 4145 : 150 (orig. string 100-150)
# 8831 : >100 (string)
# 8959 : >100 (string)
# 4151 : 400 (orig. string 250-400)
# 4155 : >200 (string)
# 4156 : >100 (string)
# 4162 : >100 (string)
# 4163 : >100 (string)
# 4165 : >100 (string)
# 4167 : >100 (string)
# 4168 : >100 (string)
# 7338 : >100 (string)
# 9450 : >100 (string)
# 4171 : >200 (string)
# 4172 : >400 (string)
# 9750 : >100 (string)
# 4177 : >200 (string)
# 4178 : >100 (string)
# 4180 : >100 (string)
# 4181 : >100 (string)
# 4182 : >100 (string)
# 8353 : >100 (string)
# 4186 : >100 (string)
# 4187 : >100 (string)
# 4189 : indefinite (string)
# 4191 : >100 (string)
# 4196 : >100 (string)
# 4197 : >100 (string)
# 9691 : 10? (string)
# 9904 : annual/biennial (string)
# 13980 : annual (string)
# 9690 : annual (string)
# 2672 : >100 (string)
# 9899 : 30 (orig. string 5-30)
# 2721 : annual (string)
# 8332 : <10 (string)
# 5958 : 25 (orig. string 5-25)
# 9166 : 3 (orig. string 1-3)
# 7778 : 10? (string)
# 7019 : annual (string)
# 7734 : >30 (string)
# 10615 : indefinite (9) / absent or rare in 10 yo heath (46) (string)
# 6015 : present at 22 yo site (string)
# 5860 : present at 20 yo site (string)
# 4992 : 10? (string)
# 7479 : long? (string)
# 3924 : >100 (string)
# 8407 : long (string)
# 7396 : annual (string)
# 9367 : annual (string)
# 9649 : annual (string)
# 2442 : indefinite (9), present and flowering at 22 yo site (105) (string)
# 1450 : annual (string)
# 5681 : annual (string)
# 5685 : annual (string)
# 5687 : annual (string)
# 10142 : annual (string)
# 10143 : annual (string)
# 8337 : long, annual replacement of the tuber (string)
# 7631 : annual (string)
# 14547 : 10? (string)
# 3146 : 10? (string)
# 3148 : short (string)
# 7107 : 10? (string)
# 3154 : long (string)
# 3156 : short (string)
# 8226 : short (string)
# 7138 : indefinite (string)
# 6708 : indefinite (string)
# 8093 : indefinite (string)
# 9360 : >60 (string)
# 4466 : indefinite (string)
# 2864 : 25 (orig. string 5-25)
# 2865 : 25 (orig. string 5-25)
# 2866 : medium (string)
# 2867 : 25 (9), <25 (33), present at 20 yo site (105) (orig. string 15-25 (9), <25 (33), present at 20 yo site (105))
# This did not work > 2867 : 25 (9), <25 (33), present at 20 yo site (105) (orig. string 15-25 (9), <25 (33), present at 20 yo site (105))
# 3242 : short? (string)
# 3243 : <5 (string)
# 8649 : <5 (string)
# 3244 : 10? (string)
# 3246 : 20 (orig. string 5-20)
# 3247 : indefinite (string)
# 3248 : 20 (orig. string 5-20)
# 8711 : 60 (1, 9) / absent or rare in 10 yo heath (46) (orig. string 25-60 (1, 9) / absent or rare in 10 yo heath (46))
# This did not work > 8711 : 60 (1, 9) / absent or rare in 10 yo heath (46) (orig. string 25-60 (1, 9) / absent or rare in 10 yo heath (46))
# 8874 : 60 (orig. string 25-60)
# 7958 : 10? (string)
# 9168 : annual (string)
# 3192 : <30? (string)
# 7057 : short (string)
# 3193 : long (string)
# 2871 : 20 (orig. string 5-20)
# 10744 : 20 (orig. string 5-20)
# 10518 : indefinite (string)
# 6441 : 50? (string)
# 9956 : present and flowering at 30 yo site (105) (string)
# 8293 : 30 (orig. string 20-30)
# 8409 : 20 (orig. string 10-20)
# 5365 : 15y, estimated half (orig. string c. 20 (13) / senescence occurs from 12-15y, estimated half-life 8.6y (R4))
# This did not work > 5365 : 15y, estimated half (orig. string c. 20 (13) / senescence occurs from 12-15y, estimated half-life 8.6y (R4))
# 5378 : decades (string)
# 5381 : present and flowering at 30 yo site (105) (string)
# 5385 : medium? (orig. string short-medium?)
# This did not work > 5385 : medium? (orig. string short-medium?)
# 9626 : indefinite? (string)
# 5388 : indefinite (string)
# 5389 : 60 (orig. string 25-60)
# 10009 : 60 (orig. string 25-60)
# 5395 : probably >25 (string)
# 5399 : 25 (orig. string 5-25)
# 5401 : 40 (orig. string 20-40)
# 9482 : c. 30 (string)
# 2445 : indefinite (string)
# 9031 : annual (string)
# 6435 : 60 (orig. string 25-60)
# 3236 : absent or rare in 10 yo heath (string)
# 5000 : annual (string)
# 9114 : long (orig. string medium-long)
# This did not work > 9114 : long (orig. string medium-long)
# 5409 : 28? (orig. string 15-28?)
# This did not work > 5409 : 28? (orig. string 15-28?)
# 10802 : >100 (string)
# 5415 : 30? (orig. string 20-30?)
# This did not work > 5415 : 30? (orig. string 20-30?)
# 10804 : 80 (orig. string 40-80)
# 9602 : <20? (string)
# 5420 : 70? (string)
# 10806 : 30? (orig. string 20-30?)
# This did not work > 10806 : 30? (orig. string 20-30?)
# 5425 : 20; 23 (1), present with fruits at 20 (orig. string 15-20; 23 (1), present with fruits at 20-25 yo sites (105))
# This did not work > 5425 : 20; 23 (1), present with fruits at 20 (orig. string 15-20; 23 (1), present with fruits at 20-25 yo sites (105))
# 5427 : 60 (orig. string 25-60)
# 3252 : short? (string)
# 3253 : annual (string)
# 2873 : 30 (orig. string 5-30)
# 1811 : annual (string)
# 3914 : 50 (orig. string 20-50)
# 8913 : annual (string)
# 1502 : 10? (string)
# 1761 : annual (string)
# 7871 : indefinite (string)
# 3376 : 40 (orig. string 20-40)
# 9667 : annual (string)
# 3549 : 10? (string)
# 10554 : present at 22 yo site (string)
# 2531 : present & flowering at 20 yo site (string)
# 2532 : common at 22 yo site (string)
# 10863 : 60 (orig. string 25-60)
# 2536 : absent or rare in 10 yo heath (string)
# 9696 : >15 (string)
# 2545 : 80 (9) (orig. string >60 (1) / 40-80 (9))
# This did not work > 2545 : 80 (9) (orig. string >60 (1) / 40-80 (9))
# 2548 : 30 (orig. string 5-30)
# 2550 : 80 (orig. string 40-80)
# 3641 : 10 (orig. string 3-10)
# 8877 : 40 (orig. string 10-40)
# 3645 : 10 (orig. string 5-10)
# 7271 : indefinite (string)
# 11947 : 30 (orig. string 20-30)
# 9768 : 70? (string)
# 3649 : 20 (orig. string 5-20)
# 9412 : annual (string)
# 7959 : <5 (string)
# 1123 : <5 (string)
# 1124 : annual (string)
# 1128 : present in 10 yo site (string)
# 8107 : indefinite (string)
# 7240 : 25 (1, 9), present at 20 yo site (105) (orig. string 5-25 (1, 9), present at 20 yo site (105))
# This did not work > 7240 : 25 (1, 9), present at 20 yo site (105) (orig. string 5-25 (1, 9), present at 20 yo site (105))
# 2203 : 10? (string)
# 1540 : annual (string)
# 5533 : indefinite (9) / absent or rare in 10 yo heath (46) (string)
# 7749 : indefinite (string)
# 3553 : 60 (orig. string 25-60)
# 6803 : 22 yo sites (orig. string present at 20-22 yo sites)
# This did not work > 6803 : 22 yo sites (orig. string present at 20-22 yo sites)
# 1542 : annual (string)
# 2446 : 5? (string)
# 6471 : 5? (string)
# 2456 : 5? (string)
# 2458 : annual (string)
# 2463 : 5? (string)
# 5433 : 80 (9) (orig. string c. 50 (29) / 40-80 (9))
# This did not work > 5433 : 80 (9) (orig. string c. 50 (29) / 40-80 (9))
# 6839 : medium (1), common & flowering 30 yo site (105) (string)
# 5434 : medium (string)
# 7964 : indefinite (string)
# 3318 : annual (string)
# 3324 : annual (string)
# 3328 : 15? (string)
# 3333 : 15? (string)
# 3340 : 25 (orig. string 5-25)
# 2897 : 20? (orig. string 10-20?)
# This did not work > 2897 : 20? (orig. string 10-20?)
# 2898 : medium (1), common at 20 yo site (105) (orig. string short-medium (1), common at 20 yo site (105))
# This did not work > 2898 : medium (1), common at 20 yo site (105) (orig. string short-medium (1), common at 20 yo site (105))
# 4204 : 40 (1), common at 22 yo site (105) (orig. string 15-40 (1), common at 22 yo site (105))
# This did not work > 4204 : 40 (1), common at 22 yo site (105) (orig. string 15-40 (1), common at 22 yo site (105))
# 4207 : 80 (1, 9), absent or rare in 10 yo heath (46), common & flowering at 15 yo site (105) (orig. string 40-80 (1, 9), absent or rare in 10 yo heath (46), common & flowering at 15 yo site (105))
# This did not work > 4207 : 80 (1, 9), absent or rare in 10 yo heath (46), common & flowering at 15 yo site (105) (orig. string 40-80 (1, 9), absent or rare in 10 yo heath (46), common & flowering at 15 yo site (105))
# 4208 : >70 (string)
# 4209 : 50? (string)
# 11388 : annual (string)
# 11959 : common & flowering at 20 yo site (string)
# 5440 : 80 (orig. string 40-80)
# 6248 : 30 (orig. string 5-30)
# 8015 : indefinite (string)
# 8016 : indefinite (string)
# 3557 : <15? (string)
# 10734 : 70? (string)
# 10735 : long (string)
# 1822 : 15y (orig. string mean 4y, up to 10-15y)
# This did not work > 1822 : 15y (orig. string mean 4y, up to 10-15y)
# 1824 : annual (string)
# 1830 : 2 (orig. string 1-2)
# 8380 : indefinite (string)
# 6402 : indefinite (string)
# 2469 : indefinite (string)
# 2471 : indefinite (string)
# 11028 : indefinite (string)
# 8703 : 10? (string)
# 5865 : 60 (orig. string 25-60)
# 1554 : short (string)
# 11104 : annual (string)
# 1557 : 10? (string)
# 1559 : annual (string)
# 4213 : 80 (orig. string 40-80)
# 7970 : 80 (orig. string 40-80)
# 7766 : 80 (orig. string 40-80)
# 4221 : 80 (orig. string 40-80)
# 4222 : 50; 100 (orig. string 30-50; 100-150)
# This did not work > 4222 : 50; 100 (orig. string 30-50; 100-150)
# 4229 : 25 (orig. string 10-25)
# 4232 : 50? (orig. string 25-50?)
# This did not work > 4232 : 50? (orig. string 25-50?)
# 4233 : 80 (orig. string 40-80)
# 8197 : 80 (orig. string 40-80)
# 4239 : 60 (orig. string 25-60)
# 8317 : 40 (orig. string at least 25-40)
# 8486 : 80 (orig. string 40-80)
# 5535 : indefinite (string)
# 5541 : indefinite (string)
# 8924 : annual (string)
# 2610 : 30 (orig. string 20-30)
# 2616 : 40 (9), 5 (orig. string 20-40 (9), 5-20 (1), present & flowering at 30 yo site (105))
# This did not work > 2616 : 40 (9), 5 (orig. string 20-40 (9), 5-20 (1), present & flowering at 30 yo site (105))
# 2617 : 25 (orig. string 5-25)
# 2620 : 50? (string)
# 6425 : >25 (1), present at 22 yo site (105) (string)
# 2629 : 25 (orig. string 5-25)
# 7216 : 20 (1), present & fruiting at 25 yo site (105) (orig. string 5-20 (1), present & fruiting at 25 yo site (105))
# This did not work > 7216 : 20 (1), present & fruiting at 25 yo site (105) (orig. string 5-20 (1), present & fruiting at 25 yo site (105))
# 2630 : medium (string)
# 2632 : 100 (orig. string 20-100)
# 2638 : 25 (orig. string 5-25)
# 6152 : annual (string)
# 5972 : 10? (string)
# 5978 : annual (string)
# 8127 : indefinite (string)
# 6406 : indefinite (string)
# 6401 : indefinite (string)
# 3584 : annual (string)
# 10713 : long (string)
# 11108 : long (string)
# 14464 : annual (string)
# 7072 : not evident in long unburnt areas (string)
# 1917 : annual (string)
# 5032 : annual (string)
# 5033 : annual (string)
# 6296 : 15? (orig. string 10-15?)
# This did not work > 6296 : 15? (orig. string 10-15?)
# 6298 : indefinite (string)
# 6302 : indefinite (string)
# 6511 : indefinite (string)
# 7931 : indefinite (string)
# 6304 : indefinite (string)
# 6308 : 30 (95, 96) (orig. string 15? (58) / 5-30 (95, 96))
# This did not work > 6308 : 30 (95, 96) (orig. string 15? (58) / 5-30 (95, 96))
# 6312 : indefinite (string)
# 5443 : indefinite (string)
# 5444 : long? (string)
# 5445 : 80 (orig. string 40-80)
# 4242 : 200 (orig. string 100-200)
# 8567 : 10? (string)
# 3360 : 10? (string)
# 9293 : indefinite (string)
# 6409 : indefinite (string)
# 8133 : 5? (string)
# 3623 : annual (string)
# 3907 : annual (string)
# 3928 : >50 (string)
# 6327 : 120 (orig. string >60-120)
# 6335 : >60 (string)
# 2735 : >50 (string)
# 3657 : annual (string)
# 13837 : annual (string)
# 1231 : 50? (orig. string 10-50?)
# This did not work > 1231 : 50? (orig. string 10-50?)
# 1234 : <5 (string)
# 2035 : >30 (string)
# 2920 : annual (string)
# 2922 : annual (string)
# 2926 : annual (string)
# 11117 : 30 (1) / >30 (96) (orig. string 20-30 (1) / >30 (96))
# This did not work > 11117 : 30 (1) / >30 (96) (orig. string 20-30 (1) / >30 (96))
# 4248 : >100 (string)
# 4249 : >100 (string)
# 6391 : 100 (orig. string 50-100)
# 4252 : >20? (string)
# 4257 : 150 (orig. string 60-150)
# 4260 : >100 (string)
# 4262 : 60 (orig. string 25-60)
# 4263 : 80 (orig. string 40-80)
# 4266 : 80 (orig. string 40-80)
# 3680 : 100 (orig. string 70-100)
# 12061 : 60? (string)
# 2928 : annual (string)
# 10904 : annual (string)
# 1835 : annual (string)
# 3387 : indefinite (string)
# 1034 : annual (string)
# 2736 : indefinite (string)
# 7707 : 25 (9), preseent at 20 yo site (105) (orig. string 5-25 (9), preseent at 20 yo site (105))
# This did not work > 7707 : 25 (9), preseent at 20 yo site (105) (orig. string 5-25 (9), preseent at 20 yo site (105))
# 4272 : common & flowering at 22 yo site (string)
# 1566 : 15? (string)
# 11009 : indefinite (string)
# 10160 : annual (string)
# 1568 : annual (string)
# 2938 : 25 (1, 9), common at 20 (orig. string 5-25 (1, 9), common at 20-25 yo sites (105))
# This did not work > 2938 : 25 (1, 9), common at 20 (orig. string 5-25 (1, 9), common at 20-25 yo sites (105))
# 7736 : 25 (orig. string 5-25)
# 3592 : 25 (orig. string 5-25)
# 3595 : 25 (1, 9), absent or rare in 10 yo heath (46), present at 22 yo site (105) (orig. string 5-25 (1, 9), absent or rare in 10 yo heath (46), present at 22 yo site (105))
# This did not work > 3595 : 25 (1, 9), absent or rare in 10 yo heath (46), present at 22 yo site (105) (orig. string 5-25 (1, 9), absent or rare in 10 yo heath (46), present at 22 yo site (105))
# 2738 : 25 (orig. string 5-25)
# 2647 : >100 (string)
# 2649 : long (1), present at 22 yo site (105) (orig. string medium-long (1), present at 22 yo site (105))
# This did not work > 2649 : long (1), present at 22 yo site (105) (orig. string medium-long (1), present at 22 yo site (105))
# 7906 : 80 (orig. string 20-80)
# 8218 : 30 (orig. string c.10-30)
# 3954 : 30 (orig. string 5-30)
# 1765 : annual (string)
# 1576 : annual (string)
# 3264 : indefinite (string)
# 11953 : indefinite (string)
# 9607 : >20 (string)
# 8731 : 10? (string)
# 5695 : 10? (string)
# 6046 : annual (string)
# 6423 : >30 (96), present at 22 yo site (105) (string)
# 1578 : 50? (string)
# 1580 : 300 (15) / c. 100 (101) (orig. string 50-300 (15) / c. 100 (101))
# This did not work > 1580 : 300 (15) / c. 100 (101) (orig. string 50-300 (15) / c. 100 (101))
# 1582 : 30 (orig. string 5-30)
# 1587 : 20? (orig. string 15-20?)
# This did not work > 1587 : 20? (orig. string 15-20?)
# 1591 : 50? (string)
# 1592 : 3 (orig. string 2-3)
# 1595 : short (string)
# 1611 : short (string)
# 1771 : annual (string)
# 1620 : annual (string)
# 5697 : 22 yo sites (105) (orig. string <5 (96), absent or rare in 10 yo heath (46), present at 20-22 yo sites (105))
# This did not work > 5697 : 22 yo sites (105) (orig. string <5 (96), absent or rare in 10 yo heath (46), present at 20-22 yo sites (105))
# 5701 : 25 (orig. string 5-25)
# 2478 : 10? (string)
# 1135 : 10? (string)
# 1137 : 10? (string)
# 1138 : 10? (string)
# 5449 : 70? (string)
# 4476 : indefinite (string)
# 1140 : 10? (string)
# 3682 : >200 (string)
# 2950 : 50? (string)
# 10157 : 50? (string)
# 10156 : 50? (58) / still present in 51 yo site (61) (string)
# 9968 : 50? (string)
# 1836 : annual (string)
# 9349 : >30 (string)
# 10485 : 100? (orig. string 50-100?)
# This did not work > 10485 : 100? (orig. string 50-100?)
# 5066 : 25 yo sites (orig. string present & flowering at 20-25 yo sites)
# This did not work > 5066 : 25 yo sites (orig. string present & flowering at 20-25 yo sites)
# 4635 : annual (string)
# 4638 : annual (string)
# 5992 : annual (string)
# 5993 : annual (string)
# 6231 : annual (string)
# 8886 : short (a few years) (string)
# 3301 : indefinite (string)
# 3303 : indefinite (string)
# 3157 : <5 (string)
# 3160 : 10? (string)
# 3161 : short (string)
# 8444 : indefinite (string)
# 5101 : annual (string)
# 5102 : annual (string)
# 7568 : 3 (orig. string 1-3)
# 5282 : 2 (1) (orig. string annual / 1-2 (1))
# This did not work > 5282 : 2 (1) (orig. string annual / 1-2 (1))
# 5286 : indefinite (string)
# 5460 : 60 (orig. string 25-60)
# 9823 : 100 (orig. string 50-100)
# 5462 : 80 (orig. string 40-80)
# 8990 : present at 22 yo site (string)
# 9005 : 30 yo site (orig. string present at 20-30 yo site)
# This did not work > 9005 : 30 yo site (orig. string present at 20-30 yo site)
# 8995 : 30 (orig. string 10-30)
# 5469 : 60 (orig. string 25-60)
# 9048 : References!C72 (string)
# 5479 : 60 (orig. string 25-60)
# 5480 : 30 yo sites (orig. string present & fruiting at 22-30 yo sites)
# This did not work > 5480 : 30 yo sites (orig. string present & fruiting at 22-30 yo sites)
# 7584 : annual (string)
# 1976 : annual (string)
# 5826 : 40 (9) / 70? (58) / 30 (orig. string 20-40 (9) / 70? (58) / 30-47 (80))
# This did not work > 5826 : 40 (9) / 70? (58) / 30 (orig. string 20-40 (9) / 70? (58) / 30-47 (80))
# 10577 : 40 (9) / absent or rare in 10 yo heath (46) (orig. string 20-40 (9) / absent or rare in 10 yo heath (46))
# This did not work > 10577 : 40 (9) / absent or rare in 10 yo heath (46) (orig. string 20-40 (9) / absent or rare in 10 yo heath (46))
# 10586 : 25 (orig. string 5-25)
# 10594 : 25 (orig. string 5-25)
# 10596 : 40 (9), common & flowering at 25 yo site (105) (orig. string 20-40 (9), common & flowering at 25 yo site (105))
# This did not work > 10596 : 40 (9), common & flowering at 25 yo site (105) (orig. string 20-40 (9), common & flowering at 25 yo site (105))
# 5113 : indefinite (string)
# 2746 : 8 (orig. string 3-8)
# 2748 : annual (string)
# 6822 : annual (string)
# 6676 : indefinite (string)
# 2957 : indefinite (string)
# 2958 : present & fruiting at 30 yo site (string)
# 2959 : indefinite (string)
# 6058 : short (string)
# 10183 : biennial (string)
# 6170 : 50? (string)
# 6176 : long (string)
# 6179 : 25y) (orig. string absent in older sites (20-25y))
# This did not work > 6179 : 25y) (orig. string absent in older sites (20-25y))
# 6182 : 12 (P) / absent or rare in 10 yo sites (46), 5 (orig. string 10-12 (P) / absent or rare in 10 yo sites (46), 5-25 (9))
# This did not work > 6182 : 12 (P) / absent or rare in 10 yo sites (46), 5 (orig. string 10-12 (P) / absent or rare in 10 yo sites (46), 5-25 (9))
# 6814 : 22 yo sites (orig. string present & flowering at 20-22 yo sites)
# This did not work > 6814 : 22 yo sites (orig. string present & flowering at 20-22 yo sites)
# 6194 : annual (string)
# 4683 : >30 (string)
# 4685 : 40 (orig. string 30-40)
# 1773 : annual (string)
# 4686 : 10? (string)
# 4690 : annual (string)
# 4691 : annual (string)
# 4692 : <5? (string)
# 4693 : 10? (string)
# 4694 : long (string)
# 4704 : annual (string)
# 8159 : indefinite (string)
# 1142 : 10? (orig. string 5-10?)
# This did not work > 1142 : 10? (orig. string 5-10?)
# 1143 : short? (1), present at 22 yo site (105) (string)
# 1144 : c. 25 (string)
# 1145 : 40; maybe indefinite with suckering (1), common & flowering at 20 (orig. string 10-40; maybe indefinite with suckering (1), common & flowering at 20-25 yo sites (105))
# This did not work > 1145 : 40; maybe indefinite with suckering (1), common & flowering at 20 (orig. string 10-40; maybe indefinite with suckering (1), common & flowering at 20-25 yo sites (105))
# 1146 : <10 (string)
# 3397 : 5 (orig. string 2-5)
# 5117 : indefinite (string)
# 5119 : indefinite (string)
# 5121 : annual (string)
# 5126 : 10? (string)
# 5128 : 10? (string)
# 5131 : 10? (string)
# 5136 : 10? (string)
# 11143 : <5 (string)
# 5248 : indefinite (string)
# 1630 : annual (string)
# 1631 : annual (string)
# 1633 : annual (string)
# 1637 : 15? (string)
# 10706 : 50? (string)
# 9912 : long (orig. string medium-long)
# This did not work > 9912 : long (orig. string medium-long)
# 1639 : annual (string)
# 11144 : annual (string)
# 9668 : annual (string)
# 1979 : annual (string)
# 3227 : >50 (string)
# 5145 : annual (string)
# 1211 : indefinite (1) / <30? (CT) (string)
# 5568 : 25 (orig. string 10-25)
# 5571 : 25 (1); c. 100 (101) (orig. string 10-25 (1); c. 100 (101))
# This did not work > 5571 : 25 (1); c. 100 (101) (orig. string 10-25 (1); c. 100 (101))
# 9865 : 25 (orig. string 10-25)
# 5573 : 25 (orig. string 10-25)
# 5576 : 25 (orig. string 10-25)
# 5577 : 25 (1), common at 20 yo site (105) (orig. string 10-25 (1), common at 20 yo site (105))
# This did not work > 5577 : 25 (1), common at 20 yo site (105) (orig. string 10-25 (1), common at 20 yo site (105))
# 5578 : 25 (orig. string 10-25)
# 5579 : 25 (orig. string 10-25)
# 7979 : 25 (orig. string 10-25)
# 5581 : 25 (orig. string 10-25)
# 5582 : 25 (orig. string 10-25)
# 5589 : 25 (orig. string 10-25)
# 5590 : >10 (string)
# 5593 : 25 (orig. string 10-25)
# 5703 : medium (1), present at 22 yo site (105) (orig. string short-medium (1), present at 22 yo site (105))
# This did not work > 5703 : medium (1), present at 22 yo site (105) (orig. string short-medium (1), present at 22 yo site (105))
# 2753 : <20 (string)
# 7395 : annual (string)
# 5324 : 2 (1) (orig. string annual / 1-2 (1))
# This did not work > 5324 : 2 (1) (orig. string annual / 1-2 (1))
# 11955 : indefinite (string)
# 4491 : 60 (orig. string 25-60)
# 4494 : 60 (orig. string 25-60)
# 10935 : 15? (string)
# 4525 : 15? (string)
# 7980 : indefinite (string)
# 1925 : indefinite (string)
# 1926 : indefinite (string)
# 3403 : 50 (80) / >13 (R42) (orig. string 70? (58) / >30-50 (80) / >13 (R42))
# This did not work > 3403 : 50 (80) / >13 (R42) (orig. string 70? (58) / >30-50 (80) / >13 (R42))
# 9884 : indefinite (string)
# 3417 : 60 (orig. string 25-60)
# 3430 : 25? (string)
# 3436 : <10? (string)
# 2756 : 60 (orig. string 25-60)
# 1010 : indefinite (string)
# 7780 : annual (string)
# 13524 : 10? (string)
# 6403 : indefinite (string)
# 8175 : 5 (orig. string probably 2-5)
# 8177 : indefinite (string)
# 4566 : 60 (orig. string 25-60)
# 8956 : indefinite (string)
# 2974 : 25 (orig. string 5-25)
# 2977 : 30 (orig. string 20-30)
# 2985 : 15 (1, 9), c. 30 (101), present at 20 (orig. string 5-15 (1, 9), c. 30 (101), present at 20-30 yo sites (105))
# This did not work > 2985 : 15 (1, 9), c. 30 (101), present at 20 (orig. string 5-15 (1, 9), c. 30 (101), present at 20-30 yo sites (105))
# 2987 : 80 (orig. string 40-80)
# 3007 : medium (string)
# 3014 : 10 (orig. string 5-10)
# 3015 : 40 (orig. string 20-40)
# 11386 : 80 (orig. string 40-80)
# 8912 : annual (string)
# 10853 : annual (string)
# 8163 : indefinite (string)
# 3228 : long (string)
# 5505 : 15? (string)
# 5506 : 15? (string)
# 5509 : 15? (string)
# 5517 : 15? (string)
# 5520 : annual (string)
# 5525 : annual (string)
# 1641 : annual (string)
# 7808 : 30 (orig. string 5-30)
# 8563 : 15? (58) <5? (1) (string)
# 8919 : annual (string)
# 9383 : annual (string)
# 8921 : annual (string)
# 9384 : annual (string)
# 8922 : annual (string)
# 9421 : annual (string)
# 2651 : 50? (string)
# 2759 : 30 (orig. string 5-30)
# 1842 : short (string)
# 11236 : 30 (orig. string 5-30)
# 5642 : indefinite (string)
# 6146 : 10 (orig. string 5-10)
# 5296 : 5 (orig. string 1-5)
# 10638 : 5? (string)
# 14316 : 5? (string)
# 14322 : >25 (string)
# 1980 : annual (string)
# 7923 : annual (string)
# 13751 : 20? (orig. string 15-20?)
# This did not work > 13751 : 20? (orig. string 15-20?)
# 6384 : >50 (string)
# 3688 : <5 (string)
# 3205 : 10? (string)
# 3208 : 30 yo sites (orig. string present at 22-30 yo sites)
# This did not work > 3208 : 30 yo sites (orig. string present at 22-30 yo sites)
# 5156 : annual (string)
# 5157 : annual (string)
# 8181 : indefinite (string)
# 8182 : indefinite (string)
# 2275 : long (string)
# 2491 : annual (string)
# 2492 : indefinite (string)
# 2494 : 10? (string)
# 2495 : indefinite (string)
# 2496 : indefinite (string)
# 2498 : annual (string)
# 9057 : indefinite (string)
# 2499 : indefinite (string)
# 2501 : indefinite (string)
# 2504 : annual / indefinite (9) (string)
# 2507 : indefinite (string)
# 2508 : indefinite (string)
# 1985 : 10? (string)
# 1987 : annual (string)
# 1989 : 10? (string)
# 2165 : annual (string)
# 3137 : annual (string)
# 5159 : annual (string)
# 8185 : annual (string)
# 8187 : indefinite (string)
# 1654 : annual (string)
# 7914 : short (string)
# 7097 : relatively long (string)
# 1660 : annual (string)
# 1661 : epemeral (string)
# 1663 : 15? (string)
# 1664 : annual (string)
# 1664 : 25 (orig. string 5-25)
# 1666 : <5 (string)
# 1667 : <5 (string)
# 6465 : annual (string)
# 1671 : annual (string)
# 11164 : annual (string)
# 14039 : 15? (string)
# 1674 : annual (string)
# 1675 : annual (string)
# 8589 : <2 (string)
# 11237 : 4? (orig. string 2-4?)
# This did not work > 11237 : 4? (orig. string 2-4?)
# 1681 : annual (string)
# 8772 : 20 (orig. string 5-20)
# 2261 : 5 (1) (orig. string annual / 1-5 (1))
# This did not work > 2261 : 5 (1) (orig. string annual / 1-5 (1))
# 8789 : <5 (string)
# 7020 : annual (string)
# 1853 : annual (string)
# 1855 : annual (string)
# 7592 : 30 (orig. string 5-30)
# 6069 : short (string)
# 6073 : annual (string)
# 6091 : annual (string)
# 6095 : annual (string)
# 6100 : annual (string)
# 6102 : annual (string)
# 6109 : 30 (orig. string 5-30)
# 6115 : short (string)
# 7454 : long (string)
# 7398 : 15? (string)
# 6513 : annual (string)
# 3567 : indefinite (string)
# 6254 : >10 (string)
# 1996 : annual (string)
# 2000 : annual (string)
# 2001 : annual (string)
# 7519 : annual (string)
# 3033 : 25 (orig. string 5-25)
# 10603 : indefinite (string)
# 5177 : annual (string)
# 2654 : 25 (orig. string 5-25)
# 3450 : annual (string)
# 6122 : 40 (orig. string 20-40)
# 6123 : 10? (string)
# 2003 : annual (string)
# 2004 : <5 (CT) / indefinite (1) (string)
# 2006 : annual (string)
# 2007 : annual (string)
# 2008 : 10? (string)
# 1857 : annual (string)
# 1859 : annual (string)
# 1860 : annual (string)
# 7035 : indefinite (string)
# 3931 : >75 (string)
# 1693 : annual (string)
# 6157 : 22 yo sites (105) (orig. string 10? (58), present at 20-22 yo sites (105))
# This did not work > 6157 : 22 yo sites (105) (orig. string 10? (58), present at 20-22 yo sites (105))
# 6159 : 60 (orig. string 25-60)
# 2659 : >20 (string)
# 2661 : 25 (orig. string 5-25)
# 3056 : >20 (string)
# 5484 : 25 (orig. string 5-25)
# 5485 : 25 (orig. string 5-25)
# 10748 : 500 (orig. string >100-500)
# 11178 : long (string)
# 4293 : 200 (orig. string 75-200)
# 1695 : annual (string)
# 5488 : long (string)
# 11185 : <5 (string)
# 2516 : indefinite (string)
# 7993 : indefinite (string)
# 6204 : 60 (orig. string 25-60)
# 6205 : 10? (orig. string 6-10?)
# This did not work > 6205 : 10? (orig. string 6-10?)
# 6214 : 60 (orig. string 25-60)
# 7664 : indefinite (string)
# 6461 : indefinite (9) / absent or rare in 10 yo heath (46) (string)
# 7393 : 15? (string)
# 7770 : c. 15 (string)
# 5871 : short (string)
# 1864 : annual (string)
# 3572 : 60 (orig. string 25-60)
# 9628 : indefinite (string)
# 8168 : indefinite (string)
# 8169 : limited (string)
# 8151 : indefinite (string)
# 8839 : 200 (orig. string 100-200)
# 7794 : annual (string)
# 1151 : annual (string)
# 6999 : 15? (string)
# 5224 : annual (string)
# 7680 : annual (string)
# 1774 : 3 (orig. string 2-3)
# 3577 : 60 (orig. string 25-60)
# 2518 : indefinite (string)
# 3073 : annual (string)
# 3074 : annual (string)
# 3091 : annual (string)
# 3092 : annual (string)
# 9618 : common and fruiting at 15 yo site  (string)
# 5229 : annual (string)
# 8925 : annual (string)
# 5231 : annual (string)
# 5233 : 10? (string)
# 4295 : 75 (orig. string 25-75)
# 4297 : >100 (string)
# 6200 : annual (string)
# 2663 : >10 (string)
# 7774 : annual (string)
# 6237 : <5 (string)
# 6238 : annual (string)
# 3507 : indefinite (string)
# 3508 : indefinite (string)
# 3212 : annual (string)
# 3214 : <5 (string)
# 3215 : 10? (string)
# 3216 : annual (string)
# 3218 : <5 (string)
# 3219 : 60 (orig. string 25-60)
# 9254 : 5 (orig. string 1-5)
# 13395 : 10? (string)
# 3692 : indefinite (string)
# 3105 : 25 (orig. string 5-25)
# 6270 : 15? (string)
# 6272 : 15? (58) / <5 (96) (string)
# 11190 : 60 (orig. string 25-60)
# 1711 : annual (string)
# 1715 : annual (string)
# 1717 : annual (string)
# 5239 : annual (string)
# 5242 : annual (string)
# 1928 : 15? (string)
# 1932 : 15? (string)
# 1933 : annual (string)
# 1937 : 15? (string)
# 1721 : annual (string)
# 1722 : annual (string)
# 7832 : long (string)
# 3918 : long (string)
# 2664 : 20 (1) / absent or rare in 10 yo heath (46) / present in 13 yo site (1) (orig. string 10-20 (1) / absent or rare in 10 yo heath (46) / present in 13 yo site (1))
# This did not work > 2664 : 20 (1) / absent or rare in 10 yo heath (46) / present in 13 yo site (1) (orig. string 10-20 (1) / absent or rare in 10 yo heath (46) / present in 13 yo site (1))
# 7452 : annual (string)
# 6316 : >50 (33) / 300 (38) (string)
# 6321 : 250 (orig. string 80-250)
# 1161 : 25 (orig. string 5-25)
# 1162 : 25 (orig. string 5-25)
# 1163 : 25 (9) (orig. string <20 (1) / 5-25 (9))
# This did not work > 1163 : 25 (9) (orig. string <20 (1) / 5-25 (9))
# 11377 : short (usually annual) (string)
# 11379 : annual (string)
# 11380 : annual (string)
# 6322 : indefinite (string)
# 6323 : indefinite (string)
# 6324 : indefinite (string)
# 6325 : indefinite (string)
# 9489 : 30? (orig. string 20-30?)
# This did not work > 9489 : 30? (orig. string 20-30?)
# 9492 : 30? (orig. string 20-30?)
# This did not work > 9492 : 30? (orig. string 20-30?)
# 5840 : 20 (orig. string 10-20)
# 5841 : 25 (9) / absent or rare in 10 yo heath (46) (orig. string 5-25 (9) / absent or rare in 10 yo heath (46))
# This did not work > 5841 : 25 (9) / absent or rare in 10 yo heath (46) (orig. string 5-25 (9) / absent or rare in 10 yo heath (46))
# 9494 : 30 (orig. string c. 20-30)
# 9595 : c. 50 (string)
# 6349 : annual (string)
# 6352 : annual (string)
# 6354 : annual (string)
# Total of 237 rows updated
# 958 excluded / 237 included
# Database connection closed.

# %% [markdown]
# ### Other traits

# %%
j=13
varname=ws.cell(row=2, column=j).value
print(varname)


switcher={
    "canopy":"canopy",
    "canopy - transient":"canopy",
    "persistent":"soil-persistent",
    "peristent":"soil-persistent",
    "persistent soil":"soil-persistent", 
    "a-persistent soil":"soil-persistent", 
    "soil":"soil-persistent",
    "transient":"transient", 
    "none":"transient",
    "shed at maturity":"transient", 
    "viviparous":"transient",
    "canopy / released at maturity":"transient",
    "canopy / regularly without fire":"transient",
    "not canopy":"non-canopy",
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,seedbank_type) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET seedbank_type=EXCLUDED.seedbank_type"
updated_rows = 0

for i in range(1300,2800):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "other")
        #if varref is not None:
        #    print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        #else:
        #    print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur = conn.cursor()
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = updated_rows + cur.rowcount
            conn.commit()
            cur.close()
print("Total of %s rows updated" % (updated_rows))


if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Seed storage
# Connecting to the PostgreSQL database...
# Total of 2660 rows updated
# Database connection closed.

# %%
j=22
varname=ws.cell(row=2, column=j).value
print(varname)

switcher={
    "prolific":"abundant",
    "abundant":"abundant",
    "common":"abundant",
    "high":"abundant",
    "substantial":"abundant",
    "vigourous":"abundant",
    "1-4 seedlings/m2":"abundant",
    "no":"absent",
    "none observed":"absent"
}

# connect to the PostgreSQL server
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**params)
qrystr= "INSERT INTO litrev.traits(species,species_code,postfire_seedling_recruitment) values(%s,%s,%s) ON CONFLICT (species,species_code) DO UPDATE SET postfire_seedling_recruitment=EXCLUDED.postfire_seedling_recruitment"
cur = conn.cursor()
updated_rows = 0
for i in range(3,3000):
    spname=ws.cell(row=i, column=1).value
    spcode=ws.cell(row=i, column=2).value
    varvalue=ws.cell(row=i, column=j).value
    varref=ws.cell(row=i, column=j).hyperlink
    if varvalue is not None:
        transvalue=switcher.get(varvalue, "present")
        #if varref is not None:
        #    print("%s: %s / (%s) %s / %s" % (spcode,spname,varvalue,transvalue, varref.location))
        #else:
        #    print("%s: %s / (%s) %s " % (spcode,spname,varvalue,transvalue))
        if spcode.isnumeric():
            cur.execute(qrystr, (spname,int(spcode),transvalue))
            updated_rows = updated_rows + cur.rowcount
            
conn.commit()
cur.close()            
print("Total of %s rows updated" % (updated_rows))

if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Post-fire recruitment
# Connecting to the PostgreSQL database...
# Total of 590 rows updated
# Database connection closed.
