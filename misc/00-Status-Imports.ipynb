# %% [markdown]
# # Summary of database import

# %% [markdown]
# ## Set up
# Load libraries

# %%
from pathlib import Path
import os
from configparser import ConfigParser
import psycopg2
from psycopg2.extras import DictCursor
import pandas as pd
import pyprojroot
from datetime import date

# %% [markdown]
# Load functions from `lib` folder, we will use a function to read db credentials and one for database queries:

# %%
from lib.parseparams import read_dbparams
from lib.firevegdb import dbquery

# %% [markdown]
# Find project root directory

# %%
repodir = pyprojroot.find_root(pyprojroot.has_dir(".git"))

# %% [markdown]
# Read database credentials from `database.ini` file

# %%
dbparams = read_dbparams(repodir / 'secrets' / 'database.ini', section='aws-lght-sl')

# %% [markdown]
# ## Define queries
# Define queries we are going to use multiple times:

# %%
# Check comments on vocabularies
qry_vocabulary = "SELECT pg_catalog.obj_description(t.oid, 'pg_type')::json from pg_type t where typname = '%s';" 

# Number of records per source
qry_source = 'SELECT main_source,count(*) FROM litrev.%s GROUP BY main_source'
# Number of records per value of categorical variable
qry_values = ' select norm_value,count(*),count(distinct species),count(distinct species_code) from litrev.%s group by norm_value;'

# Number of records per value of numerical variable
qry_triplet = ' select best is NULL as b, lower is NULL as l, upper is NULL as u,count(*),count(distinct species),count(distinct species_code) from litrev.%s group by b,l,u;'

# Raw values when norm value is NULL 
qry_nulls = ' select raw_value,count(*),count(distinct species),count(distinct species_code) from litrev.%s where norm_value is NULL group by raw_value;'
# Raw values when best/lower/upper are all NULL 
qry_triplet_nulls = 'select raw_value,count(*),count(distinct species),count(distinct species_code) from litrev.%s where best is NULL and lower is NULL and upper is NULL group by raw_value;'

# %% [markdown]
# This is a complex query for the comments in one column:

# %%
qry_comment = """
SELECT
    (
        SELECT
            pg_catalog.col_description(c.oid, cols.ordinal_position::int)
        FROM pg_catalog.pg_class c
        WHERE
            c.oid     = (SELECT CONCAT(cols.table_schema,'.',cols.table_name)::regclass::oid) AND
            c.relname = cols.table_name
    )::json as column_comment
 
FROM information_schema.columns cols
WHERE
    cols.table_catalog = 'dbfireveg' AND
    cols.table_schema  = 'litrev' AND
    cols.table_name    = '%s' AND
    cols.column_name    = 'best';   
"""

# %% [markdown]
# ## What is in the database?
# ### Field work
# Here we query all visits and samples:

# %%
qry = """
SELECT survey_name,visit_id,visit_date,CONCAT(givennames,' ', surname) as observer,
COUNT(distinct sample_nr) as samples,
COUNT(distinct record_id) as records
FROM form.field_visit
LEFT JOIN form.observerid
 ON mainobserver=userkey
LEFT JOIN form.field_samples
 USING(visit_id,visit_date)
LEFT JOIN form.quadrat_samples
 USING(visit_id,visit_date,sample_nr)
GROUP BY survey_name,visit_id,visit_date,observer
;
"""
res = dbquery(qry,dbparams)
colnames=['survey','site_label','visit_date','observer','samples','records']
site_visits = pd.DataFrame(res,columns=colnames)

# %% [markdown]
# We now print a summary of all visits with vegetation records:

# %%
ss=site_visits[site_visits.records>0]

# %%
msg="""
There are {} surveys, {} sites, and {} visits by {} main observers.
There are {} samples and {} records.
"""

print(msg.format(
    ss.survey.unique().size,
    ss.site_label.unique().size,
    ss.shape[0],
    ss.observer.unique().size,
    ss.samples.sum(),
    ss.records.sum()
))
# Out:
# There are 10 surveys, 153 sites, and 178 visits by 7 main observers.
# There are 1270 samples and 19242 records.

# %% [markdown]
# We do the same for the 'legacy' datasets (visits prior to october 2019):

# %%
ss=site_visits[site_visits['visit_date'] < date(year=2019,month=10,day=1)]

# %%
ss
# Out:
#                survey    site_label  visit_date            observer  samples
# 39       UplandBasalt      CRC09B7U  1994-11-03  Alexandria Thomsen        0  \
# 42       UplandBasalt      CRC13B7C  1998-12-08  Alexandria Thomsen        0
# 44       UplandBasalt      CRC50B6R  2011-02-10  Alexandria Thomsen        0
# 46       UplandBasalt      CRN36B7S  2009-06-17  Alexandria Thomsen        0
# 49       UplandBasalt      CRN60B4U  1998-12-08  Alexandria Thomsen        0
# ..                ...           ...         ...                 ...      ...
# 246  Mallee Woodlands       T2017/3  2017-03-26                            0
# 247  Mallee Woodlands       T2017/4  2017-03-25                            8
# 248  Mallee Woodlands  T2017/4_AX_2  2017-03-26                            0
# 249  Mallee Woodlands       T2017/5  2017-03-25                            8
# 255      UplandBasalt      WINGE115  2016-01-08  Alexandria Thomsen        0
#
#      records
# 39         0
# 42         0
# 44         0
# 46         0
# 49         0
# ..       ...
# 246        0
# 247      144
# 248        0
# 249      111
# 255        0
#
# [108 rows x 6 columns]

# %%
print(msg.format(
    ss.survey.unique().size,
    ss.site_label.unique().size,
    ss.shape[0],
    ss.observer.unique().size,
    ss.samples.sum(),
    ss.records.sum()
))
# Out:
# There are 3 surveys, 81 sites, and 108 visits by 3 main observers.
# There are 526 samples and 8588 records.

# %% [markdown]
# ### Fire history

# %%
qry="""
SELECT site_label,count(*),MIN(earliest_date),MAX(latest_date)
FROM form.field_site
LEFT JOIN form.fire_history
USING (site_label)
GROUP BY site_label
"""
res = dbquery(qry,dbparams)
colnames=['site_label','fire_records','min_date','max_date']
fire_history = pd.DataFrame(res,columns=colnames)

# %%
fire_history.fire_records.sum()
fire_history
# Out:
#          site_label  fire_records    min_date    max_date
# 0       HORT_1_UNSW             3  2019-11-09  2019-11-09
# 1       BFEH_1_UNSW             3  2019-11-09  2019-11-09
# 2           S2011/3             2  1918-01-25  2012-09-27
# 3       TOOL_1_UNSW             3  2019-11-09  2019-11-09
# 4           Madden1             1        None        None
# ..              ...           ...         ...         ...
# 171           Ka3_b             1        None        None
# 172          ROY001             1        None        None
# 173  AUSALPS_NSW038             2  2003-01-01  2020-01-31
# 174    GGRR_01_UNSW             3  1940-01-01  2019-11-09
# 175           MR_N4             2  2021-01-04  2021-01-04
#
# [176 rows x 4 columns]

# %% [markdown]
# ### Species in field samples

# %%
qry = """
SELECT DISTINCT species,species_code
FROM form.quadrat_samples
WHERE species_code is not NULL
;
"""
colnames=['species','species_code']
res = dbquery(qry,dbparams)
quadrats = pd.DataFrame(res,columns=colnames)

# %%
quadrats
# Out:
#                    species  species_code
# 0     Leucanthemum vulgare          1560
# 1       Epacris breviflora          2591
# 2        Baumea rubiginosa          2302
# 3          Pellaea falcata          8444
# 4            Ficus fraseri          3921
# ...                    ...           ...
# 1044     Syzygium australe          6778
# 1045      Cryptandra amara          5554
# 1046    Stephania japonica          3690
# 1047   Symplocos stawellii          6165
# 1048       Viola hederacea          6272
#
# [1049 rows x 2 columns]

# %%
msg="""
There are {} species with {} unique codes.
"""

print(msg.format(
    quadrats.species.unique().size,
    quadrats.species_code.unique().size
))
# Out:
# There are 1043 species with 1047 unique codes.

# %% [markdown]
# ### traits from the literature

# %%
qry="""
    SELECT 'repr2' AS table_name, species, species_code FROM litrev.repr2
    UNION SELECT 'germ8' AS table_name, species, species_code FROM litrev.germ8
    UNION SELECT 'rect2' AS table_name, species, species_code FROM litrev.rect2
    UNION SELECT 'germ1' AS table_name, species, species_code FROM litrev.germ1
    UNION SELECT 'grow1' AS table_name, species, species_code FROM litrev.grow1
    UNION SELECT 'repr4' AS table_name, species, species_code FROM litrev.repr4
    UNION SELECT 'surv5' AS table_name, species, species_code FROM litrev.surv5
    UNION SELECT 'surv6' AS table_name, species, species_code FROM litrev.surv6
    UNION SELECT 'surv7' AS table_name, species, species_code FROM litrev.surv7
    UNION SELECT 'disp1' AS table_name, species, species_code FROM litrev.disp1
    UNION SELECT 'repr3' AS table_name, species, species_code FROM litrev.repr3a
    UNION SELECT 'repr3a' AS table_name, species, species_code FROM litrev.repr3
    UNION SELECT 'surv4' AS table_name, species, species_code FROM litrev.surv4
    UNION SELECT 'surv1' AS table_name, species, species_code FROM litrev.surv1
;
"""
colnames=['traits','species','species_code']
res = dbquery(qry,dbparams)
lit_traits = pd.DataFrame(res,columns=colnames)

# %%
lit_traits.species.unique().size
# Out:
# 12591

# %%
lit_traits.shape
# Out:
# (27630, 3)

# %%
lit_traits.species_code.unique().size
# Out:
# 7253

# %%
lit_traits.traits.unique().size
# Out:
# 14

# %% [markdown]
# ## Read table with trait information

# %%
qry = "select code,name,description,value_type,life_stage,life_history_process,category_vocabulary,method_vocabulary from litrev.trait_info ;"
res = dbquery(qry,dbparams)
data = pd.DataFrame(res)
trait_info=data.rename(columns={0:"Trait code", 1:"Trait name", 2:"Description", 4:"Life stage", 5:"Life history process",  3:"value_type",6:"category_vocabulary",7:"method_vocabulary"})

# %% [markdown]
# Transform to pandas dataframe

# %%
traitdata = pd.DataFrame(res,columns=['code','name', 'description', 'value_type', 'life_stage', 'life_history_process', 'category_vocabulary', 'method_vocabulary'])
traitdata
# Out:
#       code                                               name  \
# 0    surv7                                     Seed longevity
# 1    repr4                                     Maturation age
# 2   grow2a                               Maximum growth stage
# 3    grow3                             Maximum bark thickness
# 4    grow4                               Maximum plant height
# 5    rect3                       Seedling emergence phenology
# 6    surv2  Basal scorch response (scorch height < 50% of ...
# 7    surv3                            Survival - basal scorch
# 8    grow2                  Age to reach maximum growth stage
# 9    surv5                     Standing plant longevity (Max)
# 10   surv6                                 Seedbank half-life
# 11   rect2                              Establishment pattern
# 12   surv1                   Resprouting - full canopy scorch
# 13   grow1      Age to develop regenerative/resistance organs
# 14   repr3         Age at first flower production (from seed)
# 15  repr3a  Time to first postfire reproduction (from resp...
# 16   repr2                       Post-fire flowering response
# 17   germ8                                 Seed dormancy type
# 18   germ1                                      Seedbank Type
# 19  germ10                         Postfire residual seedbank
# 20   surv4                                 Regenerative Organ
# 21   repr1                                     Flowering time
# 22   repr5                     Age at maximum seed production
# 23   repr6                      Age of maximum seed bank size
# 24  repr7a         Resprout flowering response to summer fire
# 25  repr7b                  Flowering response to autumn fire
# 26  repr7c                  Flowering response to winter fire
# 27  repr7d                  Flowering response to spring fire
# 28   germ2                        Heat-pulse-cued germination
# 29   germ3                             Smoke-cued germination
# 30   germ4       Heat shock-smoke interactive germination cue
# 31   germ5                                                H50
# 32   germ6                                              H-max
# 33   germ7                                           H-lethal
# 34   germ9                                                TBA
# 35   rect1                      Postfire seedling recruitment
# 36  rect3a    Seedling emergence phenology - rainfall context
# 37   disp1                           Propagule dispersal mode
#
#                                           description   value_type  \
# 0   Age at which all seeds in a cohort (excluding ...    numerical
# 1   The time taken for 50% of individuals in a coh...    numerical
# 2   Taxon-specific definition of maximum growth st...         text
# 3                         Maximum bark thickness [mm]      numeric
# 4                            Maximum plant height [m]      numeric
# 5   The  month(s) of seedling emergence event. Ent...  categorical
# 6   Non-ordinal categories of survival response fo...          TBA
# 7   Ordinal categories of survival and resprouting...          TBA
# 8   Age of a cohort at which 50% of individuals re...          TBA
# 9   Age at which 50% of individuals in a cohort (e...    numerical
# 10  Age at which 50% of a seed cohort in an in sit...    numerical
# 11  The temporal pattern of seedling or clonal est...  categorical
# 12  Ordinal categories of survival and resprouting...  categorical
# 13  The time taken to develop organs or tissues en...    numerical
# 14  The time taken for first individual in a recru...    numerical
# 15  The time taken after fire for first reproducti...    numerical
# 16                                                TBA  categorical
# 17                                                TBA  categorical
# 18                                                TBA  categorical
# 19                                                TBA  categorical
# 20                                                TBA  categorical
# 21  Earliest (1st decile of individuals) and lates...          TBA
# 22  Age of a cohort at which seed production reach...      numeric
# 23  Age of a cohort at which the accumulated seedb...      numeric
# 24  Proportion of surviving resprouting individual...          TBA
# 25  Proportion of surviving resprouting individual...          TBA
# 26  Proportion of surviving resprouting individual...          TBA
# 27  Proportion of surviving resprouting individual...          TBA
# 28                 Germination response to heat pulse  categorical
# 29           Germination response to smoke treatments  categorical
# 30  Germination response to combined heat and smok...  categorical
# 31  Minimum temperature of heat pulse (exposure ti...    numerical
# 32  Temperature of heat pulse (exposure time up to...    numerical
# 33  Minimum temperature of heat pulse (exposure ti...    numerical
# 34                                                TBA          TBA
# 35  The observed incidence of post-fire (within fi...  categorical
# 36  Occurrence of significant dry spell (>3 months...  categorical
# 37                           Propagule dispersal mode  categorical
#
#         life_stage life_history_process             category_vocabulary  \
# 0             Seed             Survival                            None
# 1   Standing plant         Reproduction                            None
# 2   Standing plant               Growth                            None
# 3   Standing plant               Growth                            None
# 4   Standing plant               Growth                            None
# 5         Seedling          Recruitment                            None
# 6   Standing plant             Survival                            None
# 7   Standing plant             Survival                            None
# 8   Standing plant               Growth                            None
# 9   Standing plant             Survival                            None
# 10            Seed             Survival                            None
# 11        Seedling          Recruitment        establishment_vocabulary
# 12  Standing plant             Survival          resprouting_vocabulary
# 13  Standing plant               Growth                            None
# 14  Standing plant         Reproduction                            None
# 15  Standing plant         Reproduction                            None
# 16  Standing plant         Reproduction               postfire_response
# 17            Seed          Germination        seed_dormancy_vocabulary
# 18            Seed          Germination             seedbank_vocabulary
# 19            Seed          Germination                            None
# 20  Standing plant             Survival       resprout_organ_vocabulary
# 21  Standing plant         Reproduction                            None
# 22  Standing plant         Reproduction                            None
# 23  Standing plant         Reproduction                            None
# 24  Standing plant         Reproduction                            None
# 25  Standing plant         Reproduction                            None
# 26  Standing plant         Reproduction                            None
# 27  Standing plant         Reproduction                            None
# 28            Seed          Germination                            None
# 29            Seed          Germination                            None
# 30            Seed          Germination                            None
# 31            Seed          Germination                            None
# 32            Seed          Germination                            None
# 33            Seed          Germination                            None
# 34            Seed          Germination                            None
# 35        Seedling          Recruitment                            None
# 36        Seedling          Recruitment                            None
# 37            Seed            Dispersal  propagule_dispersal_vocabulary
#
#            method_vocabulary
# 0                       None
# 1    method_repr4_vocabulary
# 2                       None
# 3                       None
# 4                       None
# 5    method_rect3_vocabulary
# 6    method_surv2_vocabulary
# 7    method_surv3_vocabulary
# 8    method_grow2_vocabulary
# 9                       None
# 10                      None
# 11                      None
# 12   method_surv1_vocabulary
# 13   method_grow1_vocabulary
# 14   method_repr3_vocabulary
# 15  method_repr3a_vocabulary
# 16                      None
# 17   method_germ8_vocabulary
# 18                      None
# 19                      None
# 20                      None
# 21                      None
# 22                      None
# 23                      None
# 24                      None
# 25                      None
# 26                      None
# 27                      None
# 28                      None
# 29                      None
# 30                      None
# 31                      None
# 32                      None
# 33                      None
# 34                      None
# 35                      None
# 36                      None
# 37   method_disp1_vocabulary

# %% [markdown]
# Use `shape` to count number of rows (traits).

# %%
traitdata.shape
# Out:
# (38, 8)

# %%
Count how many are categorical, etc.

# %%
traitdata.value_type.value_counts()
# Out:
# categorical    14
# numerical      10
# TBA             9
# numeric         4
# text            1
# Name: value_type, dtype: int64

# %%
traitdata.life_stage.value_counts()
# Out:
# Standing plant    21
# Seed              13
# Seedling           4
# Name: life_stage, dtype: int64

# %%
traitdata.life_history_process.value_counts()
# Out:
# Reproduction    11
# Germination     10
# Survival         7
# Growth           5
# Recruitment      4
# Dispersal        1
# Name: life_history_process, dtype: int64

# %% [markdown]
# ## First tranche

# %% [markdown]
# ### Trait code surv1
#
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others| Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>11563 records</font>|<font color='darkgreen'>18344 records</font>|None|<font color='red'>43 records to review</font>

# %% [markdown]
# #### Trait information
#
# Check trait information for this trait:

# %%
elem = trait_info[trait_info["Trait code"]=="surv1"]
elem.transpose()
# Out:
#                                                                      31
# Trait code                                                        surv1
# Trait name                             Resprouting - full canopy scorch
# Description           Ordinal categories of survival and resprouting...
# value_type                                                  categorical
# Life stage                                               Standing plant
# Life history process                                           Survival
# category_vocabulary                              resprouting_vocabulary
# method_vocabulary                               method_surv1_vocabulary

# %% [markdown]
# #### Vocabularies
#
# This trait uses one vocabulary for the categories and one for the methods

# %%
#For the category
res = dbquery(qry_vocabulary %  elem.iloc[0]['category_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                          0
# None     < 5 % individuals in a population resprout aft...
# Few      > 5 and < 30 % individuals in a population res...
# Half     > 30 and < 70 % individuals in a population re...
# Most     > 70 and < 90 % individuals in a population re...
# All      > 90 % individuals in a population resprout af...
# Unknown                                            No data

# %%
#For the methods
res = dbquery(qry_vocabulary %  elem.iloc[0]['method_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                                                     0
# Direct field observation or measure (unknown sa...  Estimates based on data observed or measured i...
# Direct observation (small sample)                   Estimates based on data observed or measured i...
# Direct observation (large sample)                   Estimates based on data observed or measured i...
# Estimated by extrapolation from observed values     Estimated by extrapolation from (time series) ...
# Inferred from plant / organ / growth stage morp...  Inference based on relevant morphological stru...
# Inferred from related taxa                          Assigned to same category as congeners or conf...
# Manipulative experiment                             Manipulative experiment. Individuals sampled b...
# Qualitative estimate                                Guestimate from visual assessment of post-fire...
# Unspecified methods                                                  Methods unclear or undocumented.

# %% [markdown]
# #### Importing records
#
# I ran the script in notebook '[Read resprouting data from NSWFFRD](python/Literature-review/Read-resprouting-data-from-NSWFFRD.ipynb)'. It imported 11563 records. Then I ran the script in notebook [Read resprouting from Austraits data](python/Literature-review/Read-resprouting-from-Austraits-data.ipynb) and it imported more than 18344 records.
#
# #### Check records in database

# %%
res=dbquery(qry_source % 'surv1',dbparams)
pd.DataFrame(res)
# Out:
#                           0      1
# 0               NSWFFRDv2.1  11564
# 1  Bell Vollmer Gellie 1993      1
# 2           austraits-3.0.2  18344

# %%
res = dbquery(qry_values % 'surv1',dbparams)
data=pd.DataFrame(res)
data.rename(columns={0:"Value",1:"Nr. records",2:"Nr. taxa",3:"Nr. valid"})
# Out:
#      Value  Nr. records  Nr. taxa  Nr. valid
# 0     None        12389      5600       4050
# 1      Few          254       181        181
# 2     Half          773       542        533
# 3     Most          244       163        163
# 4      All        16189      6410       3963
# 5  Unknown           15        14         14
# 6     None           43        36         31

# %% [markdown]
# Few missing values, they all fall in similar categories:

# %%
res=dbquery(qry_nulls % 'surv1',dbparams)
pd.DataFrame(res)
# Out:
#                                                    0   1   2   3
# 0  [fire_response, fire_killed fire_not_relevant,...  11   7   6
# 1  [fire_response, fire_not_relevant not_fire_kil...   4   4   4
# 2  [fire_response, fire_not_relevant resprouts, e...  28  25  21

# %% [markdown]
# ### Trait code surv4
#
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='red'>Description missing</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| <font color='darkgreen'>1411 records</font> | TO DO | None | <font color='red'>TO DO: ca. 20 records </font>

# %% [markdown]
# #### Trait information
#
# Check trait information

# %%
elem = trait_info[trait_info["Trait code"]=="surv4"]
elem.transpose()
# Out:
#                                              11
# Trait code                                surv4
# Trait name                   Regenerative Organ
# Description                                None
# value_type                          categorical
# Life stage                       Standing plant
# Life history process                   Survival
# category_vocabulary   resprout_organ_vocabulary
# method_vocabulary                          None

# %% [markdown]
# #### Vocabularies
#
# This trait uses one vocabulary for the categories but does not include a methods vocabulary:

# %%
#For the category
res = dbquery(qry_vocabulary %  elem.iloc[0]['category_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                              0
# Epicormic                    Resprouting from epicormic meristematic tissue...
# Apical                       Resprouting from active shoots protected by cr...
# Lignotuber                   Resprouting from meristematic tissues or buds ...
# Basal                        Resprouting from meristematic tissues or buds ...
# Tuber                        Resprouting from non-woody nodular subsoil org...
# Tussock                      Shoots protected and resprouting within tightl...
# Long rhizome or root sucker  Resprouting from buried woody or non-woody hor...
# Short rhizome                Resprouting from buried woody or non-woody hor...
# Stolon                       Resprouting from non-woody horizontal organs o...
# None                                   No vegetative recovery - killed by fire

# %% [markdown]
# #### Importing records
#
# I ran the script in notebook '[Read categorical variables from NSWFFRD](python/Literature-review/Read-categorical-variables-from-NSWFFRD.ipynb)' for several variables. For _surv4_ it imported 1411 records, only 18 records had errors and could not be assigned to one of the predefined categories.
#
#
# #### Check records in database

# %%
res = dbquery(qry_values % 'surv4',dbparams)
data=pd.DataFrame(res)
data.rename(columns={0:"Value",1:"Nr. records",2:"Nr. taxa",3:"Nr. valid"})
# Out:
#                          Value  Nr. records  Nr. taxa  Nr. valid
# 0                    Epicormic          147       146        146
# 1                       Apical           14        14         14
# 2                   Lignotuber          157       157        157
# 3                        Basal          630       630        613
# 4                        Tuber          104       104        104
# 5                Short rhizome          166       165        165
# 6  Long rhizome or root sucker          172       171        171
# 7                       Stolon            3         3          3
# 8                         None           18        17         17

# %% [markdown]
# Summary of raw values when norm value is NULL:

# %%
res=dbquery(qry_nulls % 'surv4',dbparams)
pd.DataFrame(res)
# Out:
#                                                     0  1  2  3
# 0                    [Resprout location, apical buds]  4  4  4
# 1   [Resprout location, basal, possibly rhizome, -...  1  1  1
# 2                  [Resprout location, basal rhizome]  1  1  1
# 3   [Resprout location, basal & some epicormic, ->...  1  1  1
# 4   [Resprout location, basal; stem buds; swamp fo...  1  1  1
# 5   [Resprout location, basal: tuber (10; 48), ->,...  1  1  1
# 6                    [Resprout location, has rhizome]  2  2  2
# 7                     [Resprout location, or rhizome]  1  1  1
# 8                       [Resprout location, rhizome?]  1  1  1
# 9                          [Resprout location, roots]  2  2  2
# 10           [Resprout location, rootsuckers &, ->, ]  1  1  1
# 11             [Resprout location, sometimes suckers]  1  1  1
# 12                    [Resprout location, stem bases]  1  1  1

# %% [markdown]
# ### repr3
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| <font color='darkgreen'>838 records</font>| <font color='red'>TO DO</font> | None | <font color='red'>49 records</font>

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="repr3"]
elem.transpose()
# Out:
#                                                                      36
# Trait code                                                        repr3
# Trait name                   Age at first flower production (from seed)
# Description           The time taken for first individual in a recru...
# value_type                                                    numerical
# Life stage                                               Standing plant
# Life history process                                       Reproduction
# category_vocabulary                                                None
# method_vocabulary                               method_repr3_vocabulary

# %% [markdown]
# #### Vocabularies

# %%
res=dbquery(qry_comment % 'repr3',dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                        0
# years  The time taken for first individual in a recru...

# %%
#For the method
res = dbquery(qry_vocabulary %  elem.iloc[0]['method_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                                                     0
# Direct field observation or measure (unknown sa...  Estimates based on data observed or measured i...
# Direct observation (small sample)                   Estimates based on data observed or measured i...
# Direct observation (large sample)                   Estimates based on data observed or measured i...
# Trait evidence, but start date uncertain            Evidence of trait expression, but age of first...
# No evidence of trait expression by specified age    No evidence of trait expression by specified a...
# Unspecified methods                                                  Methods unclear or undocumented.

# %% [markdown]
# #### Importing records
#
# I ran the script in notebook '[Read numerical variables from NSWFFRD](python/Literature-review/Read-numerical-variables-from-NSWFFRD.ipynb)' for several variables. For _surv4_ it imported 838 records, but 81 records had errors and could not be assigned to a fuzzy number.
#
#
# #### Check records in database
# This query will show how many records have null values in each colum (a line with 'True True True' means raw values could not be translated to a triplet:

# %%
res = dbquery(qry_triplet % 'repr3',dbparams)
data=pd.DataFrame(res)
data.rename(columns={0:"Best",1:"Lower",2:"Upper",3:"Nr. records",4:"Nr. taxa",5:"Nr. valid"})
# Out:
#     Best  Lower  Upper  Nr. records  Nr. taxa  Nr. valid
# 0  False   True   True          546       532        528
# 1   True  False  False          142       138        138
# 2   True  False   True           29        29         29
# 3   True   True  False           72        72         72
# 4   True   True   True           49        47         47

# %%
res=dbquery(qry_triplet_nulls % 'repr3',dbparams)
pd.DataFrame(res)
# Out:
#                                                     0  1  2  3
# 0                         [Primary juvenile period, ]  1  1  1
# 1                 [Primary juvenile period, 0.25-0.5]  1  1  1
# 2                      [Primary juvenile period, 0.3]  1  1  1
# 3   [Primary juvenile period, <10% flowering at 4 ...  1  1  1
# 4   [Primary juvenile period, 15% produce seed at 1y]  1  1  1
# 5                       [Primary juvenile period, 2;]  1  1  1
# 6                [Primary juvenile period, 22 months]  1  1  1
# 7               [Primary juvenile period, 2; 3 (138)]  1  1  1
# 8                 [Primary juvenile period, 2.5 (1b)]  1  1  1
# 9   [Primary juvenile period, 2 for first flowerin...  1  1  1
# 10  [Primary juvenile period, >2, peak flowering 4...  1  1  1
# 11                   [Primary juvenile period, >3<10]  1  1  1
# 12              [Primary juvenile period, >3<10 (48)]  3  3  3
# 13              [Primary juvenile period, 3, >6 (1b)]  1  1  1
# 14  [Primary juvenile period, 3 for first flowerin...  1  1  1
# 15  [Primary juvenile period, <3 for some plants, ...  1  1  1
# 16              [Primary juvenile period, 3, peak <5]  1  1  1
# 17           [Primary juvenile period, 3, peak 5 (1)]  1  1  1
# 18  [Primary juvenile period, 4 for first flowerin...  1  1  1
# 19  [Primary juvenile period, 4 for first flowerin...  1  1  1
# 20  [Primary juvenile period, 4 to first flowering...  1  1  1
# 21  [Primary juvenile period, 5, 8 on shallow soil...  1  1  1
# 22  [Primary juvenile period, 5% of plants floweri...  1  1  1
# 23                [Primary juvenile period, 6, 8 (9)]  1  1  1
# 24             [Primary juvenile period, at least 3y]  1  1  1
# 25                    [Primary juvenile period, c. 3]  1  1  1
# 26                    [Primary juvenile period, c. 5]  2  2  2
# 27                   [Primary juvenile period, c. 80]  1  1  1
# 28  [Primary juvenile period, flowring starts at 1...  1  1  1
# 29  [Primary juvenile period, no flowering after 5...  1  1  1
# 30  [Primary juvenile period, one plant flowering ...  1  1  1
# 31  [Primary juvenile period, one plant flowering ...  1  1  1
# 32  [Primary juvenile period, peak flowering at 5 ...  1  1  1
# 33  [Primary juvenile period, Preliminary observat...  1  1  1
# 34              [Primary juvenile period, probably 1]  2  2  2
# 35          [Primary juvenile period, References!C12]  1  1  1
# 36           [Primary juvenile period, References!C2]  1  1  1
# 37              [Primary juvenile period, short (61)]  1  1  1
# 38          [Primary juvenile period, slow to mature]  6  6  6
# 39  [Primary juvenile period, some green fruit at ...  1  1  1

# %% [markdown]
# ### repr4
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others
# ---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| <font color='red'>TO DO</font>| <font color='red'>TO DO</font>  | None

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="repr4"]
elem.transpose()
# Out:
#                                                                       1
# Trait code                                                        repr4
# Trait name                                               Maturation age
# Description           The time taken for 50% of individuals in a coh...
# value_type                                                    numerical
# Life stage                                               Standing plant
# Life history process                                       Reproduction
# category_vocabulary                                                None
# method_vocabulary                               method_repr4_vocabulary

# %% [markdown]
# #### Vocabularies

# %%
res=dbquery(qry_comment % 'repr4',dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                        0
# years  The time taken for 50% of individuals in a coh...

# %%
#For the method
res = dbquery(qry_vocabulary %  elem.iloc[0]['method_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                                                     0
# Direct field observation or measure (unknown sa...  Estimates based on data observed or measured i...
# Direct observation (small sample)                   Estimates based on data observed or measured i...
# Direct observation (large sample)                   Estimates based on data observed or measured i...
# Estimated by extrapolation from observed values     Estimated by extrapolation from (time series) ...
# Trait evidence, but start date uncertain            Evidence of trait expression, but age of first...
# Inferred form other trait                           Inferred from values of a different, but relat...
# Inferred from partial data                          Inferred from incomplete or indirect informati...
# No evidence of trait expression by specified age    No evidence of trait expression by specified a...
# Unspecified methods                                                  Methods unclear or undocumented.

# %%
res = dbquery(qry_triplet % 'repr4',dbparams)
data=pd.DataFrame(res)
data.rename(columns={0:"Best",1:"Lower",2:"Upper",3:"Nr. records",4:"Nr. taxa",5:"Nr. valid"})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### germ8
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others
# ---|---|---|---|---|---
# <font color='red'>TO DO: update description</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| No records| <font color='red'>TO DO</font>  | None

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="germ8"]
elem.transpose()
# Out:
#                                              3
# Trait code                               germ8
# Trait name                  Seed dormancy type
# Description                               None
# value_type                         categorical
# Life stage                                Seed
# Life history process               Germination
# category_vocabulary   seed_dormancy_vocabulary
# method_vocabulary      method_germ8_vocabulary

# %% [markdown]
# #### Vocabularies

# %%
#For the category
res = dbquery(qry_vocabulary %  elem.iloc[0]['category_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                        0
# PY     Physical dormancy (PY) is caused by a water-im...
# PD     Physiological dormancy (PD) is caused by a che...
# PY-PD  A combination of physical dormancy (PY) and ph...
# MPD    A combination of morphological dormancy (MD), ...
# MD     Morphological dormancy (MD) is caused by an un...
# ND     Non-dormant (ND) species are able to germinate...

# %%
#For the methods
res = dbquery(qry_vocabulary %  elem.iloc[0]['method_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                                                     0
# Direct field observation or measure (unknown sa...  Estimates based on data observed or measured i...
# Direct observation (small sample)                   Estimates based on data observed or measured i...
# Direct observation (large sample)                   Estimates based on data observed or measured i...
# Inferred from plant / organ / growth stage morp...  Inference based on relevant morphological stru...
# Inferred from related taxa                          Assigned to same category as congeners or conf...
# Unspecified methods                                                  Methods unclear or undocumented.

# %% [markdown]
# ## Second tranche

# %% [markdown]
# ### repr2
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='red'>TO DO: update description</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| <font color='darkgreen'>144 records</font>|  TO DO | None | <font color='red'>TO DO: ca. 20 records</font>

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="repr2"]
elem.transpose()
# Out:
#                                                  2
# Trait code                                   repr2
# Trait name            Post-fire flowering response
# Description                                   None
# value_type                             categorical
# Life stage                          Standing plant
# Life history process                  Reproduction
# category_vocabulary              postfire_response
# method_vocabulary                             None

# %% [markdown]
# #### Vocabularies
#
# This trait uses one vocabulary for the categories but does not include a methods vocabulary:

# %%
#For the category
res = dbquery(qry_vocabulary %  elem.iloc[0]['category_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                              0
# Exclusive    Flowering occurs exclusively in the first 5 ye...
# Facultative  Flowering occurs most prolifically in the firs...
# Negligible   Flowering similar or variable throughout the f...
# Unknown                                                No data

# %% [markdown]
# #### Importing records
#
# I ran the script in notebook '[Read categorical variables from NSWFFRD](/lab/tree/python/Literature-review/Read-categorical-variables-from-NSWFFRD.ipynb)' for several variables. For _repr2_ it imported 144 records, ca. 120 species in two categories, and ca. 23 records had errors and could not be assigned to one of the predefined categories. No records for class 'Negligible' or 'Unknown'.
#
#
# #### Check records in database

# %%
res = dbquery(qry_values % 'repr2',dbparams)
data=pd.DataFrame(res)
data.rename(columns={0:"Value",1:"Nr. records",2:"Nr. taxa",3:"Nr. valid"})
# Out:
#          Value  Nr. records  Nr. taxa  Nr. valid
# 0    Exclusive           30        30         30
# 1  Facultative           91        91         91
# 2         None           23        21         21

# %% [markdown]
# ### grow1
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others
# ---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|TO DO|TO DO| TO DO| TO DO | None

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="grow1"]
elem.transpose()
# Out:
#                                                                      34
# Trait code                                                        grow1
# Trait name                Age to develop regenerative/resistance organs
# Description           The time taken to develop organs or tissues en...
# value_type                                                    numerical
# Life stage                                               Standing plant
# Life history process                                             Growth
# category_vocabulary                                                None
# method_vocabulary                               method_grow1_vocabulary

# %% [markdown]
# #### Vocabularies

# %%
#For the category
res = dbquery(qry_vocabulary %  elem.iloc[0]['method_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                                                     0
# Direct field observation or measure (unknown sa...  Estimates based on data observed or measured i...
# Direct observation (small sample)                   Estimates based on data observed or measured i...
# Direct observation (large sample)                   Estimates based on data observed or measured i...
# Estimated by extrapolation from observed values     Estimated by extrapolation from (time series) ...
# Trait evidence, but start date uncertain            Evidence of trait expression, but age of first...
# Inferred from plant / organ / growth stage morp...  Inference based on relevant morphological stru...
# Inferred from related taxa                          Assigned to same category as congeners or conf...
# Manipulative experiment                             Manipulative experiment. Experimental heating ...
# No evidence of trait expression by specified age    No evidence of trait expression by specified a...
# Unspecified methods                                                  Methods unclear or undocumented.

# %% [markdown]
# ### rect2
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| <font color='darkgreen'>Done</font>| TO DO | None | <font color='red'>TO DO: >90 records</font>

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="rect2"]
elem.transpose()
# Out:
#                                                                      14
# Trait code                                                        rect2
# Trait name                                        Establishment pattern
# Description           The temporal pattern of seedling or clonal est...
# value_type                                                  categorical
# Life stage                                                     Seedling
# Life history process                                        Recruitment
# category_vocabulary                            establishment_vocabulary
# method_vocabulary                                                  None

# %% [markdown]
# #### Vocabularies

# %%
res = dbquery(qry_vocabulary %  elem.iloc[0]['category_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                      0
# Intolerant           I- intolerant of conditions in established com...
# Intolerant-Tolerant  I/T- intolerant or tolerant of conditions in e...
# Tolerant             T- tolerant of conditions through the fire cyc...
# Tolerant-Requiring   T/R- tolerant or requiring of conditions in es...
# Requiring            R- requiring of of conditions in established c...
# Unknown                                                        No data

# %% [markdown]
# #### Importing records
#
# I ran the script in notebook '[Read categorical variables from NSWFFRD](python/Literature-review/Read-categorical-variables-from-NSWFFRD.ipynb)' for several variables. For _rect2_ it imported 1088 records, >900 species in four categories, and ca. 96 records had errors and could not be assigned to one of the predefined categories.
#
#
# #### Check records in database

# %%
dbquery(qry_values % 'rect2',dbparams)
# Out:
# [['Intolerant', 636, 634, 634],
#  ['Intolerant-Tolerant', 3, 3, 3],
#  ['Tolerant', 318, 318, 318],
#  ['Requiring', 35, 34, 34],
#  [None, 96, 92, 92]]

# %% [markdown]
# ### germ1
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='red'>TO DO: add description</font>|<font color='darkgreen'>Done</font>|<font color='darkgreen'>Done</font>| <font color='darkgreen'>Done: 1635 imported</font>| TO DO | None | <font color='red'>TO DO: >80 records</font>

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="germ1"]
elem.transpose()
# Out:
#                                         5
# Trait code                          germ1
# Trait name                  Seedbank Type
# Description                          None
# value_type                    categorical
# Life stage                           Seed
# Life history process          Germination
# category_vocabulary   seedbank_vocabulary
# method_vocabulary                    None

# %%
dbquery(qry_vocabulary % elem['category_vocabulary'],dbparams)
# Out:
# []

# %% [markdown]
# #### Importing records
#
# I ran the script in notebook '[Read categorical variables from NSWFFRD](python/Literature-review/Read-categorical-variables-from-NSWFFRD.ipynb)' for several variables. For _rect2_ it imported 1635 records, >1300 species in four categories, and >80 records had errors and could not be assigned to one of the predefined categories.
#
#
# #### Check records in database

# %%
dbquery(qry_values % 'germ1',dbparams)
# Out:
# [['Soil-persistent', 962, 958, 957],
#  ['Transient', 267, 267, 266],
#  ['Canopy', 228, 226, 220],
#  ['Non-canopy', 95, 95, 90],
#  [None, 83, 82, 82]]

# %% [markdown]
# ### repr3a
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|TO DO|TO DO| TO DO| TO DO | None | <font color='red'>TO DO: >80 records</font>

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="repr3a"]
elem.transpose()
# Out:
#                                                                      37
# Trait code                                                       repr3a
# Trait name            Time to first postfire reproduction (from resp...
# Description           The time taken after fire for first reproducti...
# value_type                                                    numerical
# Life stage                                               Standing plant
# Life history process                                       Reproduction
# category_vocabulary                                                None
# method_vocabulary                              method_repr3a_vocabulary

# %%
res = dbquery(qry_vocabulary %  elem.iloc[0]['method_vocabulary'],dbparams)
pd.DataFrame(res[0]).transpose()
# Out:
#                                                                                                     0
# Direct field observation or measure (unknown sa...  Estimates based on data observed or measured i...
# Direct observation (small sample)                   Estimates based on data observed or measured i...
# Direct observation (large sample)                   Estimates based on data observed or measured i...
# Trait evidence, but start date uncertain            Evidence of trait expression, but age of first...
# No evidence of trait expression by specified age    No evidence of trait expression by specified a...
# Unspecified methods                                                  Methods unclear or undocumented.

# %%
res = dbquery(qry_triplet % 'repr3a',dbparams)
data=pd.DataFrame(res)
data.rename(columns={0:"Best",1:"Lower",2:"Upper",3:"Nr. records",4:"Nr. taxa",5:"Nr. valid"})
# Out:
#     Best  Lower  Upper  Nr. records  Nr. taxa  Nr. valid
# 0  False   True   True          394       392        383
# 1   True  False  False           38        38         38
# 2   True  False   True           19        19         19
# 3   True   True  False          124       124        124
# 4   True   True   True           87        87         87

# %% [markdown]
# ## Third tranche

# %% [markdown]
# ### surv5
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|TO DO|TO DO|1262 records| TO DO| TO DO | <font color='red'>>500 (!)</font>

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="surv5"]
elem.transpose()
# Out:
#                                                                      12
# Trait code                                                        surv5
# Trait name                               Standing plant longevity (Max)
# Description           Age at which 50% of individuals in a cohort (e...
# value_type                                                    numerical
# Life stage                                               Standing plant
# Life history process                                           Survival
# category_vocabulary                                                None
# method_vocabulary                                                  None

# %% [markdown]
# ### surv6
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|TO DO|TO DO|TO DO| TO DO| TO DO | None

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="surv6"]
elem.transpose()
# Out:
#                                                                      13
# Trait code                                                        surv6
# Trait name                                           Seedbank half-life
# Description           Age at which 50% of a seed cohort in an in sit...
# value_type                                                    numerical
# Life stage                                                         Seed
# Life history process                                           Survival
# category_vocabulary                                                None
# method_vocabulary                                                  None

# %% [markdown]
# ### surv7
# Metadata | Structure | Vocabularies | Records NSWFFRD | Records austraits | Others | Data curation
# ---|---|---|---|---|---|---
# <font color='darkgreen'>Done</font>|TO DO|TO DO|87 records| TO DO| TO DO | half of them (!)

# %% [markdown]
# #### Trait information

# %%
elem = trait_info[trait_info["Trait code"]=="surv7"]
elem.transpose()
# Out:
#                                                                       0
# Trait code                                                        surv7
# Trait name                                               Seed longevity
# Description           Age at which all seeds in a cohort (excluding ...
# value_type                                                    numerical
# Life stage                                                         Seed
# Life history process                                           Survival
# category_vocabulary                                                None
# method_vocabulary                                                  None
