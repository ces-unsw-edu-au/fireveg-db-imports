# %% [markdown]
# # Status for data in the litrev schema
# This represents the existing sources data stream

# %% [markdown]
# Compare from version v1.0 and v1.1

# %%
# work with paths in operating system
from pathlib import Path
import os, sys
import pandas as pd
# Pyprojroot for easier handling of working directory
import pyprojroot

# %% [markdown]
# ### Define paths for input and output

# %% [markdown]
# Define project directory using the `pyprojroot` functions, and add this to the execution path.

# %%
repodir = pyprojroot.find_root(pyprojroot.has_dir(".git"))
sys.path.append(str(repodir))

# %% [markdown]
# ### Load own functions
# Load functions from `lib` folder, we will use a function to read db credentials, one for executing database queries and three functions for extracting data from the reference description string

# %%
from lib.parseparams import read_dbparams
from lib.firevegdb import dbquery

# %% [markdown]
# ### Database credentials
#
# 🤫 We use a folder named "secrets" to keep the credentials for connection to different services (database credentials, API keys, etc). This checked this folder in our `.gitignore` so that its content are not tracked by git and not exposed. Future users need to copy the contents of this folder manually.
#
# We read database credentials stored in a `database.ini` file using our own `read_dbparams` function.

# %%
db_v1_0 = read_dbparams(repodir / 'secrets' / 'database.ini', 
                         section='fireveg-db-v1.0')
db_v1_1 = read_dbparams(repodir / 'secrets' / 'database.ini', 
                         section='fireveg-db-v1.1')

# %% [raw]
# select count(*) from litrev.surv1;
#
# # references for one trait
# select * from litrev.ref_list where ref_code IN (select distinct unnest(original_sources) from litrev.rect2);
#
# select main_source,count(*) from litrev.repr2 group by main_source;
#
#
#
# select raw_value,count(*) from litrev.disp1 where norm_value is NULL group by raw_value order by count DESC limit 15;

# %%
qrystr = "select count(*) from litrev.ref_list;"
dbquery(qrystr,db_v1_0)
# Out:
# [[309]]

# %%
dbquery(qrystr,db_v1_1)
# Out:
# [[347]]

# %%
qrystr = "select norm_value,count(*) from litrev.disp1 group by norm_value;"

# %%
dbquery(qrystr,db_v1_0)
# Out:
# [['animal-ingestion', 1320],
#  ['ant', 4399],
#  ['animal-unspec.', 1840],
#  ['passive', 696],
#  ['ballistic', 141],
#  [None, 4038],
#  ['wind-hairs', 21],
#  ['water', 440],
#  ['animal-cohesion', 2179],
#  ['wind-unspec.', 4023],
#  ['wind-wing', 224]]

# %%
dbquery(qrystr,db_v1_1)
# Out:
# [[None, 8433],
#  ['animal-cohesion', 2154],
#  ['wind-wing', 258],
#  ['animal-unspec.', 9378],
#  ['animal-ingestion', 1531],
#  ['water', 957],
#  ['wind-unspec.', 9319],
#  ['ant', 2412],
#  ['ballistic', 125],
#  ['wind-hairs', 24]]

# %%
qrystr="select main_source,count(*) from litrev.{} group by main_source;"
records=list()
for trait in ["surv1","surv4", "surv5", "surv6", "surv7", 
              "germ1","germ8",
              "repr2","repr3","repr3a","repr4",
              "grow1",
              "rect2",
              "disp1"]:
    qry = qrystr.format(trait)
    res = dbquery(qry, db_v1_1)
    record={'trait': trait,'version': 'v1.1'}
    for row in res:
        record[row[0]]=row[1]
    records.append(record)
    res = dbquery(qry, db_v1_0)
    record={'trait': trait,'version': 'v1.0'}
    for row in res:
        record[row[0]]=row[1]
    records.append(record)

# %%
df = pd.DataFrame(records)

# %%
df
# Out:
#      trait version  austraits-6.0.0  NSWFFRDv2.1  Bell Vollmer Gellie 1993
# 0    surv1    v1.1          29896.0      11563.0                       NaN  \
# 1    surv1    v1.0              NaN      11564.0                       1.0
# 2    surv4    v1.1              NaN       1411.0                       NaN
# 3    surv4    v1.0              NaN       1411.0                       NaN
# 4    surv5    v1.1              NaN       1262.0                       NaN
# 5    surv5    v1.0              NaN       1263.0                       NaN
# 6    surv6    v1.1              NaN          NaN                       NaN
# 7    surv6    v1.0              NaN          7.0                       NaN
# 8    surv7    v1.1              NaN         87.0                       NaN
# 9    surv7    v1.0              NaN         87.0                       NaN
# 10   germ1    v1.1           4164.0       1635.0                       NaN
# 11   germ1    v1.0              NaN       1635.0                       NaN
# 12   germ8    v1.1           4171.0          NaN                       NaN
# 13   germ8    v1.0              NaN          NaN                       NaN
# 14   repr2    v1.1            431.0        139.0                       NaN
# 15   repr2    v1.0              NaN        143.0                       NaN
# 16   repr3    v1.1              NaN        838.0                       NaN
# 17   repr3    v1.0              NaN        936.0                       NaN
# 18  repr3a    v1.1              NaN        662.0                       NaN
# 19  repr3a    v1.0              NaN        664.0                       NaN
# 20   repr4    v1.1              NaN          NaN                       NaN
# 21   repr4    v1.0              NaN         23.0                       NaN
# 22   grow1    v1.1              NaN         33.0                       NaN
# 23   grow1    v1.0              NaN         33.0                       NaN
# 24   rect2    v1.1              NaN       1088.0                       NaN
# 25   rect2    v1.0              NaN       1088.0                       NaN
# 26   disp1    v1.1          34591.0          NaN                       NaN
# 27   disp1    v1.0              NaN          NaN                       NaN
#
#     austraits-3.0.2  Ooi Myerscough Auld 2007  None
# 0               NaN                       NaN   NaN
# 1           18344.0                       NaN   NaN
# 2               NaN                       NaN   NaN
# 3               NaN                       NaN   NaN
# 4               NaN                       NaN   NaN
# 5               NaN                       NaN   NaN
# 6               NaN                       NaN   NaN
# 7               NaN                       NaN   NaN
# 8               NaN                       NaN   NaN
# 9               NaN                       NaN   NaN
# 10              NaN                       NaN   NaN
# 11              NaN                       NaN   NaN
# 12              NaN                       NaN   NaN
# 13              NaN                     194.0   NaN
# 14              NaN                       NaN   1.0
# 15              NaN                       NaN   1.0
# 16              NaN                       NaN   NaN
# 17              NaN                       NaN   NaN
# 18              NaN                       NaN   NaN
# 19              NaN                       NaN   NaN
# 20              NaN                       NaN   NaN
# 21              NaN                       NaN   NaN
# 22              NaN                       NaN   NaN
# 23              NaN                       NaN   NaN
# 24              NaN                       NaN   NaN
# 25              NaN                       NaN   NaN
# 26              NaN                       NaN   NaN
# 27          19321.0                       NaN   NaN

# %%
ss=df['version']=='v1.1'
df[ss]
# Out:
#      trait version  austraits-6.0.0  NSWFFRDv2.1  Bell Vollmer Gellie 1993
# 0    surv1    v1.1          29896.0      11563.0                       NaN  \
# 2    surv4    v1.1              NaN       1411.0                       NaN
# 4    surv5    v1.1              NaN       1262.0                       NaN
# 6    surv6    v1.1              NaN          NaN                       NaN
# 8    surv7    v1.1              NaN         87.0                       NaN
# 10   germ1    v1.1           4164.0       1635.0                       NaN
# 12   germ8    v1.1           4171.0          NaN                       NaN
# 14   repr2    v1.1            431.0        139.0                       NaN
# 16   repr3    v1.1              NaN        838.0                       NaN
# 18  repr3a    v1.1              NaN        662.0                       NaN
# 20   repr4    v1.1              NaN          NaN                       NaN
# 22   grow1    v1.1              NaN         33.0                       NaN
# 24   rect2    v1.1              NaN       1088.0                       NaN
# 26   disp1    v1.1          34591.0          NaN                       NaN
#
#     austraits-3.0.2  Ooi Myerscough Auld 2007  None
# 0               NaN                       NaN   NaN
# 2               NaN                       NaN   NaN
# 4               NaN                       NaN   NaN
# 6               NaN                       NaN   NaN
# 8               NaN                       NaN   NaN
# 10              NaN                       NaN   NaN
# 12              NaN                       NaN   NaN
# 14              NaN                       NaN   1.0
# 16              NaN                       NaN   NaN
# 18              NaN                       NaN   NaN
# 20              NaN                       NaN   NaN
# 22              NaN                       NaN   NaN
# 24              NaN                       NaN   NaN
# 26              NaN                       NaN   NaN

# %%
ss=df['trait']=='germ1'
df[ss]
# Out:
#     trait version  austraits-6.0.0  NSWFFRDv2.1  Bell Vollmer Gellie 1993
# 10  germ1    v1.1           4164.0       1635.0                       NaN  \
# 11  germ1    v1.0              NaN       1635.0                       NaN
#
#     austraits-3.0.2  Ooi Myerscough Auld 2007  None
# 10              NaN                       NaN   NaN
# 11              NaN                       NaN   NaN
