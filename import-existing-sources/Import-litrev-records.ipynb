# %%
import openpyxl
from pathlib import Path
import os
from datetime import datetime
from configparser import ConfigParser
import psycopg2
from psycopg2.extras import DictCursor
from psycopg2.extensions import AsIs
import pandas as pd
import numpy as np

# %%
repodir = Path("../../") 
filename = repodir / 'secrets' / 'database.ini'
section = 'aws-lght-sl'

parser = ConfigParser()
parser.read(filename)

dbparams = {}
if parser.has_section(section):
    params = parser.items(section)
    for param in params:
        dbparams[param[0]] = param[1]
else:
    raise Exception('Section {0} not found in the {1} file'.format(section, filename))

# %%
inputdir = repodir / "data" / "input-form"

# %%
os.listdir(inputdir)
# Out:
# ['Species traits_Blue table_RFW_ 20220505.xlsx',
#  'fireveg-trait-input-spreadsheet_V3_DE_trial.xlsx']

# %% [markdown]
# ## Read data entry form with pandas

# %%
newdata = pd.read_excel(inputdir / 'Species traits_Blue table_RFW_ 20220505.xlsx', sheet_name='Data entry')
contributor = pd.read_excel(inputdir / 'Species traits_Blue table_RFW_ 20220505.xlsx', sheet_name='Contributor')

# %%
contributor.shape[0]
# Out:
# 3

# %%
newdata.head()
# Out:
#    Main source           Original sources   Original species name  \
# 0  NSWFFRDv2.1                  Auld 1987       Acacia suaveolens
# 1  NSWFFRDv2.1  Auld Keith Bradstock 2000  Conospermum taxifolium
# 2  NSWFFRDv2.1            Auld Scott 1997        Darwinia biflora
# 3  NSWFFRDv2.1            Auld Scott 1997        Grevillea caleyi
# 4  NSWFFRDv2.1  Auld Keith Bradstock 2000  Grevillea linearifolia
#
#    Species code            Species name Trait code          Trait name  \
# 0          3881       Acacia suaveolens      surv6  Seedbank half-life
# 1          5352  Conospermum taxifolium      surv6  Seedbank half-life
# 2          4024        Darwinia biflora      surv6  Seedbank half-life
# 3          5365        Grevillea caleyi      surv6  Seedbank half-life
# 4          5381  Grevillea linearifolia      surv6  Seedbank half-life
#
#   Trait type  Raw value Norm value  Best  Lower  Upper Method of estimation  \
# 0  numerical  hl 10.7 y        NaN  10.7    NaN    NaN                  NaN
# 1  numerical       hl 2        NaN   2.0    NaN    NaN                  NaN
# 2  numerical     hl 0.9        NaN   0.9    NaN    NaN                  NaN
# 3  numerical     hl 7.6        NaN   7.6    NaN    NaN                  NaN
# 4  numerical    hl 9-10        NaN   NaN    9.0   10.0                  NaN
#
#                      Notes
# 0  No vocabularies for MoE
# 1  No vocabularies for MoE
# 2  No vocabularies for MoE
# 3  No vocabularies for MoE
# 4  No vocabularies for MoE

# %%
records=dict()
for row in newdata.to_dict(orient='records'):
    trait = row['Trait code']
    if trait not in records.keys():
        records[trait]=list()
    ttype = row['Trait type']
    record=dict()
    notes=list()
    if contributor.shape[0]>0:
        contribdata = [x for x in contributor['Your response'].values.tolist() if pd.isnull(x) == False]
        notes.append('Data entry by')
        notes.extend(contribdata)
    
    record['species']=row['Species name']
    if row['Species name']!=row['Original species name']:
        notes.append('Original species name')
        notes.append(record['Original species name'])
    if not pd.isnull(row['Notes']):
        notes.append(row['Notes'])
    for k in ('Main source','Species code',):
        if not pd.isnull(row[k]):
            record[k.lower().replace(' ','_')] = row[k]
    for k in ('Original sources','Raw value'):
        if not pd.isnull(row[k]):
            record[k.lower().replace(' ','_')] = [row[k]]
    if ttype == 'numerical':
        for k in ('Best','Lower', 'Upper'):
            if not pd.isnull(row[k]):
                record[k.lower()] = row[k]
    elif ttype == 'categorical':
        for k in ('Norm value',):
            if not pd.isnull(row[k]):
                record[k.lower().replace(' ','_')] = row[k]
    if len(notes)>0:
        record['original_notes']=notes
    records[trait].append(record)

# %%
print(records.keys())

records['repr3a']
# Out:
# dict_keys(['surv6', 'repr3', 'repr4', 'surv1', 'surv5', 'repr3a'])
# [{'species': 'Acacia melanoxylon',
#   'main_source': 'NSWFFRDv2.1',
#   'species_code': 3824,
#   'original_sources': ['Wark 1997'],
#   'raw_value': ['Secondary juvenile period ->3<10'],
#   'lower': 3.0,
#   'upper': 10.0,
#   'original_notes': ['Data entry by', 'Renee Woodward']},
#  {'species': 'Lambertia formosa',
#   'main_source': 'NSWFFRDv2.1',
#   'species_code': 5440,
#   'original_sources': ['Pyke 1983'],
#   'raw_value': ['Secondary juvenile period -peak flowering at 2-3 y post-fire'],
#   'best': 2.0,
#   'upper': 3.0,
#   'original_notes': ['Data entry by', 'Renee Woodward']}]

# %%
print('Connecting to the PostgreSQL database...')
conn = psycopg2.connect(**dbparams)
cur = conn.cursor()
affected_rows=0

insert_statement = 'insert into litrev.%s (%s) values %s ON CONFLICT DO NOTHING'

for trait in records.keys():
    print("total of %s records prepared for trait %s" % (len(records[trait]), trait))
    for record in records[trait]: 
        cur.execute(insert_statement, (AsIs(trait),AsIs(','.join(record.keys())), tuple(record.values())))
        affected_rows = affected_rows+cur.rowcount
        
#records.clear()
conn.commit()
print("total number of lines updated: %s" % affected_rows)

cur.close()
if conn is not None:
    conn.close()
    print('Database connection closed.')
# Out:
# Connecting to the PostgreSQL database...
# total of 7 records prepared for trait surv6
# total of 98 records prepared for trait repr3
# total of 23 records prepared for trait repr4
# total of 2 records prepared for trait surv1
# total of 1 records prepared for trait surv5
# total of 2 records prepared for trait repr3a
# total number of lines updated: 133
# Database connection closed.

# %% [markdown]
# ## Alternative with openpyxl

# %%
inputfile=inputdir / 'Species traits_Blue table_RFW_ 20220505.xlsx'
wb = openpyxl.load_workbook(inputfile,data_only=True)
wb.worksheets
# Out:
# [<Worksheet "Instructions">,
#  <Worksheet "Contributor">,
#  <Worksheet "Data entry">,
#  <Worksheet "References">,
#  <Worksheet "Species list">,
#  <Worksheet "Trait description">,
#  <Worksheet "Vocabularies">,
#  <Worksheet "Vocabularies for methods">]

# %% [markdown]
# ### References table

# %%
ws=wb["References"]

# %%
for table in ws.tables:
    print(table)
# Out:
# References

# %%
table = ws.tables['References']

# %%
tbl=ws[table.ref]

# %%
for cell in tbl[0]:
    print(cell.value)
# Out:
# Code
# Full reference

# %%
for cell in tbl[len(tbl)-1]:
    print(cell.value)
# Out:
# Benson McDougall 2000
# Benson, D. & McDougall, L. (2000). Ecology of Sydney plant species: Part 7b: Dicotyledon families Proteaceae to Rubiaceae. Cunninghamia 6(4) 1016-1202.

# %% [markdown]
# ### Input table

# %%
ws=wb["Data entry"]

# %%
ws['A1':'B7']
# Out:
# ((<Cell 'Data entry'.A1>, <Cell 'Data entry'.B1>),
#  (<Cell 'Data entry'.A2>, <Cell 'Data entry'.B2>),
#  (<Cell 'Data entry'.A3>, <Cell 'Data entry'.B3>),
#  (<Cell 'Data entry'.A4>, <Cell 'Data entry'.B4>),
#  (<Cell 'Data entry'.A5>, <Cell 'Data entry'.B5>),
#  (<Cell 'Data entry'.A6>, <Cell 'Data entry'.B6>),
#  (<Cell 'Data entry'.A7>, <Cell 'Data entry'.B7>))

# %%
for table in ws.tables:
    print(table)
# Out:
# DataEntry

# %%
table = ws.tables['DataEntry']

# %%
for row in table:
    print(row)
# Out:
# ('id', '3')
# ('name', 'DataEntry')
# ('displayName', 'DataEntry')
# ('ref', 'A1:O134')
# ('headerRowCount', '1')
# ('headerRowDxfId', '17')
# ('dataDxfId', '16')
# ('totalsRowDxfId', '15')

# %%
table.ref
# Out:
# 'A1:O134'

# %%
for row in ws[table.ref]:
    for cell in row:
        print(cell.value)
# Out:
# Main source
# Original sources
# Original species name
# Species code
# Species name
# Trait code
# Trait name
# Trait type
# Raw value
# Norm value
# Best
# Lower
# Upper
# Method of estimation
# Notes
# NSWFFRDv2.1
# Auld 1987
# Acacia suaveolens
# 3881
# Acacia suaveolens
# surv6
# Seedbank half-life
# numerical
# hl 10.7 y
# None
# 10.7
# None
# None
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# Auld Keith Bradstock 2000
# Conospermum taxifolium
# 5352
# Conospermum taxifolium
# surv6
# Seedbank half-life
# numerical
# hl 2
# None
# 2
# None
# None
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# Auld Scott 1997
# Darwinia biflora
# 4024
# Darwinia biflora
# surv6
# Seedbank half-life
# numerical
# hl 0.9
# None
# 0.9
# None
# None
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# Auld Scott 1997
# Grevillea caleyi
# 5365
# Grevillea caleyi
# surv6
# Seedbank half-life
# numerical
# hl 7.6
# None
# 7.6
# None
# None
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# Auld Keith Bradstock 2000
# Grevillea linearifolia
# 5381
# Grevillea linearifolia
# surv6
# Seedbank half-life
# numerical
# hl 9-10
# None
# None
# 9
# 10
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# RP Velleia perfoliata
# Velleia perfoliata
# 3218
# Velleia perfoliata
# surv6
# Seedbank half-life
# numerical
# long, hl 10
# None
# 10
# None
# None
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# RP Zieria involucrata
# Zieria involucrata
# 5840
# Zieria involucrata
# surv6
# Seedbank half-life
# numerical
# short, hl c. 3
# None
# 3
# None
# None
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Acacia baueri subsp. baueri
# 7060
# Acacia baueri subsp. baueri
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Acacia binervata
# 3716
# Acacia binervata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia bulgaensis
# 8601
# Acacia bulgaensis
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-5
# None
# None
# 3
# 5
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Acacia dealbata
# 3758
# Acacia dealbata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Acacia dealbata
# 3758
# Acacia dealbata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia fulva
# 3780
# Acacia fulva
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-5 (min)
# None
# 5
# 3
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Acacia hispidula
# 3790
# Acacia hispidula
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Acacia irrorata subsp. irrorata
# 6472
# Acacia irrorata subsp. irrorata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 8
# None
# 8
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia kulnurensis
# 9983
# Acacia kulnurensis
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-5
# None
# None
# 3
# 5
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Acacia longifolia subsp. longifolia
# 10790
# Acacia longifolia subsp. longifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Acacia longifolia subsp. sophorae
# 10791
# Acacia longifolia subsp. sophorae
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Acacia mitchellii
# 3827
# Acacia mitchellii
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 4
# None
# 4
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia prominens
# 3857
# Acacia prominens
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-5
# None
# None
# 3
# 5
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia pubescens
# 3860
# Acacia pubescens
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-5
# None
# None
# 3
# 5
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Acacia suaveolens
# 3881
# Acacia suaveolens
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall 1996
# Acacia terminalis
# 3885
# Acacia terminalis
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 2.5
# None
# 2.5
# None
# None
# None
# None
# NSWFFRDv2.1
# EcoGIS 2002
# Acacia terminalis
# 3885
# Acacia terminalis
# repr4
# Maturation age
# numerical
# Prim Juv period -  40-60% plants flowering at 6 years post-fire (105)
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Bell Vollmer Gellie 1993
# Acacia alaticaulis
# 9982
# Acacia alaticaulis
# surv1
# Resprouting - full canopy scorch
# categorical
# S
# None
# None
# None
# None
# None
# None
# Bell Vollmer Gellie 1993
# None
# Acacia alaticaulis
# 9982
# Acacia alaticaulis
# surv1
# Resprouting - full canopy scorch
# categorical
# S
# None
# None
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia alaticaulis
# 9982
# Acacia alaticaulis
# surv5
# Standing plant longevity (Max)
# numerical
# 15-25
# None
# None
# 15
# 25
# None
# No vocabularies for MoE
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Acacia alaticaulis
# 9982
# Acacia alaticaulis
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-5
# None
# None
# 3
# 5
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Acacia verticillata subsp. verticillata
# 11245
# Acacia verticillata subsp. verticillata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Acaena echinata
# 5603
# Acaena echinata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Actinotus helianthi
# 1094
# Actinotus helianthi
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson 1985
# Actinotus helianthi
# 1094
# Actinotus helianthi
# repr4
# Maturation age
# numerical
# Prim Juv period - 3-4 for 50% of population to flower (BE)
# None
# 4
# 3
# None
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Actinotus minor
# 1095
# Actinotus minor
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Alectryon coriaceus
# 5872
# Alectryon coriaceus
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - >6 <20
# None
# None
# 6
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Alectryon coriaceus
# 5872
# Alectryon coriaceus
# repr4
# Maturation age
# numerical
# Maturity - >6 <20
# None
# None
# 6
# 20
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Alectryon subcinereus
# 5875
# Alectryon subcinereus
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - >7
# None
# None
# 7
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Alexfloydia repens
# 8979
# Alexfloydia repens
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - <8
# None
# None
# None
# 8
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Pannell Myerscough 1993
# Allocasuarina distyla
# 2010
# Allocasuarina distyla
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 7-9
# None
# None
# 7
# 9
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Allocasuarina littoralis
# 2012
# Allocasuarina littoralis
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 10
# None
# 10
# None
# None
# None
# None
# NSWFFRDv2.1
# Pannell Myerscough 1993
# Allocasuarina nana
# 2014
# Allocasuarina nana
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 10
# None
# 10
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Allocasuarina torulosa
# 2017
# Allocasuarina torulosa
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - >5
# None
# None
# 5
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Alphitonia excelsa
# 7686
# Alphitonia excelsa
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - >6
# None
# None
# 6
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# Russell-Smith Ryan Klessa Waight Harwood 1998
# Alyxia ruscifolia
# 1167
# Alyxia ruscifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - >5
# None
# None
# 5
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# None
# Asparagus aethiopicus
# 11784
# Asparagus aethiopicus
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - <1year
# None
# None
# None
# 1
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# None
# Asparagus asparagoides
# 3519
# Asparagus asparagoides
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - <1year
# None
# None
# None
# 1
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Astrotricha latifolia
# 1202
# Astrotricha latifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Bradstock 1988
# Banksia ericifolia subsp. ericifolia
# 11049
# Banksia ericifolia subsp. ericifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6 (30)
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall 2000
# Banksia ericifolia subsp. ericifolia
# 11049
# Banksia ericifolia subsp. ericifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - cones develop up to 1 year after flowering, shish commences from 6yrs  (1)
# None
# None
# 6
# None
# None
# None
# NSWFFRDv2.1
# EcoGIS 2002
# Banksia ericifolia subsp. ericifolia
# 11049
# Banksia ericifolia subsp. ericifolia
# repr4
# Maturation age
# numerical
# Seed set  - >85% fruiting at 15 yo (105)
# None
# None
# None
# 15
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Banksia integrifolia
# 5343
# Banksia integrifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 7
# None
# 7
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Banksia integrifolia subsp. integrifolia
# 6603
# Banksia integrifolia subsp. integrifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 5-6
# None
# None
# 5
# 6
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Banksia integrifolia subsp. integrifolia
# 6603
# Banksia integrifolia subsp. integrifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 10
# None
# 10
# None
# None
# None
# None
# NSWFFRDv2.1
# None
# Banksia marginata
# 5344
# Banksia marginata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - +2 (therefore 7-9)
# None
# None
# 7
# 9
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Banksia oblongifolia
# 5345
# Banksia oblongifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 7
# None
# 7
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Banksia robur
# 5347
# Banksia robur
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Bradstock 1990
# Banksia serrata
# 5348
# Banksia serrata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 7
# None
# 7
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Baumea articulata
# 2296
# Baumea articulata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - <8
# None
# None
# None
# 8
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Kenny unpub.
# Boronia ledifolia
# 5744
# Boronia ledifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - <4
# None
# None
# None
# 4
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Bossiaea cinerea
# 2777
# Bossiaea cinerea
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Bossiaea prostrata
# 2786
# Bossiaea prostrata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Bulbine bulbosa
# 3531
# Bulbine bulbosa
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Callistemon shiressii
# 4016
# Callistemon shiressii
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 4-5 (min)
# None
# 5
# 4
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Calochlaena dubia
# 8341
# Calochlaena dubia
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - <8
# None
# None
# None
# 8
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Stewart 1996
# Carex breviculmis
# 2313
# Carex breviculmis
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Cassinia compacta
# 1364
# Cassinia compacta
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Casuarina glauca
# 2022
# Casuarina glauca
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 8
# None
# 8
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Chrysocephalum baxteri
# 9609
# Chrysocephalum baxteri
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Conospermum ericifolium
# 9976
# Conospermum ericifolium
# repr4
# Maturation age
# numerical
# Prim Juv period - peak 4-5
# None
# 4
# None
# 5
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Cynoglossum suaveolens
# 1749
# Cynoglossum suaveolens
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - <1
# None
# None
# None
# 1
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Dampiera stricta
# 3174
# Dampiera stricta
# repr4
# Maturation age
# numerical
# Prim Juv period - peak 2-3 (1b)
# None
# None
# 2
# 3
# None
# None
# NSWFFRDv2.1
# RP Darwinnia biflora
# Darwinia biflora
# 4024
# Darwinia biflora
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - fruit production very low at sites less than five years old
# None
# None
# 5
# None
# None
# None
# NSWFFRDv2.1
# RP Darwinnia biflora
# Darwinia biflora
# 4024
# Darwinia biflora
# repr3
# Age at first flower production (from seed)
# numerical
# Prim Juv period - flowring starts at 1.5y but little fruit produced at this stage (R34)
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Dichelachne crinita
# 4897
# Dichelachne crinita
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Dillwynia retorta species complex
# 11904
# Dillwynia retorta species complex
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Maryott-Brown Wilks 1993
# Dillwynia tenuifolia
# 2853
# Dillwynia tenuifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 3-4 (min)
# None
# 4
# 3
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Diuris sulphurea
# 4456
# Diuris sulphurea
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Dodonaea triquetra
# 5911
# Dodonaea triquetra
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Drosera peltata
# 2559
# Drosera peltata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Eucalyptus oreades
# 4145
# Eucalyptus oreades
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 25
# None
# 25
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Galium murale
# 5687
# Galium murale
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Goodenia bellidifolia subsp. bellidifolia
# 8711
# Goodenia bellidifolia subsp. bellidifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# None
# Goodenia elongata
# 3180
# Goodenia elongata
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 3
# None
# 3
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Goodenia humilis
# 3191
# Goodenia humilis
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# RP Grevillea beadleana
# Grevillea beadleana
# 8293
# Grevillea beadleana
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Kenny unpub.
# Grevillea buxifolia
# 5364
# Grevillea buxifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 4
# None
# 4
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall 2000
# Grevillea buxifolia subsp. buxifolia
# 8409
# Grevillea buxifolia subsp. buxifolia
# repr4
# Maturation age
# numerical
# Prim Juv period - peak 4-5
# None
# None
# 4
# 5
# None
# None
# NSWFFRDv2.1
# RP Grevillea caleyi
# Grevillea caleyi
# 5365
# Grevillea caleyi
# repr4
# Maturation age
# numerical
# Seed set - 59-88% with some fruit at 3y
# None
# 3
# None
# None
# None
# None
# NSWFFRDv2.1
# RP Grevillea caleyi
# Grevillea caleyi
# 5365
# Grevillea caleyi
# repr4
# Maturation age
# numerical
# Prim Juv period - 98% flowered in 3y, fecundity highest at 6-8y (R4)
# None
# None
# 6
# 8
# None
# None
# NSWFFRDv2.1
# Kubiak 2009
# Grevillea linearifolia
# 5381
# Grevillea linearifolia
# repr4
# Maturation age
# numerical
# Prim Juv period - peak flowering at 5 y post-fire (138)
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# McDougall Keith pers. comm.
# Grevillea rivularis
# 5395
# Grevillea rivularis
# repr4
# Maturation age
# numerical
# Prim Juv period - no flowering after 5 years in wild; all plants flowering after 14 years; cultivated plants flower at 4-5y
# None
# None
# None
# 14
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Kenny unpub.
# Grevillea sericea
# 5399
# Grevillea sericea
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - <4
# None
# None
# None
# 4
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Grevillea sericea
# 5399
# Grevillea sericea
# repr3
# Age at first flower production (from seed)
# numerical
# Prim Juv period - >2
# None
# None
# 2
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Grevillea sericea
# 5399
# Grevillea sericea
# repr4
# Maturation age
# numerical
# Prim Juv period - peak flowering 4-5 yr post-fire (1b)
# None
# None
# 4
# 5
# None
# None
# NSWFFRDv2.1
# Benson 1985
# Grevillea sericea
# 5399
# Grevillea sericea
# repr3
# Age at first flower production (from seed)
# numerical
# 4 for first flowering
# None
# 4
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson 1986
# Grevillea sericea
# 5399
# Grevillea sericea
# repr4
# Maturation age
# numerical
# 6 for 50% of population to flower (BE)
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Kenny unpub.
# Grevillea speciosa
# 5401
# Grevillea speciosa
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - <4
# None
# None
# None
# 4
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# None
# Gymnostachys anceps
# 1195
# Gymnostachys anceps
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 9 months
# None
# 0.75
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall 2005
# Haemodorum planifolium
# 3236
# Haemodorum planifolium
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Hakea constablei
# 5408
# Hakea constablei
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - +2 (no data on first flower production)
# None
# None
# 2
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Hakea propinqua
# 5421
# Hakea propinqua
# repr3
# Age at first flower production (from seed)
# numerical
# Prim Juv period -  >5 for most
# None
# None
# 5
# None
# No evidence of trait expression by specified age
# None
# NSWFFRDv2.1
# Benson 1986
# Hakea teretifolia
# 5427
# Hakea teretifolia
# repr4
# Maturation age
# numerical
# Prim Juv period - 6 for 50% of population to flower (BE)
# None
# None
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Hemigenia purpurea
# 3376
# Hemigenia purpurea
# repr4
# Maturation age
# numerical
# Prim Juv period - some green fruit at 2 y, peak flowering at 3 y (1)
# None
# None
# 3
# None
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Hibbertia fasciculata
# 2536
# Hibbertia fasciculata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Hypericum gramineum
# 7240
# Hypericum gramineum
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - <1
# None
# None
# None
# 1
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Jacksonia scoparia
# 2892
# Jacksonia scoparia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall 2002
# Leptomeria acida
# 5865
# Leptomeria acida
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 7
# None
# 7
# None
# None
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Luzula meridionalis
# 3359
# Luzula meridionalis
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Mitrasacme polymorpha
# 3595
# Mitrasacme polymorpha
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# EcoGIS 2002
# Mitrasacme polymorpha
# 3595
# Mitrasacme polymorpha
# repr4
# Maturation age
# numerical
# Prim Juv period - 60-85 % flowering at 6 months (105)
# None
# 0.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Ozothamnus rufescens
# 8665
# Ozothamnus rufescens
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 7
# None
# 7
# None
# None
# None
# None
# NSWFFRDv2.1
# None
# Patersonia longifolia
# 3302
# Patersonia longifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Department Natural Resources Environment
# Persoonia juniperina
# 5459
# Persoonia juniperina
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 6
# None
# 6
# None
# None
# None
# None
# NSWFFRDv2.1
# Bradstock 1988
# Petrophile pulchella
# 5479
# Petrophile pulchella
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson 1986
# Petrophile pulchella
# 5479
# Petrophile pulchella
# repr4
# Maturation age
# numerical
# Prim Juv period - 9 for 50% of population flowering (BE)
# None
# 9
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson 1986
# Philotheca buxifolia
# 10577
# Philotheca buxifolia
# repr4
# Maturation age
# numerical
# Prim Juv period - 5-6 for 50% of population flowering (BE)
# None
# None
# 5
# 6
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Pimelea humilis
# 6179
# Pimelea humilis
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Pimelea linifolia
# 6182
# Pimelea linifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# RP Pimelea spicata
# Pimelea spicata
# 6190
# Pimelea spicata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5-2
# None
# None
# 1.5
# 2
# None
# None
# NSWFFRDv2.1
# Clemens Franklin 1980
# Platysace lanceolata
# 1144
# Platysace lanceolata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1.5
# None
# 1.5
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson 1985
# Platysace linearifolia
# 1145
# Platysace linearifolia
# repr4
# Maturation age
# numerical
# Prim Juv period - 4 for 50% of population to flower
# None
# 4
# None
# None
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Poa labillardierei var. labillardierei
# 11196
# Poa labillardierei var. labillardierei
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Stewart 1996
# Poa sieberiana var. sieberiana
# 8742
# Poa sieberiana var. sieberiana
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Pomaderris discolor
# 5577
# Pomaderris discolor
# repr4
# Maturation age
# numerical
# Prim Juv period - peak <5
# None
# None
# None
# 5
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Pomaderris ferruginea
# 5579
# Pomaderris ferruginea
# repr4
# Maturation age
# numerical
# Prim Juv period - peak 5 (1)
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall Ecology Sydney Plant Species Cunn
# Pomaderris intermedia
# 7979
# Pomaderris intermedia
# repr4
# Maturation age
# numerical
# Prim Juv period - peak 5
# None
# 5
# None
# None
# None
# None
# NSWFFRDv2.1
# Benson McDougall 2002
# Rulingia dasyphylla
# 6145
# Rulingia dasyphylla
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Burrows 1995
# Senecio garlandii
# 7097
# Senecio garlandii
# repr4
# Maturation age
# numerical
# Prim Juv period - 44% flowered in 2nd season, 95% in 3rd
# None
# None
# 2
# 3
# None
# None
# NSWFFRDv2.1
# Watts Greg. pers. comm.
# Swainsona galegifolia
# 3041
# Swainsona galegifolia
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 2
# None
# 2
# None
# None
# None
# None
# NSWFFRDv2.1
# Clarke 1989
# Tetragonia tetragonioides
# 11185
# Tetragonia tetragonioides
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - 1
# None
# 1
# None
# None
# None
# None
# NSWFFRDv2.1
# Morgan Lunt 1999
# Wurmbea dioica subsp. dioica
# 7699
# Wurmbea dioica subsp. dioica
# repr3
# Age at first flower production (from seed)
# numerical
# Maturity - <1
# None
# None
# None
# 1
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Kenny unpub.
# Zieria laevigata
# 5841
# Zieria laevigata
# repr3
# Age at first flower production (from seed)
# numerical
# Seed set - <4
# None
# None
# None
# 4
# Trait evidence, but start date uncertain
# None
# NSWFFRDv2.1
# Wark 1997
# Acacia melanoxylon
# 3824
# Acacia melanoxylon
# repr3a
# Time to first postfire reproduction (from resprouts)
# numerical
# Secondary juvenile period ->3<10
# None
# None
# 3
# 10
# None
# None
# NSWFFRDv2.1
# Pyke 1983
# Lambertia formosa
# 5440
# Lambertia formosa
# repr3a
# Time to first postfire reproduction (from resprouts)
# numerical
# Secondary juvenile period -peak flowering at 2-3 y post-fire
# None
# 2
# None
# 3
# None
# None

# %%
dir(table)
# Out:
# ['__add__',
#  '__attrs__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__elements__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__namespaced__',
#  '__ne__',
#  '__nested__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_initialise_columns',
#  '_path',
#  '_rel_id',
#  '_rel_type',
#  '_write',
#  'autoFilter',
#  'column_names',
#  'comment',
#  'connectionId',
#  'dataCellStyle',
#  'dataDxfId',
#  'displayName',
#  'extLst',
#  'from_tree',
#  'headerRowBorderDxfId',
#  'headerRowCellStyle',
#  'headerRowCount',
#  'headerRowDxfId',
#  'id',
#  'idx_base',
#  'insertRow',
#  'insertRowShift',
#  'mime_type',
#  'name',
#  'namespace',
#  'path',
#  'published',
#  'ref',
#  'sortState',
#  'tableBorderDxfId',
#  'tableColumns',
#  'tableStyleInfo',
#  'tableType',
#  'tagname',
#  'to_tree',
#  'totalsRowBorderDxfId',
#  'totalsRowCellStyle',
#  'totalsRowCount',
#  'totalsRowDxfId',
#  'totalsRowShown']

# %%
table.column_names
# Out:
# ['main_source',
#  'original_sources',
#  'original_species_name',
#  'species_code',
#  'species name',
#  'Trait code',
#  'Trait name',
#  'Trait type',
#  'raw_value',
#  'norm_value',
#  'Best',
#  'Lower',
#  'Upper',
#  'method_of_estimation',
#  'notes']

# %%
table.headerRowCount
# Out:
# 1

# %%
tbl=ws[table.ref]
hdr=table.column_names
surv1=list()
surv4=list()
records=list()
for k in range(1,len(tbl)):
    record=dict()
    for j in range(0,len(hdr)):
        record[hdr[j]]=tbl[k][j].value
    if record['Trait code']=='surv1':
        surv1.append(record)
    elif record['Trait code']=='surv4':
        surv4.append(record)
    else: 
        records.append(record)

# %%
surv1
# Out:
# [{'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia anemonifolia subsp. anemonifolia',
#   'species_code': 12257,
#   'species name': 'Boronia anemonifolia subsp. anemonifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia floribunda',
#   'species_code': 5740,
#   'species name': 'Boronia floribunda',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia fraseri',
#   'species_code': 5741,
#   'species name': 'Boronia fraseri',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia ledifolia',
#   'species_code': 5744,
#   'species name': 'Boronia ledifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia pinnata',
#   'species_code': 5750,
#   'species name': 'Boronia pinnata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia serrulata',
#   'species_code': 5759,
#   'species name': 'Boronia serrulata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'MacKenzie Auld Keith Ooi 2021 ',
#   'original_sources': None,
#   'original_species_name': 'Boronia thujona',
#   'species_code': 7210,
#   'species name': 'Boronia thujona',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': None,
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Acacia barringtonensis',
#   'species_code': 3712,
#   'species name': 'Acacia barringtonensis',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Acacia beadleana',
#   'species_code': 11039,
#   'species name': 'Acacia beadleana',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Acacia cangaiensis',
#   'species_code': 9085,
#   'species name': 'Acacia cangaiensis',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Boronia angustisepala',
#   'species_code': 10750,
#   'species name': 'Boronia angustisepala',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's-',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Boronia inflexa subsp. inflexa',
#   'species_code': 12356,
#   'species name': 'Boronia inflexa subsp. inflexa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Callistemon flavovirens',
#   'species_code': 4006,
#   'species name': 'Callistemon flavovirens',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Callitris monticola',
#   'species_code': 2281,
#   'species name': 'Callitris monticola',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Dillwynia rupestris',
#   'species_code': 12302,
#   'species name': 'Dillwynia rupestris',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's and r',
#   'norm_value': 'Half',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Dodonaea serratifolia',
#   'species_code': 5907,
#   'species name': 'Dodonaea serratifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': 'An obligate seeding shrub. Only two seedlings have been seen since fire. Not observed recruiting in known locations in Gibraltar Range National Park. '},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Eucalyptus dissita',
#   'species_code': 9719,
#   'species name': 'Eucalyptus dissita',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hakea macrorrhyncha',
#   'species_code': 9602,
#   'species name': 'Hakea macrorrhyncha',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hibbertia rhynchocalyx',
#   'species_code': 10558,
#   'species name': 'Hibbertia rhynchocalyx',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hibbertia villosa',
#   'species_code': 8590,
#   'species name': 'Hibbertia villosa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hovea pedunculata',
#   'species_code': 11014,
#   'species name': 'Hovea pedunculata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Genoplesium bishopii',
#   'species_code': 12408,
#   'species name': 'Genoplesium bishopii',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (few)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea acanthifolia',
#   'species_code': 5355,
#   'species name': 'Grevillea acanthifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea acerata',
#   'species_code': 8292,
#   'species name': 'Grevillea acerata',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea mollis',
#   'species_code': 9297,
#   'species name': 'Grevillea mollis',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Grevillea rhizomatosa',
#   'species_code': 9299,
#   'species name': 'Grevillea rhizomatosa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Leionema ambiens',
#   'species_code': 10724,
#   'species name': 'Leionema ambiens',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'Population lost to fire, obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Leptospermum benwellii',
#   'species_code': 12325,
#   'species name': 'Leptospermum benwellii',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Melaleuca tortifolia',
#   'species_code': 7695,
#   'species name': 'Melaleuca tortifolia',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Persoonia rufa',
#   'species_code': 8624,
#   'species name': 'Persoonia rufa',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Podolobium aestivum',
#   'species_code': 9913,
#   'species name': 'Podolobium aestivum',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'r ',
#   'norm_value': 'All',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Prostanthera rhombea',
#   'species_code': 3426,
#   'species name': 'Prostanthera rhombea',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Prostanthera saxicola var. major',
#   'species_code': 9207,
#   'species name': 'Prostanthera saxicola var. major',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Pseudanthus pauciflorus',
#   'species_code': 12971,
#   'species name': 'Pseudanthus pauciflorus',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Pultenaea tarik',
#   'species_code': 12552,
#   'species name': 'Pultenaea tarik',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 's - obligate seeder',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Telopea aspera',
#   'species_code': 9685,
#   'species name': 'Telopea aspera',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'R, s Resprouts post fire. A small number of seedling recruits (7) seen',
#   'norm_value': 'Most',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None},
#  {'main_source': 'Sheringham 2022',
#   'original_sources': None,
#   'original_species_name': 'Hakea macrorrhyncha',
#   'species_code': 9602,
#   'species name': 'Hakea macrorrhyncha',
#   'Trait code': 'surv1',
#   'Trait name': 'Resprouting - full canopy scorch',
#   'Trait type': 'categorical',
#   'raw_value': 'Hakea macrorryncha is an obligate seeding species, Four mature plants were observed to survive fire',
#   'norm_value': 'None',
#   'Best': None,
#   'Lower': None,
#   'Upper': None,
#   'method_of_estimation': 'Direct observation (many)',
#   'notes': None}]

# %%
hdr 'surv1'
# Out:
# False
